# %%
# data load

# %%
import json
import pandas as pd
# 
file_paths = [
    "/data/jaesung/llm_for_diabetes/src/trial3/model_response/model_output_base.jsonl",
    # "/data/jaesung/llm_for_diabetes/src/trial/CoT_collection/model_response/test_1.jsonl"
]

data = []
for file_path in file_paths:
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))

df = pd.DataFrame(data)

# %%
# medqa

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa1 = df[df['task'] == 'qa1']

# 정답 판별 수행
correct_count = 0
total_count = len(qa1)

for _, row in qa1.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.6333

# %%
# medmcqa

import pandas as pd

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa2 = df[df['task'] == 'qa2']

# 정답 판별 수행
correct_count = 0
total_count = len(qa2)

for _, row in qa2.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.5667

# %%
# pubmedqa

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa3 = df[df['task'] == 'qa3']

# 정답 판별 수행
correct_count = 0
total_count = len(qa3)

for _, row in qa3.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.8000

# %%
# bionli

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
nli = df[df['task'] == 'nli']

# 정답 판별 수행
correct_count = 0
total_count = len(nli)

for _, row in nli.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.3333

# %%
# ddi

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_relation_correctness(true_relation, model_relation):
    """
    GPT-3.5-turbo를 사용하여 true_relation과 model_relation이 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated relationship extraction model.
    Compare the following two sets of extracted relationships and determine if they contain the same meaning.

    **Correct Relationships**: {true_relation}
    **Model Predicted Relationships**: {model_relation}

    If the model output correctly conveys the same relationships as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
re_df = df[df['task'] == 're']

# 정답 판별 수행 및 메트릭 계산
total_true_positive = 0
total_false_positive = 0
total_false_negative = 0

for _, row in re_df.iterrows():
    true_relations = set(row['output'].split(', '))
    model_relations = set(row['model_output_128'].split(', '))

    true_positive = 0
    false_positive = 0
    false_negative = 0

    # 모델 예측과 정답을 비교하여 TP, FP, FN 계산
    for relation in model_relations:
        if any(check_relation_correctness(relation, correct_rel) for correct_rel in true_relations):
            true_positive += 1
        else:
            false_positive += 1

    for relation in true_relations:
        if not any(check_relation_correctness(relation, predicted_rel) for predicted_rel in model_relations):
            false_negative += 1

    # 누적 합산
    total_true_positive += true_positive
    total_false_positive += false_positive
    total_false_negative += false_negative

# Precision, Recall, F1 계산
precision = total_true_positive / (total_true_positive + total_false_positive) if (total_true_positive + total_false_positive) > 0 else 0
recall = total_true_positive / (total_true_positive + total_false_negative) if (total_true_positive + total_false_negative) > 0 else 0
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# 결과 출력
print(f"GPT-based Total Precision: {precision:.4f}")
print(f"GPT-based Total Recall: {recall:.4f}")
print(f"GPT-based Total F1-Score: {f1:.4f}")
# Out:
# GPT-based Total Precision: 0.2333
# GPT-based Total Recall: 0.2333
# GPT-based Total F1-Score: 0.2333

# %%
# chemdner

from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd

# 데이터프레임 예시 (df_ie 가 주어진 데이터프레임)
ie = df[df['task'] == 'ie']

ie["output"] = ie["output"].str.lower().str.split(", ")
ie["model_output_128"] = ie["model_output_128"].str.lower().str.split(", ")

# Precision, Recall, F1-score 계산 함수
def calculate_scores(y_true, y_pred):
    all_precisions = []
    all_recalls = []
    all_f1s = []
    
    for true_vals, pred_vals in zip(y_true, y_pred):
        true_set = set(true_vals) if isinstance(true_vals, list) else set()
        pred_set = set(pred_vals) if isinstance(pred_vals, list) else set()

        TP = len(true_set & pred_set)  # True Positives (정답과 예측이 일치하는 것)
        FP = len(pred_set - true_set)  # False Positives (예측했지만 정답이 아닌 것)
        FN = len(true_set - pred_set)  # False Negatives (정답이지만 예측하지 못한 것)

        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        all_precisions.append(precision)
        all_recalls.append(recall)
        all_f1s.append(f1)

    return sum(all_precisions) / len(all_precisions), sum(all_recalls) / len(all_recalls), sum(all_f1s) / len(all_f1s)

# Precision, Recall, F1-score 계산
precision, recall, f1 = calculate_scores(ie["output"], ie["model_output_128"])

# 결과 출력
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Precision: 0.0091
# Recall: 0.0100
# F1-score: 0.0095
# /tmp/ipykernel_168992/2471990142.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ie["output"] = ie["output"].str.lower().str.split(", ")
# /tmp/ipykernel_168992/2471990142.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ie["model_output_128"] = ie["model_output_128"].str.lower().str.split(", ")

# %%
import openai
import pandas as pd
import time
from sklearn.metrics import precision_score, recall_score, f1_score

# ✅ OpenAI API Key 설정
openai.api_key = "YOUR_OPENAI_API_KEY"

# ✅ GPT-3.5를 활용하여 정답과 예측을 비교하는 함수
def gpt_judge(true_text, pred_text):
    """
    GPT-3.5를 사용하여 예측값과 정답값이 의미적으로 일치하는지 판단.
    """
    prompt = f"""
    You are an expert in named entity recognition evaluation.
    Compare the gold standard answer with the predicted answer and determine whether they match.

    Gold Standard: {true_text}
    Model Prediction: {pred_text}

    Output "Yes" if both values are identical, including cases where both are empty (None, "", [], or {{}}). Output "No" otherwise.
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "system", "content": "You are a helpful assistant."},
                      {"role": "user", "content": prompt}],
            max_tokens=5,
            temperature=0
        )

        answer = response.choices[0].message.content.strip()
        return 1 if answer.lower() == "yes" else 0

    except Exception as e:
        print(f"[ERROR] OpenAI API call failed: {str(e)}")
        return 0

# ✅ 데이터프레임에서 "ie" 태스크 선택
ie = df[df['task'] == 'ie'].copy()

# ✅ 전처리: 소문자로 변환 후 리스트로 변환
ie["output"] = ie["output"].str.lower().str.split(", ")
ie["model_output_128"] = ie["model_output_128"].str.lower().str.split(", ")

# ✅ GPT-3.5를 이용한 Precision, Recall, F1-score 계산
all_precisions, all_recalls, all_f1s = [], [], []

for idx, (true_vals, pred_vals) in enumerate(zip(ie["output"], ie["model_output_128"])):
    true_set = set(true_vals) if isinstance(true_vals, list) else set()
    pred_set = set(pred_vals) if isinstance(pred_vals, list) else set()

    TP = sum(gpt_judge(t, p) for t in true_set for p in pred_set)  # GPT로 TP 판별
    FP = len(pred_set) - TP  # False Positives
    FN = len(true_set) - TP  # False Negatives

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    all_precisions.append(precision)
    all_recalls.append(recall)
    all_f1s.append(f1)

    # ✅ 진행상황 출력
    print(f"[{idx+1}/{len(ie)}] Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")
    time.sleep(1)  # OpenAI API Rate Limit 방지

# ✅ 최종 성능 계산
final_precision = sum(all_precisions) / len(all_precisions)
final_recall = sum(all_recalls) / len(all_recalls)
final_f1 = sum(all_f1s) / len(all_f1s)

# ✅ 결과 출력
print("\n=== Final Evaluation Scores ===")
print(f"Precision: {final_precision:.4f}")
print(f"Recall: {final_recall:.4f}")
print(f"F1-score: {final_f1:.4f}")
# Out:
# [1/30] Precision: 0.2222, Recall: 0.6667, F1: 0.3333
# [2/30] Precision: 0.3333, Recall: 0.5000, F1: 0.4000
# [3/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [4/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [5/30] Precision: 0.2857, Recall: 0.1667, F1: 0.2105
# [6/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [7/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [8/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [9/30] Precision: 0.5000, Recall: 0.6667, F1: 0.5714
# [10/30] Precision: 0.2500, Recall: 1.0000, F1: 0.4000
# [11/30] Precision: 0.3333, Recall: 0.5000, F1: 0.4000
# [12/30] Precision: 0.0455, Recall: 0.2500, F1: 0.0769
# [13/30] Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# [14/30] Precision: 0.8000, Recall: 0.6667, F1: 0.7273
# [15/30] Precision: 0.6667, Recall: 1.3333, F1: 0.8889
# [16/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [17/30] Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# [18/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [19/30] Precision: 0.0833, Recall: 0.5000, F1: 0.1429
# [20/30] Precision: 0.1667, Recall: 0.2000, F1: 0.1818
# [21/30] Precision: 0.2000, Recall: 0.5000, F1: 0.2857
# [22/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [23/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [24/30] Precision: 0.3333, Recall: 0.5000, F1: 0.4000
# [25/30] Precision: 0.7273, Recall: 0.8000, F1: 0.7619
# [26/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [27/30] Precision: 0.2222, Recall: 0.5000, F1: 0.3077
# [28/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [29/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [30/30] Precision: 0.1429, Recall: 0.1667, F1: 0.1538
#
# === Final Evaluation Scores ===
# Precision: 0.2437
# Recall: 0.3639
# F1-score: 0.2747

# %%
import openai
import pandas as pd
import json
import time
from sklearn.metrics import precision_score, recall_score, f1_score

# ✅ OpenAI API Key 설정
openai.api_key = "YOUR_OPENAI_API_KEY"

# ✅ GPT-4o를 활용하여 정답과 예측을 비교하는 함수
def gpt_judge(true_text, pred_text):
    """
    GPT-4o를 사용하여 예측값과 정답값이 의미적으로 일치하는지 판단.
    """
    prompt = f"""
    You are an expert in named entity recognition evaluation.
    Compare the gold standard entity with the predicted entity.
    
    Gold Standard Entity: "{true_text}"
    Model Predicted Entity: "{pred_text}"
    
    If both entities refer to the same concept, output "Yes".
    If they are different, output "No".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "system", "content": "You are a helpful assistant."},
                      {"role": "user", "content": prompt}],
            max_tokens=5,
            temperature=0
        )

        answer = response.choices[0].message.content.strip()
        return 1 if answer.lower() == "yes" else 0

    except Exception as e:
        print(f"[ERROR] OpenAI API call failed: {str(e)}")
        return 0

# ✅ 데이터프레임에서 "ie" 태스크 선택
ie = df[df['task'] == 'ie'].copy()

# ✅ 전처리 함수: 다양한 형태를 리스트로 변환
def normalize_to_list(value):
    if isinstance(value, str):
        try:
            parsed_value = json.loads(value)  # JSON 문자열 파싱 시도
            if isinstance(parsed_value, list):
                return [v.strip().lower() for v in parsed_value]
            elif isinstance(parsed_value, dict):
                return [v.strip().lower() for v in parsed_value.values()]
            else:
                return [str(parsed_value).strip().lower()]
        except json.JSONDecodeError:
            return [v.strip().lower() for v in value.replace("\n", ",").split(",")]
    elif isinstance(value, dict):
        return [v.strip().lower() for v in value.values()]
    elif isinstance(value, list):
        return [v.strip().lower() for v in value]
    else:
        return [str(value).strip().lower()]

# ✅ 데이터 정리
ie["output"] = ie["output"].apply(normalize_to_list)
ie["model_output_128"] = ie["model_output_128"].apply(normalize_to_list)

# ✅ GPT-4o를 이용한 Precision, Recall, F1-score 계산
all_precisions, all_recalls, all_f1s = [], [], []

for idx, (true_vals, pred_vals) in enumerate(zip(ie["output"], ie["model_output_128"])):
    true_set = set(true_vals)
    pred_set = set(pred_vals)

    # ✅ GPT-4o로 TP(정답 매칭) 판별
    TP = sum(1 for t in true_set if any(gpt_judge(t, p) for p in pred_set))
    FP = len(pred_set) - TP  # False Positives (잘못된 예측)
    FN = len(true_set) - TP  # False Negatives (누락된 정답)

    # ✅ 정밀도, 재현율, F1-score 계산
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    all_precisions.append(precision)
    all_recalls.append(recall)
    all_f1s.append(f1)

    print(f"[{idx+1}/{len(ie)}] Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

# ✅ 최종 성능 출력
print("\n=== Final Evaluation Scores ===")
print(f"Precision: {sum(all_precisions) / len(all_precisions):.4f}")
print(f"Recall: {sum(all_recalls) / len(all_recalls):.4f}")
print(f"F1-score: {sum(all_f1s) / len(all_f1s):.4f}")
# Out:
# [1/30] Precision: 0.0769, Recall: 0.3333, F1: 0.1250
# [2/30] Precision: 0.2500, Recall: 1.0000, F1: 0.4000
# [3/30] Precision: 0.0625, Recall: 0.3333, F1: 0.1053
# [4/30] Precision: 0.0833, Recall: 0.5000, F1: 0.1429
# [5/30] Precision: 0.0909, Recall: 0.1667, F1: 0.1176
# [6/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [7/30] Precision: 0.3333, Recall: 1.0000, F1: 0.5000
# [8/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [9/30] Precision: 0.2500, Recall: 0.6667, F1: 0.3636
# [10/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [11/30] Precision: 0.1667, Recall: 0.3333, F1: 0.2222
# [12/30] Precision: 0.0800, Recall: 0.5000, F1: 0.1379
# [13/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [14/30] Precision: 0.9000, Recall: 0.7500, F1: 0.8182
# [15/30] Precision: 0.3000, Recall: 1.0000, F1: 0.4615
# [16/30] Precision: 0.1250, Recall: 0.5000, F1: 0.2000
# [17/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [18/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [19/30] Precision: 0.1429, Recall: 1.0000, F1: 0.2500
# [20/30] Precision: 0.1429, Recall: 0.2000, F1: 0.1667
# [21/30] Precision: 0.1053, Recall: 0.3333, F1: 0.1600
# [22/30] Precision: 0.0625, Recall: 0.1667, F1: 0.0909
# [23/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [24/30] Precision: 0.2500, Recall: 0.5000, F1: 0.3333
# [25/30] Precision: 0.2500, Recall: 0.4000, F1: 0.3077
# [26/30] Precision: 0.5000, Recall: 1.0000, F1: 0.6667
# [27/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [28/30] Precision: 0.0526, Recall: 0.3333, F1: 0.0909
# [29/30] Precision: 0.0625, Recall: 1.0000, F1: 0.1176
# [30/30] Precision: 0.2857, Recall: 0.3333, F1: 0.3077
#
# === Final Evaluation Scores ===
# Precision: 0.1524
# Recall: 0.4117
# F1-score: 0.2029

# %%
# summarization

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

summarization = df[df['task'] == 'summarization']
results = []

for _, row in summarization.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output_1024'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    print(f"Evaluation result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Evaluation result:
# - Coherence: 4.5
#   - The model's response closely aligns with the context provided, accurately reflecting the medical scenario, diagnosis, and treatment details discussed between the doctor and the patient in the input conversation. However, it assumes the narration from both patient and doctor perspectives, which is a minor coherence inconsistency.
#
# - Completeness: 4.8
#   - The model provides a comprehensive answer that includes key details from the input conversation, such as the patient's symptoms, diagnosis, and treatment. It effectively encompasses the medical and procedural aspects covered in the discussion.
#
# - Naturalness: 4.2
#   - While the response is fluent and detailed, the format is somewhat clinical and lacks the conversational exchange typical of an actual patient-doctor dialogue. The model's response compresses the dialogue into a single narrative, which slightly affects its naturalness as a conversational piece.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is mostly coherent with the input context. It correctly identifies the sequence of medication changes and the resolution of symptoms after the reintroduction of olanzapine. However, it implicitly suggests that adjustments were continually made without specifying that it's an ongoing process unless further needed.
#
# - Completeness: 3.5
#
# While the model captures the main events (medication change from olanzapine to iloperidone and back, and the issue of retrograde ejaculation), it lacks some specific details provided in the true answer, such as the titration of iloperidone to a specific dose and the specific symptom description. These omissions might limit the clinical completeness of the response.
#
# - Naturalness: 5.0
#
# The model's response reads fluently and mimics the style of a clinical note, which suits the provided context well. It uses professional language expected in a medical setting, enhancing its human-like quality.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   - The model's response accurately conveys the conversation between the doctor and the patient, reflecting the logical order and content of the dialogue. It maintains the structure and detail of the original context without introducing inconsistencies or errors.
#
# - Completeness: 4.0
#   - While the model's response captures most of the details from the conversation, it doesn't provide new insights or additional context beyond what is explicitly covered in the patient-doctor interaction. The response is mainly a repetition of the dialogue and lacks the depth present in the true answer (e.g., the specific 2–20 episodes of diarrhea the mother experienced is not mentioned or emphasized).
#
# - Naturalness: 5.0
#   - The dialogue in the model's response sounds very fluent and human-like. It mimics a real-life conversation flow between a doctor and a patient, maintaining readability and engaging style. The response replicates the natural exchange characteristics and conversational etiquette shown in the input.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#   - The model's response mostly aligns with the context provided, detailing the patient's diagnosis, medical history, treatments, and outcomes. However, it incorrectly reports the patient's age as 55 instead of 68 and prematurely concludes with the patient's death, which was not mentioned in the context.
#
# - Completeness: 3.5
#   - The model captures most of the critical points, including the diagnosis, medical history, treatment, and initial outcomes. However, it lacks specific treatment details such as the dosage of radiation therapy and it incorrectly concludes that the patient passed away, which was not a confirmed outcome in the input.
#
# - Naturalness: 4.0
#   - The response is mostly fluent and human-like, using professional language appropriate for medical documentation. However, the inclusion of the patient's death, which wasn't confirmed in the dialogue, might confuse real human interpretations.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# - Completeness: 4.3
# - Naturalness: 4.7
#
# **Coherence**: The model's response is largely coherent and aligns well with the input context. However, the model does not include a mention of "pupillary block, intraocular inflammation, iris chafing, or vitreous prolapse," which were part of the examination findings in the full context provided, slightly impacting the coherence.
#
# **Completeness**: The model's response satisfactorily covers almost all aspects of the input context. However, it misses a couple of details such as the lack of specific mention of no evidence of certain conditions (like pupillary block, intraocular inflammation, iris chafing, or vitreous prolapse) and a reference to a figure (though it may not be critical for textual responses). These omissions lead to a slightly lower completeness score.
#
# **Naturalness**: The response is fluent and sounds quite human-like. The language and tone are appropriate for a clinical setting, and the information flows logically, making the response relatively natural.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response mostly aligns with the provided context. It correctly identifies key conditions and treatments mentioned in the dialogue, although it omits some specific details regarding the patient's background and more detailed symptom progression.
#
# - Completeness: 3.5
#   - The response captures many essential elements of the patient's condition and treatment but lacks specific details found in the True Answer, such as the patient's exact age, the specific timeline of symptom progression, and detailed diagnostic findings (e.g., sensorimotor polyneuropathy, muscle biopsy results). It also omits some background information about the patient's history.
#
# - Naturalness: 4.0
#   - The response is fluent and generally sounds human-like, but it is somewhat structured and lacks the natural variability of a human narrative. It provides information succinctly but could benefit from a more conversational tone that mirrors the doctor's style from the input.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   *The model's response logically aligns with the context provided. It touches upon all the key elements discussed between the doctor and patient, such as the treatment regimen, outcomes, biopsy results, and advice on avoiding sun exposure. However, it omits some detailed aspects like the specific regimen timeline and some patient history details.*
#
# - Completeness: 4.0
#   *The response captures most of the essential points needed to answer the question effectively, including treatment details and outcomes. However, it lacks some comprehensive details about the regimens, such as the exact timeline of dosage re-adjustment and some background information provided in the input, which appears in the true answer.*
#
# - Naturalness: 4.8
#   *The response sounds fluent and human-like. It effectively uses medical terminology naturally, reflecting a well-structured clinical report. Minor variations in phrasing could enhance the human-like quality slightly more.*
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#
#     The model's response logically aligns with the input context. It accurately summarizes key patient information shared in the dialogue, such as medical history, treatment, symptoms, test results, and risk classification as per the 2015 GOLD guidelines. However, it slightly alters the patient's age, which affects its overall coherence.
#
# - Completeness: 3.5
#
#     The model's response is mostly complete but lacks details about the patient's past smoking history, which is mentioned in the true answer. It also does not mention the patient's lifestyle, such as being sedentary or the details about imaging tests like the chest X-ray and HRCT scans described in the true answer.
#
# - Naturalness: 4.5
#
#     The model's response is generally fluent and human-like. It presents information in a structured manner, akin to how a professional medical report might be communicated, maintaining a tone and style consistent with the given context of a medical discussion. However, it's more report-like than conversational, which slightly affects the naturalness in a dialogue context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   - The model's response logically aligns with the given dialogue. It accurately summarizes the patient's condition, the findings from the examination and tests, and the subsequent medical actions taken. There are no discrepancies between the input conversation and the model's summary.
#
# - Completeness: 4.5
#   - The model provides a comprehensive summary of the main points, including the patient's presenting symptoms, diagnostic findings, and treatment plan. However, it omits specific details such as the patient's age and the specific antibiotics mentioned in the true answer. While these details might not be crucial for understanding the overall situation, their inclusion would make the response more complete.
#
# - Naturalness: 4.8
#   - The response is well-structured and fluent, closely resembling a human-like medical summary. It maintains a formal and clinical tone appropriate for the medical context. However, it lacks a few minor details that could have enhanced its naturalness, such as using full names for medical tests like "MRI" or "CT scan" when they are first mentioned. The language used is otherwise clear and professional.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response logically aligns with the context provided in the input. It accurately reflects the patient's condition and treatment details discussed in the dialogue. However, there's a minor age discrepancy between the model's response and the true answer.
#
# - Completeness: 4.0
#   - The response includes most relevant details like the medical conditions, treatment history, and outcomes after dose reduction. However, it omits certain specifics such as the patient's age, ethnicity, and the specific timeline of events mentioned in the true answer.
#
# - Naturalness: 4.5
#   - The response is fluent and human-like, with structured and clear medical reporting. It reads like a concise medical summary one might expect in a clinical setting. However, some parts could be made slightly more conversational to enhance naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#
# The model's response does not logically align with the context provided. The context is about the dog's medical history and preparation for cataract surgery, while the model's response jumps to a follow-up appointment and repeats information unnecessarily.
#
# - Completeness: 1.0
#
# The model's response fails to provide a complete and relevant answer regarding the medical history and context provided in the input. Instead, it mostly consists of repetitive and irrelevant dialogue.
#
# - Naturalness: 2.5
#
# While the initial parts of the conversation sound relatively conversational, the excessive repetition in the dialogue reduces the naturalness significantly. The conversation lacks typical variations found in human interactions.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response aligns well with the context provided in the input. It accurately reports the timeline of events and medical details, maintaining consistency with the dialogue between the doctor and the patient. However, it misses the specifics about the situation at work and some personal details, which slightly affects full coherence with the narrative.
#
# - Completeness: 3.5
#   - The response includes important medical details and treatment plans, but it omits background information about the patient's occupation, the conditions leading to the burn, and the absence of the waist support belt, which were noted in the true answer. This lack of context diminishes the completeness of the response.
#
# - Naturalness: 4.5
#   - The response is fluent and largely human-like. It uses appropriate medical terminology and provides a structured summary consistent with a professional report. However, some areas read more like a clinical note than a conversational summary, slightly affecting the naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response generally aligns logically with the context provided in the input. Most of the key points from the interaction are captured correctly. However, it omitted specific details like the echocardiogram findings (ASD and PDA) and precise details about the acylcarnitine and coagulation profile.
#
# - Completeness: 4.0
#   - The model's response includes key elements from the conversation such as hypotonia, cardiac murmur, jaundice, and a diagnosis of L-3 hydroxyacyl-CoA dehydrogenase deficiency. However, it misses some specific findings, such as echocardiogram details and more precise laboratory results, which are provided in the true answer.
#
# - Naturalness: 4.8
#   - The model's response is fluent and formatted in a clear and human-like manner. It presents the information in a concise summary form, which might be more characteristic of a medical report than a natural conversation but fits the context of summarizing patient information.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#   - The model's response is coherent with the conversation; however, it includes an unnecessary repetition of the entire conversation in the initial part of its response, which diminishes coherence in terms of focus and relevance to summarization.
#
# - Completeness: 2.5
#   - The model's response is incomplete as it only begins to summarize after the lengthy repetition of the conversation, and the provided starting point of the summary ("The patient was") is cut-off, leaving the summary unfinished. Additionally, it fails to capture key patient details such as age, weight, and height included in the True Answer.
#
# - Naturalness: 3.0
#   - The model response is initially natural but falters because it repeats the conversation verbatim rather than providing a summary. This diminishes the perception of fluency and human-like narrative flow. The beginning of the intended summary, though incomplete, could align well if appropriately extended.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided in the input. It effectively summarizes the patient's symptoms, diagnosis, and treatment plan in a coherent manner. However, it lacks some specific details found in the true answer, such as mentioning the absence of pain medication and specific evaluation devices.
#
# - Completeness: 4.0
#   The model's response sufficiently answers the question by summarizing key aspects of the case, including symptoms, diagnosis, and treatment protocol. Nonetheless, it omits certain details that were present in the true answer, such as the specifics of the visual analogue scale and HRV analysis devices used, as well as the patient's age and nationality.
#
# - Naturalness: 4.7
#   The model's response sounds fluent and human-like, consistently using professional language that would be expected in a medical setting. It reads naturally and maintains clarity throughout. Minor improvements could be made for even more natural phrasing, but overall, it is quite effective.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# - Completeness: 4.0
# - Naturalness: 4.5
#
# **Coherence**: The model's response logically aligns with the context provided in the input. The clinical note accurately reflects the details shared during the conversation such as the patient's medical history, description of the nodular formation, medications, and proposed treatment plan. The lower score accounts for missing details such as the specific patient age and sex, which would need to be included for a fully coherent clinical record.
#
# **Completeness**: The response covers much of the necessary information but lacks some specifics that are present in the true answer, such as the patient’s exact age, the specific year of the visit (2019), and certain finer details about the nodular formation’s location (vestibular intercanine region specifically) and the type of dental probe used. Therefore, it falls slightly short of maximum completeness.
#
# **Naturalness**: The language used in the response is fluent and mimics the style of human-generated clinical notes, earning a high score in naturalness. It reads smoothly and utilizes medical terminology appropriately for the context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is coherent and aligns well with the context provided in the input. It accurately recounts the key details of the interaction between the doctor and the patient.
#
# - Completeness: 4.0
#   - The model's response sufficiently answers the question and covers most of the relevant details about the patient's condition and the diagnosis. However, it omits some minor contextual details such as the patient's love for the outdoors and not traveling outside West Virginia, which were mentioned in the true answer.
#
# - Naturalness: 4.2
#   - The response is mostly fluent and human-like, although it follows a structured, clinical format which might be expected in a medical summary but lacks conversational flow. However, such format fits the context well given the nature of the interaction.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is largely coherent with the context provided in the input. It accurately follows the sequence of events and medical status described in the conversation, and no major logical discrepancies are present. However, it omits some specific details such as the decreased muscle tone and persistent bradypnea one hour after exposure, which detracts slightly from coherence.
#
# - Completeness: 4.0
#
# The response captures most of the important pieces of information from the conversation, such as the initial symptoms, the interventions made, and the progression of the baby's condition, leading to discharge. However, it lacks some finer details such as the baby's reaction one hour after exposure and the specifics of when bradypneic episodes stopped, which are present in the true answer.
#
# - Naturalness: 4.8
#
# The language used in the model's response is fluent and reads like a typical clinical note. It maintains a professional tone and uses medical terminology appropriately, which is suitable given the context. The overall presentation is clear and human-like, with minor areas that could be slightly more polished or detailed.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 2.0**
#
#   The model's response lacks coherence since it jumbles the presentation of symptoms and context. The dialogue does not follow a logical sequence after admitting the patient has passed away, reverting to a discussion about symptoms and tests. The conversation seems repetitive and does not align well with the chronological flow of the patient's condition.
#
# - **Completeness: 1.5**
#
#   The response fails to address the critical fact mentioned in the input, which is the patient's unfortunate passing. It also repeats similar points multiple times without progressing the conversation or reaching any meaningful conclusion. Thus, it doesn't sufficiently answer the question implied by the implied patient concern about the seriousness of their condition.
#
# - **Naturalness: 2.5**
#
#   The dialogue sounds somewhat repetitive and robotic, as the model iterates over the same facts multiple times without adding new information or demonstrating understanding. Although some segments of the dialogue can sound passable, the lack of progression and repetition make it seem less human-like overall.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#
# The model's response is logically aligned with the context provided in the input. It captures the main medical concerns, diagnoses, treatments, and the significance of the patient's comorbidities. The response reflects an accurate understanding of the progression and management of the patient's condition.
#
# - Completeness: 4.5
#
# The model's response is mostly complete, as it includes the key points about the patient's diagnosis, laboratory results, surgical procedures, and treatment plan. However, some specific laboratory details and the full breadth of the diagnostic processes (like CT urography findings) were not thoroughly elaborated as in the true answer. Despite this, the response sufficiently covers the primary aspects required to answer the question in the input.
#
# - Naturalness: 4.8
#
# The model's response sounds fluent and human-like, similar to professional medical documentation. It maintains a clear and concise structure typical of clinical notes, making it feel authentic and appropriately formal for the medical context. The language used is easily understandable and replicates the natural tone found in medical assessments.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.0**
#   The model's response generally aligns with the context of the dialogue. However, it incorrectly states the patient's age as 35 instead of 50, which slightly detracts from the coherence with the input context.
#
# - **Completeness: 3.5**
#   The response covers many key aspects of the patient's medical condition and history post-accident, such as the injuries sustained, treatments administered, and rehabilitation progress. However, it omits important details such as the patient's smoking habits, family, and personal medical history, which were included in the true answer.
#
# - **Naturalness: 4.5**
#   The response is fluent and resembles a summary one might expect from a human. The language used is clear and appropriate for conveying medical information. However, small errors like the incorrect age slightly impact its natural feel.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#
# The model's response maintains some coherence with the structure of a medical consultation, but it inaccurately shifts the patient from a child to an adult, changing the situation and altering key patient details (e.g., age, gender, caregiver involvement).
#
# - Completeness: 2.5
#
# The model's response covers many aspects of the true answer but omits important specific details such as medication types and some treatment specifics. The consistency of switching from child to adult affects the completeness of representing the full context.
#
# - Naturalness: 4.5
#
# The responses sound fluent and mimic a human-like conversation well. The dialogue is formatted and structured in a natural and clinically appropriate manner, though the content does contain critical factual inaccuracies.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is generally coherent and logically aligns with the context of the conversation between the patient and the doctor. It captures the main points discussed in the dialogue, such as the patient's belief about insects, the prescribed medication, and the outcomes of the treatment.
#
# - Completeness: 4.0
#   - The model's response is mostly complete but lacks some nuances found in the true answer. While it mentions the patient's complaints, medical history, and treatment, it omits details such as the patient's and wife's behavior towards mosquitoes and the wife's refusal to accept the medical explanation initially. These details could provide a fuller picture of the situation.
#
# - Naturalness: 4.8
#   - The model's response is quite fluent and reads like a typical clinical note that would be written by a healthcare provider. The language used is professional and clear, closely resembling natural human writing within a medical context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response accurately reflects the interactions and details provided in the input context. The sequence of dialogue is consistent, and the response stays within the context presented. However, there might be minor elements or nuances from the true answer's context that aren't explicitly mirrored.
#
# - Completeness: 3.5
#   - While the model's response captures most of the details from the input, it doesn't fully encapsulate the additional medical history details (e.g., diabetes mellitus, class III obesity, treatment specifics) and certain motivations behind medical decisions that appear in the true answer. These missing elements could contribute to a deeper understanding of the case.
#
# - Naturalness: 5.0
#   - The dialogue flows naturally and sounds fluent and human-like. The conversational exchange between the doctor and patient is coherent and resembles real-life communication effectively.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 3.0**
#   The model's response logically follows the dialogue excerpt provided, summarizing the patient's condition and treatment steps accurately. However, there is an inconsistency in terms of patient gender and identification (referring to the patient as "she" instead of "he"), which detracts from coherence.
#
# - **Completeness: 4.5**
#   The model's response is largely complete, covering the main points of the patient's condition and treatment as described in the dialogue. It includes details about the recurrent carcinoma, treatment methods, symptoms experienced, and further surveillance. However, the response lacks specific details such as the patient's age and diabetic condition, which are mentioned in the true answer.
#
# - **Naturalness: 4.0**
#   The response is generally natural and fluent, with well-structured sentences and appropriate medical terminology aligning with the style of clinical case reporting. However, the use of the wrong pronoun ("she") affects the naturalness, as it would typically be jarring in a medical context to misidentify patient details.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
#
# The model's response captures some core details from the conversation about the patient's condition, including the right eye's blindness and pain, specific symptoms like rubeosis iridis, and the elevated intraocular pressure of 41 mmHg. However, it omits the patient's detailed medical history, which was a crucial part of the overall context, reducing the logical alignment with the comprehensive input.
#
# - Completeness: 2.5
#
# The model provides a snapshot of the patient's right eye conditions and the treatment plan but fails to address many aspects, such as the detailed medical history, medication details, and the differential diagnoses discussed. It omits the steps leading to the diagnosis and recommendation for enucleation, making the response feel incomplete.
#
# - Naturalness: 4.0
#
# The model's language is clear and concise, resembling a clinical note. However, it lacks a conversational flow that mirrors natural human interaction, making it sound more like a list of findings rather than a naturally flowing response from a doctor to a patient.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response logically aligns with the context provided. However, it omits specific details regarding the continuation of medication and the instruction to monitor symptoms, which slightly affects the overall coherence with the entire context.
#
# - Completeness: 4.0
#
# The response captures most of the critical information, such as the patient's diagnosis, medications, and the plan for further diagnosis via colonoscopy. However, the family and academic institution relation, as well as the detail about the patient's follow-up and symptom tracking, are missing, leading to a minor reduction in score.
#
# - Naturalness: 3.5
#
# While the model's response presents the information clearly, it is brief and lacks the conversational flow and nuance present in the original dialogue. It reads more like a clinical note than a naturally spoken human exchange.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is largely coherent and closely follows the context of the input, capturing the patient's medical history, symptoms, test results, and the doctor's recommendation for transfer. However, there is a discrepancy in the patient's age; the input does not specify it, but the true answer mentions 67 years.
#
# - Completeness: 4.8
#   - The model's response includes most critical details needed to understand the patient's condition, such as medical history, current symptoms, test results, and proposed treatment plan. It misses some specifics like the exact laboratory test values and mentions of reduced food intake and weight loss percentage, but these do not materially impact the completeness of the response for most practical purposes.
#
# - Naturalness: 5.0
#   - The model's response is fluent and maintains a professional tone typical of medical summaries. It reads very much like it was composed by a human familiar with medical communication, using appropriate terminology and structure.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# The model's response aligns well with the input context. The dialogue flows logically and maintains consistency with the discussions about the weight management clinic, the patient's medical history, and the recommended care plan. However, it doesn't delve deeply into the specific metrics and details given in the true answer, like the precise BMI, age, and other clinical specifics.
#
# - Completeness: 3.5
# While the model's response covers most key points discussed in the dialogue, including stress-related emotional eating, activity levels, and family health history, it lacks specific details found in the true answer, such as precise BMI, the exact nature of the lipid levels, or the screen time. These details would provide a more complete picture of the patient's situation.
#
# - Naturalness: 5.0
# The dialogue is fluent and sounds natural. The exchanges between the patient and doctor are represented in a way that mimics a conversational interaction typical in a medical context, making it sound human-like.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
#   - The model's response does not logically align with the input context. It repeats the dialogue almost verbatim without any adaptation or new contribution, which doesn't address the specifics of a new question or context.
#
# - Completeness: 1.0
#   - The response does not answer any particular question from the input or provide any new relevant information. It simply echoes the given dialogue without addressing the specifics of the complete question.
#
# - Naturalness: 2.0
#   - The response sounds fluent and human-like as it mirrors the original input, but it lacks originality or variation. The repetition diminishes the naturalness since it doesn't simulate a genuine conversation shift as expected in a follow-up appointment scenario.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       4.000000
# Completeness    3.546667
# Naturalness     4.270000
# BLEURT          0.463923
# BERTScore_F1    0.594292
# dtype: float64

# %%
# generation

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

generation = df[df['task'] == 'generation']
results = []

for _, row in generation.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output_1024'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    print(f"Evaluation result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Evaluation result:
# - Coherence: 4.5
#   The model's response is coherent and logically aligns with the context provided in the input. It acknowledges the symptoms and blood test results, connecting them to complications arising from diabetes and suggesting relevant lifestyle changes and medication adjustments.
#
# - Completeness: 4.5
#   The model provides a comprehensive response, addressing various symptoms and offering a detailed lifestyle and medication plan to help manage the condition. However, it could emphasize the need for consultation with a healthcare professional for a more personalized treatment plan.
#
# - Naturalness: 4.5
#   The model's response is fluent and human-like, providing clear and detailed suggestions in a professional and empathetic manner. However, minor variations in phrasing could make it sound even more conversational.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided. It advises against pulling back the foreskin for wiping based on concerns about irritation, which aligns with a portion of the true answer. However, it does not acknowledge the role of smegma or address immune-compromised conditions mentioned in the true answer.
#
# - Completeness: 3.5
#   The model addresses the primary question about post-urination hygiene without pulling back the foreskin but lacks depth. It does not mention smegma or the importance of cleaning the undersurface of the foreskin during bathing, which are significant parts of comprehensive foreskin hygiene. It also doesn't address conditions like diabetes that could affect foreskin health.
#
# - Naturalness: 4.8
#   The response is fluent and sounds human-like, offering clear advice that is easy to understand. The language used is appropriate and conveys the information smoothly.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.5
#   - The model's response partially aligns with the context but lacks specific relevance to the user's symptoms, such as the hard bumps and localized pain described. It offers several potential conditions without tailoring the explanation closely to the user's context.
#
# - Completeness: 2.0
#   - The response lists numerous conditions without giving a focused diagnosis or recommendation for the specific symptoms provided. It lacks a concise conclusion or advice for the next steps, such as seeking medical attention or considering specific treatments, that are relevant to the user's particular symptoms.
#
# - Naturalness: 2.0
#   - The response is repetitive and less fluent, with sentences often repeating similar structures and phrases. The language is mechanical due to its redundancy and lack of personalization, which detracts from sounding human-like and conversational.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0 - The model's response is generally coherent with the input context, acknowledging the baby's heart rate and AFI. However, it inaccurately states the AFI is normal without deeper analysis or consideration of the threshold (usually below 8 cm can be considered low).
#
# - Completeness: 2.0 - The response lacks detail and does not thoroughly answer the question. It fails to consider other important factors mentioned in the true answer, such as CTG monitoring, lack of high-risk factors, and timing guidelines for induction.
#
# - Naturalness: 4.5 - The response sounds fluent and human-like. It uses clear and straightforward language, suitable for effective communication.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided in the input. It correctly identifies that flashes of light in the eye can be associated with conditions like diabetic retinopathy, which aligns with the mention of diabetes medication in the input. However, it does not address posterior vitreous detachment (PVD) as a possible age-related cause, which slightly affects coherence.
#
# - Completeness: 3.5
#   The response provides a fairly comprehensive discussion of potential eye conditions related to diabetes, which is relevant given the user's background of diabetes medication. However, it does not cover the possibility of posterior vitreous detachment, which is relevant given the user's age. Mentioning PVD and offering advice based on that scenario would make the response more complete.
#
# - Naturalness: 5.0
#   The response is fluently written and sounds very human-like. The language used resembles that of a knowledgeable healthcare professional providing advice. It is polite, informative, and well-structured, fitting well within the expectations for naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#   - The model's response is somewhat coherent in the sense that it recognizes the severity of the situation and suggests reaching out to a crisis line. However, it fails to address the nuances of the emotional and psychological issues presented in the input.
#
# - Completeness: 1.5
#   - The response does not sufficiently address the underlying questions or concerns of the user. The user is seeking specific guidance on coping mechanisms and emotional support besides contacting a crisis hotline. The model's response lacks depth and does not provide any advice or supportive statements tailored to the detailed personal issues described.
#
# - Naturalness: 3.0
#   - The language used in the model's response is grammatically correct and straightforward, but the tone is impersonal and brief. It lacks empathy and the human-like engagement that would be expected in a response to someone expressing such distressing personal issues.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context given. It accurately discusses potential causes of the symptoms described, connecting them to possible infections and other conditions like hormonal changes or foreign object insertion.
#
# - Completeness: 4.0
#   While the response provides a comprehensive list of potential causes for the symptoms, it does not explicitly address if hormonal imbalance is connected to the described discharge. The true answer emphasizes that hormonal imbalance is not the cause, which the model does not clearly state. However, it suggests consulting a healthcare provider for a proper diagnosis.
#
# - Naturalness: 5.0
#   The response is fluent and human-like, with a warm and empathetic tone. It reads naturally and provides practical advice, such as maintaining good genital hygiene and the importance of consulting a healthcare provider.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5 - The model's response is coherent as it addresses most issues raised in the input, such as the potential effects of oral contraceptives and antibiotics, and suggests alternative treatments. However, it did not directly address some specific concerns, such as the efficacy of Tetracycline if taken again in the future or the concern about nutrient absorption due to stomach issues.
#
# - Completeness: 4.0 - The response provides a comprehensive overview of possible treatment avenues, including discussing the pros and cons of oral contraceptives and alternative options. However, it doesn't directly answer all of the nuanced concerns, such as the long-term effects of Spironolactone, potential issues with Tetracycline resistance, and the effects on hair regrowth if restarting oral contraceptives like Marvelon.
#
# - Naturalness: 4.7 - The response is quite natural and reflects a human-like understanding of the situation, offering consideration and suggestions as a medical professional might. Minor improvements could be made in terms of warmth and empathy in the language used to align more with a sensitive human interaction.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#   - The model's response provides some correct and relevant information about kidney stones, CAT scans, and natural remedies. However, it repeatedly clarifies that it is not a doctor, which limits the alignment with the specific medical inquiries posed. The response could have been more coherent with the context by directly addressing the specific questions asked, such as about the use of anesthesia, the potential complications of the kidney stone, and the concerns regarding using natural remedies.
#
# - Completeness: 2.0
#   - The model's response fails to thoroughly answer the user's queries. It doesn't provide a direct answer to whether surgery is necessary, the type of anesthesia used, or a clear medical interpretation of the situation. While it offers general information about kidney stones, CAT scans, and natural remedies, it falls short of addressing the user's specific medical concerns and questions with substantive advice.
#
# - Naturalness: 4.5
#   - The language used in the model's response is fluent and human-like. The conversational tone is appropriate and clear. However, the persistent disclaimer regarding its inability to provide medical advice, while responsible, slightly interrupts the natural flow of providing the requested information.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response is coherent with the given context. It accurately interprets the medical terms and aligns logically with the information provided in the input. It correctly explains the meaning of "hypoplastic right cavernosal artery" and how it might relate to the reported ED.
#
# - Completeness: 3.5
#   The response provides a basic explanation of the doppler test results and suggests a possible connection to ED, but it doesn't address other factors or follow-up questions that could be pertinent, such as the patient's medical history, medication use, and other conditions. The true answer hints at a broader diagnostic inquiry which is missing in the model's response.
#
# - Naturalness: 4.5
#   The model's response is fluent and sounds fairly human-like. It uses polite language and medical explanations in a manner that is easy to understand for the patient, maintaining a professional tone suitable for a medical consultation.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#
# The model's response somewhat aligns with the context of the input question, confirming the risks of a long-term ketogenic diet but fails to account for the nuances presented in the true answer. While it lists numerous potential negative effects, it incorrectly repeats and redundantly emphasizes the phrase "high in fat and low in carbohydrates" without varying the explanation or rationale behind each potential risk.
#
# - Completeness: 3.0
#
# The response attempts to answer the question by listing several potential risks of a long-term ketogenic diet. However, it lacks depth and doesn't appropriately address the true answer's mention of ketosis, the role of a trained nutritionist, and the reasoning behind these health problems. The redundant nature of the list also leads to a lack of new, meaningful content, thereby reducing its overall completeness.
#
# - Naturalness: 2.5
#
# The response feels mechanical and repetitive, lacking fluency and a human-like quality. The repeated structure of each point makes the model's answer appear automated rather than naturally formulated. Simplified language and variation in sentence structure could have enhanced its naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is coherent with the input context. It correctly identifies Argyreia speciosa and acknowledges its traditional use for treating conditions like gonorrhea and syphilis. It provides general information about the plant's medical applications and advises consulting a healthcare professional. However, it does not directly address the preparation techniques as queried, slightly impacting coherence.
#
# - Completeness: 3.5
#
# While the response provides a broad view on the medicinal use of Argyreia speciosa and responsibilities when engaging with traditional medicine, it lacks specific instructions or traditional preparation techniques for treating gonorrhea and syphilis, which was the core of the question. The model suggests seeking medical advice but does not deliver the detailed procedural insights the user requested.
#
# - Naturalness: 4.8
#
# The response is fluent and natural-sounding. It is well-structured, follows a logical flow, and reads like something a human might say, demonstrating an understanding of standard communication practices and language use. The caution it provides is also expressed in a professional, empathetic tone that would be expected from a healthcare professional.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
# - Completeness: 2.0
# - Naturalness: 4.0
#
# Explanation:
# - **Coherence**: The model's response is somewhat coherent as it acknowledges the user's symptoms and advises visiting a doctor, which is a logical conclusion given the context. However, it does not specifically address any of the symptoms or medications mentioned, which impacts its relevance to the user's detailed concerns.
#
# - **Completeness**: The response falls short in completeness because it doesn't address the specific questions and concerns raised by the user. The model doesn't provide any potential explanations for the symptoms, nor does it evaluate or provide alternatives to the medications already prescribed, thus offering insufficient help compared to the true answer.
#
# - **Naturalness**: The response is fluent and human-like, similar to what one might expect from an individual who cannot provide direct medical advice but still suggests seeing a doctor. The tone is polite and professional, contributing positively to this metric.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response aligns logically with the context provided. It acknowledges the user's concern about their weakened immune system and provides general guidance based on recommendations for individuals with weakened immune systems.
#
# - Completeness: 3.0
#   The model's response is somewhat lacking in detail. While it provides a general suggestion to take extra precautions, it avoids giving specific advice about whether the user should self-isolate based on their condition, which the user specifically asked about.
#
# - Naturalness: 4.0
#   The response is generally fluent and human-like. However, the repetition of "I can’t" at the beginning might slightly disrupt the natural flow. Nevertheless, it sounds polite and professionally neutral.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
# - Completeness: 1.0
# - Naturalness: 1.0
#
# The model's response fails across all three metrics.
#
# - **Coherence**: The response lacks logical alignment with the input context. There is an excessive repetition ("The cancer has spread to distant organs." repeated multiple times) that does not provide meaningful information related to the input query.
#
# - **Completeness**: The response does not sufficiently answer the question. It repeats the same phrase without addressing the primary concern about treatment options for stage 4 endometrial cancer with lung metastasis.
#
# - **Naturalness**: The repetition of the same phrase over and over again makes the response sound unnatural and robotic, lacking the fluency or human-like quality expected in a helpful answer.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#   - The model’s response lacks coherence due to excessive repetition and failure to provide a logical structure. It mentions possible conditions like ulnar neuropathy and cubital tunnel syndrome but doesn't explore alternative explanations or align well with the context.
# - Completeness: 1.5
#   - The response focuses a lot on repeating information rather than answering the specific questions regarding treatment options or long-term effects. It fails to provide specific actionable advice or steps for managing the condition.
# - Naturalness: 1.5
#   - The response is highly repetitive, which detracts from sounding natural or human-like. A human response would not repeat the same sentence over and over; instead, it would contain more varied language and structured explanations.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#   - The model's response does not logically align with the context of the question. Instead of addressing the specific problem of excessive sweating and foot odor, the response provides an overwhelmingly extensive list of unrelated health conditions, many of which are redundant or irrelevant to the context.
#
# - Completeness: 1.0
#   - The response does not sufficiently answer the user's question. It fails to offer an assessment of potential causes or provide advice that would help address the issue of excessive sweating and odor in the context of the symptoms described.
#
# - Naturalness: 2.0
#   - Although the initial part of the response is somewhat natural in tone, the excessive and repetitive listing of questions makes it sound mechanical and unnatural, similar to a checklist, rather than conversational or human-like.
#
# The model's response could be improved by focusing on the symptoms described and providing targeted, concise questions or suggestions relevant to the user's problem.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#
# The model's response is somewhat coherent in the sense that it addresses the symptoms described in the input by suggesting a possible condition (varicocele) that matches the symptoms. However, it does not address the attached picture of the vein, which could be an important part of the assessment. Also, the true answer suggested hernia as a likely condition, showing a potential gap in diagnostic interpretation.
#
# - Completeness: 2.0
#
# While the response does provide a diagnosis and a thorough discussion of varicocele, it lacks the completeness in exploring alternative diagnoses or asking the input-provider for more specifics about their symptoms, which the true answer does. It also does not address patient-specific advice or questions such as the cough impulse test that are present in the true answer.
#
# - Naturalness: 2.5
#
# Initially, the response is fluent and human-like, providing a clear explanation. However, it becomes less natural due to repetitive content about surgical procedures, which detracts from the overall naturalness and makes it cumbersome for the user to read and understand.
#
# Overall, the model's response has basic alignment with the input context but lacks breadth in diagnosis consideration and is excessively lengthy with redundant information affecting its quality.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is mostly coherent with the context provided. It addresses the normal pregnancy and thyroid conditions, with an understanding of the user's medical background and potential travel concerns. However, it doesn't specifically mention the importance of consulting an obstetrician to ensure the pregnancy is not high-risk, which is a crucial safety aspect.
#
# - Completeness: 4.0
#
# The response provides detailed tips and considerations for travel, addressing both the pregnancy and thyroid conditions. However, it misses mentioning some specific safety measures from the True Answer, such as ensuring the pregnancy is not high-risk and the need for a "fit to fly" certificate, which are key considerations for pregnant travelers.
#
# - Naturalness: 4.7
#
# The model's response is quite fluent and human-like. It sounds informative and approachable, akin to advice from a healthcare professional. It uses a friendly and supportive tone, making it easy to read and understand.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#
# The response logically explains what a brain hemorrhage is and its potential symptoms and outcomes. However, it does not address specifics in the input context such as the location of the hemorrhage or details about the patient's condition, resulting in some lack of alignment with the true specifics.
#
# - Completeness: 2.5
#
# While the model’s response provides generic information about brain hemorrhages, it does not address the mother's specific situation or offer any unique insights, such as possible causes or the prognosis, which are present in the true answer. There is an over-repetition of information without further analysis or specific medical guidance, which affects the completeness.
#
# - Naturalness: 3.5
#
# The response is generally fluent and uses medical terms appropriately, sounding like what one might expect from informational text. However, the excessive repetition diminishes the human-like quality, making it sound mechanical after a point.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
#   - The response partially aligns with the context of discussing exercise times and the impact on blood sugar levels for someone on diabetes medication. However, it incorrectly suggests exercising after breakfast, which was not an option provided by the user. This misalignment affects coherence.
#
# - Completeness: 3.0
#   - The response discusses maintaining healthy blood sugar levels and hypoglycemia, relevant to diabetes, but it doesn’t address the concept of body temperature and its impact on exercise efficiency. It also misplaces the recommendation of exercising after breakfast rather than before, as the user is only considering before breakfast or morning as options.
#
# - Naturalness: 4.5
#   - The response is mostly fluent and reads naturally, akin to advice from a human, with slight inaccuracies in phrasing that might impact clarity (e.g., 'So, if you are planning to exercise in the evening'). Overall, it still maintains a human-like tone.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
#
#    The model response provides general information about tinnitus which seems relevant to the ringing symptom described. However, it doesn't directly address the specific context provided in the input, such as the recent cold or the examination results suggesting everything appears clear. There's some logical alignment, but it lacks specificity to the user's situation.
#
# - Completeness: 2.5
#
#    The model's response offers a broad explanation of tinnitus but fails to address the user's particular circumstances and subsequent questions, such as why the ringing is present despite the cold clearing up or how long it might take to resolve. It lacks exploration of possible fluid accumulation or follow-up questions that could help diagnose and tailor advice.
#
# - Naturalness: 4.0
#
#    The language used in the response is fluent and reads quite naturally. It provides structured information and suggestions, making it sound fairly human-like. However, the repetition towards the end slightly detracts from the fluidity.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
#
# The model's response logically follows the input context, recommending potential next steps after a cyst's infection has been treated with antibiotics. However, it fails to address specific concerns such as the ongoing presence of pus and the patient's reluctance for surgery, which affects the alignment somewhat.
#
# - Completeness: 3.0
#
# The model does provide some advice on future management, mentioning surgical options and recovery precautions. Nevertheless, it does not offer an immediate plan to address the current infection's symptoms, such as the presence of pus, or take into account basic precautions and investigations, which leaves the response somewhat incomplete.
#
# - Naturalness: 4.5
#
# The response is fluent and reads like a human-written piece. It provides an empathetic tone and explains the process, including patient care steps, in a clear manner. However, it could improve by acknowledging the patient's concerns directly for optimal empathy.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response logically aligns with the context and provides detailed answers to each of the questions asked. However, it doesn't fully integrate all aspects of complexity, such as cost considerations or further implications of pancreas transplants, found in the true answer.
#
# - Completeness: 4.0
#   - The response covers most of the key questions and provides sufficient information for each. However, it lacks some specific details, such as economic considerations for treatment and the nuances of pancreas functions beyond insulin production, which are present in the true answer.
#
# - Naturalness: 4.8
#   - The response sounds fluent and human-like. It adopts a professional and reassuring tone, which is appropriate for the context of medical advice. There are no noticeable grammatical errors, and it reads smoothly.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#   The model's response focuses primarily on the dry skin issue and suggests that diabetes could be a contributing factor. However, it overlooks the connection the user made between the skin issue and the cat scratch, which is a significant part of the context. Furthermore, the model does not address the ineffectiveness and adverse reaction to the lotions already tried by the user, missing coherence with the user's expressed concerns.
#
# - Completeness: 2.5
#   While the model provides general advice on managing dry skin, it fails to acknowledge or address the progression of redness from the cat scratch, which may imply an infection or allergic reaction. Additionally, the suggestion to use lotions contradicts the user's experience of lotions exacerbating the issue. The recommendation to consult a dermatologist or to explore potential allergens or infections would have made the response more complete.
#
# - Naturalness: 4.5
#   The response is fluent and reads like a natural communication a doctor might have with a patient. It uses clear, patient-friendly language while providing general advice. However, it could be more empathetic by recognizing the user's prior adverse experiences with lotions.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#   - The model's response does not logically align well with the context. Although the answer starts by addressing the question about infections not presenting symptoms, it repetitively lists types of infections rather than providing distinct examples or additional information about the condition in question.
#
# - Completeness: 1.5
#   - The response falls short in answering the multiple facets of the question. It briefly touches on possible infections without symptoms and suggests sepsis, but does not address the query about high vacuolated neutrophil results indicating problems other than infections. The list of infections also appears more as a filler rather than informative content.
#
# - Naturalness: 2.0
#   - The response lacks fluency due to the excessive and repetitive listing of infections. This repetition makes it sound robotic and unnatural, detracting from a human-like conversational quality. It begins naturally but quickly devolves into an unnatural, verbose format.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response logically aligns with the context, explaining the implications of elevated M2-PK levels and the need for further investigation. However, it slightly lacks the depth present in the true answer regarding false positivity rates and alternative testing methods.
#
# - Completeness: 4.0
#   - The response addresses the main concern about the potential presence of cancer, indicating that elevated M2-PK is not a definitive indicator and suggesting further tests. However, it does not mention as many non-cancerous conditions that might cause elevation or provide detailed next steps related to specific tests like the true answer does.
#
# - Naturalness: 4.8
#   - The model’s response is fluent and human-like, providing a clear and empathetic explanation. It maintains a professional tone appropriate for a doctor's consultation.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.5**
#   The model's response logically aligns well with the context. It explains the function of the thyroid, the implications of having a small amount of thyroid tissue, and how it could relate to the symptoms described. The response is mostly coherent, but it doesn't consider potential non-thyroidal causes for the symptoms, which the true answer does, slightly affecting its coherence in perspective.
#
# - **Completeness: 4.0**
#   The response sufficiently answers the primary concern about thyroid function after partial thyroidectomy and how it relates to the reported symptoms. However, it lacks a more comprehensive exploration of other possible causes for the symptoms, such as calcium or vitamin D deficiency, which are mentioned in the true answer. This makes the response somewhat incomplete in addressing all potential facets of the issue.
#
# - **Naturalness: 4.7**
#   The language used in the model's response is fluent and sounds human-like. It uses medical terminology accurately and provides advice in a professional manner typical of how a healthcare professional might respond. However, the response could be slightly more conversational to enhance its naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.5
#   - The model's response somewhat aligns with the context by acknowledging the medications and the concern that they are no longer working. However, it does not directly address the specifics of the medication or the duration of the problem, unlike the true answer. The model's focus on gathering more information is somewhat logical but doesn't align with the immediate context of seeking advice.
#
# - Completeness: 2.0
#   - The response is incomplete as it fails to provide any concrete advice or suggestions on what should be done next, which was the main request. Instead, it asks for further information without offering any initial guidance or considerations, unlike the true answer.
#
# - Naturalness: 4.0
#   - The model's response is quite fluent and human-like. It uses polite language and structured questions akin to what a human might ask in a clinical consultation scenario. However, its coherence issues slightly detract from the naturalness in terms of appropriateness of response content.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response is coherent in that it acknowledges the user's problem and offers practical, albeit general, advice to seek professional consultation.
#
# - Completeness: 2.5
#   The model's response is not very complete compared to the level of detail in the true answer. It avoids giving specific advice or potential causes, and instead directs the user to seek professional help.
#
# - Naturalness: 4.7
#   The response is fluent and human-like, maintaining a polite and professional tone consistent with a healthcare setting.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       3.516667
# Completeness    2.766667
# Naturalness     3.850000
# BLEURT          0.560513
# BERTScore_F1    0.554674
# dtype: float64

# %%
# daily_diets

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response["choices"][0]["message"]["content"]
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

daily = df[df['task'] == 'daily_diets']
results = []

for i, row in daily.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_outpu_1024'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    if i % 10 == 0:
        print(f"Evaluation {i+1} result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Warning: Column BLEURT not found in DataFrame. Skipping normalization.
# Warning: Column BERTScore_F1 not found in DataFrame. Skipping normalization.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 147
#     144 evaluation_df = normalize_scores(evaluation_df, "BLEURT")
#     145 evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")
# --> 147 average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
#     148 print("평균 점수:")
#     149 print(average_scores)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Coherence', 'Completeness', 'Naturalness', 'BLEURT', 'BERTScore_F1'], dtype='object')] are in the [columns]"

# %%
# alternative_diets

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response["choices"][0]["message"]["content"]
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

alternative = df[df['task'] == 'alternative_diet']
results = []

for _, row in alternative.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    if i % 10 == 0:
        print(f"Evaluation {i+1} result:\n{evaluation}")
            
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       3.223577
# Completeness    2.880081
# Naturalness     3.008130
# BLEURT          0.488236
# BERTScore_F1    0.627131
# dtype: float64

# %%
import pandas as pd

dfh = pd.read_csv("/data/jaesung/llm_for_diabetes/src/data/data2_daily_diets/diabetes_food_hub_new_nutri_facts.csv")
dfh.head(2)
# Out:
#                                  title  \
# 0   Raspberry Swirl Frozen Yogurt Bark
# 1  Maple-Pumpkin Spice Oatmeal Cookies
#
#                                          description prep_time cook_time  \
# 0  Raspberry Swirl Frozen Yogurt Bark: Dive into ...    10 min      4 hr
# 1                              Description not found    10 min    25 min
#
#       servings                                              steps  \
# 0   6 Servings  ['Cover a freezer-safe tray with parchment pap...
# 1  14 Servings  ['Preheat the oven to 350 degrees F. Line two ...
#
#                                                 tags  \
# 0  ['Kid Friendly', 'Vegetarian', 'Dessert', 'Sna...
# 1  ['Kid Friendly', 'Vegetarian', 'Snacks', 'Glut...
#
#                                      nutrition_facts  \
# 0  {'Servings': '6 Servings', 'Serving Size': '1 ...
# 1  {'Servings': '14 Servings', 'Serving Size': '1...
#
#                                          ingredients
# 0  [{'label': 'Plain Nonfat Greek yogurt', 'us_me...
# 1  [{'label': 'old-fashioned rolled oats', 'us_me...

# %%
# daily diet - nutri score

import ast
import pandas as pd
import json
import re
import openai
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from dotenv import load_dotenv
import os
from tqdm import tqdm

# Load environment variables
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def extract_numeric_value(value):
    try:
        if isinstance(value, str):
            match = re.search(r"(\d+(\.\d+)?)", value)
            if match:
                return float(match.group(1))
        elif isinstance(value, (int, float)):
            return float(value)
    except Exception as e:
        print(f"Error in extract_numeric_value: {e}, value: {value}")
    return 0.0

def is_valid_meal_structure(json_string):
    try:
        data = json.loads(json_string)
        return all(key in data for key in ['Breakfast', 'Lunch', 'Dinner'])
    except (json.JSONDecodeError, TypeError):
        return False

def find_most_similar_row(title, dfh):
    try:
        dfh['title'] = dfh['title'].fillna('')  # Handle NaN values
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(dfh['title'])
        input_vector = vectorizer.transform([title])
        similarities = cosine_similarity(input_vector, tfidf_matrix)
        most_similar_idx = similarities.argmax()
        return dfh.iloc[most_similar_idx]
    except Exception as e:
        print(f"Error in find_most_similar_row: {e}, title: {title}")
        return None

def identify_fruit_veg(ingredients_list):
    try:
        prompt = f"Identify which items in the following ingredient list are fruits or vegetables:\n\n{ingredients_list}\n\nReturn only the names of items that are fruits or vegetables in a Python list format."
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an assistant identifying fruits and vegetables."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=100,
            temperature=0
        )
        fruits_vegetables = response['choices'][0]['message']['content']
        return ast.literal_eval(fruits_vegetables)
    except Exception as e:
        print(f"Error identifying fruits and vegetables: {e}")
        return []

def calculate_fruit_veg_points(ingredients, total_weight):
    try:
        ingredients_list = ast.literal_eval(ingredients)
        fruit_veg_labels = identify_fruit_veg(ingredients_list)

        fruit_veg_weight = 0
        for ingredient in ingredients_list:
            label = ingredient.get('label', '')
            weight = extract_numeric_value(ingredient.get('metric_measure', 0))
            if label in fruit_veg_labels:
                fruit_veg_weight += weight

        # 과일/채소 비율을 100g 기준으로 변환
        fruit_veg_ratio = (fruit_veg_weight / total_weight) * 100 if total_weight > 0 else 0

        if fruit_veg_ratio > 80:
            return 5
        elif fruit_veg_ratio > 60:
            return 2
        elif fruit_veg_ratio > 40:
            return 1
        else:
            return 0
    except Exception as e:
        print(f"Error calculating fruit_veg_points: {e}")
        return 0

def extract_nested_value(data, keys, default=0):
    try:
        for key in keys:
            if isinstance(data, dict):
                data = data.get(key, {})
            else:
                return default
        return extract_numeric_value(data) if isinstance(data, (int, float, str)) else default
    except Exception as e:
        print(f"Error in extract_nested_value: {e}, keys: {keys}, data: {data}")
        return default

def calculate_nutri_score(nutrition_facts, ingredients):
    try:
        if isinstance(nutrition_facts, str):
            nutrition_facts = ast.literal_eval(nutrition_facts)

        # 전체 무게 계산
        total_weight = sum(
            extract_numeric_value(ingredient.get('metric_measure', 0)) 
            for ingredient in ast.literal_eval(ingredients)
        )
        if total_weight == 0:
            print("Warning: Total weight is zero. Skipping calculation.")
            return None

        # 100g 기준으로 성분 정규화
        energy = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Calories']) / total_weight * 100
        saturated_fat = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Fat', 'Amount']) / total_weight * 100
        sugar = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Total Sugars']) / total_weight * 100
        sodium = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Sodium']) / total_weight * 100
        fiber = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Dietary Fiber']) / total_weight * 100
        protein = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Protein']) / total_weight * 100

        # Unfavorable points calculation
        energy_points = min(energy / 80, 800)
        saturated_fat_points = min(saturated_fat / 1, 10)
        sugar_points = min(sugar / 4.5, 45)
        sodium_points = min(sodium / 90, 900)

        unfavorable_points = energy_points + saturated_fat_points + sugar_points + sodium_points

        # Favorable points calculation
        fiber_points = min(fiber / 0.7, 3.5)
        protein_points = min(protein / 1.6, 8.0)
        fruit_veg_points = calculate_fruit_veg_points(ingredients, total_weight)

        favorable_points = fiber_points + protein_points + fruit_veg_points

        # Final Nutri-Score calculation
        total_score = unfavorable_points - favorable_points
        return total_score
    except Exception as e:
        print(f"Error in calculate_nutri_score: {e}, nutrition_facts: {nutrition_facts}")
        return None

def get_nutri_score_grade(score):
    if score <= -1:
        return "A"
    elif score <= 2:
        return "B"
    elif score <= 10:
        return "C"
    elif score <= 18:
        return "D"
    else:
        return "E"

def calculate_meal_nutri_score(meal_data, dfh):
    meal_scores = {}

    for meal, title in meal_data.items():
        matched_row = find_most_similar_row(title, dfh)
        if matched_row is None:
            continue

        nutrition_facts = matched_row['nutrition_facts']
        ingredients = matched_row['ingredients']
        score = calculate_nutri_score(nutrition_facts, ingredients)

        if score is None:
            print(f"Warning: Nutri-Score calculation failed for meal '{meal}' with title '{title}'.")
            grade = "N/A"
        else:
            grade = get_nutri_score_grade(score)

        meal_scores[meal] = {'score': score, 'grade': grade}

    return meal_scores

def calculate_scores_with_comparison(df, dfh):
    results = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        output_scores = {}
        model_scores = {}
        if is_valid_meal_structure(row.get('output', '')):
            output_data = json.loads(row['output'])
            output_scores = calculate_meal_nutri_score(output_data, dfh)
        if is_valid_meal_structure(row.get('model_output_512', '')):
            model_data = json.loads(row['model_output_512'])
            model_scores = calculate_meal_nutri_score(model_data, dfh)
        results.append({'row_index': idx, 'output_scores': output_scores, 'model_scores': model_scores})
    return results

def calculate_average_scores(results):
    """
    Calculate the average Nutri-Scores for outputs and model outputs.
    """
    output_total_score = 0
    model_total_score = 0
    output_count = 0
    model_count = 0

    for result in results:
        # Extract output scores
        for meal, score_data in result['output_scores'].items():
            if score_data['score'] is not None:
                output_total_score += score_data['score']
                output_count += 1

        # Extract model scores
        for meal, score_data in result['model_scores'].items():
            if score_data['score'] is not None:
                model_total_score += score_data['score']
                model_count += 1

    # Calculate averages
    output_avg = output_total_score / output_count if output_count > 0 else None
    model_avg = model_total_score / model_count if model_count > 0 else None

    return output_avg, model_avg


# 'daily_diets' task Nutri-Score calculation
filtered_df = df[df['task'] == 'daily_diets']
results = calculate_scores_with_comparison(filtered_df, dfh)

# Calculate overall averages
output_avg, model_avg = calculate_average_scores(results)

# Print results
print("=== Results for Each Row ===")
for result in results:
    print(f"Row Index: {result['row_index']}")
    print(f"Output Scores: {result['output_scores']}")
    print(f"Model Output Scores: {result['model_scores']}")
    print()

print("=== Overall Averages ===")
print(f"Output Average Nutri-Score: {output_avg}")
print(f"Model Output Average Nutri-Score: {model_avg}")
# Out:
# 100%|██████████| 274/274 [00:00<00:00, 22063.42it/s]
# === Results for Each Row ===
# Row Index: 661
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 662
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 663
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 664
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 665
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 666
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 667
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 668
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 669
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 670
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 671
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 672
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 673
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 674
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 675
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 676
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 677
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 678
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 679
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 680
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 681
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 682
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 683
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 684
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 685
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 686
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 687
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 688
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 689
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 690
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 691
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 692
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 693
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 694
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 695
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 696
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 697
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 698
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 699
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 700
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 701
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 702
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 703
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 704
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 705
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 706
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 707
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 708
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 709
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 710
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 711
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 712
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 713
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 714
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 715
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 716
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 717
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 718
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 719
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 720
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 721
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 722
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 723
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 724
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 725
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 726
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 727
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 728
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 729
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 730
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 731
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 732
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 733
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 734
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 735
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 736
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 737
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 738
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 739
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 740
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 741
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 742
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 743
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 744
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 745
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 746
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 747
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 748
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 749
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 750
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 751
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 752
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 753
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 754
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 755
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 756
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 757
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 758
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 759
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 760
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 761
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 762
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 763
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 764
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 765
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 766
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 767
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 768
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 769
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 770
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 771
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 772
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 773
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 774
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 775
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 776
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 777
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 778
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 779
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 780
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 781
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 782
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 783
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 784
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 785
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 786
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 787
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 788
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 789
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 790
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 791
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 792
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 793
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 794
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 795
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 796
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 797
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 798
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 799
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 800
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 801
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 802
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 803
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 804
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 805
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 806
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 807
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 808
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 809
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 810
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 811
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 812
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 813
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 814
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 815
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 816
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 817
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 818
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 819
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 820
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 821
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 822
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 823
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 824
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 825
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 826
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 827
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 828
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 829
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 830
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 831
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 832
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 833
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 834
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 835
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 836
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 837
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 838
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 839
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 840
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 841
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 842
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 843
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 844
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 845
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 846
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 847
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 848
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 849
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 850
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 851
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 852
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 853
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 854
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 855
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 856
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 857
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 858
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 859
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 860
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 861
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 862
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 863
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 864
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 865
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 866
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 867
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 868
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 869
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 870
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 871
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 872
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 873
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 874
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 875
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 876
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 877
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 878
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 879
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 880
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 881
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 882
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 883
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 884
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 885
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 886
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 887
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 888
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 889
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 890
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 891
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 892
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 893
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 894
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 895
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 896
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 897
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 898
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 899
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 900
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 901
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 902
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 903
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 904
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 905
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 906
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 907
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 908
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 909
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 910
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 911
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 912
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 913
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 914
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 915
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 916
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 917
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 918
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 919
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 920
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 921
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 922
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 923
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 924
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 925
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 926
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 927
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 928
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 929
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 930
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 931
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 932
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 933
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 934
# Output Scores: {}
# Model Output Scores: {}
#
# === Overall Averages ===
# Output Average Nutri-Score: None
# Model Output Average Nutri-Score: None

# %%
# alternative diet - nutri score

import ast
import pandas as pd
import json
import re
import openai
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from dotenv import load_dotenv
import os
from tqdm import tqdm

# Load environment variables
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def extract_numeric_value(value):
    try:
        if isinstance(value, str):
            match = re.search(r"(\d+(\.\d+)?)", value)
            if match:
                return float(match.group(1))
        elif isinstance(value, (int, float)):
            return float(value)
    except Exception as e:
        print(f"Error in extract_numeric_value: {e}, value: {value}")
    return 0.0

def is_valid_meal_structure(json_string):
    try:
        data = json.loads(json_string)
        return isinstance(data, dict)
    except (json.JSONDecodeError, TypeError):
        return False

def find_most_similar_row(title, dfh):
    try:
        dfh['title'] = dfh['title'].fillna('')  # Handle NaN values
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(dfh['title'])
        input_vector = vectorizer.transform([title])
        similarities = cosine_similarity(input_vector, tfidf_matrix)
        most_similar_idx = similarities.argmax()
        return dfh.iloc[most_similar_idx]
    except Exception as e:
        print(f"Error in find_most_similar_row: {e}, title: {title}")
        return None

def identify_fruit_veg(ingredients_list):
    try:
        prompt = f"Identify which items in the following ingredient list are fruits or vegetables:\n\n{ingredients_list}\n\nReturn only the names of items that are fruits or vegetables in a Python list format."
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an assistant identifying fruits and vegetables."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=100,
            temperature=0
        )
        fruits_vegetables = response['choices'][0]['message']['content']
        return ast.literal_eval(fruits_vegetables)
    except Exception as e:
        print(f"Error identifying fruits and vegetables: {e}")
        return []

def calculate_fruit_veg_points(ingredients, total_weight):
    try:
        ingredients_list = ast.literal_eval(ingredients)
        fruit_veg_labels = identify_fruit_veg(ingredients_list)

        fruit_veg_weight = 0
        for ingredient in ingredients_list:
            label = ingredient.get('label', '')
            weight = extract_numeric_value(ingredient.get('metric_measure', 0))
            if label in fruit_veg_labels:
                fruit_veg_weight += weight

        # 과일/채소 비율을 100g 기준으로 변환
        fruit_veg_ratio = (fruit_veg_weight / total_weight) * 100 if total_weight > 0 else 0

        if fruit_veg_ratio > 80:
            return 5
        elif fruit_veg_ratio > 60:
            return 2
        elif fruit_veg_ratio > 40:
            return 1
        else:
            return 0
    except Exception as e:
        print(f"Error calculating fruit_veg_points: {e}")
        return 0

def extract_nested_value(data, keys, default=0):
    try:
        for key in keys:
            if isinstance(data, dict):
                data = data.get(key, {})
            else:
                return default
        return extract_numeric_value(data)
    except Exception as e:
        print(f"Error in extract_nested_value: {e}, keys: {keys}, data: {data}")
        return default

def calculate_nutri_score(nutrition_facts, ingredients):
    try:
        if isinstance(nutrition_facts, str):
            nutrition_facts = ast.literal_eval(nutrition_facts)

        # 전체 무게 계산
        total_weight = sum(
            extract_numeric_value(ingredient.get('metric_measure', 0)) 
            for ingredient in ast.literal_eval(ingredients)
        )
        if total_weight == 0:
            print("Warning: Total weight is zero. Skipping calculation.")
            return None

        # 100g 기준으로 성분 정규화
        energy = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Calories']) / total_weight * 100
        saturated_fat = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Fat', 'Amount']) / total_weight * 100
        sugar = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Total Sugars']) / total_weight * 100
        sodium = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Sodium']) / total_weight * 100
        fiber = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Dietary Fiber']) / total_weight * 100
        protein = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Protein']) / total_weight * 100

        # Unfavorable points calculation
        energy_points = min(energy / 80, 800)
        saturated_fat_points = min(saturated_fat / 1, 10)
        sugar_points = min(sugar / 4.5, 45)
        sodium_points = min(sodium / 90, 900)

        unfavorable_points = energy_points + saturated_fat_points + sugar_points + sodium_points

        # Favorable points calculation
        fiber_points = min(fiber / 0.7, 3.5)
        protein_points = min(protein / 1.6, 8.0)
        fruit_veg_points = calculate_fruit_veg_points(ingredients, total_weight)

        favorable_points = fiber_points + protein_points + fruit_veg_points

        # Final Nutri-Score calculation
        total_score = unfavorable_points - favorable_points
        return total_score
    except Exception as e:
        print(f"Error in calculate_nutri_score: {e}, nutrition_facts: {nutrition_facts}")
        return None

def get_nutri_score_grade(score):
    if score <= -1:
        return "A"
    elif score <= 2:
        return "B"
    elif score <= 10:
        return "C"
    elif score <= 18:
        return "D"
    else:
        return "E"

def calculate_scores_with_comparison_no_meals(df, dfh):
    results = []
    output_scores_list = []
    model_output_scores_list = []

    for idx, row in tqdm(df.iterrows(), total=len(df)):
        try:
            output_text = row.get('output', '')
            if output_text:
                matched_row = find_most_similar_row(output_text, dfh)
                if matched_row is not None:
                    nutrition_facts = matched_row['nutrition_facts']
                    ingredients = matched_row['ingredients']
                    output_score = calculate_nutri_score(nutrition_facts, ingredients)
                    output_scores_list.append(output_score)
                else:
                    output_score = None

            model_output_text = row.get('model_output_512', '')
            if model_output_text:
                matched_row = find_most_similar_row(model_output_text, dfh)
                if matched_row is not None:
                    nutrition_facts = matched_row['nutrition_facts']
                    ingredients = matched_row['ingredients']
                    model_output_score = calculate_nutri_score(nutrition_facts, ingredients)
                    model_output_scores_list.append(model_output_score)
                else:
                    model_output_score = None

            results.append({
                'row_index': idx,
                'output_score': output_score,
                'model_output_score': model_output_score
            })

        except Exception as e:
            print(f"Error processing row {idx}: {e}")
            results.append({
                'row_index': idx,
                'output_score': None,
                'model_output_score': None
            })

    final_output_avg = sum(output_scores_list) / len(output_scores_list) if output_scores_list else None
    final_model_output_avg = sum(model_output_scores_list) / len(model_output_scores_list) if model_output_scores_list else None

    print(f"Output Average Nutri-Score: {final_output_avg}")
    print(f"Model Output Average Nutri-Score: {final_model_output_avg}")

    return results

# Execution
filtered_df = df[df['task'] == 'alternative_diet']
results = calculate_scores_with_comparison_no_meals(filtered_df, dfh)

# Print results
for result in results:
    print(result)
# Out:
#   0%|          | 0/246 [00:00<?, ?it/s]
#  64%|██████▍   | 158/246 [03:34<01:46,  1.21s/it]
# Error identifying fruits and vegetables: unterminated string literal (detected at line 1) (<unknown>, line 1)
#  84%|████████▍ | 207/246 [04:37<00:40,  1.03s/it]
# Warning: Total weight is zero. Skipping calculation.
# 100%|██████████| 246/246 [05:27<00:00,  1.33s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 216
#     214 # Execution
#     215 filtered_df = df[df['task'] == 'alternative_diet']
# --> 216 results = calculate_scores_with_comparison_no_meals(filtered_df, dfh)
#     218 # Print results
#     219 for result in results:
#
# Cell In[32], line 207, in calculate_scores_with_comparison_no_meals(df, dfh)
#     200         results.append({
#     201             'row_index': idx,
#     202             'output_score': None,
#     203             'model_output_score': None
#     204         })
#     206 final_output_avg = sum(output_scores_list) / len(output_scores_list) if output_scores_list else None
# --> 207 final_model_output_avg = sum(model_output_scores_list) / len(model_output_scores_list) if model_output_scores_list else None
#     209 print(f"Output Average Nutri-Score: {final_output_avg}")
#     210 print(f"Model Output Average Nutri-Score: {final_model_output_avg}")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'
