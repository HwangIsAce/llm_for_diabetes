# %%
# data load

# %%
import json
import pandas as pd
# 
file_paths = [
    "/data/jaesung/llm_for_diabetes/src/trial3/model_response/model_output_zero_shot.jsonl",
    # "/data/jaesung/llm_for_diabetes/src/trial/CoT_collection/model_response/test_1.jsonl"
]

data = []
for file_path in file_paths:
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))

df = pd.DataFrame(data)

# %%
# medqa

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa1 = df[df['task'] == 'qa1']

# 정답 판별 수행
correct_count = 0
total_count = len(qa1)

for _, row in qa1.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.3667

# %%
# medmcqa

import pandas as pd

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa2 = df[df['task'] == 'qa2']

# 정답 판별 수행
correct_count = 0
total_count = len(qa2)

for _, row in qa2.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.2333

# %%
# pubmedqa

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa3 = df[df['task'] == 'qa3']

# 정답 판별 수행
correct_count = 0
total_count = len(qa3)

for _, row in qa3.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.4000

# %%
# bionli

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
nli = df[df['task'] == 'nli']

# 정답 판별 수행
correct_count = 0
total_count = len(nli)

for _, row in nli.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_128'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.0000

# %%
# ddi

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_relation_correctness(true_relation, model_relation):
    """
    GPT-3.5-turbo를 사용하여 true_relation과 model_relation이 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated relationship extraction model.
    Compare the following two sets of extracted relationships and determine if they contain the same meaning.

    **Correct Relationships**: {true_relation}
    **Model Predicted Relationships**: {model_relation}

    If the model output correctly conveys the same relationships as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
re_df = df[df['task'] == 're']

# 정답 판별 수행 및 메트릭 계산
total_true_positive = 0
total_false_positive = 0
total_false_negative = 0

for _, row in re_df.iterrows():
    true_relations = set(row['output'].split(', '))
    model_relations = set(row['model_output_128'].split(', '))

    true_positive = 0
    false_positive = 0
    false_negative = 0

    # 모델 예측과 정답을 비교하여 TP, FP, FN 계산
    for relation in model_relations:
        if any(check_relation_correctness(relation, correct_rel) for correct_rel in true_relations):
            true_positive += 1
        else:
            false_positive += 1

    for relation in true_relations:
        if not any(check_relation_correctness(relation, predicted_rel) for predicted_rel in model_relations):
            false_negative += 1

    # 누적 합산
    total_true_positive += true_positive
    total_false_positive += false_positive
    total_false_negative += false_negative

# Precision, Recall, F1 계산
precision = total_true_positive / (total_true_positive + total_false_positive) if (total_true_positive + total_false_positive) > 0 else 0
recall = total_true_positive / (total_true_positive + total_false_negative) if (total_true_positive + total_false_negative) > 0 else 0
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# 결과 출력
print(f"GPT-based Total Precision: {precision:.4f}")
print(f"GPT-based Total Recall: {recall:.4f}")
print(f"GPT-based Total F1-Score: {f1:.4f}")
# Out:
# GPT-based Total Precision: 0.1940
# GPT-based Total Recall: 0.3714
# GPT-based Total F1-Score: 0.2549

# %%
# chemdner

from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd

# 데이터프레임 예시 (df_ie 가 주어진 데이터프레임)
ie = df[df['task'] == 'ie']

ie["output"] = ie["output"].str.lower().str.split(", ")
ie["model_output_128"] = ie["model_output_128"].str.lower().str.split(", ")

# Precision, Recall, F1-score 계산 함수
def calculate_scores(y_true, y_pred):
    all_precisions = []
    all_recalls = []
    all_f1s = []
    
    for true_vals, pred_vals in zip(y_true, y_pred):
        true_set = set(true_vals) if isinstance(true_vals, list) else set()
        pred_set = set(pred_vals) if isinstance(pred_vals, list) else set()

        TP = len(true_set & pred_set)  # True Positives (정답과 예측이 일치하는 것)
        FP = len(pred_set - true_set)  # False Positives (예측했지만 정답이 아닌 것)
        FN = len(true_set - pred_set)  # False Negatives (정답이지만 예측하지 못한 것)

        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        all_precisions.append(precision)
        all_recalls.append(recall)
        all_f1s.append(f1)

    return sum(all_precisions) / len(all_precisions), sum(all_recalls) / len(all_recalls), sum(all_f1s) / len(all_f1s)

# Precision, Recall, F1-score 계산
precision, recall, f1 = calculate_scores(ie["output"], ie["model_output_128"])

# 결과 출력
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Precision: 0.0091
# Recall: 0.0100
# F1-score: 0.0095
# /tmp/ipykernel_168992/2471990142.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ie["output"] = ie["output"].str.lower().str.split(", ")
# /tmp/ipykernel_168992/2471990142.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ie["model_output_128"] = ie["model_output_128"].str.lower().str.split(", ")

# %%
import openai
import pandas as pd
import time
from sklearn.metrics import precision_score, recall_score, f1_score

# ✅ OpenAI API Key 설정
openai.api_key = "YOUR_OPENAI_API_KEY"

# ✅ GPT-3.5를 활용하여 정답과 예측을 비교하는 함수
def gpt_judge(true_text, pred_text):
    """
    GPT-3.5를 사용하여 예측값과 정답값이 의미적으로 일치하는지 판단.
    """
    prompt = f"""
    You are an expert in named entity recognition evaluation.
    Compare the gold standard answer with the predicted answer and determine whether they match.

    Gold Standard: {true_text}
    Model Prediction: {pred_text}

    Output "Yes" if both values are identical, including cases where both are empty (None, "", [], or {{}}). Output "No" otherwise.
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "system", "content": "You are a helpful assistant."},
                      {"role": "user", "content": prompt}],
            max_tokens=5,
            temperature=0
        )

        answer = response.choices[0].message.content.strip()
        return 1 if answer.lower() == "yes" else 0

    except Exception as e:
        print(f"[ERROR] OpenAI API call failed: {str(e)}")
        return 0

# ✅ 데이터프레임에서 "ie" 태스크 선택
ie = df[df['task'] == 'ie'].copy()

# ✅ 전처리: 소문자로 변환 후 리스트로 변환
ie["output"] = ie["output"].str.lower().str.split(", ")
ie["model_output_128"] = ie["model_output_128"].str.lower().str.split(", ")

# ✅ GPT-3.5를 이용한 Precision, Recall, F1-score 계산
all_precisions, all_recalls, all_f1s = [], [], []

for idx, (true_vals, pred_vals) in enumerate(zip(ie["output"], ie["model_output_128"])):
    true_set = set(true_vals) if isinstance(true_vals, list) else set()
    pred_set = set(pred_vals) if isinstance(pred_vals, list) else set()

    TP = sum(gpt_judge(t, p) for t in true_set for p in pred_set)  # GPT로 TP 판별
    FP = len(pred_set) - TP  # False Positives
    FN = len(true_set) - TP  # False Negatives

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    all_precisions.append(precision)
    all_recalls.append(recall)
    all_f1s.append(f1)

    # ✅ 진행상황 출력
    print(f"[{idx+1}/{len(ie)}] Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")
    time.sleep(1)  # OpenAI API Rate Limit 방지

# ✅ 최종 성능 계산
final_precision = sum(all_precisions) / len(all_precisions)
final_recall = sum(all_recalls) / len(all_recalls)
final_f1 = sum(all_f1s) / len(all_f1s)

# ✅ 결과 출력
print("\n=== Final Evaluation Scores ===")
print(f"Precision: {final_precision:.4f}")
print(f"Recall: {final_recall:.4f}")
print(f"F1-score: {final_f1:.4f}")
# Out:
# [1/30] Precision: 0.2222, Recall: 0.6667, F1: 0.3333
# [2/30] Precision: 0.3333, Recall: 0.5000, F1: 0.4000
# [3/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [4/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [5/30] Precision: 0.2857, Recall: 0.1667, F1: 0.2105
# [6/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [7/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [8/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [9/30] Precision: 0.5000, Recall: 0.6667, F1: 0.5714
# [10/30] Precision: 0.2500, Recall: 1.0000, F1: 0.4000
# [11/30] Precision: 0.3333, Recall: 0.5000, F1: 0.4000
# [12/30] Precision: 0.0455, Recall: 0.2500, F1: 0.0769
# [13/30] Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# [14/30] Precision: 0.8000, Recall: 0.6667, F1: 0.7273
# [15/30] Precision: 0.6667, Recall: 1.3333, F1: 0.8889
# [16/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [17/30] Precision: 1.0000, Recall: 1.0000, F1: 1.0000
# [18/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [19/30] Precision: 0.0833, Recall: 0.5000, F1: 0.1429
# [20/30] Precision: 0.1667, Recall: 0.2000, F1: 0.1818
# [21/30] Precision: 0.2000, Recall: 0.5000, F1: 0.2857
# [22/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [23/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [24/30] Precision: 0.3333, Recall: 0.5000, F1: 0.4000
# [25/30] Precision: 0.7273, Recall: 0.8000, F1: 0.7619
# [26/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [27/30] Precision: 0.2222, Recall: 0.5000, F1: 0.3077
# [28/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [29/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [30/30] Precision: 0.1429, Recall: 0.1667, F1: 0.1538
#
# === Final Evaluation Scores ===
# Precision: 0.2437
# Recall: 0.3639
# F1-score: 0.2747

# %%
import openai
import pandas as pd
import json
import time
from sklearn.metrics import precision_score, recall_score, f1_score

# ✅ OpenAI API Key 설정
openai.api_key = "YOUR_OPENAI_API_KEY"

# ✅ GPT-4o를 활용하여 정답과 예측을 비교하는 함수
def gpt_judge(true_text, pred_text):
    """
    GPT-4o를 사용하여 예측값과 정답값이 의미적으로 일치하는지 판단.
    """
    prompt = f"""
    You are an expert in named entity recognition evaluation.
    Compare the gold standard entity with the predicted entity.
    
    Gold Standard Entity: "{true_text}"
    Model Predicted Entity: "{pred_text}"
    
    If both entities refer to the same concept, output "Yes".
    If they are different, output "No".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "system", "content": "You are a helpful assistant."},
                      {"role": "user", "content": prompt}],
            max_tokens=5,
            temperature=0
        )

        answer = response.choices[0].message.content.strip()
        return 1 if answer.lower() == "yes" else 0

    except Exception as e:
        print(f"[ERROR] OpenAI API call failed: {str(e)}")
        return 0

# ✅ 데이터프레임에서 "ie" 태스크 선택
ie = df[df['task'] == 'ie'].copy()

# ✅ 전처리 함수: 다양한 형태를 리스트로 변환
def normalize_to_list(value):
    if isinstance(value, str):
        try:
            parsed_value = json.loads(value)  # JSON 문자열 파싱 시도
            if isinstance(parsed_value, list):
                return [v.strip().lower() for v in parsed_value]
            elif isinstance(parsed_value, dict):
                return [v.strip().lower() for v in parsed_value.values()]
            else:
                return [str(parsed_value).strip().lower()]
        except json.JSONDecodeError:
            return [v.strip().lower() for v in value.replace("\n", ",").split(",")]
    elif isinstance(value, dict):
        return [v.strip().lower() for v in value.values()]
    elif isinstance(value, list):
        return [v.strip().lower() for v in value]
    else:
        return [str(value).strip().lower()]

# ✅ 데이터 정리
ie["output"] = ie["output"].apply(normalize_to_list)
ie["model_output_128"] = ie["model_output_128"].apply(normalize_to_list)

# ✅ GPT-4o를 이용한 Precision, Recall, F1-score 계산
all_precisions, all_recalls, all_f1s = [], [], []

for idx, (true_vals, pred_vals) in enumerate(zip(ie["output"], ie["model_output_128"])):
    true_set = set(true_vals)
    pred_set = set(pred_vals)

    # ✅ GPT-4o로 TP(정답 매칭) 판별
    TP = sum(1 for t in true_set if any(gpt_judge(t, p) for p in pred_set))
    FP = len(pred_set) - TP  # False Positives (잘못된 예측)
    FN = len(true_set) - TP  # False Negatives (누락된 정답)

    # ✅ 정밀도, 재현율, F1-score 계산
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    all_precisions.append(precision)
    all_recalls.append(recall)
    all_f1s.append(f1)

    print(f"[{idx+1}/{len(ie)}] Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

# ✅ 최종 성능 출력
print("\n=== Final Evaluation Scores ===")
print(f"Precision: {sum(all_precisions) / len(all_precisions):.4f}")
print(f"Recall: {sum(all_recalls) / len(all_recalls):.4f}")
print(f"F1-score: {sum(all_f1s) / len(all_f1s):.4f}")
# Out:
# [1/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [2/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [3/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [4/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [5/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [6/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [7/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [8/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [9/30] Precision: 0.1250, Recall: 0.3333, F1: 0.1818
# [10/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [11/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [12/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# [13/30] Precision: 0.0000, Recall: 0.0000, F1: 0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 77
#      74 pred_set = set(pred_vals)
#      76 # ✅ GPT-4o로 TP(정답 매칭) 판별
# ---> 77 TP = sum(1 for t in true_set if any(gpt_judge(t, p) for p in pred_set))
#      78 FP = len(pred_set) - TP  # False Positives (잘못된 예측)
#      79 FN = len(true_set) - TP  # False Negatives (누락된 정답)
#
# Cell In[7], line 77, in <genexpr>(.0)
#      74 pred_set = set(pred_vals)
#      76 # ✅ GPT-4o로 TP(정답 매칭) 판별
# ---> 77 TP = sum(1 for t in true_set if any(gpt_judge(t, p) for p in pred_set))
#      78 FP = len(pred_set) - TP  # False Positives (잘못된 예측)
#      79 FN = len(true_set) - TP  # False Negatives (누락된 정답)
#
# Cell In[7], line 77, in <genexpr>(.0)
#      74 pred_set = set(pred_vals)
#      76 # ✅ GPT-4o로 TP(정답 매칭) 판별
# ---> 77 TP = sum(1 for t in true_set if any(gpt_judge(t, p) for p in pred_set))
#      78 FP = len(pred_set) - TP  # False Positives (잘못된 예측)
#      79 FN = len(true_set) - TP  # False Negatives (누락된 정답)
#
# Cell In[7], line 27, in gpt_judge(true_text, pred_text)
#      25 try:
#      26     client = openai.OpenAI()
# ---> 27     response = client.chat.completions.create(
#      28         model="gpt-4o",
#      29         messages=[{"role": "system", "content": "You are a helpful assistant."},
#      30                   {"role": "user", "content": prompt}],
#      31         max_tokens=5,
#      32         temperature=0
#      33     )
#      35     answer = response.choices[0].message.content.strip()
#      36     return 1 if answer.lower() == "yes" else 0
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)
#     876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/openai/_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)
#    1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/openai/_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     964 else:
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/openai/_base_client.py:1003, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1000 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1002 try:
# -> 1003     response = self._client.send(
#    1004         request,
#    1005         stream=stream or self._should_stream_response_body(request=request),
#    1006         **kwargs,
#    1007     )
#    1008 except httpx.TimeoutException as err:
#    1009     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# summarization

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

summarization = df[df['task'] == 'summarization']
results = []

for _, row in summarization.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output_1024'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    print(f"Evaluation result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Evaluation result:
# - Coherence: 4.0
#   - The model's response captures many essential elements of the doctor-patient dialogue and presents them logically. However, it omits some details that would provide a fuller picture, such as the absence of fever, cough, or weight loss, and the patient's diabetes status.
#
# - Completeness: 3.5
#   - While the summary includes key points like the symptoms, test results, diagnosis, and treatment, it lacks some critical context regarding the absence of certain symptoms and the patient's diabetes. The ending is abrupt and misses out on the follow-up and advice given by the doctor.
#
# - Naturalness: 4.5
#   - The response is quite fluent and maintains a human-like dialogue format. It follows the conversational exchange style between the doctor and the patient well, retaining the questions and answers naturally.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   The model's response logically aligns with and accurately follows the sequence of events as presented in the given input conversation. It clearly summarizes the main points discussed between the doctor and the patient, maintaining logical progression and accuracy with the input context.
#
# - Completeness: 4.5
#   The model's response sufficiently answers and summarizes the main points of the conversation, closely matching the information in the input and the true answer. However, it omits specific details such as the age and specific health conditions (nonhypertensive, nondiabetic) of the patient provided in the true answer. Including these details would have provided a more comprehensive summary.
#
# - Naturalness: 4.8
#   The model's response is generally fluent and human-like. It presents the information in a clear and concise manner, maintaining a professional tone suitable for a medical setting. There are no awkward phrasings or grammar issues, which contributes to its naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#
# The model's response captures the essence of the conversation between the doctor and the patient by summarizing the key points discussed, such as the patient's medical history, his mother's medical conditions, and the suggested follow-ups. However, the response does not accurately reflect certain details. For instance, it incorrectly states that there is a diagnosis when the doctor's conclusion was that it's unlikely the son has systemic mastocytosis but tests are needed.
#
# - Completeness: 2.5
#
# While the model's response touches on the major components of the conversation, it lacks depth and specificity compared to the true answer. It doesn't include specific details like symptoms experienced by the mother or the exact details of the diagnostic work-up. It's also missing the specific recommendation for a follow-up appointment and the tests the doctor plans to conduct.
#
# - Naturalness: 4.5
#
# The model's response is mostly fluent and human-like. It reads clearly and logically, following a typical structure one might find in clinical notes. However, its overly general nature makes it slightly less plausible as an actual medical summary, striking a more generic than a detailed note that one might expect from a medical conversation.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Given the model's response, "<|end_of_text|>", here is the evaluation based on the provided metrics:
#
# - **Coherence: 1.0**
#   - The model's response is blank, providing no logical alignment with the context provided in the input. There is no reflection of understanding or connection to the input dialogue.
#
# - **Completeness: 1.0**
#   - The model's response fails to answer any aspect of the context or question. It offers no information or summary of the patient's diagnosis, treatment, or outcome.
#
# - **Naturalness: 1.0**
#   - A blank response does not exhibit any characteristics of fluent or human-like language. There is no text to assess for language naturalness.
#
# Overall, the model's output does not meet any of the criteria for coherence, completeness, or naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   - The model's response logically aligns with the context provided in the input. It is consistent with the details of the patient's medical history and the sequence of events described by the doctor and patient.
#
# - Completeness: 4.8
#   - The model's response sufficiently answers the question by summarizing the key details of the patient's condition, history, and treatments. It captures most of the significant points, though minor details such as "Figure" and some narrative flow may be missing, affecting the overall detail completeness slightly.
#
# - Naturalness: 4.5
#   - The model's response is fluent and mostly human-like. However, the structured format with bullet points makes it slightly less conversational than it could be. Adding more connective elements and variations in sentence structure could improve the natural feel.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.8
#   - The model's response is highly coherent, accurately reflecting the context given in the input. It doesn’t introduce any information that contradicts the context but aligns well with the details shared in the conversation.
#
# - Completeness: 4.5
#   - The response provides a comprehensive summary of the patient’s medical condition and history as discussed in the input. However, it misses minor details such as the patient’s relocation to Sweden or certain symptoms like perioral movements and specified psychiatric issues treated with aripiprazole pre-dating its administration. These omissions slightly impact the completeness.
#
# - Naturalness: 4.6
#   - The response is generally fluent and closely mirrors natural speech patterns. However, it reads more like a clinical summary than a human conversation, making it slightly less natural when considering the informal and interactive nature of the original dialogue.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response aligns well with the context provided in the input. It maintains the sequence and reasoning from the input dialogue between the doctor and patient. However, it does not fully incorporate the background details about the patient's other medical conditions like type 2 diabetes, dyslipidemia, and hypertension that were mentioned in the true answer.
#
# - Completeness: 3.5
#   The response captures many important details about the patient's case, such as the treatment regimen, outcomes, and biopsy results. However, it misses some background information and the interpretation process that led to the diagnosis, as found in the true answer's comprehensive description.
#
# - Naturalness: 4.8
#   The model's response is highly fluent and reads naturally, simulating a real conversation between a doctor and a patient. The conversational tone and the structure of the dialogue are maintained effectively. However, the lack of any introductory context can slightly impact the naturalness when compared to a more narrative style summary.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# It seems the model's response is missing entirely ("<|end_of_text|>"), indicating no response was generated. Based on the absence of a response, here's how I would rate each metric:
#
# - **Coherence: 1.0**
#   - Without a response, there is no logical alignment to assess.
#
# - **Completeness: 1.0**
#   - The model failed to provide any information or answer, making it entirely incomplete.
#
# - **Naturalness: 1.0**
#   - Since there is no response, it cannot be evaluated for fluency or a human-like quality.
#
# In this case, the model didn't provide any output, indicating a significant failure in generating a relevant and coherent response.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#   - The model's response outlines a structured clinical note format rather than directly addressing the specifics from the doctor-patient interaction. While the suggested structure is logically sound for clinical documentation, it doesn't strictly align with the context provided in the conversation.
#
# - Completeness: 2.0
#   - The model's response does not directly answer the question or summarize the doctor-patient dialogue. Instead, it offers a generic template for writing a clinical note without addressing specific details such as the patient's demographic information or the diagnostic findings discussed in the conversation.
#
# - Naturalness: 4.0
#   - The response is fluent and uses appropriate medical terminology. However, it does not address the doctor-patient dialogue in a conversational or human-like manner, as it delivers instructions for how to write a clinical note rather than providing a direct answer or summary.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# - Completeness: 2.0
# - Naturalness: 5.0
#
# **Explanation**:
# - **Coherence**: The model's response logically aligns with the context provided by the input. It follows the same concluding remarks made by the doctor regarding future follow-ups and open communication. However, it doesn't address all aspects of the conversation, specifically the medical complexities involved.
#
# - **Completeness**: The model's response is not complete in terms of providing a summary or sufficient detail about the patient's medical history and conditions, which are comprehensively outlined in the input and the true answer. The response merely repeats a small procedural part of the original interaction.
#
# - **Naturalness**: The response sounds fluent and human-like. The language is clear and appropriate for medical settings, making it easily understandable for a patient.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response generally aligns well with the conversation context, accurately recounting the main points. However, it incorrectly frames certain details, like the purpose of the conversation (it was not solely about planning the cataract surgery but involved a follow-up, among other details). Nonetheless, it does capture most specifics related to the medical history and current subject.
#
# - Completeness: 4.0
#   - The model's response covers almost all the relevant points mentioned in the input dialogue, including medical history details and the medical plan going forward (insulin adjustment and follow-up). However, it omits the specific blood glucose range noted during the 24-hour blood glucose curve and doesn't explicitly mention the patient's weight like in the true answer, which may affect clinical decisions.
#
# - Naturalness: 4.8
#   - The model's summary is written in a fluent and human-like manner, presenting the information in a coherent sequence that mirrors a typical clinical note. It feels well-structured and uses appropriate medical terminology confidently. However, the repetition at the beginning about summarizing the conversation might feel slightly awkward.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response closely follows the dialogue from the input; however, it is abruptly cut off during the doctor's response about the test results showing raised biochemical markers of inflammation. Despite this, the response logically aligns with the input context provided.
#
# - Completeness: 3.0
#
# While the model captures many key elements from the conversation, it does not provide a full summary of important points like the outcome of the antibiotic treatment and the scheduled follow-up. The response is incomplete as it ends abruptly.
#
# - Naturalness: 4.8
#
# The part of the model's response that is present maintains a fluent, human-like dialogue similar to a real doctor-patient interaction. The language used is natural and clear, mirroring the tone and flow of a genuine conversation until it is truncated.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
#   - The model's response is essentially empty, providing no alignment with the context provided in the input dialogue.
#
# - Completeness: 1.0
#   - The model's response completely fails to answer any part of the question or statement, as it lacks any content.
#
# - Naturalness: 1.0
#   - With no response provided, the model does not demonstrate fluency or a human-like tone.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Since the model's response is empty and does not provide any information, it must be rated poorly in all aspects.
#
# - **Coherence: 1.0**
#   - The model's response does not logically align with the context as it does not provide any response at all.
#
# - **Completeness: 1.0**
#   - The response is non-existent, meaning it does not answer the question or provide any information from the context.
#
# - **Naturalness: 1.0**
#   - An empty response cannot be considered fluent or human-like, as no text is provided to evaluate for naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Certainly, let's evaluate the model's response according to the provided metrics.
#
# 1. **Coherence**: 4.5
#    - The model's response logically aligns with the context given in the input. It correctly identifies the patient's symptoms and correlates them with the diagnosis of burning mouth syndrome (BMS). Furthermore, it accurately recounts the proposed treatment plan by the doctor and its evaluation methods. However, the response could mention more specific patient details such as the patient's age and medication dosage which were present in the true answer, but this omission is minor with respect to Coherence.
#
# 2. **Completeness**: 4.0
#    - The model's response covers most of the essential aspects of the diagnosis and treatment plan discussed between the doctor and the patient. It describes the symptoms, diagnosis, and the treatment procedure, and mentions the evaluation methods. However, it lacks detail regarding the patient's specific characteristics, such as age and ethnicity, which are mentioned in the true answer. While these details may not be critical to the general understanding of the treatment, they contribute to the completeness of the medical case context.
#
# 3. **Naturalness**: 4.7
#    - The language used in the model's response is fluent and professional, in line with how a medical summary might be articulated by a healthcare professional. The response maintains a formal and informative tone consistent with the patterns expected in medical settings. However, the style is somewhat more analytical and repetitive than conversational, which slightly affects its naturalness if considering a more typical human dialogue format.
#
# Overall, the model provides a coherent and largely complete summary with high naturalness for a professional context but could integrate a few more specifics for enhanced completeness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# - Completeness: 4.0
# - Naturalness: 5.0
#
# **Coherence**: The model's response is generally coherent and aligns well with the context provided in the input, capturing the key details about the patient's condition and medical history. However, it incorrectly states the patient's age as 58 instead of 71, which slightly lessens its coherence.
#
# **Completeness**: The response is largely complete, covering major points like the patient's medical history, medications, and the doctor's recommendation for a biopsy. However, it lacks some specific details mentioned in the true answer, such as the exact location and color description of the nodular formation, and the fact that the patient was referred in July 2019.
#
# **Naturalness**: The response sounds fluent and human-like, using clear and natural language to convey information, which warrants a high score in naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#   - The model's response does not directly align with the input context. It appears to expect structured medical information that was not explicitly provided in the input. This discrepancy affects the logical coherence of the response.
#
# - Completeness: 1.0
#   - The model's response is incomplete. It fails to answer the question posed by the patient, which concerns the next steps in their treatment. Instead, it provides a set of information fields without filling them out with the relevant details from the input context.
#
# - Naturalness: 1.0
#   - The response lacks naturalness. It does not engage with the conversational context or provide human-like elaborations. Instead, it presents a template that doesn't convey fluency or natural conversational flow.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# To evaluate the QA model's response using the requested metrics, I'll take into account the coherence, completeness, and fluency of the model's response regarding the given input:
#
# 1. **Coherence**: The model's response does not exist, as it consists only of numbers from 1 to 342, and does not logically align with the context provided in the input. There's no connection with the input context or any relevant information provided in the model's output.
#    - Coherence: 1.0
#
# 2. **Completeness**: There is no actual content provided in the model's response. It does not answer the question or add any relevant information based on the provided context.
#    - Completeness: 1.0
#
# 3. **Naturalness**: Numbers listed sequentially do not constitute a human-like, natural response. There is no attempt at generating natural language in the model's response.
#    - Naturalness: 1.0
#
# Given the lack of any coherent, complete, or natural response from the model, the lowest possible scores are appropriate for each metric.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Based on the metrics provided, here is the evaluation of the model's response:
#
# - Coherence: 1.0
#   - The model's response "<|end_of_text|>" does not logically align with any context provided in the input. It appears to terminate the conversation without offering any coherent continuation or conclusion.
#
# - Completeness: 1.0
#   - The model's response is completely missing and does not provide any answer to the question or closure to the scenario described in the input. It fails to address any of the information that should be included based on the input's context and the true answer.
#
# - Naturalness: 1.0
#   - Since the model's response is essentially empty, it lacks any fluency or human-like quality. There is no text to assess for naturalness, so it cannot be considered a realistic or human-like response.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# The model's response is effectively empty as it did not generate any answer. Therefore, the evaluation metrics would be as follows:
#
# - **Coherence: 1.0**
#   - Since the model did not produce any response, there is no content to assess in terms of logical alignment with the context.
#
# - **Completeness: 1.0**
#   - The response fails to address the patient's question about prevention, providing no information that could be considered an answer.
#
# - **Naturalness: 1.0**
#   - An empty response cannot be evaluated for fluency or human-like qualities.
#
# The lack of response indicates a failure across all evaluation metrics.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#   The model's response does not maintain coherence with the provided context. It gives a generic description of a clinical note without reflecting specific details from the doctor-patient conversation. It fails to accurately relay the sequence of events and important details discussed in the dialogue.
#
# - Completeness: 1.5
#   The response lacks completeness as it does not offer specific information about the patient, medical history, or treatment plan related to the case at hand. It does not summarize or reference crucial details from the dialogue such as the patient's condition progression, treatments administered, or rehabilitation details.
#
# - Naturalness: 3.0
#   While the language used is grammatically correct and formal, it lacks the detail and specificity expected in a clinical note. The summary sounds more like a report of a standard procedure rather than a unique case, thus reducing its naturalness and applicability to the actual conversation.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
# - Completeness: 2.0
# - Naturalness: 4.5
#
# **Explanation:**
#
# - **Coherence (3.5)**: The model’s response accurately captures the structure of the doctor-patient conversation, noting that the discussion includes patient demographics, medical history, symptoms, examination findings, and treatment plans. However, it does not directly tie these elements to specific details from the conversation, making the response somewhat general in context.
#
# - **Completeness (2.0)**: The model fails to provide detailed content from the conversation or the true answer, such as specific medical conditions, examination findings, and treatment plans. It only generally describes the type of information included in the conversation, lacking the depth and specifics required for completeness.
#
# - **Naturalness (4.5)**: The response is fluent and human-like, employing a clear and concise summarization style. It reads smoothly and utilizes appropriate medical terminology, which enhances its naturalness. However, due to its general nature, it might come across as formulaic rather than tailored or insightful.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
#   - The model's response is empty, so it does not provide any information or logical alignment with the context provided in the input.
#
# - Completeness: 1.0
#   - The model fails to provide any answer, let alone a complete response to the question. It does not summarize or address any part of the scenario described.
#
# - Naturalness: 1.0
#   - Since the model's response is empty, it does not provide any content to assess for fluency or human-like quality.
#
# Overall, the model’s response is entirely missing, leading to the lowest score in all evaluation metrics.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is generally coherent with the input. It accurately captures the sequence of events and significant medical details mentioned in the doctor-patient interaction. However, it does not address all the elements from the context that could enhance understanding, such as references to the patient's past medical history with autoimmune disorders or details regarding the surgery procedure and its implications.
#
# - Completeness: 3.0
#
# The model's response is a concise summary but lacks several important details that provide a complete picture of the patient’s condition and the reasoning behind her treatment plan. Details such as the patient's history with autoimmune disorders, the reason for discontinuing oral contraceptives, and specifics about the surgery are omitted. These omissions reduce the completeness of the summary in relaying all necessary medical context.
#
# - Naturalness: 4.7
#
# The model's response is fluent and uses clinical language appropriately. It sounds structured and human-like, akin to a typical clinical note written by a healthcare professional. It maintains a logical sequence and uses precise medical terms effectively, contributing to its naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response is mostly coherent with the context provided. It follows the chronological order and captures the key events discussed in the conversation. However, there are minor deviations, such as using "You" instead of more formal language like "The patient" or "He," which might reduce the coherence slightly in a clinical note.
#
# - Completeness: 4.0
#   The model's response covers most of the key points from the conversation but lacks certain details present in the true answer, such as the specific intervals of treatment and the description of the medication used. There's also a lack of patient-specific details like age and medical history (type II diabetic), which would be crucial in a clinical note.
#
# - Naturalness: 4.0
#   The structure of the response is clear and straightforward, aligning with a clinical note format. However, it lacks the professional tone and detailed medical terminology often seen in clinical documents, possibly making it less natural for a medical practitioner reviewing the note.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# It appears there was no model response provided. Given this scenario, I can't evaluate the model's output based on coherence, completeness, or naturalness because there is no response to judge. Therefore, I'll have to rate all the metrics as follows:
#
# - Coherence: 1.0 (No response to compare for logical alignment)
# - Completeness: 1.0 (No response provided, so it cannot be complete)
# - Naturalness: 1.0 (No response provided, so it cannot be assessed for fluency or human-likeness)
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# The model's response is missing, and as such, it cannot be evaluated against the metrics provided. Below is an evaluation based on the absence of input:
#
# - **Coherence**: 1.0
#   There is no response to evaluate logic or alignment with the context.
#
# - **Completeness**: 1.0
#   The model has not provided a response, so it does not answer the question at all.
#
# - **Naturalness**: 1.0
#   A response is necessary to evaluate fluency and the human-like quality of language usage.
#
# Overall, since there's no output from the model, each metric scores the lowest possible, reflecting the lack of input to assess.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# The model's response is empty, denoted by `<|end_of_text|>`. This impacts all the metrics adversely.
#
# - **Coherence: 1.0**
#   - The response doesn't align with the context as it is completely absent. There is no logical flow or content to evaluate.
#
# - **Completeness: 1.0**
#   - The model fails to answer the question or provide any information, resulting in a lack of completeness. It doesn't offer any response to the input scenario.
#
# - **Naturalness: 1.0**
#   - An absent response cannot be evaluated for fluency or human-like qualities. There is nothing to assess in terms of language use.
#
# Overall, the absence of a response leads to the lowest possible scores across all metrics.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#   - The model's response logically aligns with the context provided in the input, summarizing the key points from the doctor-patient conversation clearly. However, it assumes certain details such as the patient's name and specific numerical age that were not mentioned in the original conversation context. This slightly affects the coherence score, as it introduces data that wasn't present in the initial input.
#
# - Completeness: 3.5
#   - The model captures many critical details, such as the patient's weight concerns, familial history of obesity-related conditions, eating habits, and the need for a care plan involving the parents. However, it misses some specific details from the true answer, such as the patient's original birth weight and height, the exact average screen time, and additional context related to the patient's neuropsychiatric history and development. These omissions slightly reduce the completeness of the response.
#
# - Naturalness: 4.5
#   - The model's response is predominantly natural and reads fluently, resembling a structured clinical note. The use of straightforward and professional language contributes to a high naturalness score. However, there could be a slight improvement in stylistic fluency if domain-specific jargon were further simplified where possible.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
# - Completeness: 1.0
# - Naturalness: 1.0
#
# **Evaluation:**
#
# 1. **Coherence (1.0):** The model's response shows a lack of coherence, as it repeats the same statements without addressing the content of the input. It fails to capture or logically align with the conversation between the doctor and patient regarding the patient's condition and the reimbursement system.
#
# 2. **Completeness (1.0):** The response does not adequately answer or summarize the context given in the input. It consistently repeats a statement about the lack of specific details without offering any substantive information about the situation or the discussions highlighted in the scenario.
#
# 3. **Naturalness (1.0):** The model's response is highly unnatural due to excessive repetition of a poorly constructed sentence. It reads like a malfunctioning output rather than a fluent, human-like response.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       2.626667
# Completeness    2.143333
# Naturalness     2.800000
# BLEURT          0.328360
# BERTScore_F1    0.396047
# dtype: float64

# %%
# generation

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

generation = df[df['task'] == 'generation']
results = []

for _, row in generation.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output_1024'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    print(f"Evaluation result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Evaluation result:
# - Coherence: 1.0
#   The model's response fails to provide any coherent treatment plan or guidance based on the input context. Instead, it repeatedly reiterates the symptoms and advises to consult a doctor without engaging with the details presented.
#
# - Completeness: 1.0
#   The response does not formulate a treatment plan nor provide guidance to address the root cause of the health issues, which was the primary request in the input. It merely repeats the information from the question without adding value or steps forward.
#
# - Naturalness: 1.0
#   The response lacks fluency and human-like quality due to the excessive repetition of phrases and sentences without any meaningful progression or variation. This repetitive pattern makes it sound mechanical and unnatural.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
# - Completeness: 1.0
# - Naturalness: 1.0
#
# The model's response unfortunately did not provide any meaningful answer to the user's question. It consists entirely of tags that do not align logically with the input context, offer no completeness in addressing the question, and do not demonstrate any natural, conversational style.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#
# The model's response exhibits some coherence with the user's input by identifying an infection and suggesting a visit to a doctor for further examination. However, it inaccurately focuses primarily on tonsillitis, which is not directly indicated by the symptoms described. The user's symptoms suggest localized issues with the tongue and surrounding area rather than the tonsils.
#
# - Completeness: 2.0
#
# The response is incomplete as it primarily suggests tonsillitis, missing other potential causes of the symptoms such as inflamed taste buds, canker sores, herpes, or oral thrush. It fails to consider the specific location of the symptoms on the tongue and to ask about additional factors that could help refine the diagnosis (e.g., recent injuries, dietary habits, or systemic conditions).
#
# - Naturalness: 4.5
#
# The model's response is quite natural and fluent. It uses empathetic and professional language, providing general advice effectively. However, it could include more specific and varied parts of speech related to the user's symptoms to appear more tailored and knowledgeable.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#
#   The model’s response is coherent with the context and aligns logically with the scenario where consulting an obstetrician is a relevant step. However, it lacks specific details regarding the medical conditions mentioned in the input.
#
# - Completeness: 3.0
#
#   While the model advises consulting an obstetrician, it doesn't specifically address the details mentioned in the input, such as AFI level, cephalic presentation, fetal heartbeat, and potential criteria for induction. The response lacks specific medical insights provided in the true answer to fully answer the question.
#
# - Naturalness: 4.5
#
#   The model's response is fluent and human-like. It communicates politely and professionally as one would expect in a medical context. The language is clear and appropriate for a healthcare setting.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Given the model's response is empty, we need to evaluate based on the absence of information:
#
# - **Coherence: 1.0**
#   Since there is no response, there is nothing to evaluate in terms of alignment with the context.
#
# - **Completeness: 1.0**
#   The question in the input is not answered at all, resulting in a score of 1.0 for completeness.
#
# - **Naturalness: 1.0**
#   With the absence of a response, no assessment of fluency or human-like quality can be made.
#
# Overall, the model substantially fails to provide any information or answer the question posed in the input.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# - Completeness: 4.0
# - Naturalness: 4.5
#
# Explanation:
# - **Coherence**: The model's response logically aligns with the input, directly addressing each of the user's main concerns: depression, heart pain, and issues surrounding masturbation. It suggests consulting professionals for both mental and physical symptoms, providing a clear and logical path forward.
# - **Completeness**: The response sufficiently answers the questions posed in the input by addressing depression, heart pain, and concerns about masturbation. However, it could be more empathetic and personalized to the user's specific situation, as the true answer attempts to provide a motivational perspective and a wider philosophical context.
# - **Naturalness**: The response is fluent and human-like, using language that is clear, professional, and generally supportive. However, incorporating a more empathetic tone might improve its naturalness further, given the personal and sensitive nature of the issue.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# The model's response is coherent and logically aligns with the context provided. It identifies that the symptoms could be due to various causes, including infections and hormonal changes. It recommends seeing a doctor for proper diagnosis, which is a reasonable suggestion given the symptoms described.
#
# - Completeness: 3.5
# While the response addresses the possibility of hormonal imbalance and other general causes for vaginal discharge, it does not definitively rule out hormonal imbalance like the true answer does. It also misses some specific recommendations mentioned in the true answer, such as checking for a urinary infection and considering the patient's sugar levels. However, it provides general advice and suggests consulting a doctor, which covers some ground.
#
# - Naturalness: 4.5
# The model's response is fluent and sounds human-like. The language is polite and empathetic, which is appropriate for addressing a medical concern. The structure and wording are similar to how a healthcare professional might communicate in a general advice setting.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# - Completeness: 4.0
# - Naturalness: 5.0
#
# The model's response is generally well-structured and maintains coherence by addressing the concerns regarding the combined pill, alternative treatments, and long-term effects of Spironolactone. However, it did not address specific questions about Tetracycline and potential resistance fully, which impacts completeness slightly. The language used is natural and empathetic, aligning well with the human-like tone expected in such consultations.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
# The model's response logically aligns with the context provided; it summarizes the patient's concerns, medical history, and addresses queries about anesthesia and natural remedies. However, it does not directly mention the patient's reluctance to surgery, which affects coherence in addressing her concerns.
#
# - Completeness: 3.5
# The response partially answers the patient's questions but lacks specificity. It discusses anesthesia options but doesn't definitively state that general anesthesia will be used, and it leaves potential treatment plans unclear. The response also only generally advises on natural remedies without providing detailed guidance on lemons and olive oil's effects.
#
# - Naturalness: 4.5
# The response is generally fluent and human-like. It uses medical terminology appropriately while maintaining clarity and readability. The language is professional and empathetic, though slightly repetitive at times, especially regarding consulting healthcare providers.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response does well in logically aligning with the context provided. It correctly identifies the condition mentioned in the report, explains the role of cavernosal arteries, and suggests possible causes for the issue.
#
# - Completeness: 4.2
#   - The model's response sufficiently answers the question by explaining the details of the report and suggesting lifestyle changes. However, it could have been more complete by asking additional follow-up questions, similar to the true answer, which might help in further diagnosis.
#
# - Naturalness: 4.8
#   - The response is fluent and human-like. The tone is polite and reassuring, suitable for a medical professional addressing a patient's concerns. It reads smoothly and provides information in a conversational manner.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response logically aligns with the input request. It explains why a ketogenic diet might not be advisable in the long term and lists several potential negative effects, such as increased risks of heart disease, kidney stones, liver damage, bone fractures, and cancer. However, it doesn't address the potential for ketosis in diabetic patients or mention diarrhea, which could have been additional relevant points.
#
# - Completeness: 4.0
#
# The response covers several key points about the negative effects of a long-term ketogenic diet, supporting the notion that it may not be safe for prolonged use. However, it could be more comprehensive by acknowledging that there are also varying opinions and studies regarding the safety and effectiveness of long-term ketogenic diets, as noted in the true answer. The model should also mention that professional guidance is advised for such dietary plans.
#
# - Naturalness: 4.8
#
# The model's response is quite fluent and well-structured, with appropriate language use and sentence construction. It sounds professional and human-like, suitable for explaining a health-related topic. Slight deductions are due to somewhat repetitive use of "the high-fat content of the diet," which could have been phrased more naturally.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response logically aligns with the context provided in the input. It acknowledges the use of Argyreia speciosa in treating gonorrhea and syphilis and provides a coherent explanation of traditional preparation techniques. However, it slightly deviates from the true answer's specifics in preparation methods.
#
# - Completeness: 4.0
#   - The model provides a detailed response regarding the traditional preparation methods for using Argyreia speciosa. It covers both tea and tincture preparations, but it could be more complete by mentioning alternative methods such as direct application of leaves or seed decoctions as highlighted in the true answer.
#
# - Naturalness: 4.7
#   - The response is fluent and human-like, maintaining a friendly and informative tone suitable for a consultation scenario. It includes proper salutations, contextual advice, and a closing statement, enhancing the naturalness of the interaction.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context, accurately addressing the issues of respiratory and gastrointestinal symptoms.
#
# - Completeness: 3.5
#   While the response covers a broad understanding of the symptoms and makes general suggestions, it lacks the specificity and targeted treatment advice found in the true answer. It does not mention specific medications or detailed follow-up questions that could further guide the patient.
#
# - Naturalness: 4.7
#   The model's response is fluent and maintains a professional tone typical of a healthcare professional. There's a logical flow, and it reads in a natural, human-like manner.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Since the model's response is missing, we can evaluate it with the lowest possible scores for all the metrics, as there is no content to assess:
#
# - Coherence: 1.0
# - Completeness: 1.0
# - Naturalness: 1.0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#   - The model's response is mostly coherent and logically aligns with the context provided. It emphasizes treatment options like chemotherapy and radiation therapy, consistent with common approaches for stage 4 cancer with metastasis. However, it misrepresents prognosis by stating it is generally good, which may not be accurate for stage 4 cancer.
#
# - Completeness: 3.5
#   - The response outlines several typical treatment options effectively, such as chemotherapy, radiation therapy, and other therapies like hormonal and targeted therapy. However, it lacks specific guidance and doesn't consider some factors mentioned in the true answer (e.g., patient's age, general health, contraindications for certain treatments). It also doesn't address the non-viability of surgery or the ineffectiveness of hormonal therapy due to the removal of the uterus.
#
# - Naturalness: 4.5
#   - The response is quite fluent and human-like, with a caring tone and clear language. It manages to provide reassurance and guidance in a manner similar to what might be expected from a human healthcare provider.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response logically aligns with the context provided in the input; it addresses the symptoms and potential condition (ulnar neuropathy) described by the user. However, it could have acknowledged the normal test results more explicitly.
#
# - Completeness: 4.0
#   - The model's response provides a general overview of potential treatments and mentions long-term effects but lacks specific advice or alternative explanations or tests that could be explored (like blood tests for deficiencies). It does suggest seeking further medical help, which is appropriate.
#
# - Naturalness: 4.5
#   - The response is fluent and human-like, with a tone that is sympathetic and reassuring. It uses natural language and provides a cohesive answer to the user's concerns. However, it could be slightly more detailed in medical advice to improve naturalness in a professional medical context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
#   The model's response starts to address the issue by asking relevant questions that could be related to changes causing the symptoms, but it lacks direct suggestions or explanations to connect with the specific problem of excessive sweating and stinky feet. The repetition of similar questions dilutes the relevance and cohesiveness.
#
# - Completeness: 1.0
#   The response fails to provide a direct answer or any recommendations for addressing the issue described. It only asks a series of questions repeatedly without offering insights or solutions, leaving the main problem unresolved.
#
# - Naturalness: 1.5
#   While the language used in the model's response is fluent, the excessive repetition of the same questions makes it sound unnatural and robotic. A human conversation would not involve recycling the same questions to such an extent.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
#   The model's response does not logically align with the context provided in the input. It repeats part of the issue (the dull ache) but omits significant details, like the enlarged vein and relief after sitting, and doesn't directly address the patient's situation.
#
# - Completeness: 1.0
#   The response fails to provide a diagnosis, suggestions, or further questions to help assess the situation like the true answer does. It doesn't sufficiently address the patient's concern about the ache and the vein.
#
# - Naturalness: 2.0
#   While the language in the response is fluent, it lacks a human-like engagement or empathy that could assure the patient. It merely restates the issue without genuine interaction or fluid dialogue expected in a medical consultation context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided in the input. It acknowledges the concerns related to flying during pregnancy and provides relevant information, although it doesn't explicitly address the concern about high thyroid levels, which could have been considered for better alignment.
#
# - Completeness: 3.5
#   While the model's response covers general guidelines for flying during pregnancy, it misses specific advice tailored to the individual's circumstances, such as the mention of thyroid levels and not highlighting the importance of checking with healthcare professionals for clearance to fly due to possible high-risk factors.
#
# - Naturalness: 4.7
#   The language used in the model's response is fluent and sounds human-like. It uses a friendly and supportive tone typical of a patient-doctor interaction, with clear and easy-to-understand advice.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Based on the provided input and the model's response:
#
# - **Coherence: 1.0**
#   The model's response does not provide any content or information that aligns with the input. Therefore, it shows no logical connection with the context provided.
#
# - **Completeness: 1.0**
#   The model's response is entirely absent (represented by <|end_of_text|>), meaning it fails to address or answer the question at all.
#
# - **Naturalness: 1.0**
#   Since there is no text output from the model, it cannot be evaluated for fluency or human-likeness.
#
# Overall, the model did not provide any response, which leads to the lowest possible score for each metric.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Based on the provided metrics and the fact that the model's response is missing, here is the evaluation:
#
# - **Coherence: 1.0**
#   The response is missing, so we cannot determine if the model's response logically aligns with the context provided.
#
# - **Completeness: 1.0**
#   Since there is no content, the model does not provide any answer to the question and therefore does not meet the requirement for completeness.
#
# - **Naturalness: 1.0**
#   Without a response, the model cannot be evaluated for fluency or if it sounds human-like.
#
# Overall, due to the absence of the model's response, all metrics receive the lowest possible score.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response logically aligns with the context provided in the input. It accurately acknowledges the persistence of symptoms following a cold and suggests a reasonable course of action, such as consulting a doctor if the symptoms persist. However, it slightly lacks specificity regarding potential causes of the ringing noise and their connection to the patient's described situation.
#
# - Completeness: 3.0
#   - The response provides general advice about residual symptoms post-cold, but it does not fully address the specific question about the nature and duration of the ringing noise. It misses discussing possible causes or offering time frames for when the noise might resolve. Additionally, it does not include any follow-up questions that could help clarify the situation further, as seen in the true answer.
#
# - Naturalness: 4.8
#   - The model's response is fluently written and sounds human-like. The language used is professional, polite, and non-technical, making it accessible to the patient. The tone is supportive and empathetic, which is suitable for a medical context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 1.0
# - Completeness: 1.0
# - Naturalness: 1.0
#
# Explanation:
# - **Coherence**: The model's response is completely absent, hence it does not logically align with or address the context provided in the input at all.
# - **Completeness**: Since there is no response from the model, the question remains unanswered.
# - **Naturalness**: There was no text generated, so it cannot be evaluated for fluency or a human-like tone.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is generally coherent and aligns well with the context of the questions asked. It provides a logical explanation for each query, although it misses some detailed distinctions such as the specific economic considerations highlighted in the true answer.
#
# - Completeness: 4.0
#   - The response addresses most of the questions quite thoroughly but lacks specific details mentioned in the true answer. For example, it does not address the economic factors or the exact circumstances under which a pancreas transplant might be preferred over an islet cell transplant.
#
# - Naturalness: 5.0
#   - The model's response is fluent and human-like. It uses appropriate medical terminology and sounds like a response from a seasoned medical professional.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.5**
#   The model's response is largely coherent with the input context. It accurately restates the user's symptoms and timeline, and it logically addresses potential causes and related concerns. The advice aligns with the symptoms described, although it doesn't mention the picture, which may provide additional context.
#
# - **Completeness: 4.2**
#   The model provides a comprehensive discussion about the user's symptoms, suggesting possible causes related to diabetes and the cat scratch. It advises on interim remedies and the importance of consulting a healthcare professional. However, it could have been more complete by explicitly addressing the stratification of symptoms based on the picture or offering more detailed home care tips.
#
# - **Naturalness: 4.8**
#   The response is articulated in a fluent and human-like manner. It uses language that is clear and reads like advice from a professional, maintaining a conversational and empathetic tone suitable for a medical consultation.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.5**
#   The model's response is logically coherent with the input question. It addresses the context of high vacuolated neutrophil results and the possibility of infections not showing symptoms immediately. It also considers other potential causes for the result, such as genetic disorders, aligning with the input's inquiry.
#
# - **Completeness: 4.0**
#   The model provides a well-rounded answer by discussing the possibility of non-apparent infections and other causes of high vacuolated neutrophil results. However, it could have been more complete by mentioning how neutrophilia and total WBC count are related, as highlighted in the true answer. Additionally, it does not address the rapid weight loss condition mentioned in the true answer, which could have been more comprehensive.
#
# - **Naturalness: 4.8**
#   The response is fluent and sounds human-like. The language is polite and clear, adhering to a professional tone expected from a healthcare provider. The use of phrases like "Thank you for your question" and "It is important to note" contributes to a natural and conversational tone in medical communication.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# The model's response clearly does not attempt to answer the user's query about the M2-PK levels and their implications regarding cancer, instead providing a code snippet unrelated to the medical inquiry. Below is the evaluation based on the provided metrics:
#
# - **Coherence: 1.0**
#   The response is entirely incoherent in relation to the context of a medical question. It provides Python code that does not relate to the user's concern about M2-PK levels and potential cancer risks.
#
# - **Completeness: 1.0**
#   The response fails to address the question. It does not provide any medical information or guidance based on the user's M2-PK levels, nor does it mention anything health-related, leaving the question unanswered.
#
# - **Naturalness: 1.0**
#   The response consists of a code snippet, which lacks the characteristics of natural, fluent, human-like language expected in a conversational response to a medical query. It does not resemble conversational dialogue.
#
# Overall, the model's response does not meet any of the criteria for evaluating a quality answer in this context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Given that the model's response is absent, I will evaluate the response accordingly:
#
# - **Coherence: 1.0**
#   Since there is no response, there is no information to assess whether the model's answer logically aligns with the context.
#
# - **Completeness: 1.0**
#   The model provided no information or answer to the question, indicating a lack of any attempt to address the concerns or questions presented by the user.
#
# - **Naturalness: 1.0**
#   With no response, there is nothing to evaluate in terms of fluency or human-like qualities.
#
# Overall, the lack of response results in the lowest possible scores on all metrics.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is coherent and aligns logically with the context of the input. It acknowledges the patient's struggle with anxiety and taking specific medications. The response, however, lacks the questioning of the necessity of taking Olanzapine for anxiety, which is highlighted in the True Answer.
#
# - Completeness: 4.0
#   - The response addresses the question to some extent by providing general advice on managing anxiety, including medication adherence and additional lifestyle strategies. However, it does not specifically address potential medication adjustments or alternatives like in the True Answer. The omission of direct prescription advice or questioning the current medication limits its completeness.
#
# - Naturalness: 5.0
#   - The response is very natural and human-like. It maintains a calm, supportive, and empathic tone throughout, resembling how a professional might respond in a real-life consultation setting. The language used is fluent and clear.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# To evaluate the model's response, we must first acknowledge that it provided no substantive content because the response contained only a placeholder, indicating a lack of completion. Given this, I'll score the metrics accordingly:
#
# - **Coherence: 1.0**
#   The model's response is entirely missing, hence there is no logical alignment with the input context.
#
# - **Completeness: 1.0**
#   The response does not answer the question at all as it lacks any constructive content related to the query.
#
# - **Naturalness: 1.0**
#   Since no actual language content was provided, it cannot be assessed for fluency or how human-like it sounds.
#
# Overall, the model did not fulfill the task based on the given input.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       3.033333
# Completeness    2.596667
# Naturalness     3.270000
# BLEURT          0.530783
# BERTScore_F1    0.524856
# dtype: float64

# %%
# daily_diets

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response["choices"][0]["message"]["content"]
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

daily = df[df['task'] == 'daily_diets']
results = []

for i, row in daily.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_outpu_1024'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    if i % 10 == 0:
        print(f"Evaluation {i+1} result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Warning: Column BLEURT not found in DataFrame. Skipping normalization.
# Warning: Column BERTScore_F1 not found in DataFrame. Skipping normalization.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 147
#     144 evaluation_df = normalize_scores(evaluation_df, "BLEURT")
#     145 evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")
# --> 147 average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
#     148 print("평균 점수:")
#     149 print(average_scores)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Coherence', 'Completeness', 'Naturalness', 'BLEURT', 'BERTScore_F1'], dtype='object')] are in the [columns]"

# %%
# alternative_diets

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response["choices"][0]["message"]["content"]
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

alternative = df[df['task'] == 'alternative_diet']
results = []

for _, row in alternative.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    if i % 10 == 0:
        print(f"Evaluation {i+1} result:\n{evaluation}")
            
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       3.223577
# Completeness    2.880081
# Naturalness     3.008130
# BLEURT          0.488236
# BERTScore_F1    0.627131
# dtype: float64

# %%
import pandas as pd

dfh = pd.read_csv("/data/jaesung/llm_for_diabetes/src/data/data2_daily_diets/diabetes_food_hub_new_nutri_facts.csv")
dfh.head(2)
# Out:
#                                  title  \
# 0   Raspberry Swirl Frozen Yogurt Bark
# 1  Maple-Pumpkin Spice Oatmeal Cookies
#
#                                          description prep_time cook_time  \
# 0  Raspberry Swirl Frozen Yogurt Bark: Dive into ...    10 min      4 hr
# 1                              Description not found    10 min    25 min
#
#       servings                                              steps  \
# 0   6 Servings  ['Cover a freezer-safe tray with parchment pap...
# 1  14 Servings  ['Preheat the oven to 350 degrees F. Line two ...
#
#                                                 tags  \
# 0  ['Kid Friendly', 'Vegetarian', 'Dessert', 'Sna...
# 1  ['Kid Friendly', 'Vegetarian', 'Snacks', 'Glut...
#
#                                      nutrition_facts  \
# 0  {'Servings': '6 Servings', 'Serving Size': '1 ...
# 1  {'Servings': '14 Servings', 'Serving Size': '1...
#
#                                          ingredients
# 0  [{'label': 'Plain Nonfat Greek yogurt', 'us_me...
# 1  [{'label': 'old-fashioned rolled oats', 'us_me...

# %%
# daily diet - nutri score

import ast
import pandas as pd
import json
import re
import openai
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from dotenv import load_dotenv
import os
from tqdm import tqdm

# Load environment variables
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def extract_numeric_value(value):
    try:
        if isinstance(value, str):
            match = re.search(r"(\d+(\.\d+)?)", value)
            if match:
                return float(match.group(1))
        elif isinstance(value, (int, float)):
            return float(value)
    except Exception as e:
        print(f"Error in extract_numeric_value: {e}, value: {value}")
    return 0.0

def is_valid_meal_structure(json_string):
    try:
        data = json.loads(json_string)
        return all(key in data for key in ['Breakfast', 'Lunch', 'Dinner'])
    except (json.JSONDecodeError, TypeError):
        return False

def find_most_similar_row(title, dfh):
    try:
        dfh['title'] = dfh['title'].fillna('')  # Handle NaN values
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(dfh['title'])
        input_vector = vectorizer.transform([title])
        similarities = cosine_similarity(input_vector, tfidf_matrix)
        most_similar_idx = similarities.argmax()
        return dfh.iloc[most_similar_idx]
    except Exception as e:
        print(f"Error in find_most_similar_row: {e}, title: {title}")
        return None

def identify_fruit_veg(ingredients_list):
    try:
        prompt = f"Identify which items in the following ingredient list are fruits or vegetables:\n\n{ingredients_list}\n\nReturn only the names of items that are fruits or vegetables in a Python list format."
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an assistant identifying fruits and vegetables."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=100,
            temperature=0
        )
        fruits_vegetables = response['choices'][0]['message']['content']
        return ast.literal_eval(fruits_vegetables)
    except Exception as e:
        print(f"Error identifying fruits and vegetables: {e}")
        return []

def calculate_fruit_veg_points(ingredients, total_weight):
    try:
        ingredients_list = ast.literal_eval(ingredients)
        fruit_veg_labels = identify_fruit_veg(ingredients_list)

        fruit_veg_weight = 0
        for ingredient in ingredients_list:
            label = ingredient.get('label', '')
            weight = extract_numeric_value(ingredient.get('metric_measure', 0))
            if label in fruit_veg_labels:
                fruit_veg_weight += weight

        # 과일/채소 비율을 100g 기준으로 변환
        fruit_veg_ratio = (fruit_veg_weight / total_weight) * 100 if total_weight > 0 else 0

        if fruit_veg_ratio > 80:
            return 5
        elif fruit_veg_ratio > 60:
            return 2
        elif fruit_veg_ratio > 40:
            return 1
        else:
            return 0
    except Exception as e:
        print(f"Error calculating fruit_veg_points: {e}")
        return 0

def extract_nested_value(data, keys, default=0):
    try:
        for key in keys:
            if isinstance(data, dict):
                data = data.get(key, {})
            else:
                return default
        return extract_numeric_value(data) if isinstance(data, (int, float, str)) else default
    except Exception as e:
        print(f"Error in extract_nested_value: {e}, keys: {keys}, data: {data}")
        return default

def calculate_nutri_score(nutrition_facts, ingredients):
    try:
        if isinstance(nutrition_facts, str):
            nutrition_facts = ast.literal_eval(nutrition_facts)

        # 전체 무게 계산
        total_weight = sum(
            extract_numeric_value(ingredient.get('metric_measure', 0)) 
            for ingredient in ast.literal_eval(ingredients)
        )
        if total_weight == 0:
            print("Warning: Total weight is zero. Skipping calculation.")
            return None

        # 100g 기준으로 성분 정규화
        energy = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Calories']) / total_weight * 100
        saturated_fat = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Fat', 'Amount']) / total_weight * 100
        sugar = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Total Sugars']) / total_weight * 100
        sodium = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Sodium']) / total_weight * 100
        fiber = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Dietary Fiber']) / total_weight * 100
        protein = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Protein']) / total_weight * 100

        # Unfavorable points calculation
        energy_points = min(energy / 80, 800)
        saturated_fat_points = min(saturated_fat / 1, 10)
        sugar_points = min(sugar / 4.5, 45)
        sodium_points = min(sodium / 90, 900)

        unfavorable_points = energy_points + saturated_fat_points + sugar_points + sodium_points

        # Favorable points calculation
        fiber_points = min(fiber / 0.7, 3.5)
        protein_points = min(protein / 1.6, 8.0)
        fruit_veg_points = calculate_fruit_veg_points(ingredients, total_weight)

        favorable_points = fiber_points + protein_points + fruit_veg_points

        # Final Nutri-Score calculation
        total_score = unfavorable_points - favorable_points
        return total_score
    except Exception as e:
        print(f"Error in calculate_nutri_score: {e}, nutrition_facts: {nutrition_facts}")
        return None

def get_nutri_score_grade(score):
    if score <= -1:
        return "A"
    elif score <= 2:
        return "B"
    elif score <= 10:
        return "C"
    elif score <= 18:
        return "D"
    else:
        return "E"

def calculate_meal_nutri_score(meal_data, dfh):
    meal_scores = {}

    for meal, title in meal_data.items():
        matched_row = find_most_similar_row(title, dfh)
        if matched_row is None:
            continue

        nutrition_facts = matched_row['nutrition_facts']
        ingredients = matched_row['ingredients']
        score = calculate_nutri_score(nutrition_facts, ingredients)

        if score is None:
            print(f"Warning: Nutri-Score calculation failed for meal '{meal}' with title '{title}'.")
            grade = "N/A"
        else:
            grade = get_nutri_score_grade(score)

        meal_scores[meal] = {'score': score, 'grade': grade}

    return meal_scores

def calculate_scores_with_comparison(df, dfh):
    results = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        output_scores = {}
        model_scores = {}
        if is_valid_meal_structure(row.get('output', '')):
            output_data = json.loads(row['output'])
            output_scores = calculate_meal_nutri_score(output_data, dfh)
        if is_valid_meal_structure(row.get('model_output_512', '')):
            model_data = json.loads(row['model_output_512'])
            model_scores = calculate_meal_nutri_score(model_data, dfh)
        results.append({'row_index': idx, 'output_scores': output_scores, 'model_scores': model_scores})
    return results

def calculate_average_scores(results):
    """
    Calculate the average Nutri-Scores for outputs and model outputs.
    """
    output_total_score = 0
    model_total_score = 0
    output_count = 0
    model_count = 0

    for result in results:
        # Extract output scores
        for meal, score_data in result['output_scores'].items():
            if score_data['score'] is not None:
                output_total_score += score_data['score']
                output_count += 1

        # Extract model scores
        for meal, score_data in result['model_scores'].items():
            if score_data['score'] is not None:
                model_total_score += score_data['score']
                model_count += 1

    # Calculate averages
    output_avg = output_total_score / output_count if output_count > 0 else None
    model_avg = model_total_score / model_count if model_count > 0 else None

    return output_avg, model_avg


# 'daily_diets' task Nutri-Score calculation
filtered_df = df[df['task'] == 'daily_diets']
results = calculate_scores_with_comparison(filtered_df, dfh)

# Calculate overall averages
output_avg, model_avg = calculate_average_scores(results)

# Print results
print("=== Results for Each Row ===")
for result in results:
    print(f"Row Index: {result['row_index']}")
    print(f"Output Scores: {result['output_scores']}")
    print(f"Model Output Scores: {result['model_scores']}")
    print()

print("=== Overall Averages ===")
print(f"Output Average Nutri-Score: {output_avg}")
print(f"Model Output Average Nutri-Score: {model_avg}")
# Out:
# 100%|██████████| 274/274 [00:00<00:00, 22063.42it/s]
# === Results for Each Row ===
# Row Index: 661
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 662
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 663
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 664
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 665
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 666
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 667
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 668
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 669
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 670
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 671
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 672
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 673
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 674
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 675
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 676
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 677
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 678
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 679
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 680
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 681
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 682
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 683
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 684
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 685
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 686
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 687
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 688
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 689
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 690
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 691
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 692
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 693
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 694
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 695
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 696
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 697
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 698
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 699
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 700
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 701
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 702
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 703
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 704
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 705
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 706
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 707
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 708
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 709
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 710
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 711
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 712
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 713
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 714
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 715
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 716
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 717
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 718
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 719
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 720
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 721
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 722
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 723
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 724
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 725
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 726
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 727
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 728
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 729
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 730
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 731
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 732
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 733
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 734
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 735
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 736
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 737
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 738
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 739
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 740
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 741
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 742
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 743
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 744
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 745
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 746
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 747
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 748
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 749
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 750
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 751
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 752
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 753
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 754
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 755
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 756
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 757
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 758
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 759
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 760
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 761
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 762
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 763
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 764
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 765
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 766
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 767
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 768
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 769
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 770
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 771
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 772
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 773
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 774
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 775
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 776
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 777
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 778
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 779
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 780
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 781
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 782
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 783
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 784
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 785
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 786
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 787
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 788
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 789
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 790
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 791
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 792
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 793
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 794
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 795
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 796
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 797
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 798
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 799
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 800
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 801
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 802
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 803
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 804
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 805
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 806
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 807
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 808
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 809
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 810
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 811
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 812
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 813
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 814
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 815
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 816
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 817
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 818
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 819
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 820
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 821
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 822
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 823
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 824
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 825
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 826
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 827
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 828
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 829
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 830
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 831
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 832
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 833
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 834
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 835
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 836
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 837
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 838
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 839
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 840
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 841
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 842
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 843
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 844
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 845
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 846
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 847
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 848
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 849
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 850
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 851
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 852
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 853
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 854
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 855
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 856
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 857
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 858
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 859
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 860
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 861
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 862
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 863
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 864
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 865
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 866
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 867
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 868
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 869
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 870
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 871
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 872
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 873
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 874
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 875
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 876
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 877
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 878
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 879
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 880
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 881
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 882
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 883
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 884
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 885
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 886
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 887
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 888
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 889
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 890
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 891
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 892
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 893
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 894
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 895
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 896
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 897
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 898
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 899
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 900
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 901
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 902
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 903
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 904
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 905
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 906
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 907
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 908
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 909
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 910
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 911
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 912
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 913
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 914
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 915
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 916
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 917
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 918
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 919
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 920
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 921
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 922
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 923
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 924
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 925
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 926
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 927
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 928
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 929
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 930
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 931
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 932
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 933
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 934
# Output Scores: {}
# Model Output Scores: {}
#
# === Overall Averages ===
# Output Average Nutri-Score: None
# Model Output Average Nutri-Score: None

# %%
# alternative diet - nutri score

import ast
import pandas as pd
import json
import re
import openai
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from dotenv import load_dotenv
import os
from tqdm import tqdm

# Load environment variables
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def extract_numeric_value(value):
    try:
        if isinstance(value, str):
            match = re.search(r"(\d+(\.\d+)?)", value)
            if match:
                return float(match.group(1))
        elif isinstance(value, (int, float)):
            return float(value)
    except Exception as e:
        print(f"Error in extract_numeric_value: {e}, value: {value}")
    return 0.0

def is_valid_meal_structure(json_string):
    try:
        data = json.loads(json_string)
        return isinstance(data, dict)
    except (json.JSONDecodeError, TypeError):
        return False

def find_most_similar_row(title, dfh):
    try:
        dfh['title'] = dfh['title'].fillna('')  # Handle NaN values
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(dfh['title'])
        input_vector = vectorizer.transform([title])
        similarities = cosine_similarity(input_vector, tfidf_matrix)
        most_similar_idx = similarities.argmax()
        return dfh.iloc[most_similar_idx]
    except Exception as e:
        print(f"Error in find_most_similar_row: {e}, title: {title}")
        return None

def identify_fruit_veg(ingredients_list):
    try:
        prompt = f"Identify which items in the following ingredient list are fruits or vegetables:\n\n{ingredients_list}\n\nReturn only the names of items that are fruits or vegetables in a Python list format."
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an assistant identifying fruits and vegetables."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=100,
            temperature=0
        )
        fruits_vegetables = response['choices'][0]['message']['content']
        return ast.literal_eval(fruits_vegetables)
    except Exception as e:
        print(f"Error identifying fruits and vegetables: {e}")
        return []

def calculate_fruit_veg_points(ingredients, total_weight):
    try:
        ingredients_list = ast.literal_eval(ingredients)
        fruit_veg_labels = identify_fruit_veg(ingredients_list)

        fruit_veg_weight = 0
        for ingredient in ingredients_list:
            label = ingredient.get('label', '')
            weight = extract_numeric_value(ingredient.get('metric_measure', 0))
            if label in fruit_veg_labels:
                fruit_veg_weight += weight

        # 과일/채소 비율을 100g 기준으로 변환
        fruit_veg_ratio = (fruit_veg_weight / total_weight) * 100 if total_weight > 0 else 0

        if fruit_veg_ratio > 80:
            return 5
        elif fruit_veg_ratio > 60:
            return 2
        elif fruit_veg_ratio > 40:
            return 1
        else:
            return 0
    except Exception as e:
        print(f"Error calculating fruit_veg_points: {e}")
        return 0

def extract_nested_value(data, keys, default=0):
    try:
        for key in keys:
            if isinstance(data, dict):
                data = data.get(key, {})
            else:
                return default
        return extract_numeric_value(data)
    except Exception as e:
        print(f"Error in extract_nested_value: {e}, keys: {keys}, data: {data}")
        return default

def calculate_nutri_score(nutrition_facts, ingredients):
    try:
        if isinstance(nutrition_facts, str):
            nutrition_facts = ast.literal_eval(nutrition_facts)

        # 전체 무게 계산
        total_weight = sum(
            extract_numeric_value(ingredient.get('metric_measure', 0)) 
            for ingredient in ast.literal_eval(ingredients)
        )
        if total_weight == 0:
            print("Warning: Total weight is zero. Skipping calculation.")
            return None

        # 100g 기준으로 성분 정규화
        energy = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Calories']) / total_weight * 100
        saturated_fat = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Fat', 'Amount']) / total_weight * 100
        sugar = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Total Sugars']) / total_weight * 100
        sodium = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Sodium']) / total_weight * 100
        fiber = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Dietary Fiber']) / total_weight * 100
        protein = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Protein']) / total_weight * 100

        # Unfavorable points calculation
        energy_points = min(energy / 80, 800)
        saturated_fat_points = min(saturated_fat / 1, 10)
        sugar_points = min(sugar / 4.5, 45)
        sodium_points = min(sodium / 90, 900)

        unfavorable_points = energy_points + saturated_fat_points + sugar_points + sodium_points

        # Favorable points calculation
        fiber_points = min(fiber / 0.7, 3.5)
        protein_points = min(protein / 1.6, 8.0)
        fruit_veg_points = calculate_fruit_veg_points(ingredients, total_weight)

        favorable_points = fiber_points + protein_points + fruit_veg_points

        # Final Nutri-Score calculation
        total_score = unfavorable_points - favorable_points
        return total_score
    except Exception as e:
        print(f"Error in calculate_nutri_score: {e}, nutrition_facts: {nutrition_facts}")
        return None

def get_nutri_score_grade(score):
    if score <= -1:
        return "A"
    elif score <= 2:
        return "B"
    elif score <= 10:
        return "C"
    elif score <= 18:
        return "D"
    else:
        return "E"

def calculate_scores_with_comparison_no_meals(df, dfh):
    results = []
    output_scores_list = []
    model_output_scores_list = []

    for idx, row in tqdm(df.iterrows(), total=len(df)):
        try:
            output_text = row.get('output', '')
            if output_text:
                matched_row = find_most_similar_row(output_text, dfh)
                if matched_row is not None:
                    nutrition_facts = matched_row['nutrition_facts']
                    ingredients = matched_row['ingredients']
                    output_score = calculate_nutri_score(nutrition_facts, ingredients)
                    output_scores_list.append(output_score)
                else:
                    output_score = None

            model_output_text = row.get('model_output_512', '')
            if model_output_text:
                matched_row = find_most_similar_row(model_output_text, dfh)
                if matched_row is not None:
                    nutrition_facts = matched_row['nutrition_facts']
                    ingredients = matched_row['ingredients']
                    model_output_score = calculate_nutri_score(nutrition_facts, ingredients)
                    model_output_scores_list.append(model_output_score)
                else:
                    model_output_score = None

            results.append({
                'row_index': idx,
                'output_score': output_score,
                'model_output_score': model_output_score
            })

        except Exception as e:
            print(f"Error processing row {idx}: {e}")
            results.append({
                'row_index': idx,
                'output_score': None,
                'model_output_score': None
            })

    final_output_avg = sum(output_scores_list) / len(output_scores_list) if output_scores_list else None
    final_model_output_avg = sum(model_output_scores_list) / len(model_output_scores_list) if model_output_scores_list else None

    print(f"Output Average Nutri-Score: {final_output_avg}")
    print(f"Model Output Average Nutri-Score: {final_model_output_avg}")

    return results

# Execution
filtered_df = df[df['task'] == 'alternative_diet']
results = calculate_scores_with_comparison_no_meals(filtered_df, dfh)

# Print results
for result in results:
    print(result)
# Out:
#   0%|          | 0/246 [00:00<?, ?it/s]
#  64%|██████▍   | 158/246 [03:34<01:46,  1.21s/it]
# Error identifying fruits and vegetables: unterminated string literal (detected at line 1) (<unknown>, line 1)
#  84%|████████▍ | 207/246 [04:37<00:40,  1.03s/it]
# Warning: Total weight is zero. Skipping calculation.
# 100%|██████████| 246/246 [05:27<00:00,  1.33s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 216
#     214 # Execution
#     215 filtered_df = df[df['task'] == 'alternative_diet']
# --> 216 results = calculate_scores_with_comparison_no_meals(filtered_df, dfh)
#     218 # Print results
#     219 for result in results:
#
# Cell In[32], line 207, in calculate_scores_with_comparison_no_meals(df, dfh)
#     200         results.append({
#     201             'row_index': idx,
#     202             'output_score': None,
#     203             'model_output_score': None
#     204         })
#     206 final_output_avg = sum(output_scores_list) / len(output_scores_list) if output_scores_list else None
# --> 207 final_model_output_avg = sum(model_output_scores_list) / len(model_output_scores_list) if model_output_scores_list else None
#     209 print(f"Output Average Nutri-Score: {final_output_avg}")
#     210 print(f"Model Output Average Nutri-Score: {final_model_output_avg}")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'
