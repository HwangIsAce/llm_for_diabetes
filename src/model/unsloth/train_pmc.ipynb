# %%
# %%capture
# !pip install unsloth
# # Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# %%
# %pip uninstall unsloth unsloth_zoo -y
# %pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# %pip install --upgrade --no-cache-dir "git+https://github.com/unslothai/unsloth-zoo.git"

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

# EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN

# %%
# import json
# import time
# import transformers
# import torch

# # Load Hugging Face model and tokenizer
# tokenizer = transformers.LlamaTokenizer.from_pretrained('chaoyi-wu/PMC_LLAMA_7B')
# model = transformers.LlamaForCausalLM.from_pretrained('chaoyi-wu/PMC_LLAMA_7B').to("cuda")

# def load_json(file_paths):
#     data = []
#     for file_path in file_paths:
#         with open(file_path, "r", encoding="utf-8") as file:
#             data.extend(json.load(file))
#     return data

# def save_to_jsonl(file_path, data):
#     with open(file_path, "a", encoding="utf-8") as f: 
#         f.write(json.dumps(data, ensure_ascii=False) + "\n")

# def generate_response(instruction_text, input_text, max_tokens):
#     inputs = tokenizer(
#         [
#             instruction_text + "\n\n" + input_text
#         ], return_tensors="pt", add_special_tokens=True
#     ).to("cuda")

#     with torch.no_grad():
#         outputs = model.generate(
#             inputs["input_ids"],
#             max_new_tokens=max_tokens,
#             do_sample=True,
#             top_k=50
#         )
#     decoded_outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)
#     response_text = decoded_outputs[0]

#     cleaned_output = response_text.replace(instruction_text, "").replace(input_text, "").strip()
    
#     return cleaned_output


# # 실행 
# input_json_paths = [
#     "/data/jaesung/llm_for_diabetes/src/model/mLoRA/demo/data_classification_test.json",
#     "/data/jaesung/llm_for_diabetes/src/model/mLoRA/demo/data_generation_test.json"
# ]
# output_json_path = "/data/jaesung/llm_for_diabetes/src/model/unsloth/model_output/pmc_model_output_2.jsonl"

# data = load_json(input_json_paths)

# start_time = time.time()
# total_samples = len(data)
# for idx, item in enumerate(data):
#     sample_start_time = time.time()

#     input_text = item.get("input", "")
#     instruction = item.get("instruction", "")
#     task = item.get("task", "")

#     max_tokens = 32 if task in ["qa1", "qa2", "qa3", "nli", "ie", "re"] else 1024

#     model_output = generate_response(instruction, input_text, max_tokens)

#     output_data = item.copy()
#     output_data.update({
#         "model_output": model_output,
#     })
#     save_to_jsonl(output_json_path, output_data)

#     elapsed_time = time.time() - start_time
#     avg_time_per_sample = elapsed_time / (idx + 1) 
#     remaining_samples = total_samples - (idx + 1)
#     estimated_remaining_time = remaining_samples * avg_time_per_sample

#     print(f"[{idx+1}/{total_samples}] Sample processed in {time.time() - sample_start_time:.2f}s, ETA: {estimated_remaining_time/60:.2f} min")

# print(f"\nAll samples processed. Total time: {(time.time() - start_time)/60:.2f} min")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# 2025-02-12 11:05:55.423089: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-12 11:05:55.438013: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739325955.455952  561649 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739325955.461484  561649 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-12 11:05:55.480554: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /data/jaesung/anaconda3/envs/meal/lib/python3.12/site-packages/transformers/generation/configuration_utils.py:606: UserWarning: `pad_token_id` should be positive but got -1. This will cause errors when batch generating, if there is padding. Please set `pad_token_id` explicitly as `model.generation_config.pad_token_id=PAD_TOKEN_ID` to avoid errors in generation
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# [1/1181] Sample processed in 1.71s, ETA: 33.62 min
# [2/1181] Sample processed in 1.16s, ETA: 28.18 min
# [3/1181] Sample processed in 1.08s, ETA: 25.87 min
# [4/1181] Sample processed in 1.08s, ETA: 24.71 min
# [5/1181] Sample processed in 1.15s, ETA: 24.24 min
# [6/1181] Sample processed in 1.20s, ETA: 24.11 min
# [7/1181] Sample processed in 1.09s, ETA: 23.70 min
# [8/1181] Sample processed in 1.08s, ETA: 23.35 min
# [9/1181] Sample processed in 1.07s, ETA: 23.07 min
# [10/1181] Sample processed in 1.09s, ETA: 22.87 min
# [11/1181] Sample processed in 1.16s, ETA: 22.82 min
# [12/1181] Sample processed in 1.20s, ETA: 22.86 min
# [13/1181] Sample processed in 1.20s, ETA: 22.88 min
# [14/1181] Sample processed in 1.47s, ETA: 23.27 min
# [15/1181] Sample processed in 1.08s, ETA: 23.10 min
# [16/1181] Sample processed in 1.15s, ETA: 23.03 min
# [17/1181] Sample processed in 1.15s, ETA: 22.98 min
# [18/1181] Sample processed in 1.20s, ETA: 22.97 min
# [19/1181] Sample processed in 1.31s, ETA: 23.08 min
# [20/1181] Sample processed in 1.15s, ETA: 23.02 min
# [21/1181] Sample processed in 1.21s, ETA: 23.01 min
# [22/1181] Sample processed in 1.08s, ETA: 22.90 min
# [23/1181] Sample processed in 1.15s, ETA: 22.85 min
# [24/1181] Sample processed in 1.35s, ETA: 22.97 min
# [25/1181] Sample processed in 1.21s, ETA: 22.96 min
# [26/1181] Sample processed in 1.20s, ETA: 22.95 min
# [27/1181] Sample processed in 1.20s, ETA: 22.93 min
# [28/1181] Sample processed in 1.09s, ETA: 22.85 min
# [29/1181] Sample processed in 1.45s, ETA: 23.00 min
# [30/1181] Sample processed in 1.16s, ETA: 22.95 min
# [31/1181] Sample processed in 1.21s, ETA: 22.94 min
# [32/1181] Sample processed in 1.16s, ETA: 22.90 min
# [33/1181] Sample processed in 1.08s, ETA: 22.81 min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 58
#      54 task = item.get("task", "")
#      56 max_tokens = 32 if task in ["qa1", "qa2", "qa3", "nli", "ie", "re"] else 512
# ---> 58 model_output = generate_response(instruction, input_text, max_tokens)
#      60 output_data = item.copy()
#      61 output_data.update({
#      62     "model_output": model_output,
#      63 })
#
# Cell In[2], line 29, in generate_response(instruction_text, input_text, max_tokens)
#      22 inputs = tokenizer(
#      23     [
#      24         instruction_text + "\n\n" + input_text
#      25     ], return_tensors="pt", add_special_tokens=True
#      26 ).to("cuda")
#      28 with torch.no_grad():
# ---> 29     outputs = model.generate(
#      30         inputs["input_ids"],
#      31         max_new_tokens=max_tokens,
#      32         do_sample=True,
#      33         top_k=50
#      34     )
#      35 decoded_outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)
#      36 return decoded_outputs[0]
#
# File ~/anaconda3/envs/meal/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/meal/lib/python3.12/site-packages/transformers/generation/utils.py:2255, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2247     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2248         input_ids=input_ids,
#    2249         expand_size=generation_config.num_return_sequences,
#    2250         is_encoder_decoder=self.config.is_encoder_decoder,
#    2251         **model_kwargs,
#    2252     )
#    2254     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255     result = self._sample(
#    2256         input_ids,
#    2257         logits_processor=prepared_logits_processor,
#    2258         stopping_criteria=prepared_stopping_criteria,
#    2259         generation_config=generation_config,
#    2260         synced_gpus=synced_gpus,
#    2261         streamer=streamer,
#    2262         **model_kwargs,
#    2263     )
#    2265 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2266     # 11. prepare beam search scorer
#    2267     beam_scorer = BeamSearchScorer(
#    2268         batch_size=batch_size,
#    2269         num_beams=generation_config.num_beams,
#    (...)
#    2274         max_length=generation_config.max_length,
#    2275     )
#
# File ~/anaconda3/envs/meal/lib/python3.12/site-packages/transformers/generation/utils.py:3243, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3240         model_forward = self.get_compiled_call(generation_config.compile_config)
#    3242 is_prefill = True
# -> 3243 while self._has_unfinished_sequences(
#    3244     this_peer_finished, synced_gpus, device=input_ids.device, cur_len=cur_len, max_length=max_length
#    3245 ):
#    3246     # prepare model inputs
#    3247     model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    3249     # prepare variable output controls (note: some models won't accept all output controls)
#
# KeyboardInterrupt:

# %%
import json
import time
import transformers
import torch
from datasets import load_dataset

# ✅ Load Hugging Face model and tokenizer
tokenizer = transformers.LlamaTokenizer.from_pretrained('chaoyi-wu/PMC_LLAMA_7B')
model = transformers.LlamaForCausalLM.from_pretrained('chaoyi-wu/PMC_LLAMA_7B').to("cuda")

# ✅ Load dataset from Hugging Face
dataset = load_dataset("passionMan/test_dataset")  # 데이터셋 로드
data = list(dataset["test"])  # test split 사용 (train 가능)

output_json_path = "/data/jaesung/llm_for_diabetes/src/model/unsloth/model_output/pmc_model_output_2.jsonl"

def save_to_jsonl(file_path, data):
    """ JSONL 파일에 한 줄씩 저장하는 함수 (실시간 저장) """
    with open(file_path, "a", encoding="utf-8") as f: 
        f.write(json.dumps(data, ensure_ascii=False) + "\n")

def generate_response(instruction_text, input_text, max_tokens):
    """ 모델 추론 실행 """
    inputs = tokenizer(
        [
            instruction_text + "\n\n" + input_text
        ], return_tensors="pt", add_special_tokens=True
    ).to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            inputs["input_ids"],
            max_new_tokens=max_tokens,
            do_sample=True,
            top_k=50
        )
    decoded_outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    response_text = decoded_outputs[0]

    cleaned_output = response_text.replace(instruction_text, "").replace(input_text, "").strip()
    
    return cleaned_output


# ✅ 실행
start_time = time.time()
total_samples = len(data)

for idx, item in enumerate(data):
    sample_start_time = time.time()

    input_text = item.get("input", "")
    instruction = item.get("instruction", "")
    task = item.get("task", "")

    # ✅ 특정 태스크는 max_tokens=32, 그 외는 1024
    max_tokens = 32 if task in ["qa1", "qa2", "qa3", "nli", "ie", "re"] else 1024

    model_output = generate_response(instruction, input_text, max_tokens)

    # ✅ 원본 데이터 + 모델 출력 추가
    output_data = item.copy()
    output_data.update({
        "model_output": model_output,
    })
    
    # ✅ 실시간 저장
    save_to_jsonl(output_json_path, output_data)

    # ✅ 진행 상태 출력
    elapsed_time = time.time() - start_time
    avg_time_per_sample = elapsed_time / (idx + 1) 
    remaining_samples = total_samples - (idx + 1)
    estimated_remaining_time = remaining_samples * avg_time_per_sample

    print(f"[{idx+1}/{total_samples}] Sample processed in {time.time() - sample_start_time:.2f}s, ETA: {estimated_remaining_time/60:.2f} min")

print(f"\nAll samples processed. Total time: {(time.time() - start_time)/60:.2f} min")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# /data/jaesung/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:606: UserWarning: `pad_token_id` should be positive but got -1. This will cause errors when batch generating, if there is padding. Please set `pad_token_id` explicitly as `model.generation_config.pad_token_id=PAD_TOKEN_ID` to avoid errors in generation
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# [1/800] Sample processed in 1.96s, ETA: 26.06 min
# [2/800] Sample processed in 1.08s, ETA: 20.19 min
# [3/800] Sample processed in 1.16s, ETA: 18.57 min
# [4/800] Sample processed in 1.02s, ETA: 17.29 min
# [5/800] Sample processed in 1.22s, ETA: 17.05 min
# [6/800] Sample processed in 1.08s, ETA: 16.56 min
# [7/800] Sample processed in 1.40s, ETA: 16.83 min
# [8/800] Sample processed in 1.36s, ETA: 16.95 min
# [9/800] Sample processed in 1.21s, ETA: 16.82 min
# [10/800] Sample processed in 1.21s, ETA: 16.71 min
# [11/800] Sample processed in 1.30s, ETA: 16.73 min
# [12/800] Sample processed in 1.36s, ETA: 16.80 min
# [13/800] Sample processed in 1.08s, ETA: 16.58 min
# [14/800] Sample processed in 1.08s, ETA: 16.39 min
# [15/800] Sample processed in 1.37s, ETA: 16.47 min
# [16/800] Sample processed in 1.03s, ETA: 16.26 min
# [17/800] Sample processed in 1.45s, ETA: 16.39 min
# [18/800] Sample processed in 1.16s, ETA: 16.30 min
# [19/800] Sample processed in 1.16s, ETA: 16.22 min
# [20/800] Sample processed in 1.10s, ETA: 16.10 min
# [21/800] Sample processed in 1.08s, ETA: 15.99 min
# [22/800] Sample processed in 1.21s, ETA: 15.96 min
# [23/800] Sample processed in 1.23s, ETA: 15.93 min
# [24/800] Sample processed in 1.09s, ETA: 15.84 min
# [25/800] Sample processed in 1.08s, ETA: 15.74 min
# [26/800] Sample processed in 1.09s, ETA: 15.66 min
# [27/800] Sample processed in 1.03s, ETA: 15.55 min
# [28/800] Sample processed in 1.21s, ETA: 15.53 min
# [29/800] Sample processed in 1.15s, ETA: 15.49 min
# [30/800] Sample processed in 1.39s, ETA: 15.55 min
# [31/800] Sample processed in 1.08s, ETA: 15.47 min
# [32/800] Sample processed in 1.10s, ETA: 15.41 min
# [33/800] Sample processed in 1.22s, ETA: 15.40 min
# [34/800] Sample processed in 1.36s, ETA: 15.44 min
# [35/800] Sample processed in 1.32s, ETA: 15.46 min
# [36/800] Sample processed in 1.33s, ETA: 15.48 min
# [37/800] Sample processed in 1.09s, ETA: 15.41 min
# [38/800] Sample processed in 1.08s, ETA: 15.35 min
# [39/800] Sample processed in 1.21s, ETA: 15.33 min
# [40/800] Sample processed in 1.59s, ETA: 15.43 min
# [41/800] Sample processed in 1.09s, ETA: 15.37 min
# [42/800] Sample processed in 1.21s, ETA: 15.35 min
# [43/800] Sample processed in 1.16s, ETA: 15.31 min
# [44/800] Sample processed in 1.16s, ETA: 15.28 min
# [45/800] Sample processed in 1.21s, ETA: 15.26 min
# [46/800] Sample processed in 1.08s, ETA: 15.20 min
# [47/800] Sample processed in 1.32s, ETA: 15.21 min
# [48/800] Sample processed in 1.02s, ETA: 15.14 min
# [49/800] Sample processed in 1.37s, ETA: 15.16 min
# [50/800] Sample processed in 1.08s, ETA: 15.11 min
# [51/800] Sample processed in 1.00s, ETA: 15.04 min
# [52/800] Sample processed in 1.07s, ETA: 14.98 min
# [53/800] Sample processed in 1.08s, ETA: 14.94 min
# [54/800] Sample processed in 1.10s, ETA: 14.89 min
# [55/800] Sample processed in 1.08s, ETA: 14.85 min
# [56/800] Sample processed in 1.22s, ETA: 14.83 min
# [57/800] Sample processed in 1.21s, ETA: 14.82 min
# [58/800] Sample processed in 1.00s, ETA: 14.75 min
# [59/800] Sample processed in 1.16s, ETA: 14.73 min
# [60/800] Sample processed in 1.45s, ETA: 14.76 min
# [61/800] Sample processed in 1.09s, ETA: 14.72 min
# [62/800] Sample processed in 1.09s, ETA: 14.68 min
# [63/800] Sample processed in 1.08s, ETA: 14.64 min
# [64/800] Sample processed in 1.16s, ETA: 14.61 min
# [65/800] Sample processed in 1.32s, ETA: 14.62 min
# [66/800] Sample processed in 1.16s, ETA: 14.59 min
# [67/800] Sample processed in 1.08s, ETA: 14.55 min
# [225/800] Sample processed in 1.49s, ETA: 10.82 min
# [226/800] Sample processed in 1.31s, ETA: 10.81 min
# [227/800] Sample processed in 1.33s, ETA: 10.80 min
# [228/800] Sample processed in 1.46s, ETA: 10.80 min
# [229/800] Sample processed in 1.46s, ETA: 10.79 min
# [230/800] Sample processed in 1.17s, ETA: 10.77 min
# [231/800] Sample processed in 1.37s, ETA: 10.76 min
# [232/800] Sample processed in 1.33s, ETA: 10.75 min
# [233/800] Sample processed in 1.41s, ETA: 10.75 min
# [234/800] Sample processed in 1.46s, ETA: 10.74 min
# [235/800] Sample processed in 1.33s, ETA: 10.73 min
# [236/800] Sample processed in 1.33s, ETA: 10.72 min
# [237/800] Sample processed in 1.67s, ETA: 10.72 min
# [238/800] Sample processed in 1.16s, ETA: 10.70 min
# [239/800] Sample processed in 1.47s, ETA: 10.69 min
# [240/800] Sample processed in 1.22s, ETA: 10.68 min
# [241/800] Sample processed in 1.33s, ETA: 10.67 min
# [242/800] Sample processed in 1.22s, ETA: 10.65 min
# [243/800] Sample processed in 1.22s, ETA: 10.63 min
# [244/800] Sample processed in 1.24s, ETA: 10.62 min
# [245/800] Sample processed in 1.46s, ETA: 10.61 min
# [246/800] Sample processed in 1.40s, ETA: 10.60 min
# [247/800] Sample processed in 1.16s, ETA: 10.58 min
# [248/800] Sample processed in 1.37s, ETA: 10.57 min
# [249/800] Sample processed in 1.46s, ETA: 10.56 min
# [250/800] Sample processed in 1.48s, ETA: 10.56 min
# [251/800] Sample processed in 1.33s, ETA: 10.54 min
# [252/800] Sample processed in 1.33s, ETA: 10.53 min
# [253/800] Sample processed in 1.48s, ETA: 10.52 min
# [254/800] Sample processed in 1.30s, ETA: 10.51 min
# [255/800] Sample processed in 1.45s, ETA: 10.50 min
# [256/800] Sample processed in 1.23s, ETA: 10.49 min
# [257/800] Sample processed in 1.40s, ETA: 10.47 min
# [258/800] Sample processed in 1.37s, ETA: 10.46 min
# [259/800] Sample processed in 1.86s, ETA: 10.47 min
# [260/800] Sample processed in 1.17s, ETA: 10.45 min
# [261/800] Sample processed in 1.60s, ETA: 10.44 min
# [262/800] Sample processed in 1.22s, ETA: 10.43 min
# [263/800] Sample processed in 1.38s, ETA: 10.42 min
# [264/800] Sample processed in 1.23s, ETA: 10.40 min
# [265/800] Sample processed in 1.32s, ETA: 10.38 min
# [266/800] Sample processed in 1.23s, ETA: 10.37 min
# [267/800] Sample processed in 1.33s, ETA: 10.35 min
# [268/800] Sample processed in 1.22s, ETA: 10.34 min
# [269/800] Sample processed in 1.37s, ETA: 10.32 min
# [270/800] Sample processed in 1.46s, ETA: 10.31 min
# [271/800] Sample processed in 1.40s, ETA: 10.30 min
# [272/800] Sample processed in 1.39s, ETA: 10.29 min
# [273/800] Sample processed in 1.48s, ETA: 10.28 min
# [274/800] Sample processed in 1.33s, ETA: 10.26 min
# [275/800] Sample processed in 1.32s, ETA: 10.25 min
# [276/800] Sample processed in 1.61s, ETA: 10.24 min
# [330/800] Sample processed in 1.46s, ETA: 9.37 min
# [331/800] Sample processed in 1.38s, ETA: 9.35 min
# [332/800] Sample processed in 1.51s, ETA: 9.34 min
# [333/800] Sample processed in 1.41s, ETA: 9.32 min
# [334/800] Sample processed in 1.22s, ETA: 9.30 min
# [335/800] Sample processed in 1.17s, ETA: 9.28 min
# [336/800] Sample processed in 1.33s, ETA: 9.27 min
# [337/800] Sample processed in 1.09s, ETA: 9.24 min
# [338/800] Sample processed in 1.40s, ETA: 9.23 min
# [339/800] Sample processed in 1.47s, ETA: 9.21 min
# [340/800] Sample processed in 1.17s, ETA: 9.19 min
# [341/800] Sample processed in 1.32s, ETA: 9.18 min
# [342/800] Sample processed in 1.22s, ETA: 9.16 min
# [343/800] Sample processed in 1.22s, ETA: 9.14 min
# [344/800] Sample processed in 1.24s, ETA: 9.12 min
# [345/800] Sample processed in 1.16s, ETA: 9.10 min
# [346/800] Sample processed in 1.49s, ETA: 9.08 min
# [347/800] Sample processed in 1.17s, ETA: 9.06 min
# [348/800] Sample processed in 1.23s, ETA: 9.04 min
# [349/800] Sample processed in 1.23s, ETA: 9.02 min
# [350/800] Sample processed in 1.46s, ETA: 9.01 min
# [351/800] Sample processed in 1.41s, ETA: 8.99 min
# [352/800] Sample processed in 1.46s, ETA: 8.98 min
# [353/800] Sample processed in 1.40s, ETA: 8.96 min
# [354/800] Sample processed in 1.41s, ETA: 8.95 min
# [355/800] Sample processed in 1.33s, ETA: 8.93 min
# [356/800] Sample processed in 1.40s, ETA: 8.91 min
# [357/800] Sample processed in 1.48s, ETA: 8.90 min
# [358/800] Sample processed in 1.22s, ETA: 8.88 min
# [359/800] Sample processed in 0.95s, ETA: 8.86 min
# [360/800] Sample processed in 1.38s, ETA: 8.84 min
# [361/800] Sample processed in 1.60s, ETA: 8.83 min
# [362/800] Sample processed in 1.23s, ETA: 8.81 min
# [363/800] Sample processed in 1.23s, ETA: 8.79 min
# [364/800] Sample processed in 1.17s, ETA: 8.77 min
# [365/800] Sample processed in 1.49s, ETA: 8.75 min
# [366/800] Sample processed in 1.37s, ETA: 8.74 min
# [367/800] Sample processed in 1.16s, ETA: 8.71 min
# [368/800] Sample processed in 1.16s, ETA: 8.69 min
# [369/800] Sample processed in 1.47s, ETA: 8.68 min
# [370/800] Sample processed in 1.23s, ETA: 8.66 min
# [371/800] Sample processed in 1.22s, ETA: 8.64 min
# [372/800] Sample processed in 1.31s, ETA: 8.62 min
# [373/800] Sample processed in 1.31s, ETA: 8.60 min
# [374/800] Sample processed in 1.46s, ETA: 8.59 min
# [375/800] Sample processed in 1.31s, ETA: 8.57 min
# [376/800] Sample processed in 1.30s, ETA: 8.55 min
# [377/800] Sample processed in 1.33s, ETA: 8.53 min
# [378/800] Sample processed in 1.17s, ETA: 8.51 min
# [379/800] Sample processed in 1.48s, ETA: 8.50 min
# [380/800] Sample processed in 1.03s, ETA: 8.47 min
# [381/800] Sample processed in 1.37s, ETA: 8.46 min
# [382/800] Sample processed in 1.17s, ETA: 8.43 min
# [383/800] Sample processed in 1.22s, ETA: 8.41 min
# [384/800] Sample processed in 1.30s, ETA: 8.40 min
# [385/800] Sample processed in 1.40s, ETA: 8.38 min
# [386/800] Sample processed in 1.10s, ETA: 8.36 min
# [387/800] Sample processed in 1.31s, ETA: 8.34 min
# [388/800] Sample processed in 1.46s, ETA: 8.32 min
# [389/800] Sample processed in 1.17s, ETA: 8.30 min
# [390/800] Sample processed in 1.30s, ETA: 8.28 min
# [391/800] Sample processed in 1.30s, ETA: 8.26 min
# [392/800] Sample processed in 1.23s, ETA: 8.24 min
# [393/800] Sample processed in 1.22s, ETA: 8.22 min
# [394/800] Sample processed in 1.22s, ETA: 8.20 min
# [395/800] Sample processed in 1.33s, ETA: 8.19 min
# [396/800] Sample processed in 1.37s, ETA: 8.17 min
# [397/800] Sample processed in 1.21s, ETA: 8.15 min
# [398/800] Sample processed in 1.10s, ETA: 8.13 min
# [399/800] Sample processed in 1.31s, ETA: 8.11 min
# [400/800] Sample processed in 1.46s, ETA: 8.09 min
# [401/800] Sample processed in 1.46s, ETA: 8.08 min
# [402/800] Sample processed in 0.92s, ETA: 8.05 min
# [403/800] Sample processed in 1.38s, ETA: 8.03 min
# [404/800] Sample processed in 1.47s, ETA: 8.02 min
# [405/800] Sample processed in 1.48s, ETA: 8.00 min
# [406/800] Sample processed in 1.33s, ETA: 7.98 min
# [407/800] Sample processed in 0.92s, ETA: 7.96 min
# [408/800] Sample processed in 1.24s, ETA: 7.94 min
# [409/800] Sample processed in 0.92s, ETA: 7.91 min
# [410/800] Sample processed in 1.23s, ETA: 7.89 min
# [411/800] Sample processed in 0.94s, ETA: 7.87 min
# [412/800] Sample processed in 1.46s, ETA: 7.85 min
# [413/800] Sample processed in 0.92s, ETA: 7.83 min
# [414/800] Sample processed in 1.46s, ETA: 7.81 min
# [415/800] Sample processed in 1.33s, ETA: 7.79 min
# [416/800] Sample processed in 1.48s, ETA: 7.78 min
# [417/800] Sample processed in 1.17s, ETA: 7.75 min
# [418/800] Sample processed in 1.32s, ETA: 7.74 min
# [419/800] Sample processed in 1.48s, ETA: 7.72 min
# [420/800] Sample processed in 1.61s, ETA: 7.71 min
# [421/800] Sample processed in 1.33s, ETA: 7.69 min
# [422/800] Sample processed in 1.60s, ETA: 7.67 min
# [423/800] Sample processed in 1.31s, ETA: 7.65 min
# [424/800] Sample processed in 0.92s, ETA: 7.63 min
# [425/800] Sample processed in 1.24s, ETA: 7.61 min
# [426/800] Sample processed in 0.92s, ETA: 7.58 min
# [427/800] Sample processed in 1.23s, ETA: 7.56 min
# [428/800] Sample processed in 1.45s, ETA: 7.55 min
# [429/800] Sample processed in 1.40s, ETA: 7.53 min
# [430/800] Sample processed in 1.23s, ETA: 7.51 min
# [431/800] Sample processed in 1.45s, ETA: 7.49 min
# [432/800] Sample processed in 1.16s, ETA: 7.47 min
# [433/800] Sample processed in 1.46s, ETA: 7.45 min
# [434/800] Sample processed in 1.22s, ETA: 7.43 min
# [487/800] Sample processed in 1.30s, ETA: 6.39 min
# [488/800] Sample processed in 1.46s, ETA: 6.37 min
# [489/800] Sample processed in 1.30s, ETA: 6.35 min
# [490/800] Sample processed in 1.39s, ETA: 6.33 min
# [491/800] Sample processed in 0.96s, ETA: 6.31 min
# [492/800] Sample processed in 1.33s, ETA: 6.29 min
# [493/800] Sample processed in 1.16s, ETA: 6.27 min
# [494/800] Sample processed in 0.92s, ETA: 6.24 min
# [495/800] Sample processed in 1.60s, ETA: 6.23 min
# [496/800] Sample processed in 1.47s, ETA: 6.21 min
# [497/800] Sample processed in 1.38s, ETA: 6.19 min
# [498/800] Sample processed in 1.22s, ETA: 6.17 min
# [499/800] Sample processed in 0.92s, ETA: 6.15 min
# [500/800] Sample processed in 1.40s, ETA: 6.13 min
# [501/800] Sample processed in 0.96s, ETA: 6.10 min
# [502/800] Sample processed in 1.08s, ETA: 6.08 min
# [503/800] Sample processed in 1.00s, ETA: 6.06 min
# [504/800] Sample processed in 1.03s, ETA: 6.04 min
# [505/800] Sample processed in 1.01s, ETA: 6.01 min
# [506/800] Sample processed in 1.00s, ETA: 5.99 min
# [507/800] Sample processed in 1.01s, ETA: 5.97 min
# [508/800] Sample processed in 1.00s, ETA: 5.95 min
# [509/800] Sample processed in 1.02s, ETA: 5.92 min
# [510/800] Sample processed in 0.96s, ETA: 5.90 min
# [511/800] Sample processed in 1.00s, ETA: 5.88 min
# [512/800] Sample processed in 0.95s, ETA: 5.86 min
# [513/800] Sample processed in 1.00s, ETA: 5.83 min
# [514/800] Sample processed in 0.95s, ETA: 5.81 min
# [515/800] Sample processed in 0.95s, ETA: 5.79 min
# [516/800] Sample processed in 0.96s, ETA: 5.77 min
# [517/800] Sample processed in 0.96s, ETA: 5.74 min
# [518/800] Sample processed in 1.00s, ETA: 5.72 min
# [519/800] Sample processed in 0.92s, ETA: 5.70 min
# [520/800] Sample processed in 1.00s, ETA: 5.68 min
# [521/800] Sample processed in 0.96s, ETA: 5.65 min
# [522/800] Sample processed in 1.00s, ETA: 5.63 min
# [523/800] Sample processed in 1.00s, ETA: 5.61 min
# [524/800] Sample processed in 0.95s, ETA: 5.59 min
# [525/800] Sample processed in 0.95s, ETA: 5.56 min
# [526/800] Sample processed in 0.95s, ETA: 5.54 min
# [527/800] Sample processed in 0.95s, ETA: 5.52 min
# [528/800] Sample processed in 0.96s, ETA: 5.50 min
# [529/800] Sample processed in 0.95s, ETA: 5.47 min
# [530/800] Sample processed in 0.95s, ETA: 5.45 min
# [531/800] Sample processed in 0.94s, ETA: 5.43 min
# [532/800] Sample processed in 0.95s, ETA: 5.41 min
# [533/800] Sample processed in 0.96s, ETA: 5.38 min
# [534/800] Sample processed in 0.95s, ETA: 5.36 min
# [535/800] Sample processed in 0.96s, ETA: 5.34 min
# [536/800] Sample processed in 0.95s, ETA: 5.32 min
# [537/800] Sample processed in 0.96s, ETA: 5.30 min
# [538/800] Sample processed in 0.95s, ETA: 5.27 min
# [539/800] Sample processed in 1.00s, ETA: 5.25 min
# [592/800] Sample processed in 0.96s, ETA: 4.11 min
# [593/800] Sample processed in 1.00s, ETA: 4.09 min
# [594/800] Sample processed in 0.95s, ETA: 4.07 min
# [595/800] Sample processed in 0.95s, ETA: 4.05 min
# [596/800] Sample processed in 0.95s, ETA: 4.03 min
# [597/800] Sample processed in 1.00s, ETA: 4.01 min
# [598/800] Sample processed in 0.95s, ETA: 3.99 min
# [599/800] Sample processed in 1.00s, ETA: 3.97 min
# [600/800] Sample processed in 0.95s, ETA: 3.94 min
# [601/800] Sample processed in 36.25s, ETA: 4.12 min
# [602/800] Sample processed in 32.30s, ETA: 4.27 min
# [603/800] Sample processed in 36.47s, ETA: 4.44 min
# [604/800] Sample processed in 35.21s, ETA: 4.60 min
# [605/800] Sample processed in 35.54s, ETA: 4.76 min
# [606/800] Sample processed in 33.67s, ETA: 4.91 min
# [607/800] Sample processed in 33.82s, ETA: 5.05 min
# [608/800] Sample processed in 34.92s, ETA: 5.20 min
# [609/800] Sample processed in 33.61s, ETA: 5.34 min
# [610/800] Sample processed in 35.18s, ETA: 5.49 min
# [611/800] Sample processed in 35.66s, ETA: 5.63 min
# [612/800] Sample processed in 35.53s, ETA: 5.78 min
# [613/800] Sample processed in 34.13s, ETA: 5.91 min
# [614/800] Sample processed in 33.97s, ETA: 6.04 min
# [615/800] Sample processed in 34.20s, ETA: 6.17 min
# [616/800] Sample processed in 35.22s, ETA: 6.30 min
# [617/800] Sample processed in 33.70s, ETA: 6.42 min
# [618/800] Sample processed in 35.86s, ETA: 6.55 min
# [619/800] Sample processed in 34.43s, ETA: 6.67 min
# [620/800] Sample processed in 33.32s, ETA: 6.79 min
# [621/800] Sample processed in 34.24s, ETA: 6.90 min
# [622/800] Sample processed in 34.20s, ETA: 7.02 min
# [623/800] Sample processed in 33.03s, ETA: 7.12 min
# [624/800] Sample processed in 35.24s, ETA: 7.24 min
# [625/800] Sample processed in 33.84s, ETA: 7.34 min
# [626/800] Sample processed in 34.40s, ETA: 7.45 min
# [627/800] Sample processed in 33.87s, ETA: 7.55 min
# [628/800] Sample processed in 35.75s, ETA: 7.66 min
# [629/800] Sample processed in 35.12s, ETA: 7.76 min
# [630/800] Sample processed in 33.83s, ETA: 7.85 min
# [631/800] Sample processed in 35.34s, ETA: 7.95 min
# [632/800] Sample processed in 33.94s, ETA: 8.04 min
# [633/800] Sample processed in 36.34s, ETA: 8.14 min
# [634/800] Sample processed in 34.27s, ETA: 8.23 min
# [635/800] Sample processed in 35.43s, ETA: 8.32 min
# [636/800] Sample processed in 32.72s, ETA: 8.40 min
# [637/800] Sample processed in 35.47s, ETA: 8.49 min
# [638/800] Sample processed in 33.79s, ETA: 8.56 min
# [639/800] Sample processed in 35.06s, ETA: 8.65 min
# [640/800] Sample processed in 33.42s, ETA: 8.72 min
# [641/800] Sample processed in 33.89s, ETA: 8.79 min
# [642/800] Sample processed in 34.38s, ETA: 8.86 min
# [643/800] Sample processed in 33.90s, ETA: 8.93 min
# [644/800] Sample processed in 33.88s, ETA: 9.00 min
# [645/800] Sample processed in 36.10s, ETA: 9.07 min
# [646/800] Sample processed in 34.89s, ETA: 9.14 min
# [647/800] Sample processed in 35.16s, ETA: 9.20 min
# [648/800] Sample processed in 35.59s, ETA: 9.27 min
# [649/800] Sample processed in 32.56s, ETA: 9.32 min
# [650/800] Sample processed in 33.61s, ETA: 9.37 min
# [651/800] Sample processed in 35.49s, ETA: 9.43 min
# [652/800] Sample processed in 35.10s, ETA: 9.48 min
# [653/800] Sample processed in 32.97s, ETA: 9.53 min
# [654/800] Sample processed in 34.14s, ETA: 9.58 min
# [655/800] Sample processed in 34.72s, ETA: 9.62 min
# [656/800] Sample processed in 36.43s, ETA: 9.68 min
# [657/800] Sample processed in 35.49s, ETA: 9.72 min
# [658/800] Sample processed in 36.50s, ETA: 9.77 min
# [659/800] Sample processed in 36.19s, ETA: 9.82 min
# [660/800] Sample processed in 33.85s, ETA: 9.85 min
# [661/800] Sample processed in 34.67s, ETA: 9.89 min
# [662/800] Sample processed in 35.04s, ETA: 9.93 min
# [663/800] Sample processed in 34.46s, ETA: 9.96 min
# [664/800] Sample processed in 34.89s, ETA: 9.99 min
# [665/800] Sample processed in 35.99s, ETA: 10.02 min
# [666/800] Sample processed in 35.80s, ETA: 10.05 min
# [667/800] Sample processed in 34.61s, ETA: 10.08 min
# [668/800] Sample processed in 34.86s, ETA: 10.10 min
# [669/800] Sample processed in 35.04s, ETA: 10.13 min
# [670/800] Sample processed in 33.41s, ETA: 10.14 min
# [671/800] Sample processed in 34.34s, ETA: 10.16 min
# [672/800] Sample processed in 34.15s, ETA: 10.17 min
# [673/800] Sample processed in 36.13s, ETA: 10.19 min
# [674/800] Sample processed in 35.69s, ETA: 10.21 min
# [675/800] Sample processed in 35.69s, ETA: 10.22 min
# [676/800] Sample processed in 34.79s, ETA: 10.23 min
# [677/800] Sample processed in 34.40s, ETA: 10.24 min
# [678/800] Sample processed in 33.59s, ETA: 10.24 min
# [679/800] Sample processed in 36.05s, ETA: 10.25 min
# [680/800] Sample processed in 35.00s, ETA: 10.25 min
# [681/800] Sample processed in 34.72s, ETA: 10.25 min
# [682/800] Sample processed in 33.34s, ETA: 10.25 min
# [683/800] Sample processed in 34.08s, ETA: 10.24 min
# [684/800] Sample processed in 34.58s, ETA: 10.24 min
# [685/800] Sample processed in 34.71s, ETA: 10.23 min
# [686/800] Sample processed in 34.86s, ETA: 10.23 min
# [687/800] Sample processed in 36.02s, ETA: 10.22 min
# [688/800] Sample processed in 36.10s, ETA: 10.21 min
# [689/800] Sample processed in 34.97s, ETA: 10.20 min
# [690/800] Sample processed in 34.83s, ETA: 10.19 min
# [691/800] Sample processed in 33.83s, ETA: 10.17 min
# [692/800] Sample processed in 34.31s, ETA: 10.15 min
# [693/800] Sample processed in 35.01s, ETA: 10.13 min
# [694/800] Sample processed in 36.29s, ETA: 10.11 min
# [695/800] Sample processed in 34.10s, ETA: 10.09 min
# [696/800] Sample processed in 35.08s, ETA: 10.07 min
# [697/800] Sample processed in 33.48s, ETA: 10.04 min
# [698/800] Sample processed in 34.91s, ETA: 10.01 min
# [699/800] Sample processed in 36.48s, ETA: 9.99 min
# [700/800] Sample processed in 34.21s, ETA: 9.96 min
# [701/800] Sample processed in 31.19s, ETA: 9.92 min
# [702/800] Sample processed in 32.95s, ETA: 9.88 min
# [703/800] Sample processed in 30.49s, ETA: 9.83 min
# [704/800] Sample processed in 30.18s, ETA: 9.79 min
# [705/800] Sample processed in 30.42s, ETA: 9.74 min
# [706/800] Sample processed in 30.24s, ETA: 9.69 min
# [707/800] Sample processed in 30.17s, ETA: 9.64 min
# [708/800] Sample processed in 29.94s, ETA: 9.59 min
# [709/800] Sample processed in 31.49s, ETA: 9.54 min
# [710/800] Sample processed in 30.14s, ETA: 9.48 min
# [711/800] Sample processed in 30.59s, ETA: 9.43 min
# [712/800] Sample processed in 31.51s, ETA: 9.37 min
# [713/800] Sample processed in 30.32s, ETA: 9.32 min
# [714/800] Sample processed in 34.52s, ETA: 9.27 min
# [715/800] Sample processed in 30.66s, ETA: 9.21 min
# [716/800] Sample processed in 30.26s, ETA: 9.14 min
# [717/800] Sample processed in 30.43s, ETA: 9.08 min
# [718/800] Sample processed in 31.49s, ETA: 9.02 min
# [719/800] Sample processed in 32.29s, ETA: 8.96 min
# [720/800] Sample processed in 30.15s, ETA: 8.89 min
# [721/800] Sample processed in 30.05s, ETA: 8.82 min
# [722/800] Sample processed in 30.17s, ETA: 8.75 min
# [723/800] Sample processed in 30.54s, ETA: 8.68 min
# [724/800] Sample processed in 30.55s, ETA: 8.61 min
# [725/800] Sample processed in 30.49s, ETA: 8.54 min
# [726/800] Sample processed in 30.72s, ETA: 8.47 min
# [727/800] Sample processed in 29.83s, ETA: 8.39 min
# [728/800] Sample processed in 30.42s, ETA: 8.31 min
# [729/800] Sample processed in 30.28s, ETA: 8.24 min
# [730/800] Sample processed in 30.24s, ETA: 8.16 min
# [731/800] Sample processed in 30.52s, ETA: 8.08 min
# [732/800] Sample processed in 30.26s, ETA: 8.00 min
# [733/800] Sample processed in 30.33s, ETA: 7.91 min
# [734/800] Sample processed in 30.37s, ETA: 7.83 min
# [735/800] Sample processed in 30.59s, ETA: 7.75 min
# [736/800] Sample processed in 30.20s, ETA: 7.66 min
# [737/800] Sample processed in 30.47s, ETA: 7.58 min
# [738/800] Sample processed in 30.27s, ETA: 7.49 min
# [739/800] Sample processed in 30.36s, ETA: 7.40 min
# [740/800] Sample processed in 31.43s, ETA: 7.31 min
# [741/800] Sample processed in 31.18s, ETA: 7.22 min
# [742/800] Sample processed in 30.40s, ETA: 7.13 min
# [743/800] Sample processed in 30.90s, ETA: 7.03 min
# [744/800] Sample processed in 30.18s, ETA: 6.94 min
# [745/800] Sample processed in 30.78s, ETA: 6.84 min
# [746/800] Sample processed in 30.21s, ETA: 6.75 min
# [747/800] Sample processed in 30.76s, ETA: 6.65 min
# [748/800] Sample processed in 33.73s, ETA: 6.55 min
# [749/800] Sample processed in 30.15s, ETA: 6.45 min
# [750/800] Sample processed in 30.52s, ETA: 6.35 min
# [751/800] Sample processed in 30.63s, ETA: 6.25 min
# [752/800] Sample processed in 30.33s, ETA: 6.15 min
# [753/800] Sample processed in 31.82s, ETA: 6.04 min
# [754/800] Sample processed in 30.39s, ETA: 5.94 min
# [755/800] Sample processed in 30.33s, ETA: 5.83 min
# [756/800] Sample processed in 30.33s, ETA: 5.72 min
# [757/800] Sample processed in 30.19s, ETA: 5.62 min
# [758/800] Sample processed in 30.57s, ETA: 5.51 min
# [759/800] Sample processed in 30.23s, ETA: 5.40 min
# [760/800] Sample processed in 30.23s, ETA: 5.28 min
# [761/800] Sample processed in 29.87s, ETA: 5.17 min
# [762/800] Sample processed in 31.06s, ETA: 5.06 min
# [763/800] Sample processed in 30.10s, ETA: 4.94 min
# [764/800] Sample processed in 30.32s, ETA: 4.83 min
# [765/800] Sample processed in 33.90s, ETA: 4.71 min
# [766/800] Sample processed in 30.34s, ETA: 4.59 min
# [767/800] Sample processed in 32.81s, ETA: 4.48 min
# [768/800] Sample processed in 30.59s, ETA: 4.36 min
# [769/800] Sample processed in 30.31s, ETA: 4.23 min
# [770/800] Sample processed in 30.18s, ETA: 4.11 min
# [771/800] Sample processed in 30.09s, ETA: 3.99 min
# [772/800] Sample processed in 30.35s, ETA: 3.86 min
# [773/800] Sample processed in 30.67s, ETA: 3.74 min
# [774/800] Sample processed in 30.17s, ETA: 3.61 min
# [775/800] Sample processed in 30.26s, ETA: 3.49 min
# [776/800] Sample processed in 30.17s, ETA: 3.36 min
# [777/800] Sample processed in 30.77s, ETA: 3.23 min
# [778/800] Sample processed in 30.33s, ETA: 3.10 min
# [779/800] Sample processed in 30.99s, ETA: 2.97 min
# [780/800] Sample processed in 30.28s, ETA: 2.84 min
# [781/800] Sample processed in 30.52s, ETA: 2.70 min
# [782/800] Sample processed in 30.65s, ETA: 2.57 min
# [783/800] Sample processed in 30.31s, ETA: 2.43 min
# [784/800] Sample processed in 30.52s, ETA: 2.30 min
# [785/800] Sample processed in 30.22s, ETA: 2.16 min
# [786/800] Sample processed in 33.25s, ETA: 2.03 min
# [787/800] Sample processed in 30.40s, ETA: 1.89 min
# [788/800] Sample processed in 30.72s, ETA: 1.75 min
# [789/800] Sample processed in 30.31s, ETA: 1.61 min
# [790/800] Sample processed in 30.18s, ETA: 1.46 min
# [791/800] Sample processed in 30.34s, ETA: 1.32 min
# [792/800] Sample processed in 30.21s, ETA: 1.18 min
# [793/800] Sample processed in 30.21s, ETA: 1.03 min
# [794/800] Sample processed in 30.35s, ETA: 0.89 min
# [795/800] Sample processed in 30.93s, ETA: 0.74 min
# [796/800] Sample processed in 30.20s, ETA: 0.60 min
# [797/800] Sample processed in 30.30s, ETA: 0.45 min
# [798/800] Sample processed in 30.27s, ETA: 0.30 min
# [799/800] Sample processed in 30.86s, ETA: 0.15 min
# [800/800] Sample processed in 30.14s, ETA: 0.00 min
#
# All samples processed. Total time: 120.79 min
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
