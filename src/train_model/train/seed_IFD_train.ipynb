# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] ="1"

# %%
from huggingface_hub import logout, notebook_login
# logout()
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset

seed = load_dataset("passionMan/real_seed_IFD")
seed
# Out:
# README.md:   0%|          | 0.00/353 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/7.96M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/15156 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 15156
#     })
# })

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-28 00:32:17 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.2.12: Fast Llama patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-PCIE-40GB. Max memory: 39.394 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj"],
    lora_alpha = 32,
    lora_dropout = 0.05, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2025.2.12 patched 28 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]

    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("passionMan/real_seed_IFD", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/15156 [00:00<?, ? examples/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 8,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 16,
        gradient_accumulation_steps = 4,
        warmup_steps = 90, # 50
        num_train_epochs = 2, # Set this for 1 full training run.
        # max_steps = 60,
        learning_rate = 2e-5,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 100,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs/last_seed_IFD",
        report_to = "none", # Use this for WandB etc
        save_steps = 100,
    ),
)
# Out:
# Applying chat template to train dataset (num_proc=8):   0%|          | 0/8937 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=8):   0%|          | 0/8937 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=8):   0%|          | 0/8937 [00:00<?, ? examples/s]

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 8,937 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 4
# \        /    Total batch size = 64 | Total steps = 278
#  "-____-"     Number of trainable parameters = 13,631,488
#     <div>
#
#       <progress value='278' max='278' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [278/278 56:51, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.829500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.410800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
import json
import time
import random
from datasets import load_dataset
from collections import defaultdict

### ✅ Hugging Face에서 데이터 로드
dataset_name = "passionMan/test_dataset10"
dataset = load_dataset(dataset_name, split="test")  # 'test' split 로드

### ✅ JSONL 저장 함수 (평가 결과 저장용)
def save_to_jsonl(file_path, data):
    with open(file_path, "a", encoding="utf-8") as f: 
        f.write(json.dumps(data, ensure_ascii=False) + "\n")

### ✅ 모델 응답 생성 함수
def generate_response(instruction_text, input_text, max_new_tokens=128):
    try:
        FastLanguageModel.for_inference(model)  # Enable native 2x faster inference

        # ✅ 모델의 최대 입력 길이 가져오기 (보통 4096 또는 2048)
        max_input_length = getattr(model.config, "max_position_embeddings", 4096)

        # ✅ 입력 토큰 길이 확인
        input_tokens = tokenizer(
            alpaca_prompt.format(instruction_text, input_text, ""), 
            return_tensors="pt"
        ).to("cuda")

        input_length = input_tokens['input_ids'].shape[1]

        # 🔥 입력이 너무 길면 최대 입력 길이에 맞게 자름
        if input_length > max_input_length:
            print(f"[WARNING] Truncating input from {input_length} to {max_input_length} tokens.")
            input_text = tokenizer.decode(input_tokens['input_ids'][0, :max_input_length], skip_special_tokens=True)

        # ✅ 생성 수행 (max_new_tokens을 적용)
        outputs = model.generate(
            **tokenizer(alpaca_prompt.format(instruction_text, input_text, ""), return_tensors="pt").to("cuda"),
            max_new_tokens=max_new_tokens,  # ✅ 생성 길이 적용
            use_cache=True
        )

        decoded_outputs = tokenizer.batch_decode(outputs)
        response_texts = [output.split("### Response:\n")[-1].strip() for output in decoded_outputs]
        return response_texts[0].replace("<|eot_id|>", "")

    except Exception as e:
        print(f"[ERROR] Exception in response generation: {str(e)}")
        return None

# ✅ 데이터 경로 설정 (결과 저장용)
output_json_path = "response/last_seed_IFD_45_rIFD_95.jsonl"

# ✅ Task별 데이터 그룹화 (각 태스크별 0~29번 샘플 선택)
grouped_data = defaultdict(list)
for item in dataset:
    grouped_data[item["task"]].append(item)

# ✅ 성능 평가할 데이터 생성 (각 태스크별 30개만 추출)
sampled_data = []
for task, samples in grouped_data.items():
    sampled_data.extend(samples[:100])  # 최대 30개 선택

# ✅ 성능 평가 시작
start_time = time.time()
total_samples = len(sampled_data)

for idx, item in enumerate(sampled_data):
    sample_start_time = time.time()

    input_text = item.get("input", "")
    instruction = item.get("instruction", "")
    task = item.get("task", "").lower()

    # ✅ 생성할 토큰 길이 설정 (생성 토큰 수 조절)
    short_context_tasks = {"qa1", "qa2", "qa3", "nli", "re", "re2"}  # 생성 32
    medium_context_tasks = {"ie"} # 생성 128
    long_context_tasks = {"summarization", "generation", "daily_diets", "alternative_diet"}  # 생성 1024

    if task in short_context_tasks:
        max_new_tokens = 32  # ✅ 생성 길이 128
    elif task in medium_context_tasks:
        max_new_tokens = 32
    elif task in long_context_tasks:
        max_new_tokens = 512  # ✅ 생성 길이 1024
    else:
        max_new_tokens = 128  # 기본값

    try:
        model_output = generate_response(instruction, input_text, max_new_tokens)

        if model_output is not None:
            output_data = item.copy()
            output_data.update({f"model_output_{max_new_tokens}": model_output})
            save_to_jsonl(output_json_path, output_data)
        else:
            print(f"[WARNING] Skipping sample {idx+1}/{total_samples} due to length limit or generation failure.")

    except Exception as e:
        print(f"[ERROR] Skipping sample {idx+1}/{total_samples} due to unexpected error: {str(e)}")

    elapsed_time = time.time() - start_time
    avg_time_per_sample = elapsed_time / (idx + 1) 
    remaining_samples = total_samples - (idx + 1)
    estimated_remaining_time = remaining_samples * avg_time_per_sample

    print(f"[{idx+1}/{total_samples}] Sample processed in {time.time() - sample_start_time:.2f}s, ETA: {estimated_remaining_time/60:.2f} min")

print(f"\nAll samples processed. Total time: {(time.time() - start_time)/60:.2f} min")
# Out:
# [1/900] Sample processed in 6.67s, ETA: 100.01 min
# [2/900] Sample processed in 2.46s, ETA: 68.36 min
# [3/900] Sample processed in 9.81s, ETA: 94.40 min
# [4/900] Sample processed in 6.41s, ETA: 94.65 min
# [5/900] Sample processed in 6.54s, ETA: 95.16 min
# [6/900] Sample processed in 17.02s, ETA: 121.47 min
# [7/900] Sample processed in 7.44s, ETA: 119.83 min
# [8/900] Sample processed in 9.15s, ETA: 121.74 min
# [9/900] Sample processed in 2.95s, ETA: 112.96 min
# [10/900] Sample processed in 4.70s, ETA: 108.52 min
# [11/900] Sample processed in 6.13s, ETA: 106.80 min
# [12/900] Sample processed in 5.78s, ETA: 104.92 min
# [13/900] Sample processed in 8.14s, ETA: 106.00 min
# [14/900] Sample processed in 4.84s, ETA: 103.42 min
# [15/900] Sample processed in 7.12s, ETA: 103.42 min
# [16/900] Sample processed in 18.33s, ETA: 113.72 min
# [17/900] Sample processed in 18.30s, ETA: 122.75 min
# [18/900] Sample processed in 6.93s, ETA: 121.46 min
# [19/900] Sample processed in 8.89s, ETA: 121.80 min
# [20/900] Sample processed in 3.43s, ETA: 118.10 min
# [21/900] Sample processed in 9.35s, ETA: 118.87 min
# [22/900] Sample processed in 11.48s, ETA: 120.97 min
# [23/900] Sample processed in 6.30s, ETA: 119.59 min
# [24/900] Sample processed in 9.36s, ETA: 120.17 min
# [25/900] Sample processed in 7.64s, ETA: 119.68 min
# [26/900] Sample processed in 6.95s, ETA: 118.84 min
# [27/900] Sample processed in 4.17s, ETA: 116.56 min
# [28/900] Sample processed in 15.56s, ETA: 120.34 min
# [29/900] Sample processed in 6.45s, ETA: 119.29 min
# [30/900] Sample processed in 8.18s, ETA: 119.14 min
# [31/900] Sample processed in 3.74s, ETA: 116.91 min
# [32/900] Sample processed in 12.86s, ETA: 118.93 min
# [33/900] Sample processed in 3.04s, ETA: 116.53 min
# [34/900] Sample processed in 8.79s, ETA: 116.70 min
# [35/900] Sample processed in 4.51s, ETA: 115.10 min
# [36/900] Sample processed in 12.61s, ETA: 116.81 min
# [37/900] Sample processed in 9.42s, ETA: 117.19 min
# [38/900] Sample processed in 8.25s, ETA: 117.09 min
# [39/900] Sample processed in 4.48s, ETA: 115.60 min
# [40/900] Sample processed in 3.36s, ETA: 113.79 min
# [41/900] Sample processed in 14.79s, ETA: 116.05 min
# [42/900] Sample processed in 4.12s, ETA: 114.56 min
# [43/900] Sample processed in 14.06s, ETA: 116.43 min
# [44/900] Sample processed in 4.41s, ETA: 115.08 min
# [45/900] Sample processed in 5.68s, ETA: 114.19 min
# [46/900] Sample processed in 10.93s, ETA: 114.96 min
# [47/900] Sample processed in 5.91s, ETA: 114.17 min
# [48/900] Sample processed in 3.32s, ETA: 112.65 min
# [101/900] Sample processed in 0.77s, ETA: 106.99 min
# [102/900] Sample processed in 0.66s, ETA: 105.89 min
# [103/900] Sample processed in 1.20s, ETA: 104.89 min
# [104/900] Sample processed in 1.19s, ETA: 103.90 min
# [105/900] Sample processed in 1.20s, ETA: 102.93 min
# [106/900] Sample processed in 1.21s, ETA: 101.99 min
# [107/900] Sample processed in 1.20s, ETA: 101.05 min
# [108/900] Sample processed in 1.21s, ETA: 100.14 min
# [109/900] Sample processed in 1.20s, ETA: 99.24 min
# [110/900] Sample processed in 1.20s, ETA: 98.36 min
# [111/900] Sample processed in 1.21s, ETA: 97.49 min
# [112/900] Sample processed in 1.19s, ETA: 96.64 min
# [113/900] Sample processed in 1.19s, ETA: 95.80 min
# [114/900] Sample processed in 1.20s, ETA: 94.98 min
# [115/900] Sample processed in 0.44s, ETA: 94.08 min
# [116/900] Sample processed in 1.13s, ETA: 93.28 min
# [117/900] Sample processed in 1.22s, ETA: 92.50 min
# [118/900] Sample processed in 1.18s, ETA: 91.73 min
# [119/900] Sample processed in 1.21s, ETA: 90.97 min
# [120/900] Sample processed in 0.91s, ETA: 90.20 min
# [121/900] Sample processed in 1.19s, ETA: 89.47 min
# [122/900] Sample processed in 0.84s, ETA: 88.71 min
# [123/900] Sample processed in 0.79s, ETA: 87.96 min
# [124/900] Sample processed in 0.30s, ETA: 87.17 min
# [125/900] Sample processed in 0.98s, ETA: 86.46 min
# [126/900] Sample processed in 0.30s, ETA: 85.69 min
# [127/900] Sample processed in 1.21s, ETA: 85.03 min
# [128/900] Sample processed in 1.19s, ETA: 84.38 min
# [129/900] Sample processed in 1.19s, ETA: 83.73 min
# [130/900] Sample processed in 0.59s, ETA: 83.04 min
# [131/900] Sample processed in 1.13s, ETA: 82.41 min
# [132/900] Sample processed in 1.20s, ETA: 81.80 min
# [133/900] Sample processed in 0.37s, ETA: 81.11 min
# [134/900] Sample processed in 1.20s, ETA: 80.52 min
# [135/900] Sample processed in 1.21s, ETA: 79.93 min
# [136/900] Sample processed in 0.13s, ETA: 79.25 min
# [137/900] Sample processed in 1.22s, ETA: 78.68 min
# [138/900] Sample processed in 0.84s, ETA: 78.09 min
# [139/900] Sample processed in 1.15s, ETA: 77.53 min
# [140/900] Sample processed in 1.19s, ETA: 76.98 min
# [141/900] Sample processed in 1.19s, ETA: 76.44 min
# [142/900] Sample processed in 1.20s, ETA: 75.91 min
# [143/900] Sample processed in 1.21s, ETA: 75.39 min
# [144/900] Sample processed in 1.18s, ETA: 74.87 min
# [145/900] Sample processed in 0.49s, ETA: 74.29 min
# [146/900] Sample processed in 1.20s, ETA: 73.79 min
# [147/900] Sample processed in 0.34s, ETA: 73.22 min
# [148/900] Sample processed in 1.19s, ETA: 72.73 min
# [149/900] Sample processed in 1.20s, ETA: 72.25 min
# [150/900] Sample processed in 1.19s, ETA: 71.77 min
# [151/900] Sample processed in 1.19s, ETA: 71.30 min
# [152/900] Sample processed in 1.20s, ETA: 70.83 min
# [153/900] Sample processed in 1.20s, ETA: 70.37 min
# [785/900] Sample processed in 0.58s, ETA: 2.64 min
# [786/900] Sample processed in 0.51s, ETA: 2.62 min
# [787/900] Sample processed in 0.41s, ETA: 2.59 min
# [788/900] Sample processed in 0.69s, ETA: 2.57 min
# [789/900] Sample processed in 0.55s, ETA: 2.54 min
# [790/900] Sample processed in 0.76s, ETA: 2.52 min
# [791/900] Sample processed in 0.55s, ETA: 2.49 min
# [792/900] Sample processed in 0.41s, ETA: 2.47 min
# [793/900] Sample processed in 0.58s, ETA: 2.44 min
# [794/900] Sample processed in 0.55s, ETA: 2.42 min
# [795/900] Sample processed in 0.55s, ETA: 2.39 min
# [796/900] Sample processed in 0.62s, ETA: 2.37 min
# [797/900] Sample processed in 0.59s, ETA: 2.35 min
# [798/900] Sample processed in 0.41s, ETA: 2.32 min
# [799/900] Sample processed in 0.63s, ETA: 2.30 min
# [800/900] Sample processed in 0.37s, ETA: 2.27 min
# [801/900] Sample processed in 11.42s, ETA: 2.27 min
# [802/900] Sample processed in 2.92s, ETA: 2.25 min
# [803/900] Sample processed in 9.16s, ETA: 2.24 min
# [804/900] Sample processed in 8.94s, ETA: 2.23 min
# [805/900] Sample processed in 9.60s, ETA: 2.23 min
# [806/900] Sample processed in 5.79s, ETA: 2.21 min
# [807/900] Sample processed in 7.33s, ETA: 2.20 min
# [808/900] Sample processed in 22.16s, ETA: 2.22 min
# [809/900] Sample processed in 4.34s, ETA: 2.20 min
# [810/900] Sample processed in 11.32s, ETA: 2.19 min
# [811/900] Sample processed in 18.29s, ETA: 2.20 min
# [812/900] Sample processed in 11.69s, ETA: 2.19 min
# [813/900] Sample processed in 13.32s, ETA: 2.19 min
# [814/900] Sample processed in 13.47s, ETA: 2.18 min
# [815/900] Sample processed in 8.22s, ETA: 2.17 min
# [816/900] Sample processed in 15.11s, ETA: 2.17 min
# [817/900] Sample processed in 16.07s, ETA: 2.17 min
# [818/900] Sample processed in 4.82s, ETA: 2.15 min
# [819/900] Sample processed in 18.22s, ETA: 2.15 min
# [820/900] Sample processed in 6.95s, ETA: 2.13 min
# [821/900] Sample processed in 13.34s, ETA: 2.12 min
# [822/900] Sample processed in 13.88s, ETA: 2.11 min
# [823/900] Sample processed in 11.59s, ETA: 2.10 min
# [824/900] Sample processed in 4.91s, ETA: 2.08 min
# [825/900] Sample processed in 8.84s, ETA: 2.06 min
# [826/900] Sample processed in 12.64s, ETA: 2.05 min
# [827/900] Sample processed in 18.40s, ETA: 2.05 min
# [828/900] Sample processed in 12.59s, ETA: 2.04 min
# [829/900] Sample processed in 10.10s, ETA: 2.02 min
# [830/900] Sample processed in 4.92s, ETA: 2.00 min
# [831/900] Sample processed in 18.36s, ETA: 1.99 min
# [832/900] Sample processed in 9.68s, ETA: 1.97 min
# [833/900] Sample processed in 14.93s, ETA: 1.96 min
# [834/900] Sample processed in 7.70s, ETA: 1.94 min
# [835/900] Sample processed in 19.12s, ETA: 1.93 min
# [836/900] Sample processed in 11.63s, ETA: 1.92 min
# [837/900] Sample processed in 17.87s, ETA: 1.91 min
# [838/900] Sample processed in 18.34s, ETA: 1.90 min
# [839/900] Sample processed in 26.66s, ETA: 1.90 min
# [840/900] Sample processed in 22.05s, ETA: 1.89 min
# [841/900] Sample processed in 10.14s, ETA: 1.87 min
# [842/900] Sample processed in 13.91s, ETA: 1.85 min
# [843/900] Sample processed in 6.30s, ETA: 1.82 min
# [844/900] Sample processed in 7.09s, ETA: 1.80 min
# [845/900] Sample processed in 18.33s, ETA: 1.78 min
# [846/900] Sample processed in 7.94s, ETA: 1.76 min
# [847/900] Sample processed in 13.75s, ETA: 1.74 min
# [848/900] Sample processed in 10.54s, ETA: 1.71 min
# [849/900] Sample processed in 12.24s, ETA: 1.69 min
# [850/900] Sample processed in 6.62s, ETA: 1.66 min
# [851/900] Sample processed in 6.82s, ETA: 1.63 min
# [852/900] Sample processed in 18.26s, ETA: 1.61 min
# [853/900] Sample processed in 12.26s, ETA: 1.59 min
# [854/900] Sample processed in 7.36s, ETA: 1.56 min
# [855/900] Sample processed in 6.98s, ETA: 1.53 min
# [856/900] Sample processed in 8.40s, ETA: 1.50 min
# [857/900] Sample processed in 14.56s, ETA: 1.48 min
# [858/900] Sample processed in 18.48s, ETA: 1.46 min
# [859/900] Sample processed in 10.09s, ETA: 1.43 min
# [860/900] Sample processed in 9.95s, ETA: 1.40 min
# [861/900] Sample processed in 9.09s, ETA: 1.37 min
# [862/900] Sample processed in 18.32s, ETA: 1.35 min
# [863/900] Sample processed in 4.09s, ETA: 1.31 min
# [864/900] Sample processed in 6.05s, ETA: 1.28 min
# [865/900] Sample processed in 13.87s, ETA: 1.25 min
# [866/900] Sample processed in 15.35s, ETA: 1.23 min
# [867/900] Sample processed in 8.09s, ETA: 1.19 min
# [868/900] Sample processed in 11.52s, ETA: 1.16 min
# [869/900] Sample processed in 12.01s, ETA: 1.13 min
# [870/900] Sample processed in 18.29s, ETA: 1.11 min
# [871/900] Sample processed in 10.43s, ETA: 1.07 min
# [872/900] Sample processed in 12.70s, ETA: 1.04 min
# [873/900] Sample processed in 4.47s, ETA: 1.01 min
# [874/900] Sample processed in 6.03s, ETA: 0.97 min
# [875/900] Sample processed in 17.66s, ETA: 0.94 min
# [876/900] Sample processed in 12.30s, ETA: 0.91 min
# [877/900] Sample processed in 3.39s, ETA: 0.87 min
# [878/900] Sample processed in 5.10s, ETA: 0.83 min
# [879/900] Sample processed in 9.12s, ETA: 0.80 min
# [880/900] Sample processed in 18.29s, ETA: 0.77 min
# [881/900] Sample processed in 12.36s, ETA: 0.73 min
# [882/900] Sample processed in 9.00s, ETA: 0.70 min
# [883/900] Sample processed in 14.32s, ETA: 0.66 min
# [884/900] Sample processed in 8.54s, ETA: 0.62 min
# [885/900] Sample processed in 6.15s, ETA: 0.59 min
# [886/900] Sample processed in 8.38s, ETA: 0.55 min
# [887/900] Sample processed in 9.38s, ETA: 0.51 min
# [888/900] Sample processed in 10.94s, ETA: 0.47 min
# [889/900] Sample processed in 3.42s, ETA: 0.43 min
# [890/900] Sample processed in 6.35s, ETA: 0.40 min
# [891/900] Sample processed in 8.24s, ETA: 0.36 min
# [892/900] Sample processed in 12.46s, ETA: 0.32 min
# [893/900] Sample processed in 15.61s, ETA: 0.28 min
# [894/900] Sample processed in 10.05s, ETA: 0.24 min
# [895/900] Sample processed in 7.01s, ETA: 0.20 min
# [896/900] Sample processed in 3.95s, ETA: 0.16 min
# [897/900] Sample processed in 7.18s, ETA: 0.12 min
# [898/900] Sample processed in 9.07s, ETA: 0.08 min
# [899/900] Sample processed in 11.40s, ETA: 0.04 min
# [900/900] Sample processed in 8.67s, ETA: 0.00 min
#
# All samples processed. Total time: 36.76 min

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from unsloth import FastLanguageModel

import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    # model_name = "unsloth/Meta-Llama-3.1-8B-bnb-4bit",
    model_name = "/data/jaesung/llm_for_diabetes/src/trial7/main_table/llama_8b/outputs/last_seed/checkpoint-458",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)


alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-26 17:53:33 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.2.12: Fast Llama patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-PCIE-40GB. Max memory: 39.394 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.2.12 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %%
import torch
torch.manual_seed(1000) 

FastLanguageModel.for_inference(model) 

inputs = tokenizer(
[
    alpaca_prompt.format(
        # "Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.", 
        # "Can you recommend a daily diet recipe? Please provide detailed information on breakfast, lunch, and dinner.", 
        # "Prepare a healthy daily meal plan for a female aged 35 with 1400 kcal, including portion sizes in grams.",
        "Prepare a healthy daily meal plan for diebeic patien, including portion sizes in grams.",
        "",
        "", 
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 1024, do_sample=True)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Prepare a healthy daily meal plan for diebeic patien, including portion sizes in grams.
#
# ### Input:
#
#
# ### Response:
# Breakfast: 1 cup of steel-cut oats with 1/2 cup of nonfat milk and 1 tablespoon of ground flaxseed. Lunch: 3 ounces of grilled chicken breast with 1 cup of steamed broccoli and 1/2 cup of brown rice. Snack: 1 small apple with 1 tablespoon of almond butter. Dinner: 4 ounces of grilled salmon with 1 cup of steamed asparagus and 1/2 cup of quinoa.<|end_of_text|>

# %%
import torch
torch.manual_seed(400) 

FastLanguageModel.for_inference(model) 

inputs = tokenizer(
[
    alpaca_prompt.format(
        "Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.", 
        "",
        "", 
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 1024, do_sample=True)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.
#
# ### Input:
#
#
# ### Response:
# Diabetes is a metabolic disorder that affects how the body uses food for energy. It occurs when the body cannot produce enough insulin or when the body cannot properly use the insulin it produces. Insulin is a hormone that helps the body use glucose, a type of sugar, for energy. People with diabetes must carefully manage their blood sugar levels to avoid complications such as heart disease, stroke, and nerve damage.
#
# A healthy diet for a diabetic patient should include plenty of vegetables, fruits, whole grains, lean proteins, and healthy fats. It should also limit processed foods, sugary drinks, and refined carbohydrates. A typical daily diet for a diabetic patient might look like this:
#
# Breakfast: oatmeal with fresh berries, a glass of milk, and a cup of green tea
# Lunch: grilled chicken breast with steamed vegetables, brown rice, and a glass of water
# Dinner: baked fish with roasted vegetables, quinoa, and a small glass of red wine
# Snacks: a handful of nuts, a piece of fruit, or a small serving of yogurt
# It's important to consult with a registered dietitian or healthcare provider to develop a personalized diet plan for a diabetic patient. They can provide guidance on portion sizes, macronutrient ratios, and specific foods to include or avoid based on individual needs and health goals.<|end_of_text|>
