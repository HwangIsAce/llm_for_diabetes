# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] ="0"

# %%
from huggingface_hub import logout, notebook_login
# logout()
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset

seed = load_dataset("passionMan/real_seed_IFD_rIFD14")
seed
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output', 'ifd_loss'],
#         num_rows: 15156
#     })
# })

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = False # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-31 13:30:28 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.2.12: Fast Llama patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-PCIE-40GB. Max memory: 39.394 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj"],
    lora_alpha = 32,
    lora_dropout = 0.05, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2025.2.12 patched 28 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]

    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("passionMan/real_seed_IFD_rIFD14", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 8,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 16,
        gradient_accumulation_steps = 4,
        warmup_steps = 150, # 50
        num_train_epochs = 2, # Set this for 1 full training run.
        # max_steps = 60,
        learning_rate = 2e-5,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 100,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs/real_seed_IFD_rIFD14",
        report_to = "none", # Use this for WandB etc
        save_steps = 100,
    ),
)
# Out:
# Applying chat template to train dataset (num_proc=8):   0%|          | 0/15156 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=8):   0%|          | 0/15156 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=8):   0%|          | 0/15156 [00:00<?, ? examples/s]

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 15,156 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 4
# \        /    Total batch size = 64 | Total steps = 474
#  "-____-"     Number of trainable parameters = 9,175,040
#     <div>
#
#       <progress value='474' max='474' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [474/474 44:03, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>2.040000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.563100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.465400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.440700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
import json
import time
import random
from datasets import load_dataset
from collections import defaultdict

### ✅ Hugging Face에서 데이터 로드
dataset_name = "passionMan/test_dataset10"
dataset = load_dataset(dataset_name, split="test")  # 'test' split 로드

### ✅ JSONL 저장 함수 (평가 결과 저장용)
def save_to_jsonl(file_path, data):
    with open(file_path, "a", encoding="utf-8") as f: 
        f.write(json.dumps(data, ensure_ascii=False) + "\n")

### ✅ 모델 응답 생성 함수
def generate_response(instruction_text, input_text, max_new_tokens=128):
    try:
        FastLanguageModel.for_inference(model)  # Enable native 2x faster inference

        # ✅ 모델의 최대 입력 길이 가져오기 (보통 4096 또는 2048)
        max_input_length = getattr(model.config, "max_position_embeddings", 4096)

        # ✅ 입력 토큰 길이 확인
        input_tokens = tokenizer(
            alpaca_prompt.format(instruction_text, input_text, ""), 
            return_tensors="pt"
        ).to("cuda")

        input_length = input_tokens['input_ids'].shape[1]

        # 🔥 입력이 너무 길면 최대 입력 길이에 맞게 자름
        if input_length > max_input_length:
            print(f"[WARNING] Truncating input from {input_length} to {max_input_length} tokens.")
            input_text = tokenizer.decode(input_tokens['input_ids'][0, :max_input_length], skip_special_tokens=True)

        # ✅ 생성 수행 (max_new_tokens을 적용)
        outputs = model.generate(
            **tokenizer(alpaca_prompt.format(instruction_text, input_text, ""), return_tensors="pt").to("cuda"),
            max_new_tokens=max_new_tokens,  # ✅ 생성 길이 적용
            use_cache=True
        )

        decoded_outputs = tokenizer.batch_decode(outputs)
        response_texts = [output.split("### Response:\n")[-1].strip() for output in decoded_outputs]
        return response_texts[0].replace("<|eot_id|>", "")

    except Exception as e:
        print(f"[ERROR] Exception in response generation: {str(e)}")
        return None

# ✅ 데이터 경로 설정 (결과 저장용)
output_json_path = "response/real_seed_IFD_rIFD14.jsonl"

# ✅ Task별 데이터 그룹화 (각 태스크별 0~29번 샘플 선택)
grouped_data = defaultdict(list)
for item in dataset:
    grouped_data[item["task"]].append(item)

# ✅ 성능 평가할 데이터 생성 (각 태스크별 30개만 추출)
sampled_data = []
for task, samples in grouped_data.items():
    sampled_data.extend(samples[:100])  # 최대 30개 선택

# ✅ 성능 평가 시작
start_time = time.time()
total_samples = len(sampled_data)

for idx, item in enumerate(sampled_data):
    sample_start_time = time.time()

    input_text = item.get("input", "")
    instruction = item.get("instruction", "")
    task = item.get("task", "").lower()

    # ✅ 생성할 토큰 길이 설정 (생성 토큰 수 조절)
    short_context_tasks = {"qa1", "qa2", "qa3", "nli", "re", "re2"}  # 생성 32
    medium_context_tasks = {"ie"} # 생성 128
    long_context_tasks = {"summarization", "generation", "daily_diets", "alternative_diet"}  # 생성 1024

    if task in short_context_tasks:
        max_new_tokens = 32  # ✅ 생성 길이 128
    elif task in medium_context_tasks:
        max_new_tokens = 32
    elif task in long_context_tasks:
        max_new_tokens = 1024  # ✅ 생성 길이 1024
    else:
        max_new_tokens = 128  # 기본값

    try:
        model_output = generate_response(instruction, input_text, max_new_tokens)

        if model_output is not None:
            output_data = item.copy()
            output_data.update({f"model_output_{max_new_tokens}": model_output})
            save_to_jsonl(output_json_path, output_data)
        else:
            print(f"[WARNING] Skipping sample {idx+1}/{total_samples} due to length limit or generation failure.")

    except Exception as e:
        print(f"[ERROR] Skipping sample {idx+1}/{total_samples} due to unexpected error: {str(e)}")

    elapsed_time = time.time() - start_time
    avg_time_per_sample = elapsed_time / (idx + 1) 
    remaining_samples = total_samples - (idx + 1)
    estimated_remaining_time = remaining_samples * avg_time_per_sample

    print(f"[{idx+1}/{total_samples}] Sample processed in {time.time() - sample_start_time:.2f}s, ETA: {estimated_remaining_time/60:.2f} min")

print(f"\nAll samples processed. Total time: {(time.time() - start_time)/60:.2f} min")
# Out:
# [1/900] Sample processed in 5.47s, ETA: 81.94 min
# [2/900] Sample processed in 4.84s, ETA: 77.13 min
# [3/900] Sample processed in 4.81s, ETA: 75.31 min
# [4/900] Sample processed in 3.43s, ETA: 69.24 min
# [5/900] Sample processed in 5.36s, ETA: 71.33 min
# [6/900] Sample processed in 5.72s, ETA: 73.59 min
# [7/900] Sample processed in 6.72s, ETA: 77.29 min
# [8/900] Sample processed in 3.51s, ETA: 74.07 min
# [9/900] Sample processed in 1.98s, ETA: 69.03 min
# [10/900] Sample processed in 3.46s, ETA: 67.18 min
# [11/900] Sample processed in 3.75s, ETA: 66.05 min
# [12/900] Sample processed in 4.09s, ETA: 65.52 min
# [13/900] Sample processed in 8.52s, ETA: 70.10 min
# [14/900] Sample processed in 2.46s, ETA: 67.62 min
# [15/900] Sample processed in 5.49s, ETA: 68.44 min
# [16/900] Sample processed in 8.78s, ETA: 72.18 min
# [17/900] Sample processed in 2.69s, ETA: 70.18 min
# [18/900] Sample processed in 6.65s, ETA: 71.64 min
# [19/900] Sample processed in 7.06s, ETA: 73.25 min
# [20/900] Sample processed in 2.20s, ETA: 71.12 min
# [21/900] Sample processed in 2.01s, ETA: 69.06 min
# [22/900] Sample processed in 5.99s, ETA: 69.83 min
# [23/900] Sample processed in 5.17s, ETA: 70.00 min
# [24/900] Sample processed in 6.37s, ETA: 70.89 min
# [25/900] Sample processed in 6.06s, ETA: 71.51 min
# [26/900] Sample processed in 4.28s, ETA: 71.08 min
# [27/900] Sample processed in 3.99s, ETA: 70.52 min
# [28/900] Sample processed in 7.53s, ETA: 71.83 min
# [29/900] Sample processed in 3.46s, ETA: 71.00 min
# [30/900] Sample processed in 3.60s, ETA: 70.30 min
# [31/900] Sample processed in 5.95s, ETA: 70.73 min
# [32/900] Sample processed in 3.20s, ETA: 69.89 min
# [33/900] Sample processed in 4.36s, ETA: 69.60 min
# [34/900] Sample processed in 7.40s, ETA: 70.62 min
# [35/900] Sample processed in 5.21s, ETA: 70.67 min
# [36/900] Sample processed in 8.41s, ETA: 71.99 min
# [37/900] Sample processed in 7.30s, ETA: 72.80 min
# [38/900] Sample processed in 6.09s, ETA: 73.10 min
# [39/900] Sample processed in 4.70s, ETA: 72.88 min
# [40/900] Sample processed in 4.23s, ETA: 72.49 min
# [41/900] Sample processed in 4.31s, ETA: 72.14 min
# [42/900] Sample processed in 6.89s, ETA: 72.69 min
# [43/900] Sample processed in 3.65s, ETA: 72.13 min
# [44/900] Sample processed in 6.79s, ETA: 72.61 min
# [45/900] Sample processed in 3.25s, ETA: 71.94 min
# [46/900] Sample processed in 4.84s, ETA: 71.79 min
# [47/900] Sample processed in 3.27s, ETA: 71.18 min
# [48/900] Sample processed in 3.96s, ETA: 70.78 min
# [49/900] Sample processed in 6.28s, ETA: 71.08 min
# [50/900] Sample processed in 4.78s, ETA: 70.93 min
# [51/900] Sample processed in 6.67s, ETA: 71.30 min
# [52/900] Sample processed in 6.26s, ETA: 71.55 min
# [53/900] Sample processed in 6.44s, ETA: 71.84 min
# [54/900] Sample processed in 5.15s, ETA: 71.77 min
# [55/900] Sample processed in 6.72s, ETA: 72.10 min
# [56/900] Sample processed in 8.06s, ETA: 72.75 min
# [57/900] Sample processed in 3.84s, ETA: 72.34 min
# [58/900] Sample processed in 6.46s, ETA: 72.57 min
# [59/900] Sample processed in 3.54s, ETA: 72.10 min
# [60/900] Sample processed in 4.94s, ETA: 71.96 min
# [61/900] Sample processed in 6.80s, ETA: 72.26 min
# [62/900] Sample processed in 6.20s, ETA: 72.41 min
# [63/900] Sample processed in 2.19s, ETA: 71.66 min
# [64/900] Sample processed in 5.80s, ETA: 71.72 min
# [65/900] Sample processed in 5.31s, ETA: 71.66 min
# [66/900] Sample processed in 3.96s, ETA: 71.33 min
# [67/900] Sample processed in 8.18s, ETA: 71.88 min
# [68/900] Sample processed in 6.90s, ETA: 72.14 min
# [69/900] Sample processed in 4.20s, ETA: 71.85 min
# [70/900] Sample processed in 5.62s, ETA: 71.85 min
# [71/900] Sample processed in 4.52s, ETA: 71.63 min
# [72/900] Sample processed in 3.70s, ETA: 71.26 min
# [73/900] Sample processed in 3.77s, ETA: 70.91 min
# [74/900] Sample processed in 6.30s, ETA: 71.04 min
# [75/900] Sample processed in 6.65s, ETA: 71.23 min
# [76/900] Sample processed in 3.14s, ETA: 70.78 min
# [77/900] Sample processed in 8.30s, ETA: 71.25 min
# [78/900] Sample processed in 2.91s, ETA: 70.76 min
# [79/900] Sample processed in 3.20s, ETA: 70.34 min
# [80/900] Sample processed in 5.74s, ETA: 70.35 min
# [81/900] Sample processed in 4.01s, ETA: 70.08 min
# [82/900] Sample processed in 3.62s, ETA: 69.74 min
# [83/900] Sample processed in 2.20s, ETA: 69.18 min
# [84/900] Sample processed in 5.70s, ETA: 69.19 min
# [85/900] Sample processed in 7.15s, ETA: 69.44 min
# [86/900] Sample processed in 3.95s, ETA: 69.17 min
# [87/900] Sample processed in 4.17s, ETA: 68.94 min
# [88/900] Sample processed in 3.59s, ETA: 68.62 min
# [89/900] Sample processed in 2.46s, ETA: 68.14 min
# [90/900] Sample processed in 6.12s, ETA: 68.22 min
# [91/900] Sample processed in 4.88s, ETA: 68.11 min
# [92/900] Sample processed in 5.48s, ETA: 68.09 min
# [93/900] Sample processed in 4.12s, ETA: 67.87 min
# [94/900] Sample processed in 4.28s, ETA: 67.68 min
# [95/900] Sample processed in 6.24s, ETA: 67.76 min
# [96/900] Sample processed in 3.93s, ETA: 67.52 min
# [97/900] Sample processed in 4.09s, ETA: 67.31 min
# [98/900] Sample processed in 3.87s, ETA: 67.06 min
# [99/900] Sample processed in 2.22s, ETA: 66.60 min
# [100/900] Sample processed in 4.88s, ETA: 66.50 min
# [101/900] Sample processed in 0.87s, ETA: 65.88 min
# [102/900] Sample processed in 0.43s, ETA: 65.21 min
# [103/900] Sample processed in 0.66s, ETA: 64.58 min
# [104/900] Sample processed in 0.56s, ETA: 63.95 min
# [105/900] Sample processed in 0.48s, ETA: 63.32 min
# [106/900] Sample processed in 0.88s, ETA: 62.75 min
# [107/900] Sample processed in 0.27s, ETA: 62.12 min
# [108/900] Sample processed in 0.38s, ETA: 61.52 min
# [109/900] Sample processed in 0.53s, ETA: 60.94 min
# [110/900] Sample processed in 0.87s, ETA: 60.41 min
# [111/900] Sample processed in 0.88s, ETA: 59.90 min
# [112/900] Sample processed in 0.82s, ETA: 59.38 min
# [113/900] Sample processed in 0.43s, ETA: 58.83 min
# [114/900] Sample processed in 0.40s, ETA: 58.29 min
# [115/900] Sample processed in 0.87s, ETA: 57.81 min
# [116/900] Sample processed in 0.82s, ETA: 57.33 min
# [117/900] Sample processed in 0.38s, ETA: 56.81 min
# [118/900] Sample processed in 0.63s, ETA: 56.32 min
# [119/900] Sample processed in 0.85s, ETA: 55.87 min
# [120/900] Sample processed in 0.87s, ETA: 55.43 min
# [121/900] Sample processed in 0.69s, ETA: 54.98 min
# [122/900] Sample processed in 0.45s, ETA: 54.50 min
# [123/900] Sample processed in 0.77s, ETA: 54.07 min
# [124/900] Sample processed in 0.21s, ETA: 53.59 min
# [125/900] Sample processed in 0.45s, ETA: 53.14 min
# [126/900] Sample processed in 0.53s, ETA: 52.70 min
# [127/900] Sample processed in 0.87s, ETA: 52.31 min
# [128/900] Sample processed in 0.87s, ETA: 51.92 min
# [129/900] Sample processed in 0.87s, ETA: 51.54 min
# [130/900] Sample processed in 0.81s, ETA: 51.15 min
# [131/900] Sample processed in 0.87s, ETA: 50.78 min
# [132/900] Sample processed in 0.29s, ETA: 50.36 min
# [133/900] Sample processed in 0.86s, ETA: 50.00 min
# [134/900] Sample processed in 0.35s, ETA: 49.60 min
# [135/900] Sample processed in 0.88s, ETA: 49.25 min
# [136/900] Sample processed in 0.50s, ETA: 48.87 min
# [137/900] Sample processed in 0.87s, ETA: 48.53 min
# [138/900] Sample processed in 0.87s, ETA: 48.19 min
# [139/900] Sample processed in 0.87s, ETA: 47.86 min
# [140/900] Sample processed in 0.85s, ETA: 47.54 min
# [141/900] Sample processed in 0.87s, ETA: 47.22 min
# [142/900] Sample processed in 0.80s, ETA: 46.89 min
# [143/900] Sample processed in 0.53s, ETA: 46.55 min
# [144/900] Sample processed in 0.47s, ETA: 46.21 min
# [145/900] Sample processed in 0.50s, ETA: 45.87 min
# [146/900] Sample processed in 0.50s, ETA: 45.54 min
# [147/900] Sample processed in 0.88s, ETA: 45.25 min
# [148/900] Sample processed in 0.80s, ETA: 44.95 min
# [149/900] Sample processed in 0.88s, ETA: 44.66 min
# [150/900] Sample processed in 0.56s, ETA: 44.35 min
# [151/900] Sample processed in 0.88s, ETA: 44.07 min
# [152/900] Sample processed in 0.77s, ETA: 43.78 min
# [153/900] Sample processed in 0.45s, ETA: 43.48 min
# [154/900] Sample processed in 0.87s, ETA: 43.21 min
# [155/900] Sample processed in 0.42s, ETA: 42.90 min
# [156/900] Sample processed in 0.80s, ETA: 42.64 min
# [157/900] Sample processed in 0.88s, ETA: 42.38 min
# [158/900] Sample processed in 0.37s, ETA: 42.08 min
# [159/900] Sample processed in 0.87s, ETA: 41.83 min
# [160/900] Sample processed in 0.32s, ETA: 41.54 min
# [161/900] Sample processed in 0.56s, ETA: 41.26 min
# [162/900] Sample processed in 0.77s, ETA: 41.01 min
# [163/900] Sample processed in 0.31s, ETA: 40.73 min
# [164/900] Sample processed in 0.40s, ETA: 40.46 min
# [165/900] Sample processed in 0.88s, ETA: 40.22 min
# [166/900] Sample processed in 0.69s, ETA: 39.97 min
# [167/900] Sample processed in 0.88s, ETA: 39.75 min
# [168/900] Sample processed in 0.88s, ETA: 39.52 min
# [169/900] Sample processed in 0.77s, ETA: 39.29 min
# [170/900] Sample processed in 0.72s, ETA: 39.05 min
# [171/900] Sample processed in 0.86s, ETA: 38.83 min
# [172/900] Sample processed in 0.87s, ETA: 38.62 min
# [173/900] Sample processed in 0.87s, ETA: 38.40 min
# [174/900] Sample processed in 0.48s, ETA: 38.16 min
# [175/900] Sample processed in 0.87s, ETA: 37.95 min
# [176/900] Sample processed in 0.77s, ETA: 37.74 min
# [177/900] Sample processed in 0.86s, ETA: 37.53 min
# [178/900] Sample processed in 0.47s, ETA: 37.30 min
# [179/900] Sample processed in 0.40s, ETA: 37.07 min
# [180/900] Sample processed in 0.53s, ETA: 36.84 min
# [181/900] Sample processed in 0.88s, ETA: 36.65 min
# [182/900] Sample processed in 0.87s, ETA: 36.45 min
# [183/900] Sample processed in 0.86s, ETA: 36.26 min
# [184/900] Sample processed in 0.88s, ETA: 36.07 min
# [185/900] Sample processed in 0.40s, ETA: 35.85 min
# [186/900] Sample processed in 0.87s, ETA: 35.66 min
# [187/900] Sample processed in 0.32s, ETA: 35.44 min
# [188/900] Sample processed in 0.61s, ETA: 35.24 min
# [189/900] Sample processed in 0.87s, ETA: 35.06 min
# [190/900] Sample processed in 0.87s, ETA: 34.88 min
# [191/900] Sample processed in 0.87s, ETA: 34.71 min
# [192/900] Sample processed in 0.87s, ETA: 34.53 min
# [193/900] Sample processed in 0.40s, ETA: 34.33 min
# [194/900] Sample processed in 0.50s, ETA: 34.13 min
# [195/900] Sample processed in 0.24s, ETA: 33.92 min
# [196/900] Sample processed in 0.77s, ETA: 33.75 min
# [197/900] Sample processed in 0.87s, ETA: 33.58 min
# [198/900] Sample processed in 0.39s, ETA: 33.39 min
# [199/900] Sample processed in 0.87s, ETA: 33.22 min
# [200/900] Sample processed in 0.87s, ETA: 33.06 min
# [201/900] Sample processed in 0.08s, ETA: 32.85 min
# [202/900] Sample processed in 0.13s, ETA: 32.65 min
# [203/900] Sample processed in 0.48s, ETA: 32.47 min
# [204/900] Sample processed in 0.08s, ETA: 32.27 min
# [205/900] Sample processed in 0.08s, ETA: 32.07 min
# [206/900] Sample processed in 0.08s, ETA: 31.88 min
# [207/900] Sample processed in 0.62s, ETA: 31.71 min
# [208/900] Sample processed in 0.69s, ETA: 31.55 min
# [209/900] Sample processed in 0.40s, ETA: 31.38 min
# [210/900] Sample processed in 0.13s, ETA: 31.19 min
# [211/900] Sample processed in 0.87s, ETA: 31.04 min
# [212/900] Sample processed in 0.85s, ETA: 30.90 min
# [213/900] Sample processed in 0.87s, ETA: 30.76 min
# [214/900] Sample processed in 0.32s, ETA: 30.58 min
# [215/900] Sample processed in 0.08s, ETA: 30.40 min
# [216/900] Sample processed in 0.86s, ETA: 30.26 min
# [217/900] Sample processed in 0.87s, ETA: 30.13 min
# [218/900] Sample processed in 0.13s, ETA: 29.95 min
# [219/900] Sample processed in 0.08s, ETA: 29.77 min
# [220/900] Sample processed in 0.13s, ETA: 29.60 min
# [221/900] Sample processed in 0.49s, ETA: 29.45 min
# [222/900] Sample processed in 0.13s, ETA: 29.28 min
# [223/900] Sample processed in 0.47s, ETA: 29.13 min
# [224/900] Sample processed in 0.88s, ETA: 29.00 min
# [225/900] Sample processed in 0.86s, ETA: 28.87 min
# [226/900] Sample processed in 0.65s, ETA: 28.74 min
# [227/900] Sample processed in 0.87s, ETA: 28.61 min
# [228/900] Sample processed in 0.50s, ETA: 28.47 min
# [229/900] Sample processed in 0.13s, ETA: 28.31 min
# [230/900] Sample processed in 0.37s, ETA: 28.16 min
# [231/900] Sample processed in 0.08s, ETA: 28.00 min
# [232/900] Sample processed in 0.08s, ETA: 27.84 min
# [233/900] Sample processed in 0.50s, ETA: 27.70 min
# [234/900] Sample processed in 0.13s, ETA: 27.55 min
# [235/900] Sample processed in 0.11s, ETA: 27.40 min
# [236/900] Sample processed in 0.08s, ETA: 27.24 min
# [237/900] Sample processed in 0.08s, ETA: 27.09 min
# [238/900] Sample processed in 0.14s, ETA: 26.94 min
# [239/900] Sample processed in 0.13s, ETA: 26.80 min
# [240/900] Sample processed in 0.87s, ETA: 26.68 min
# [241/900] Sample processed in 0.50s, ETA: 26.56 min
# [242/900] Sample processed in 0.65s, ETA: 26.44 min
# [243/900] Sample processed in 0.31s, ETA: 26.30 min
# [244/900] Sample processed in 0.42s, ETA: 26.17 min
# [245/900] Sample processed in 0.86s, ETA: 26.06 min
# [246/900] Sample processed in 0.37s, ETA: 25.93 min
# [247/900] Sample processed in 0.08s, ETA: 25.79 min
# [248/900] Sample processed in 0.60s, ETA: 25.68 min
# [249/900] Sample processed in 0.56s, ETA: 25.56 min
# [250/900] Sample processed in 0.31s, ETA: 25.43 min
# [251/900] Sample processed in 0.32s, ETA: 25.30 min
# [252/900] Sample processed in 0.32s, ETA: 25.18 min
# [253/900] Sample processed in 0.87s, ETA: 25.08 min
# [254/900] Sample processed in 0.08s, ETA: 24.94 min
# [255/900] Sample processed in 0.37s, ETA: 24.82 min
# [256/900] Sample processed in 0.29s, ETA: 24.70 min
# [257/900] Sample processed in 0.10s, ETA: 24.57 min
# [258/900] Sample processed in 0.60s, ETA: 24.46 min
# [259/900] Sample processed in 0.34s, ETA: 24.34 min
# [260/900] Sample processed in 0.84s, ETA: 24.25 min
# [261/900] Sample processed in 0.10s, ETA: 24.12 min
# [262/900] Sample processed in 0.62s, ETA: 24.02 min
# [263/900] Sample processed in 0.29s, ETA: 23.90 min
# [264/900] Sample processed in 0.49s, ETA: 23.79 min
# [265/900] Sample processed in 0.08s, ETA: 23.67 min
# [266/900] Sample processed in 0.08s, ETA: 23.54 min
# [267/900] Sample processed in 0.52s, ETA: 23.44 min
# [268/900] Sample processed in 0.24s, ETA: 23.32 min
# [269/900] Sample processed in 0.11s, ETA: 23.20 min
# [270/900] Sample processed in 0.39s, ETA: 23.10 min
# [271/900] Sample processed in 0.58s, ETA: 23.00 min
# [272/900] Sample processed in 0.08s, ETA: 22.88 min
# [273/900] Sample processed in 0.49s, ETA: 22.78 min
# [274/900] Sample processed in 0.57s, ETA: 22.68 min
# [275/900] Sample processed in 0.08s, ETA: 22.57 min
# [276/900] Sample processed in 0.13s, ETA: 22.45 min
# [277/900] Sample processed in 0.50s, ETA: 22.36 min
# [278/900] Sample processed in 0.37s, ETA: 22.25 min
# [279/900] Sample processed in 0.69s, ETA: 22.16 min
# [280/900] Sample processed in 0.87s, ETA: 22.08 min
# [281/900] Sample processed in 0.18s, ETA: 21.97 min
# [282/900] Sample processed in 0.87s, ETA: 21.89 min
# [283/900] Sample processed in 0.86s, ETA: 21.81 min
# [284/900] Sample processed in 0.60s, ETA: 21.72 min
# [285/900] Sample processed in 0.35s, ETA: 21.62 min
# [286/900] Sample processed in 0.56s, ETA: 21.53 min
# [287/900] Sample processed in 0.08s, ETA: 21.42 min
# [288/900] Sample processed in 0.13s, ETA: 21.32 min
# [289/900] Sample processed in 0.63s, ETA: 21.23 min
# [290/900] Sample processed in 0.86s, ETA: 21.15 min
# [291/900] Sample processed in 0.13s, ETA: 21.05 min
# [292/900] Sample processed in 0.87s, ETA: 20.98 min
# [293/900] Sample processed in 0.75s, ETA: 20.90 min
# [294/900] Sample processed in 0.29s, ETA: 20.80 min
# [295/900] Sample processed in 0.29s, ETA: 20.71 min
# [296/900] Sample processed in 0.55s, ETA: 20.62 min
# [297/900] Sample processed in 0.10s, ETA: 20.52 min
# [298/900] Sample processed in 0.60s, ETA: 20.44 min
# [299/900] Sample processed in 0.32s, ETA: 20.35 min
# [300/900] Sample processed in 0.64s, ETA: 20.27 min
# [301/900] Sample processed in 0.08s, ETA: 20.17 min
# [302/900] Sample processed in 0.08s, ETA: 20.07 min
# [303/900] Sample processed in 0.08s, ETA: 19.97 min
# [304/900] Sample processed in 0.08s, ETA: 19.88 min
# [305/900] Sample processed in 0.32s, ETA: 19.79 min
# [306/900] Sample processed in 0.08s, ETA: 19.69 min
# [307/900] Sample processed in 0.21s, ETA: 19.60 min
# [308/900] Sample processed in 0.08s, ETA: 19.51 min
# [309/900] Sample processed in 0.40s, ETA: 19.43 min
# [310/900] Sample processed in 0.08s, ETA: 19.33 min
# [311/900] Sample processed in 0.19s, ETA: 19.24 min
# [312/900] Sample processed in 0.08s, ETA: 19.15 min
# [313/900] Sample processed in 0.87s, ETA: 19.09 min
# [314/900] Sample processed in 0.29s, ETA: 19.00 min
# [315/900] Sample processed in 0.08s, ETA: 18.91 min
# [316/900] Sample processed in 0.08s, ETA: 18.82 min
# [317/900] Sample processed in 0.08s, ETA: 18.73 min
# [318/900] Sample processed in 0.39s, ETA: 18.65 min
# [319/900] Sample processed in 0.08s, ETA: 18.57 min
# [320/900] Sample processed in 0.19s, ETA: 18.48 min
# [321/900] Sample processed in 0.08s, ETA: 18.39 min
# [322/900] Sample processed in 0.08s, ETA: 18.31 min
# [323/900] Sample processed in 0.08s, ETA: 18.22 min
# [324/900] Sample processed in 0.21s, ETA: 18.14 min
# [325/900] Sample processed in 0.19s, ETA: 18.06 min
# [326/900] Sample processed in 0.08s, ETA: 17.98 min
# [327/900] Sample processed in 0.08s, ETA: 17.89 min
# [328/900] Sample processed in 0.32s, ETA: 17.81 min
# [329/900] Sample processed in 0.08s, ETA: 17.73 min
# [330/900] Sample processed in 0.08s, ETA: 17.65 min
# [331/900] Sample processed in 0.87s, ETA: 17.59 min
# [332/900] Sample processed in 0.08s, ETA: 17.51 min
# [333/900] Sample processed in 0.08s, ETA: 17.43 min
# [334/900] Sample processed in 0.37s, ETA: 17.36 min
# [335/900] Sample processed in 0.24s, ETA: 17.28 min
# [336/900] Sample processed in 0.08s, ETA: 17.20 min
# [337/900] Sample processed in 0.08s, ETA: 17.12 min
# [338/900] Sample processed in 0.08s, ETA: 17.04 min
# [339/900] Sample processed in 0.08s, ETA: 16.96 min
# [340/900] Sample processed in 0.29s, ETA: 16.89 min
# [341/900] Sample processed in 0.24s, ETA: 16.82 min
# [342/900] Sample processed in 0.08s, ETA: 16.74 min
# [343/900] Sample processed in 0.08s, ETA: 16.67 min
# [344/900] Sample processed in 0.08s, ETA: 16.59 min
# [345/900] Sample processed in 0.08s, ETA: 16.51 min
# [346/900] Sample processed in 0.16s, ETA: 16.44 min
# [347/900] Sample processed in 0.08s, ETA: 16.37 min
# [348/900] Sample processed in 0.08s, ETA: 16.29 min
# [349/900] Sample processed in 0.37s, ETA: 16.23 min
# [350/900] Sample processed in 0.08s, ETA: 16.15 min
# [351/900] Sample processed in 0.16s, ETA: 16.08 min
# [352/900] Sample processed in 0.24s, ETA: 16.01 min
# [353/900] Sample processed in 0.08s, ETA: 15.94 min
# [354/900] Sample processed in 0.08s, ETA: 15.87 min
# [355/900] Sample processed in 0.08s, ETA: 15.80 min
# [356/900] Sample processed in 0.35s, ETA: 15.73 min
# [357/900] Sample processed in 0.27s, ETA: 15.67 min
# [358/900] Sample processed in 0.22s, ETA: 15.60 min
# [359/900] Sample processed in 0.08s, ETA: 15.53 min
# [360/900] Sample processed in 0.29s, ETA: 15.46 min
# [361/900] Sample processed in 0.31s, ETA: 15.40 min
# [362/900] Sample processed in 0.08s, ETA: 15.33 min
# [363/900] Sample processed in 0.19s, ETA: 15.26 min
# [364/900] Sample processed in 0.08s, ETA: 15.20 min
# [365/900] Sample processed in 0.08s, ETA: 15.13 min
# [366/900] Sample processed in 0.87s, ETA: 15.08 min
# [367/900] Sample processed in 0.21s, ETA: 15.02 min
# [368/900] Sample processed in 0.21s, ETA: 14.95 min
# [369/900] Sample processed in 0.08s, ETA: 14.89 min
# [370/900] Sample processed in 0.08s, ETA: 14.82 min
# [371/900] Sample processed in 0.37s, ETA: 14.76 min
# [372/900] Sample processed in 0.19s, ETA: 14.70 min
# [373/900] Sample processed in 0.24s, ETA: 14.64 min
# [374/900] Sample processed in 0.08s, ETA: 14.57 min
# [375/900] Sample processed in 0.19s, ETA: 14.51 min
# [376/900] Sample processed in 0.32s, ETA: 14.45 min
# [377/900] Sample processed in 0.34s, ETA: 14.39 min
# [378/900] Sample processed in 0.08s, ETA: 14.33 min
# [379/900] Sample processed in 0.16s, ETA: 14.27 min
# [380/900] Sample processed in 0.08s, ETA: 14.20 min
# [381/900] Sample processed in 0.40s, ETA: 14.15 min
# [382/900] Sample processed in 0.08s, ETA: 14.09 min
# [383/900] Sample processed in 0.08s, ETA: 14.02 min
# [384/900] Sample processed in 0.53s, ETA: 13.97 min
# [385/900] Sample processed in 0.22s, ETA: 13.91 min
# [386/900] Sample processed in 0.08s, ETA: 13.85 min
# [387/900] Sample processed in 0.27s, ETA: 13.80 min
# [388/900] Sample processed in 0.08s, ETA: 13.74 min
# [389/900] Sample processed in 0.19s, ETA: 13.68 min
# [390/900] Sample processed in 0.16s, ETA: 13.62 min
# [391/900] Sample processed in 0.08s, ETA: 13.56 min
# [392/900] Sample processed in 0.16s, ETA: 13.50 min
# [393/900] Sample processed in 0.08s, ETA: 13.44 min
# [394/900] Sample processed in 0.08s, ETA: 13.38 min
# [395/900] Sample processed in 0.34s, ETA: 13.33 min
# [396/900] Sample processed in 0.24s, ETA: 13.28 min
# [397/900] Sample processed in 0.08s, ETA: 13.22 min
# [398/900] Sample processed in 0.21s, ETA: 13.16 min
# [399/900] Sample processed in 0.08s, ETA: 13.11 min
# [400/900] Sample processed in 0.08s, ETA: 13.05 min
# [401/900] Sample processed in 0.08s, ETA: 12.99 min
# [402/900] Sample processed in 0.87s, ETA: 12.95 min
# [403/900] Sample processed in 0.21s, ETA: 12.90 min
# [404/900] Sample processed in 0.26s, ETA: 12.85 min
# [405/900] Sample processed in 0.24s, ETA: 12.79 min
# [406/900] Sample processed in 0.08s, ETA: 12.74 min
# [407/900] Sample processed in 0.08s, ETA: 12.68 min
# [408/900] Sample processed in 0.08s, ETA: 12.63 min
# [409/900] Sample processed in 0.08s, ETA: 12.57 min
# [410/900] Sample processed in 0.08s, ETA: 12.52 min
# [411/900] Sample processed in 0.08s, ETA: 12.46 min
# [412/900] Sample processed in 0.08s, ETA: 12.41 min
# [413/900] Sample processed in 0.08s, ETA: 12.35 min
# [414/900] Sample processed in 0.08s, ETA: 12.30 min
# [415/900] Sample processed in 0.08s, ETA: 12.25 min
# [416/900] Sample processed in 0.16s, ETA: 12.20 min
# [417/900] Sample processed in 0.08s, ETA: 12.14 min
# [418/900] Sample processed in 0.19s, ETA: 12.09 min
# [419/900] Sample processed in 0.19s, ETA: 12.04 min
# [420/900] Sample processed in 0.87s, ETA: 12.01 min
# [421/900] Sample processed in 0.08s, ETA: 11.95 min
# [422/900] Sample processed in 0.08s, ETA: 11.90 min
# [423/900] Sample processed in 0.13s, ETA: 11.85 min
# [424/900] Sample processed in 0.08s, ETA: 11.80 min
# [425/900] Sample processed in 0.08s, ETA: 11.75 min
# [426/900] Sample processed in 0.45s, ETA: 11.70 min
# [427/900] Sample processed in 0.77s, ETA: 11.67 min
# [428/900] Sample processed in 0.08s, ETA: 11.62 min
# [429/900] Sample processed in 0.08s, ETA: 11.57 min
# [430/900] Sample processed in 0.16s, ETA: 11.52 min
# [431/900] Sample processed in 0.08s, ETA: 11.47 min
# [432/900] Sample processed in 0.19s, ETA: 11.42 min
# [433/900] Sample processed in 0.08s, ETA: 11.37 min
# [434/900] Sample processed in 0.08s, ETA: 11.32 min
# [435/900] Sample processed in 0.08s, ETA: 11.27 min
# [436/900] Sample processed in 0.08s, ETA: 11.22 min
# [437/900] Sample processed in 0.08s, ETA: 11.18 min
# [438/900] Sample processed in 0.08s, ETA: 11.13 min
# [439/900] Sample processed in 0.08s, ETA: 11.08 min
# [440/900] Sample processed in 0.24s, ETA: 11.03 min
# [441/900] Sample processed in 0.08s, ETA: 10.99 min
# [442/900] Sample processed in 0.18s, ETA: 10.94 min
# [443/900] Sample processed in 0.16s, ETA: 10.90 min
# [444/900] Sample processed in 0.08s, ETA: 10.85 min
# [445/900] Sample processed in 0.08s, ETA: 10.80 min
# [446/900] Sample processed in 0.87s, ETA: 10.77 min
# [447/900] Sample processed in 0.08s, ETA: 10.72 min
# [448/900] Sample processed in 0.13s, ETA: 10.68 min
# [449/900] Sample processed in 0.87s, ETA: 10.64 min
# [450/900] Sample processed in 0.08s, ETA: 10.60 min
# [451/900] Sample processed in 0.08s, ETA: 10.55 min
# [452/900] Sample processed in 0.40s, ETA: 10.51 min
# [453/900] Sample processed in 0.08s, ETA: 10.47 min
# [454/900] Sample processed in 0.21s, ETA: 10.42 min
# [455/900] Sample processed in 0.16s, ETA: 10.38 min
# [456/900] Sample processed in 0.08s, ETA: 10.34 min
# [457/900] Sample processed in 0.08s, ETA: 10.29 min
# [458/900] Sample processed in 0.08s, ETA: 10.25 min
# [459/900] Sample processed in 0.32s, ETA: 10.21 min
# [460/900] Sample processed in 0.08s, ETA: 10.16 min
# [461/900] Sample processed in 0.26s, ETA: 10.12 min
# [462/900] Sample processed in 0.24s, ETA: 10.08 min
# [463/900] Sample processed in 0.08s, ETA: 10.04 min
# [464/900] Sample processed in 0.13s, ETA: 9.99 min
# [465/900] Sample processed in 0.13s, ETA: 9.95 min
# [466/900] Sample processed in 0.35s, ETA: 9.91 min
# [467/900] Sample processed in 0.36s, ETA: 9.88 min
# [468/900] Sample processed in 0.08s, ETA: 9.83 min
# [469/900] Sample processed in 0.08s, ETA: 9.79 min
# [470/900] Sample processed in 0.08s, ETA: 9.75 min
# [471/900] Sample processed in 0.08s, ETA: 9.71 min
# [472/900] Sample processed in 0.08s, ETA: 9.66 min
# [473/900] Sample processed in 0.29s, ETA: 9.63 min
# [474/900] Sample processed in 0.13s, ETA: 9.58 min
# [475/900] Sample processed in 0.08s, ETA: 9.54 min
# [476/900] Sample processed in 0.86s, ETA: 9.51 min
# [477/900] Sample processed in 0.32s, ETA: 9.48 min
# [478/900] Sample processed in 0.08s, ETA: 9.43 min
# [479/900] Sample processed in 0.21s, ETA: 9.40 min
# [480/900] Sample processed in 0.08s, ETA: 9.35 min
# [481/900] Sample processed in 0.31s, ETA: 9.32 min
# [482/900] Sample processed in 0.21s, ETA: 9.28 min
# [483/900] Sample processed in 0.08s, ETA: 9.24 min
# [484/900] Sample processed in 0.08s, ETA: 9.20 min
# [485/900] Sample processed in 0.08s, ETA: 9.16 min
# [486/900] Sample processed in 0.21s, ETA: 9.12 min
# [487/900] Sample processed in 0.13s, ETA: 9.08 min
# [488/900] Sample processed in 0.08s, ETA: 9.04 min
# [489/900] Sample processed in 0.08s, ETA: 9.00 min
# [490/900] Sample processed in 0.13s, ETA: 8.97 min
# [491/900] Sample processed in 0.08s, ETA: 8.93 min
# [492/900] Sample processed in 0.16s, ETA: 8.89 min
# [493/900] Sample processed in 0.08s, ETA: 8.85 min
# [494/900] Sample processed in 0.29s, ETA: 8.81 min
# [495/900] Sample processed in 0.08s, ETA: 8.78 min
# [496/900] Sample processed in 0.18s, ETA: 8.74 min
# [497/900] Sample processed in 0.08s, ETA: 8.70 min
# [498/900] Sample processed in 0.16s, ETA: 8.66 min
# [499/900] Sample processed in 0.08s, ETA: 8.63 min
# [500/900] Sample processed in 0.24s, ETA: 8.59 min
# [501/900] Sample processed in 0.08s, ETA: 8.55 min
# [502/900] Sample processed in 0.08s, ETA: 8.52 min
# [503/900] Sample processed in 0.08s, ETA: 8.48 min
# [504/900] Sample processed in 0.08s, ETA: 8.44 min
# [505/900] Sample processed in 0.08s, ETA: 8.40 min
# [506/900] Sample processed in 0.24s, ETA: 8.37 min
# [507/900] Sample processed in 0.08s, ETA: 8.33 min
# [508/900] Sample processed in 0.87s, ETA: 8.31 min
# [509/900] Sample processed in 0.08s, ETA: 8.27 min
# [510/900] Sample processed in 0.08s, ETA: 8.23 min
# [511/900] Sample processed in 0.08s, ETA: 8.20 min
# [512/900] Sample processed in 0.08s, ETA: 8.16 min
# [513/900] Sample processed in 0.08s, ETA: 8.13 min
# [514/900] Sample processed in 0.08s, ETA: 8.09 min
# [515/900] Sample processed in 0.08s, ETA: 8.05 min
# [516/900] Sample processed in 0.08s, ETA: 8.02 min
# [517/900] Sample processed in 0.08s, ETA: 7.98 min
# [518/900] Sample processed in 0.08s, ETA: 7.95 min
# [519/900] Sample processed in 0.08s, ETA: 7.91 min
# [520/900] Sample processed in 0.87s, ETA: 7.89 min
# [521/900] Sample processed in 0.08s, ETA: 7.85 min
# [522/900] Sample processed in 0.08s, ETA: 7.82 min
# [523/900] Sample processed in 0.27s, ETA: 7.79 min
# [524/900] Sample processed in 0.08s, ETA: 7.75 min
# [525/900] Sample processed in 0.08s, ETA: 7.72 min
# [526/900] Sample processed in 0.24s, ETA: 7.68 min
# [527/900] Sample processed in 0.08s, ETA: 7.65 min
# [528/900] Sample processed in 0.08s, ETA: 7.62 min
# [529/900] Sample processed in 0.86s, ETA: 7.59 min
# [530/900] Sample processed in 0.08s, ETA: 7.56 min
# [531/900] Sample processed in 0.27s, ETA: 7.53 min
# [532/900] Sample processed in 0.26s, ETA: 7.50 min
# [533/900] Sample processed in 0.08s, ETA: 7.46 min
# [534/900] Sample processed in 0.08s, ETA: 7.43 min
# [535/900] Sample processed in 0.08s, ETA: 7.40 min
# [536/900] Sample processed in 0.08s, ETA: 7.36 min
# [537/900] Sample processed in 0.08s, ETA: 7.33 min
# [538/900] Sample processed in 0.08s, ETA: 7.30 min
# [539/900] Sample processed in 0.08s, ETA: 7.26 min
# [540/900] Sample processed in 0.08s, ETA: 7.23 min
# [541/900] Sample processed in 0.87s, ETA: 7.21 min
# [542/900] Sample processed in 0.08s, ETA: 7.17 min
# [543/900] Sample processed in 0.08s, ETA: 7.14 min
# [544/900] Sample processed in 0.27s, ETA: 7.11 min
# [545/900] Sample processed in 0.08s, ETA: 7.08 min
# [546/900] Sample processed in 0.08s, ETA: 7.05 min
# [547/900] Sample processed in 0.08s, ETA: 7.02 min
# [548/900] Sample processed in 0.08s, ETA: 6.98 min
# [549/900] Sample processed in 0.08s, ETA: 6.95 min
# [550/900] Sample processed in 0.08s, ETA: 6.92 min
# [551/900] Sample processed in 0.08s, ETA: 6.89 min
# [552/900] Sample processed in 0.08s, ETA: 6.86 min
# [553/900] Sample processed in 0.08s, ETA: 6.83 min
# [554/900] Sample processed in 0.08s, ETA: 6.80 min
# [555/900] Sample processed in 0.08s, ETA: 6.77 min
# [556/900] Sample processed in 0.86s, ETA: 6.74 min
# [557/900] Sample processed in 0.08s, ETA: 6.71 min
# [558/900] Sample processed in 0.08s, ETA: 6.68 min
# [559/900] Sample processed in 0.08s, ETA: 6.65 min
# [560/900] Sample processed in 0.08s, ETA: 6.62 min
# [561/900] Sample processed in 0.08s, ETA: 6.59 min
# [562/900] Sample processed in 0.86s, ETA: 6.57 min
# [563/900] Sample processed in 0.08s, ETA: 6.54 min
# [564/900] Sample processed in 0.08s, ETA: 6.51 min
# [565/900] Sample processed in 0.08s, ETA: 6.48 min
# [566/900] Sample processed in 0.08s, ETA: 6.45 min
# [567/900] Sample processed in 0.27s, ETA: 6.42 min
# [568/900] Sample processed in 0.08s, ETA: 6.39 min
# [569/900] Sample processed in 0.08s, ETA: 6.36 min
# [570/900] Sample processed in 0.08s, ETA: 6.33 min
# [571/900] Sample processed in 0.08s, ETA: 6.30 min
# [572/900] Sample processed in 0.87s, ETA: 6.28 min
# [573/900] Sample processed in 0.27s, ETA: 6.25 min
# [574/900] Sample processed in 0.08s, ETA: 6.22 min
# [575/900] Sample processed in 0.08s, ETA: 6.19 min
# [576/900] Sample processed in 0.87s, ETA: 6.17 min
# [577/900] Sample processed in 0.08s, ETA: 6.14 min
# [578/900] Sample processed in 0.08s, ETA: 6.11 min
# [579/900] Sample processed in 0.08s, ETA: 6.08 min
# [580/900] Sample processed in 0.08s, ETA: 6.06 min
# [581/900] Sample processed in 0.87s, ETA: 6.03 min
# [582/900] Sample processed in 0.08s, ETA: 6.01 min
# [583/900] Sample processed in 0.08s, ETA: 5.98 min
# [584/900] Sample processed in 0.08s, ETA: 5.95 min
# [585/900] Sample processed in 0.08s, ETA: 5.92 min
# [586/900] Sample processed in 0.08s, ETA: 5.89 min
# [587/900] Sample processed in 0.08s, ETA: 5.86 min
# [588/900] Sample processed in 0.08s, ETA: 5.84 min
# [589/900] Sample processed in 0.87s, ETA: 5.82 min
# [590/900] Sample processed in 0.08s, ETA: 5.79 min
# [591/900] Sample processed in 0.08s, ETA: 5.76 min
# [592/900] Sample processed in 0.08s, ETA: 5.73 min
# [593/900] Sample processed in 0.08s, ETA: 5.70 min
# [594/900] Sample processed in 0.08s, ETA: 5.68 min
# [595/900] Sample processed in 0.08s, ETA: 5.65 min
# [596/900] Sample processed in 0.87s, ETA: 5.63 min
# [597/900] Sample processed in 0.08s, ETA: 5.60 min
# [598/900] Sample processed in 0.08s, ETA: 5.58 min
# [599/900] Sample processed in 0.08s, ETA: 5.55 min
# [600/900] Sample processed in 0.87s, ETA: 5.53 min
# [601/900] Sample processed in 0.13s, ETA: 5.50 min
# [602/900] Sample processed in 0.13s, ETA: 5.47 min
# [603/900] Sample processed in 0.13s, ETA: 5.45 min
# [604/900] Sample processed in 0.16s, ETA: 5.42 min
# [605/900] Sample processed in 0.13s, ETA: 5.40 min
# [606/900] Sample processed in 0.13s, ETA: 5.37 min
# [607/900] Sample processed in 0.18s, ETA: 5.34 min
# [608/900] Sample processed in 0.16s, ETA: 5.32 min
# [609/900] Sample processed in 0.13s, ETA: 5.29 min
# [610/900] Sample processed in 0.13s, ETA: 5.27 min
# [611/900] Sample processed in 0.13s, ETA: 5.24 min
# [612/900] Sample processed in 0.13s, ETA: 5.22 min
# [613/900] Sample processed in 0.13s, ETA: 5.19 min
# [614/900] Sample processed in 0.13s, ETA: 5.16 min
# [615/900] Sample processed in 0.13s, ETA: 5.14 min
# [616/900] Sample processed in 0.13s, ETA: 5.11 min
# [617/900] Sample processed in 0.19s, ETA: 5.09 min
# [618/900] Sample processed in 0.13s, ETA: 5.06 min
# [619/900] Sample processed in 0.13s, ETA: 5.04 min
# [620/900] Sample processed in 0.13s, ETA: 5.01 min
# [621/900] Sample processed in 0.13s, ETA: 4.99 min
# [622/900] Sample processed in 0.19s, ETA: 4.96 min
# [623/900] Sample processed in 0.18s, ETA: 4.94 min
# [624/900] Sample processed in 0.13s, ETA: 4.92 min
# [625/900] Sample processed in 0.13s, ETA: 4.89 min
# [626/900] Sample processed in 0.16s, ETA: 4.87 min
# [627/900] Sample processed in 0.13s, ETA: 4.84 min
# [628/900] Sample processed in 0.13s, ETA: 4.82 min
# [629/900] Sample processed in 0.13s, ETA: 4.79 min
# [630/900] Sample processed in 0.14s, ETA: 4.77 min
# [631/900] Sample processed in 0.18s, ETA: 4.74 min
# [632/900] Sample processed in 0.13s, ETA: 4.72 min
# [633/900] Sample processed in 0.16s, ETA: 4.70 min
# [634/900] Sample processed in 0.13s, ETA: 4.67 min
# [635/900] Sample processed in 0.13s, ETA: 4.65 min
# [636/900] Sample processed in 0.19s, ETA: 4.62 min
# [637/900] Sample processed in 0.13s, ETA: 4.60 min
# [638/900] Sample processed in 0.13s, ETA: 4.58 min
# [639/900] Sample processed in 0.13s, ETA: 4.55 min
# [640/900] Sample processed in 0.13s, ETA: 4.53 min
# [641/900] Sample processed in 0.13s, ETA: 4.51 min
# [642/900] Sample processed in 0.13s, ETA: 4.48 min
# [643/900] Sample processed in 0.13s, ETA: 4.46 min
# [644/900] Sample processed in 0.14s, ETA: 4.44 min
# [645/900] Sample processed in 0.16s, ETA: 4.41 min
# [646/900] Sample processed in 0.13s, ETA: 4.39 min
# [647/900] Sample processed in 0.13s, ETA: 4.37 min
# [648/900] Sample processed in 0.13s, ETA: 4.34 min
# [649/900] Sample processed in 0.13s, ETA: 4.32 min
# [650/900] Sample processed in 0.13s, ETA: 4.30 min
# [651/900] Sample processed in 0.13s, ETA: 4.27 min
# [652/900] Sample processed in 0.13s, ETA: 4.25 min
# [653/900] Sample processed in 0.13s, ETA: 4.23 min
# [654/900] Sample processed in 0.19s, ETA: 4.21 min
# [655/900] Sample processed in 0.13s, ETA: 4.18 min
# [656/900] Sample processed in 0.13s, ETA: 4.16 min
# [657/900] Sample processed in 0.13s, ETA: 4.14 min
# [658/900] Sample processed in 0.13s, ETA: 4.12 min
# [659/900] Sample processed in 0.13s, ETA: 4.09 min
# [660/900] Sample processed in 0.13s, ETA: 4.07 min
# [661/900] Sample processed in 0.13s, ETA: 4.05 min
# [662/900] Sample processed in 0.13s, ETA: 4.03 min
# [663/900] Sample processed in 0.16s, ETA: 4.00 min
# [664/900] Sample processed in 0.13s, ETA: 3.98 min
# [665/900] Sample processed in 0.13s, ETA: 3.96 min
# [666/900] Sample processed in 0.19s, ETA: 3.94 min
# [667/900] Sample processed in 0.13s, ETA: 3.92 min
# [668/900] Sample processed in 0.13s, ETA: 3.89 min
# [669/900] Sample processed in 0.13s, ETA: 3.87 min
# [670/900] Sample processed in 0.13s, ETA: 3.85 min
# [671/900] Sample processed in 0.13s, ETA: 3.83 min
# [672/900] Sample processed in 0.13s, ETA: 3.81 min
# [673/900] Sample processed in 0.13s, ETA: 3.79 min
# [674/900] Sample processed in 0.13s, ETA: 3.76 min
# [675/900] Sample processed in 0.13s, ETA: 3.74 min
# [676/900] Sample processed in 0.13s, ETA: 3.72 min
# [677/900] Sample processed in 0.13s, ETA: 3.70 min
# [678/900] Sample processed in 0.13s, ETA: 3.68 min
# [679/900] Sample processed in 0.13s, ETA: 3.66 min
# [680/900] Sample processed in 0.13s, ETA: 3.64 min
# [681/900] Sample processed in 0.13s, ETA: 3.62 min
# [682/900] Sample processed in 0.19s, ETA: 3.59 min
# [683/900] Sample processed in 0.13s, ETA: 3.57 min
# [684/900] Sample processed in 0.16s, ETA: 3.55 min
# [685/900] Sample processed in 0.13s, ETA: 3.53 min
# [686/900] Sample processed in 0.13s, ETA: 3.51 min
# [687/900] Sample processed in 0.19s, ETA: 3.49 min
# [688/900] Sample processed in 0.13s, ETA: 3.47 min
# [689/900] Sample processed in 0.13s, ETA: 3.45 min
# [690/900] Sample processed in 0.13s, ETA: 3.43 min
# [691/900] Sample processed in 0.13s, ETA: 3.41 min
# [692/900] Sample processed in 0.13s, ETA: 3.39 min
# [693/900] Sample processed in 0.16s, ETA: 3.37 min
# [694/900] Sample processed in 0.13s, ETA: 3.35 min
# [695/900] Sample processed in 0.13s, ETA: 3.33 min
# [696/900] Sample processed in 0.13s, ETA: 3.31 min
# [697/900] Sample processed in 0.13s, ETA: 3.29 min
# [698/900] Sample processed in 0.16s, ETA: 3.27 min
# [699/900] Sample processed in 0.19s, ETA: 3.25 min
# [700/900] Sample processed in 0.13s, ETA: 3.23 min
# [701/900] Sample processed in 0.44s, ETA: 3.21 min
# [702/900] Sample processed in 0.40s, ETA: 3.19 min
# [703/900] Sample processed in 0.40s, ETA: 3.17 min
# [704/900] Sample processed in 0.42s, ETA: 3.15 min
# [705/900] Sample processed in 0.42s, ETA: 3.13 min
# [706/900] Sample processed in 0.47s, ETA: 3.11 min
# [707/900] Sample processed in 0.37s, ETA: 3.09 min
# [708/900] Sample processed in 0.44s, ETA: 3.08 min
# [709/900] Sample processed in 0.36s, ETA: 3.06 min
# [710/900] Sample processed in 0.50s, ETA: 3.04 min
# [711/900] Sample processed in 0.37s, ETA: 3.02 min
# [712/900] Sample processed in 0.50s, ETA: 3.00 min
# [713/900] Sample processed in 0.42s, ETA: 2.98 min
# [714/900] Sample processed in 0.35s, ETA: 2.97 min
# [715/900] Sample processed in 0.34s, ETA: 2.95 min
# [716/900] Sample processed in 0.39s, ETA: 2.93 min
# [717/900] Sample processed in 0.42s, ETA: 2.91 min
# [718/900] Sample processed in 0.36s, ETA: 2.89 min
# [719/900] Sample processed in 0.29s, ETA: 2.87 min
# [720/900] Sample processed in 0.36s, ETA: 2.86 min
# [721/900] Sample processed in 0.44s, ETA: 2.84 min
# [722/900] Sample processed in 0.35s, ETA: 2.82 min
# [723/900] Sample processed in 0.37s, ETA: 2.80 min
# [724/900] Sample processed in 0.34s, ETA: 2.78 min
# [725/900] Sample processed in 0.45s, ETA: 2.77 min
# [726/900] Sample processed in 0.42s, ETA: 2.75 min
# [727/900] Sample processed in 0.37s, ETA: 2.73 min
# [728/900] Sample processed in 0.36s, ETA: 2.71 min
# [729/900] Sample processed in 0.29s, ETA: 2.69 min
# [730/900] Sample processed in 0.29s, ETA: 2.67 min
# [731/900] Sample processed in 0.44s, ETA: 2.66 min
# [732/900] Sample processed in 0.34s, ETA: 2.64 min
# [733/900] Sample processed in 0.29s, ETA: 2.62 min
# [734/900] Sample processed in 0.31s, ETA: 2.60 min
# [735/900] Sample processed in 0.39s, ETA: 2.58 min
# [736/900] Sample processed in 0.37s, ETA: 2.57 min
# [737/900] Sample processed in 0.26s, ETA: 2.55 min
# [738/900] Sample processed in 0.44s, ETA: 2.53 min
# [739/900] Sample processed in 0.86s, ETA: 2.52 min
# [740/900] Sample processed in 0.34s, ETA: 2.50 min
# [741/900] Sample processed in 0.40s, ETA: 2.48 min
# [742/900] Sample processed in 0.42s, ETA: 2.46 min
# [743/900] Sample processed in 0.44s, ETA: 2.45 min
# [744/900] Sample processed in 0.34s, ETA: 2.43 min
# [745/900] Sample processed in 0.39s, ETA: 2.41 min
# [746/900] Sample processed in 0.31s, ETA: 2.39 min
# [747/900] Sample processed in 0.34s, ETA: 2.38 min
# [748/900] Sample processed in 0.37s, ETA: 2.36 min
# [749/900] Sample processed in 0.34s, ETA: 2.34 min
# [750/900] Sample processed in 0.31s, ETA: 2.32 min
# [751/900] Sample processed in 0.39s, ETA: 2.31 min
# [752/900] Sample processed in 0.39s, ETA: 2.29 min
# [753/900] Sample processed in 0.37s, ETA: 2.27 min
# [754/900] Sample processed in 0.29s, ETA: 2.25 min
# [755/900] Sample processed in 0.31s, ETA: 2.24 min
# [756/900] Sample processed in 0.34s, ETA: 2.22 min
# [757/900] Sample processed in 0.55s, ETA: 2.20 min
# [758/900] Sample processed in 0.26s, ETA: 2.18 min
# [759/900] Sample processed in 0.29s, ETA: 2.17 min
# [760/900] Sample processed in 0.42s, ETA: 2.15 min
# [761/900] Sample processed in 0.34s, ETA: 2.13 min
# [762/900] Sample processed in 0.34s, ETA: 2.12 min
# [763/900] Sample processed in 0.37s, ETA: 2.10 min
# [764/900] Sample processed in 0.29s, ETA: 2.08 min
# [765/900] Sample processed in 0.42s, ETA: 2.07 min
# [766/900] Sample processed in 0.31s, ETA: 2.05 min
# [767/900] Sample processed in 0.44s, ETA: 2.03 min
# [768/900] Sample processed in 0.26s, ETA: 2.01 min
# [769/900] Sample processed in 0.34s, ETA: 2.00 min
# [770/900] Sample processed in 0.39s, ETA: 1.98 min
# [771/900] Sample processed in 0.39s, ETA: 1.96 min
# [772/900] Sample processed in 0.32s, ETA: 1.95 min
# [773/900] Sample processed in 0.42s, ETA: 1.93 min
# [774/900] Sample processed in 0.42s, ETA: 1.91 min
# [775/900] Sample processed in 0.45s, ETA: 1.90 min
# [776/900] Sample processed in 0.52s, ETA: 1.88 min
# [777/900] Sample processed in 0.34s, ETA: 1.86 min
# [778/900] Sample processed in 0.39s, ETA: 1.85 min
# [779/900] Sample processed in 0.39s, ETA: 1.83 min
# [780/900] Sample processed in 0.37s, ETA: 1.82 min
# [781/900] Sample processed in 0.34s, ETA: 1.80 min
# [782/900] Sample processed in 0.31s, ETA: 1.78 min
# [783/900] Sample processed in 0.39s, ETA: 1.77 min
# [784/900] Sample processed in 0.31s, ETA: 1.75 min
# [785/900] Sample processed in 0.42s, ETA: 1.73 min
# [786/900] Sample processed in 0.34s, ETA: 1.72 min
# [787/900] Sample processed in 0.29s, ETA: 1.70 min
# [788/900] Sample processed in 0.65s, ETA: 1.68 min
# [789/900] Sample processed in 0.39s, ETA: 1.67 min
# [790/900] Sample processed in 0.55s, ETA: 1.65 min
# [791/900] Sample processed in 0.39s, ETA: 1.64 min
# [792/900] Sample processed in 0.26s, ETA: 1.62 min
# [793/900] Sample processed in 0.50s, ETA: 1.60 min
# [794/900] Sample processed in 0.39s, ETA: 1.59 min
# [795/900] Sample processed in 0.40s, ETA: 1.57 min
# [796/900] Sample processed in 0.45s, ETA: 1.56 min
# [797/900] Sample processed in 0.34s, ETA: 1.54 min
# [798/900] Sample processed in 0.26s, ETA: 1.52 min
# [799/900] Sample processed in 0.44s, ETA: 1.51 min
# [800/900] Sample processed in 0.55s, ETA: 1.49 min
# [801/900] Sample processed in 22.52s, ETA: 1.52 min
# [802/900] Sample processed in 19.70s, ETA: 1.54 min
# [803/900] Sample processed in 16.69s, ETA: 1.56 min
# [804/900] Sample processed in 6.98s, ETA: 1.56 min
# [805/900] Sample processed in 11.89s, ETA: 1.56 min
# [806/900] Sample processed in 17.15s, ETA: 1.58 min
# [807/900] Sample processed in 6.25s, ETA: 1.57 min
# [808/900] Sample processed in 20.65s, ETA: 1.59 min
# [809/900] Sample processed in 15.32s, ETA: 1.60 min
# [810/900] Sample processed in 2.78s, ETA: 1.58 min
# [811/900] Sample processed in 15.60s, ETA: 1.59 min
# [812/900] Sample processed in 9.13s, ETA: 1.59 min
# [813/900] Sample processed in 17.74s, ETA: 1.60 min
# [814/900] Sample processed in 2.30s, ETA: 1.59 min
# [815/900] Sample processed in 8.24s, ETA: 1.58 min
# [816/900] Sample processed in 5.63s, ETA: 1.57 min
# [817/900] Sample processed in 16.74s, ETA: 1.58 min
# [818/900] Sample processed in 16.08s, ETA: 1.58 min
# [819/900] Sample processed in 16.31s, ETA: 1.59 min
# [820/900] Sample processed in 9.20s, ETA: 1.58 min
# [821/900] Sample processed in 17.34s, ETA: 1.59 min
# [822/900] Sample processed in 17.07s, ETA: 1.59 min
# [823/900] Sample processed in 17.74s, ETA: 1.60 min
# [824/900] Sample processed in 15.75s, ETA: 1.60 min
# [825/900] Sample processed in 13.36s, ETA: 1.60 min
# [826/900] Sample processed in 15.37s, ETA: 1.60 min
# [827/900] Sample processed in 16.62s, ETA: 1.60 min
# [828/900] Sample processed in 16.09s, ETA: 1.60 min
# [829/900] Sample processed in 18.31s, ETA: 1.60 min
# [830/900] Sample processed in 4.02s, ETA: 1.58 min
# [831/900] Sample processed in 5.04s, ETA: 1.56 min
# [832/900] Sample processed in 18.77s, ETA: 1.56 min
# [833/900] Sample processed in 16.67s, ETA: 1.56 min
# [834/900] Sample processed in 14.77s, ETA: 1.56 min
# [835/900] Sample processed in 10.77s, ETA: 1.54 min
# [836/900] Sample processed in 5.88s, ETA: 1.53 min
# [837/900] Sample processed in 17.52s, ETA: 1.52 min
# [838/900] Sample processed in 15.93s, ETA: 1.52 min
# [839/900] Sample processed in 15.20s, ETA: 1.51 min
# [840/900] Sample processed in 3.22s, ETA: 1.49 min
# [841/900] Sample processed in 3.36s, ETA: 1.46 min
# [842/900] Sample processed in 19.05s, ETA: 1.46 min
# [843/900] Sample processed in 9.08s, ETA: 1.44 min
# [844/900] Sample processed in 17.89s, ETA: 1.43 min
# [845/900] Sample processed in 14.21s, ETA: 1.42 min
# [846/900] Sample processed in 1.91s, ETA: 1.40 min
# [847/900] Sample processed in 19.69s, ETA: 1.39 min
# [848/900] Sample processed in 7.16s, ETA: 1.37 min
# [849/900] Sample processed in 18.35s, ETA: 1.36 min
# [850/900] Sample processed in 5.75s, ETA: 1.34 min
# [851/900] Sample processed in 17.52s, ETA: 1.33 min
# [852/900] Sample processed in 8.39s, ETA: 1.31 min
# [853/900] Sample processed in 2.70s, ETA: 1.28 min
# [854/900] Sample processed in 9.89s, ETA: 1.26 min
# [855/900] Sample processed in 13.08s, ETA: 1.24 min
# [856/900] Sample processed in 15.01s, ETA: 1.23 min
# [857/900] Sample processed in 15.89s, ETA: 1.21 min
# [858/900] Sample processed in 15.58s, ETA: 1.19 min
# [859/900] Sample processed in 6.57s, ETA: 1.17 min
# [860/900] Sample processed in 17.12s, ETA: 1.15 min
# [861/900] Sample processed in 2.52s, ETA: 1.12 min
# [862/900] Sample processed in 17.13s, ETA: 1.11 min
# [863/900] Sample processed in 4.63s, ETA: 1.08 min
# [864/900] Sample processed in 10.97s, ETA: 1.06 min
# [865/900] Sample processed in 20.14s, ETA: 1.04 min
# [866/900] Sample processed in 22.16s, ETA: 1.02 min
# [867/900] Sample processed in 12.54s, ETA: 1.00 min
# [868/900] Sample processed in 1.96s, ETA: 0.97 min
# [869/900] Sample processed in 2.72s, ETA: 0.94 min
# [870/900] Sample processed in 19.77s, ETA: 0.92 min
# [871/900] Sample processed in 14.97s, ETA: 0.90 min
# [872/900] Sample processed in 14.27s, ETA: 0.87 min
# [873/900] Sample processed in 3.83s, ETA: 0.84 min
# [874/900] Sample processed in 7.88s, ETA: 0.81 min
# [875/900] Sample processed in 13.15s, ETA: 0.79 min
# [876/900] Sample processed in 16.03s, ETA: 0.76 min
# [877/900] Sample processed in 22.10s, ETA: 0.74 min
# [878/900] Sample processed in 13.36s, ETA: 0.71 min
# [879/900] Sample processed in 19.63s, ETA: 0.69 min
# [880/900] Sample processed in 15.35s, ETA: 0.66 min
# [881/900] Sample processed in 15.47s, ETA: 0.63 min
# [882/900] Sample processed in 3.37s, ETA: 0.60 min
# [883/900] Sample processed in 10.61s, ETA: 0.57 min
# [884/900] Sample processed in 17.99s, ETA: 0.54 min
# [885/900] Sample processed in 2.12s, ETA: 0.51 min
# [886/900] Sample processed in 9.29s, ETA: 0.47 min
# [887/900] Sample processed in 15.99s, ETA: 0.44 min
# [888/900] Sample processed in 14.68s, ETA: 0.41 min
# [889/900] Sample processed in 12.23s, ETA: 0.38 min
# [890/900] Sample processed in 16.02s, ETA: 0.35 min
# [891/900] Sample processed in 7.83s, ETA: 0.31 min
# [892/900] Sample processed in 7.08s, ETA: 0.28 min
# [893/900] Sample processed in 11.55s, ETA: 0.25 min
# [894/900] Sample processed in 14.11s, ETA: 0.21 min
# [895/900] Sample processed in 16.40s, ETA: 0.18 min
# [896/900] Sample processed in 15.01s, ETA: 0.14 min
# [897/900] Sample processed in 17.89s, ETA: 0.11 min
# [898/900] Sample processed in 12.46s, ETA: 0.07 min
# [899/900] Sample processed in 13.14s, ETA: 0.04 min
# [900/900] Sample processed in 16.21s, ETA: 0.00 min
#
# All samples processed. Total time: 33.18 min

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from unsloth import FastLanguageModel

import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    # model_name = "unsloth/Meta-Llama-3.1-8B-bnb-4bit",
    model_name = "/data/jaesung/llm_for_diabetes/src/trial7/main_table/llama_8b/outputs/last_seed/checkpoint-458",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)


alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-26 17:53:33 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.2.12: Fast Llama patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-PCIE-40GB. Max memory: 39.394 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.2.12 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %%
import torch
torch.manual_seed(1000) 

FastLanguageModel.for_inference(model) 

inputs = tokenizer(
[
    alpaca_prompt.format(
        # "Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.", 
        # "Can you recommend a daily diet recipe? Please provide detailed information on breakfast, lunch, and dinner.", 
        # "Prepare a healthy daily meal plan for a female aged 35 with 1400 kcal, including portion sizes in grams.",
        "Prepare a healthy daily meal plan for diebeic patien, including portion sizes in grams.",
        "",
        "", 
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 1024, do_sample=True)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Prepare a healthy daily meal plan for diebeic patien, including portion sizes in grams.
#
# ### Input:
#
#
# ### Response:
# Breakfast: 1 cup of steel-cut oats with 1/2 cup of nonfat milk and 1 tablespoon of ground flaxseed. Lunch: 3 ounces of grilled chicken breast with 1 cup of steamed broccoli and 1/2 cup of brown rice. Snack: 1 small apple with 1 tablespoon of almond butter. Dinner: 4 ounces of grilled salmon with 1 cup of steamed asparagus and 1/2 cup of quinoa.<|end_of_text|>

# %%
import torch
torch.manual_seed(400) 

FastLanguageModel.for_inference(model) 

inputs = tokenizer(
[
    alpaca_prompt.format(
        "Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.", 
        "",
        "", 
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 1024, do_sample=True)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.
#
# ### Input:
#
#
# ### Response:
# Diabetes is a metabolic disorder that affects how the body uses food for energy. It occurs when the body cannot produce enough insulin or when the body cannot properly use the insulin it produces. Insulin is a hormone that helps the body use glucose, a type of sugar, for energy. People with diabetes must carefully manage their blood sugar levels to avoid complications such as heart disease, stroke, and nerve damage.
#
# A healthy diet for a diabetic patient should include plenty of vegetables, fruits, whole grains, lean proteins, and healthy fats. It should also limit processed foods, sugary drinks, and refined carbohydrates. A typical daily diet for a diabetic patient might look like this:
#
# Breakfast: oatmeal with fresh berries, a glass of milk, and a cup of green tea
# Lunch: grilled chicken breast with steamed vegetables, brown rice, and a glass of water
# Dinner: baked fish with roasted vegetables, quinoa, and a small glass of red wine
# Snacks: a handful of nuts, a piece of fruit, or a small serving of yogurt
# It's important to consult with a registered dietitian or healthcare provider to develop a personalized diet plan for a diabetic patient. They can provide guidance on portion sizes, macronutrient ratios, and specific foods to include or avoid based on individual needs and health goals.<|end_of_text|>
