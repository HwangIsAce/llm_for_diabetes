# %%
# data load

# %%
import json
import pandas as pd
# 
file_paths = [
    "/data/jaesung/llm_for_diabetes/src/trial8/anlaysis/response/asclepius.jsonl",
    # "/data/jaesung/llm_for_diabetes/src/trial/CoT_collection/model_response/test_1.jsonl"
]

data = []
for file_path in file_paths:
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))

df = pd.DataFrame(data)

# %%
# medqa

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa1 = df[df['task'] == 'qa1']

# 정답 판별 수행
correct_count = 0
total_count = len(qa1)

for _, row in qa1.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_32'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.0400

# %%
# medmcqa

import pandas as pd

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa2 = df[df['task'] == 'qa2']

# 정답 판별 수행
correct_count = 0
total_count = len(qa2)

for _, row in qa2.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_32'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.0300

# %%
# pubmedqa

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
qa3 = df[df['task'] == 'qa3']

# 정답 판별 수행
correct_count = 0
total_count = len(qa3)

for _, row in qa3.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_32'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.1900

# %%
# bionli

import openai
import pandas as pd
import os
from dotenv import load_dotenv

# 환경 변수 로드 (API 키 설정)
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def check_answer_correctness(true_answer, model_answer):
    """
    GPT-3.5-turbo를 사용하여 true_answer와 model_answer가 같은 의미인지 판별
    """
    prompt = f"""
    You are evaluating the correctness of an AI-generated medical answer.
    Compare the following two answers and determine if they mean the same thing.

    **Correct Answer**: {true_answer}
    **Model Output**: {model_answer}

    If the model output correctly conveys the same answer as the correct answer, respond only with "YES".
    If the model output is incorrect or has a different meaning, respond only with "NO".
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}]
        )
        result = response.choices[0].message.content.strip()
        return result == "YES"  # GPT 응답이 YES면 정답 처리
    except Exception as e:
        print(f"Error during GPT evaluation: {e}")
        return False  # 오류 발생 시 오답 처리

# 데이터 로드 및 필터링
nli = df[df['task'] == 'nli']

# 정답 판별 수행
correct_count = 0
total_count = len(nli)

for _, row in nli.iterrows():
    true_answer = row['output'].strip()
    model_answer = row['model_output_32'].strip()
    is_correct = check_answer_correctness(true_answer, model_answer)
    if is_correct:
        correct_count += 1

# Accuracy 계산
accuracy = correct_count / total_count if total_count > 0 else 0
print(f"GPT-based Accuracy: {accuracy:.4f}")
# Out:
# GPT-based Accuracy: 0.1100

# %%
import pandas as pd
import re
from tqdm import tqdm

def extract_drug_effect_clean(text):
    """
    output 또는 model_output_32에서 drug와 effect 값을 추출하고,
    \n이나 특수 토큰 이후의 설명은 제거한다.
    """
    if pd.isna(text) or not isinstance(text, str):
        return {"drug": None, "effect": None}
    
    text = text.lower().strip()

    # drug 추출
    drug_match = re.search(r'drug:\s*([^,\n|<]+)', text)
    drug = drug_match.group(1).strip() if drug_match else None

    # effect 추출
    effect_match = re.search(r'effect:\s*([^\n|<]+)', text)
    effect = effect_match.group(1).strip() if effect_match else None

    return {"drug": drug, "effect": effect}

# ✅ 're2' task만 필터링
re_df = df[df['task'] == 're2'].reset_index(drop=True)

# ✅ 통계 변수 초기화
true_positive, false_positive, false_negative = 0, 0, 0

# ✅ 평가 루프
for _, row in tqdm(re_df.iterrows(), total=len(re_df), desc="Evaluating drug/effect pairs"):
    true_vals = extract_drug_effect_clean(row['output'])
    pred_vals = extract_drug_effect_clean(row['model_output_32'])

    if true_vals["drug"] and true_vals["effect"]:
        if true_vals == pred_vals:
            true_positive += 1
        else:
            false_negative += 1
            if pred_vals["drug"] or pred_vals["effect"]:
                false_positive += 1
    elif pred_vals["drug"] or pred_vals["effect"]:
        false_positive += 1

# ✅ 지표 계산
precision = true_positive / (true_positive + false_positive) if (true_positive + false_positive) > 0 else 0
recall = true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 0
f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

# ✅ 출력
print("\n📊 Drug/Effect Pair Evaluation (Strict Match, cleaned)")
print(f"✅ Precision: {precision:.4f}")
print(f"✅ Recall   : {recall:.4f}")
print(f"✅ F1 Score : {f1:.4f}")
# Out:
# Evaluating drug/effect pairs: 100%|██████████| 100/100 [00:00<00:00, 20316.32it/s]
# 📊 Drug/Effect Pair Evaluation (Strict Match, cleaned)
# ✅ Precision: 0.5000
# ✅ Recall   : 0.0100
# ✅ F1 Score : 0.0196

# %%
import ast
import pandas as pd
from collections import Counter

# 'ie' 태스크 필터링
ie = df[df['task'] == 'ie'].copy()

# 문자열 형태를 안전하게 리스트로 파싱하는 함수
def safe_eval(val):
    if isinstance(val, list):  
        return [str(i).strip().lower() for i in val]
    elif isinstance(val, str) and val.strip():  
        try:
            parsed = ast.literal_eval(val)
            if isinstance(parsed, list):
                return [str(i).strip().lower() for i in parsed]
            else:
                return [str(parsed).strip().lower()]
        except:
            return [val.strip().lower()]
    return []

# output과 model_output 모두 리스트 형태로 파싱
ie["output"] = ie["output"].apply(safe_eval)
ie["model_output_32"] = ie["model_output_32"].apply(safe_eval)

# Precision, Recall, F1-score 계산 함수
def calculate_scores(y_true, y_pred):
    all_precisions, all_recalls, all_f1s = [], [], []

    for true_vals, pred_vals in zip(y_true, y_pred):
        if not true_vals and not pred_vals:
            all_precisions.append(1.0)
            all_recalls.append(1.0)
            all_f1s.append(1.0)
            continue

        true_count = Counter(true_vals)
        pred_count = Counter(pred_vals)

        TP = sum(min(true_count[k], pred_count[k]) for k in true_count.keys() & pred_count.keys())
        FP = sum(pred_count[k] - true_count.get(k, 0) for k in pred_count.keys())
        FN = sum(true_count[k] - pred_count.get(k, 0) for k in true_count.keys())

        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        all_precisions.append(precision)
        all_recalls.append(recall)
        all_f1s.append(f1)

    return sum(all_precisions) / len(all_precisions), sum(all_recalls) / len(all_recalls), sum(all_f1s) / len(all_f1s)

def calculate_scores_ignore_duplicates(y_true, y_pred):
    all_precisions, all_recalls, all_f1s = [], [], []

    for true_vals, pred_vals in zip(y_true, y_pred):
        true_set = set(true_vals)
        pred_set = set(pred_vals)

        TP = len(true_set & pred_set)
        FP = len(pred_set - true_set)
        FN = len(true_set - pred_set)

        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        recall = TP / (TP + FN) if (TP + FN) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        all_precisions.append(precision)
        all_recalls.append(recall)
        all_f1s.append(f1)

    return sum(all_precisions) / len(all_precisions), sum(all_recalls) / len(all_recalls), sum(all_f1s) / len(all_f1s)


# 점수 계산
precision, recall, f1 = calculate_scores_ignore_duplicates(ie["output"], ie["model_output_32"])

# 출력
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Precision: 0.0000
# Recall: 0.0000
# F1-score: 0.0000

# %%
# summarization

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

summarization = df[df['task'] == 'summarization']
results = []

for _, row in summarization.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output_512'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    print(f"Evaluation result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Evaluation result:
# - Coherence: 4.0
#    - The model's response logically aligns with the given context, summarizing the doctor's conclusion accurately. However, it mentions "limited information," which seems unnecessary given the detailed context provided.
#
# - Completeness: 3.5
#    - The response captures the main recommendation to monitor the patient's condition and associated disorders. However, it lacks specific details mentioned in the true answer, such as the patient's background, symptoms, and specialized testing outcomes, which would provide a more comprehensive understanding.
#
# - Naturalness: 4.5
#    - The response is fluent and human-like, using clear language and appropriate terminology. However, the comment about "limited information" slightly disrupts the natural flow, as it doesn't fit the context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is coherent with the context provided in the input. It accurately reflects the key diagnosis (severe pre-eclampsia complicated by stroke) and the recommended follow-up with the obstetrician. However, it lacks some contextual nuances that were present in the full conversation, such as the patient's medical history and the specific symptoms reported.
#
# - Completeness: 3.0
#
# The response captures the main diagnosis and management recommendation, which are crucial elements. However, it omits several important details found in both the context and the true answer, such as the patient's detailed symptomatology, medical history, and examination findings. This lack of detail results in a response that is minimally sufficient but not fully complete.
#
# - Naturalness: 4.8
#
# The model's response is fluent and human-like. It reads as a concise summary that a medical professional might provide to confirm the diagnosis and recommend a course of action, maintaining the authoritative tone expected in such communications.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided in the input. It accurately identifies the diagnosis of PTCL, NOS, stage IVB, and mentions the modified therapy and monitoring decisions, which were indeed discussed in the dialogue.
#
# - Completeness: 4.0
#   The model sufficiently answers the question by summarizing the diagnosis and treatment plan. However, it does not specify details about the modified therapy, which might be expected given the patient's inquiry about the next steps.
#
# - Naturalness: 4.5
#   The response is fluent and human-like, but it does have a slightly robotic and repetitive summary style that slightly detracts from the natural flow of a conversation. Overall, it reads well but could be more conversational.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#
# The model's response logically aligns with the context provided in the input conversation. The model correctly reflects the information about the unfortunate death of the patient and initiates communication about speaking with the patient's family, which was part of the original conversation provided in the input.
#
# - Completeness: 3.5
#
# The model's response adequately answers the implied question about the patient's outcome by providing the critical information that the patient did not survive and that measures will be taken to speak with the family. However, it lacks the detailed medical context and background information that the true answer provides, such as details on the patient's medical history, test results, and examination findings. This limits the completeness of the response.
#
# - Naturalness: 5.0
#
# The model's response is fluent and human-like. It conveys empathy and professionalism, using appropriate language for delivering the unfortunate news, closely resembling a typical human response in a clinical setting.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response aligns well with the context provided. It accurately discusses the surgery and the need for monitoring and treatment adjustments, which are consistent with the information given by the doctor. However, the response could have incorporated more details from the context for improved coherence.
#
# - Completeness: 4.0
#   - The response satisfactorily answers the immediate query about the patient's condition post-surgery. It points out the uncertainties and the need for ongoing monitoring. However, it misses detailing some specific information such as the patient's history of bisphosphonate use and their comorbid conditions which can impact the future course.
#
# - Naturalness: 4.8
#   - The model's response is fluent, well-structured, and resembles how a human might communicate in a medical context. It uses appropriate medical terminology and is easy to understand for a layperson. A small amount of technical jargon, while appropriate, could have been minimized further for better clarity.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#
# The model's response is logically aligned with the context provided in the input. It accurately summarizes the crucial details given by the doctor, such as the suspected diagnosis of a pyogenic lingual abscess and the need for further tests to rule out other possibilities like lingual tuberculosis and tongue tumor. It also correctly identifies the associated factors from the patient's medical history and symptomatology.
#
# - Completeness: 5.0
#
# The model's response sufficiently answers the primary focus of the input, which is the diagnosis and considerations regarding the patient's condition. It touches upon all the relevant points such as the patient's symptoms, medical history, and the diagnosis proposed by the doctor, providing a comprehensive summary of the situation.
#
# - Naturalness: 4.5
#
# The model's response is generally fluent and human-like. The language used is professional and appropriate for a medical context while being clear and concise. However, the response might come across as slightly formal or structured, which is common in clinical settings, but could slightly detract from the feeling of a natural conversation.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
#   The model's response logically aligns with the context provided. It correctly identifies the diagnosis of SPE caused by P. micra and mentions the empiric treatment with meropenem and vancomycin, as well as the request to contact the patient's daughter. However, it introduces a point about the patient's current condition and response to treatment, which wasn't specifically addressed in the provided context.
#
# - Completeness: 4.0
#
#   The model sufficiently answers the question by conveying the main points about the diagnosis, treatment, and communication related to the patient's care. However, it does not mention some details, such as the absence of vegetation on the heart valves or the contrast-enhanced CT scan findings, which were part of the input context.
#
# - Naturalness: 4.8
#
#   The response is fluent and sounds human-like. It uses an appropriate level of formality and detail expected in a medical context. However, the abrupt introduction of the patient's condition status, without prior context from the input, slightly affects its naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response aligns well with the context provided. It accurately summarizes the sequence of medical events and treatments. The slight deduction is due to the mention of proteinuria during pregnancy/postpartum, which is contrary to the context where proteinuria was not noted until later.
#
# - Completeness: 4.0
#   The response sufficiently answers the key elements of the provided information, such as the types of strokes and treatment received. However, it lacks detail on some specifics like the diagnosis of LPE and the exact timeline of events, which are present in the true answer.
#
# - Naturalness: 4.5
#   The model's response is fluent and reads like a coherent summary that a human might produce. It has a logical structure and employs appropriate medical terminology, though it could have been slightly more detailed to cover all nuances.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
# - Completeness: 3.5
# - Naturalness: 4.5
#
# **Coherence**: The model's response logically aligns with the context provided in the input. It mentions the key symptoms and diagnoses such as fatigue, multifocal pneumonia, and acute kidney injury, and correctly follows the sequence of events as discussed between the doctor and the patient.
#
# **Completeness**: The model's response sufficiently covers the main points of the input conversation, but it misses some specific details that are present in the true answer, such as the full medical history, details about the treatment administered (e.g., specific antibiotics), and some specific lab results. Therefore, while the response is generally complete, it lacks depth found in the true answer.
#
# **Naturalness**: The model's response is fluent and human-like. It presents the information in a clear and concise manner that is easy to understand, which mirrors natural human explanation.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response generally aligns well with the context provided. The sequence of events and the relationship between the vancomycin, blisters, and infection are coherent. However, the model implies an ongoing treatment plan postmortem, which could be confusing in light of the patient's reported death.
#
# - Completeness: 3.5
#   The model's response does capture most key elements, like the severe infection caused by vancomycin. However, it does not mention the patient's age, medical history (hypertension and diabetes), or specific details about the timeline related to their condition and surgery, which are present in the true answer.
#
# - Naturalness: 4.7
#   The response is mostly fluent and sounds human-like, maintaining a clinical tone that is appropriate for the context. The expression of condolence and offer to provide further information are suitably natural, although the mention of further monitoring after the statement of death is slightly awkward.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.5**
#   The model's response is coherent and aligns well with the context provided. It accurately summarizes the patient's condition, the treatment administered, and the need for further intervention. It maintains the logical flow of the conversation.
#
# - **Completeness: 4.0**
#   The model's response covers most of the essential elements from the dialogue, such as the diagnosis, treatment, and subsequent findings. However, it omits some context details, such as the initial presentation details and specific past medical history, which are included in the true answer.
#
# - **Naturalness: 4.5**
#   The model's response is fluent and human-like, using appropriate medical terminology and structure without unnecessary jargon. It reads like a professional summary that a doctor might provide.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 5.0**
#   The model's response logically aligns with the context of the input. It captures the sequence of events accurately, following the progression from the COVID-19 diagnosis through ICU admission and treatment to the current symptoms and the investigation for cauda equina syndrome.
#
# - **Completeness: 4.5**
#   The model's response sufficiently answers the question by summarizing the key aspects of the patient's medical history and current presentation. However, it could include more detail on the timeline of events or the sequence of presentations as depicted in the true answer, particularly the timing of the third presentation relative to previous events.
#
# - **Naturalness: 5.0**
#   The model's response is fluent and human-like. It uses appropriate medical terminology and sentence structure that would be expected from a concise medical summary, maintaining clarity without sacrificing detail.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is logically consistent with the information provided in the dialogue. There is a slight discrepancy regarding the final diagnosis of PGA, which might cause confusion if interpreted as Palmoplantar Psoriasis with Nail Dystrophy, but it aligns well with the context given.
#
# - Completeness: 4.0
#   - The response covers the key points related to the diagnosis, treatment, and outcomes. However, it omits some relevant details from the patient's comprehensive medical history, such as the initial symptoms post-hospitalization and specific biopsy results, which are present in the true answer. This might lead to a less comprehensive understanding of the case.
#
# - Naturalness: 4.8
#   - The response is fluent and human-like, using appropriate medical terminology in a clear and understandable manner. The brevity of the response maintains readability without losing coherence. However, the omission of deeper details could affect how a human would convey such complex information.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#
# The model's response logically aligns with the given information. It correctly summarizes the patient's sudden drop in heart rate and blood pressure during the infusion of propofol, resulting in cardiac arrest. The conclusion regarding the failure to revive the patient is consistent with the dialogue.
#
# - Completeness: 4.5
#
# The model's response captures the key event of cardiac arrest and the unfortunate outcome well. However, it does not provide detailed background information about the patient's medical history or specifics of the procedural context leading up to the event, which are partially captured in the true answer.
#
# - Naturalness: 5.0
#
# The response is fluent and human-like. It communicates the situation clearly and sensitively, especially in addressing the gravity of the outcome for the patient's family.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#   The model's response logically aligns with the given context and accurately reflects the discussions held between the doctor and the patient. However, the response frames the interaction as a "discharge summary," which does not fully match the conversational tone of the original dialogue.
#
# - Completeness: 4.5
#   The model's response sufficiently captures most of the key details discussed, such as the patient's medical history, the condition of the fetus's father, and the plan for the patient's care. However, it lacks some specific details featured in the true answer, such as the origin of symptoms at age 11 and the details of the second missense variant in HNF1α.
#
# - Naturalness: 4.0
#   The response is mostly fluent and human-like, though it has a slightly clinical tone that might not entirely match a human doctor's conversational style in this context. The use of phrases like "the discharge summary provides" could make it seem more document-like than dialogue-focused.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   * The model's response logically aligns with the context provided. It accurately identifies the main issues: the presence of a benign cyst, the symptoms experienced by the patient, and the decision to remove the thyroid gland. However, it does not mention some specific findings, like the absence of symptoms of local infiltration, the involvement of the strap muscles, or the specifics of the tracheal deviation.
#
# - Completeness: 3.5
#   * The response sufficiently answers the main question by summarizing the patient's condition and treatment. However, it lacks some detailed information present in the true answer, such as the specifics of the nodule size and location, the detailed findings from FNAC and imaging, and the absence of symptoms of local infiltration. It also omits some procedural details, such as the involvement of other thyroid lobes and surrounding structures.
#
# - Naturalness: 4.8
#   * The language used in the model's response is fluent and sounds human-like. It effectively conveys the patient's medical condition and treatment plan in a clear and concise manner. The sentence structure and vocabulary are appropriate for a medical context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response aligns well with the context of the dialogue. It correctly reflects the key medical history details discussed, including the history of diabetes and HCV infection, treatment with peg-interferon-α 2a and ribavirin, and evaluation for DAAs in 2015. However, the model incorrectly states that the HCV infection was diagnosed in 2000 rather than identified through retrospective serology.
#
# - Completeness: 4.0
#   While the model includes many critical components from the dialogue, such as the history of diabetes and the sequence of treatment, it omits some details like the blood transfusion event in 1996 and specific laboratory measurements. The statement about the diagnosis of chronic HCV infection being made in 2000 overlooks the information about serology tests and genotype details.
#
# - Naturalness: 4.8
#   The response flows well and is easy to read. It maintains a human-like and fluent narrative style while summarizing the patient's medical history. It uses clinical language accurately, but small details could enhance the naturalness by integrating information that might come naturally in conversational context, such as mentioning the absence of smoking habits.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided, accurately reflecting the sequence of the medical evaluation and subsequent events. However, it omits some details regarding the patient's medical history and the previous surgical complication.
#
# - Completeness: 3.5
#   While the model summarizes the critical events related to the renal mass and follow-ups accurately, it lacks detail on the patient's complete medical history, the specifics of the gastric complications, and some other snippets from the conversation that could have made the response more thorough.
#
# - Naturalness: 4.0
#   The response is mostly fluent and clear. However, it could be enhanced with a more conversational tone to sound more human-like, such as including nouns or phrases to refer to the patient directly, as in "the patient" versus a more engaging narrative style.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response aligns well with the context, capturing the main elements of the conversation and interactions between the doctor and the patient. However, it omits some specific context details such as the informal water deprivation test and the results of prior evaluations.
#
# - Completeness: 3.5
#   While the model's response includes key details about the diagnosis and treatment, it lacks specific information about the patient's age, the circumstances leading to the condition, detailed prior evaluation results, and the social history. These omissions make the response less thorough than the true answer.
#
# - Naturalness: 4.8
#   The response is fluent and clear, mirroring a human-like summary style. It effectively communicates the main points without awkward phrasing or obvious machine-generated errors.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is coherent and logically aligns with the context provided in the input. It accurately reflects the critical points discussed, such as the COVID-19 diagnosis, treatment, subsequent complications, and the diagnosis of mucormycosis. However, the level of detail in the model's response is less extensive than in the true answer.
#
# - Completeness: 3.5
#
# The model's response captures the essential parts of the patient's treatment and diagnosis but omits some specific details mentioned in the true answer, such as the patient's age, non-diabetic status, blood pressure, temperature, additional information about the second CT scan results, and the detailed background leading to the diagnosis of mucormycosis. Including such details would enhance the completeness of the response.
#
# - Naturalness: 4.8
#
# The model's response is fluent and human-like, sounding professional and clear, which is appropriate given the medical context. It maintains a formal tone that would be expected from a clinical summary, similar to how a healthcare professional might communicate in writing.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#
# The model's response logically aligns with the context provided in the input. It accurately reflects the dialogue between the doctor and the patient, summarizing the key medical details discussed.
#
# - Completeness: 4.5
#
# The model's response sufficiently answers the question by encapsulating the critical details such as the symptoms, diagnosis, treatment, and the physical examination results. However, it omits precise numerical details such as body temperature, heart rate, respiratory rate, and blood pressure, which were provided in the input.
#
# - Naturalness: 4.8
#
# The model's response is fluent and human-like. It uses appropriate medical terminology and maintains a coherent structure reflective of medical documentation. Some phrases might be slightly formal compared to natural spoken language, but it fits the context well.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
# - Completeness: 4.0
# - Naturalness: 4.5
#
# **Explanation:**
#
# - **Coherence (4.5)**: The model's response is logically aligned with the initial conversation. It accurately summarizes key information about the patient's conditions (chromosome 1q21.1 deletion syndrome, situs inversus, SIADH) and the need for monitoring sodium levels and heart conditions. However, it does not reference some specific details provided in the context, like the echocardiogram results showing dextrocardia.
#
# - **Completeness (4.0)**: While the model captures the major points regarding the patient's condition and necessary follow-up actions, it omits some less critical details from the conversation, such as specific test results or other aspects of the patient's birth history. These omissions slightly detract from its completeness.
#
# - **Naturalness (4.5)**: The response is fluent and human-like. It uses appropriate medical terminology and phrases in a way that is clear and understandable, resembling a summary that a doctor might provide. However, it could be slightly more detailed in addressing its audience if it were a truly human response.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
#   The model's response generally aligns with the context provided, capturing the main elements of the patient's medical history and condition. However, there is an error regarding the family history of colon cancer; the input explicitly states that the patient denied any family history, whereas the model incorrectly mentions a family history.
#
# - Completeness: 4.0
#   The model's response covers most of the important details from the dialogue, including the symptoms, past medical history, and the series of investigations performed. It misses some specifics, such as the details of the laboratory results, previous hospitalization context, and the reason for deferring the colonoscopy.
#
# - Naturalness: 4.5
#   The model's response is fluent and generally sounds human-like, effectively summarizing the patient's medical information. However, it could benefit from more nuanced language, especially in capturing the subtleties and details of medical conditions and management.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response aligns logically with the context provided and accurately summarizes the diagnosis and treatment of AGEP due to meropenem as stated in the dialogue. However, it omits some of the patient’s medical history and diagnostic details, which slightly affects coherence with the broader context.
#
# - Completeness: 3.0
#   - The response successfully answers the main question regarding the diagnosis and treatment of AGEP but lacks details provided in the original conversation, such as the patient's medical history, specific symptoms, and treatment updates beyond the direct results of stopping meropenem. It ignores other treatments and the comprehensive medical context discussed.
#
# - Naturalness: 5.0
#   - The language used in the model's response is fluent, clear, and sounds human-like. It summarizes the situation naturally without awkward phrasing or grammatical errors.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.0**
#   The model's response is coherent with the context provided, it acknowledges the absence of specific information about the medication the doctor prescribed for swelling and redness. However, it's a bit too focused on the lack of information rather than aligning with the broader narrative in the dialogue.
#
# - **Completeness: 3.5**
#   The response recognizes the lack of specific information about the new medication prescribed, which is relevant to the question. However, it could have included more details from the context to provide a fuller answer, such as mentioning the broader condition diagnosis and patient history.
#
# - **Naturalness: 4.5**
#   The response is fluent, clear, and reads naturally as a human-like explanation. The language is straightforward and appropriately detailed given the context of the missing information.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   The model's response logically aligns with the context provided in the input, accurately summarizing the patient's condition and the doctor's findings and actions.
#
# - Completeness: 4.5
#   The model's response sufficiently answers the question and includes the key details of the patient's symptoms and treatment. However, it omits some specific background details about the patient's history, such as his age, initial symptom presentation circumstances, and certain observations (e.g., no muscle atrophy or sensory findings).
#
# - Naturalness: 4.5
#   The model's response is fluent and reads like a summary that a human might write. However, it has a slightly clinical and formal tone, which might sound less conversational or human-like compared to the patient-doctor dialogue.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is mostly coherent and aligns well with the context of the conversation. It accurately captures the key points discussed between the doctor and the patient, such as the symptoms, medical history, and COVID-19 test results. However, the model omits the details concerning the shortness of breath that led to the hospital visit, which slightly affects coherence.
#
# - Completeness: 3.5
#   - The answer covers most of the critical elements of the input conversation, including symptoms, diagnosis, and medical history. However, it misses the patient's shortness of breath onset and the fact he was shifted to the hospital, which are significant developments mentioned in the true answer.
#
# - Naturalness: 4.8
#   - The response reads fluently and maintains a human-like conversational tone. The language used is clear, formal, and coherent, making it appear natural and professional. There are no grammatical errors or awkward phrasings in the response.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   The model's response logically aligns with the context provided in the input. It correctly describes the sequence of events and procedures from the conversation between the doctor and the patient.
#
# - Completeness: 4.5
#   The response sufficiently answers the question by summarizing the key aspects of the medical procedure and outcomes. However, it could be slightly more detailed in certain areas, such as specifying the patient's underlying conditions (diabetic and smoker) mentioned in the conversation.
#
# - Naturalness: 4.8
#   The response is fluent and human-like. It presents the information in a clear and easily understandable manner, though it maintains a clinical tone typical in medical summaries. There is little indication that it was generated by an AI rather than a human.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
# - Completeness: 4.0
# - Naturalness: 4.5
#
# **Evaluation:**
#
# - **Coherence**: The model's response is highly coherent, accurately capturing the patient's condition, diagnosis, symptoms, treatments, and follow-up actions. It logically aligns with the context provided in the input dialogue, maintaining a clear narrative throughout.
#
# - **Completeness**: While the model's response covers important elements such as the diagnosis, symptoms, and follow-up decisions, it lacks some details present in the true answer. For example, it does not mention the initial weight and body mass index, the negative results of various tests, or the psychological evaluation outcomes in as much detail as the true answer. Therefore, it falls slightly short of being fully complete.
#
# - **Naturalness**: The response sounds fluent and human-like, accurately employing medical terminology and maintaining a professional tone consistent with a medical setting. However, the response is somewhat structured and formal, which might appear less natural compared to a more conversational style.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   - The model's response logically aligns with the provided input context, accurately describing the sequence of events and medical findings mentioned by the doctor and patient.
#
# - Completeness: 4.5
#   - The model's response sufficiently answers the question by summarizing the patient's symptoms, medical examinations, treatment, and follow-up instructions. However, it omits some specific details such as the patient's exact age, blood pressure readings, and the specific dosage of medications, which are present in the true answer.
#
# - Naturalness: 5.0
#   - The model's response is fluent and sounds human-like, employing clear and coherent language to convey the medical information without awkward phrasing or errors.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   - The model's response logically aligns with the context provided. It accurately reflects details from the conversation, such as the patient's medical history, current issues, and the treatment plan proposed by the physician.
#
# - Completeness: 4.5
#   - The model's response effectively summarizes the key points from the input conversation, including the patient's treatment history and current medical conditions. However, it slightly falls short of mentioning the patient's age and some nuanced details about their history with insulin treatments and psychotherapy. These omissions do not significantly impact the overall understanding but could limit the depth of information provided.
#
# - Naturalness: 4.8
#   - The response is fluent and human-like, with clear and well-structured sentences. It reads smoothly but lacks a conversational element due to its summary style, which may slightly affect its naturalness score. The use of clinical language is appropriate given the medical context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.5**
#   The model's response logically aligns with the context provided in the input. It accurately summarizes the patient's symptoms, history, and the actions taken in the hospital. However, it misses minor contextual details such as the patient's gender and age, which could have been included to enhance coherence.
#
# - **Completeness: 4.0**
#   The response captures most essential points, such as the patient's symptoms, medical history, treatment, and diagnostic steps. However, it omits specific details like the patient's age, gender, and the inability to perform MRI due to obesity. Additionally, it doesn't mention the cerebrospinal fluid (CSF) analysis, which is part of the true answer.
#
# - **Naturalness: 4.7**
#   The response is generally fluent and human-like, effectively summarizing complex medical information in a clear manner. Nonetheless, it presents the details in a slightly more rigid and less conversational manner compared to how a human doctor might recount the information.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response is mostly coherent with the conversation context provided. It accurately highlights key aspects such as the patient's history with leukemia, diabetes management, and hospital admission. However, the model incorrectly notes there is "no indication of any complications or concerning lab results" when the elevated hemoglobin A1c and serum triglyceride levels are notable concerns.
#
# - Completeness: 3.5
#
# The response captures the essential elements of the patient's medical history and current treatment plan, but it lacks details about specific lab results and dietary information mentioned in the dialogue, such as the exact A1c and triglyceride levels, and diet composition. The follow-up steps are mentioned but are somewhat oversimplified compared to the detailed specifics shared in the conversation.
#
# - Naturalness: 4.8
#
# The language used in the model's response is fluent and human-like. It effectively communicates the relevant medical details in a manner expected of a summary, reflecting natural sentence structure and vocabulary choice. There is a slight mechanical feel due to the detached mention of the patient's elevated lab results without context on their implications, which slightly impacts naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the conversation between the doctor and the patient. It concisely summarizes the main finding from the angiography (the floating mass likely being a thrombus) and suggests follow-up steps which are in line with the medical discussion.
#
# - Completeness: 3.5
#   While the response covers the critical point regarding the diagnosis of a thrombus and the need for follow-up, it lacks detail about the patient's comprehensive medical background, tests conducted, and differential diagnoses that were considered. The expert answer provides a more detailed account of the investigative process.
#
# - Naturalness: 4.8
#   The language used in the model's response sounds fluent and human-like. It presents the information in a straightforward manner that would likely be typical of a medical summary to a patient. Some minor details or nuances in phrasing might improve it slightly, but overall, it reads naturally.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#   - The model's response is generally coherent with the context, accurately reflecting the patient's condition and the doctor's advice. However, there is a minor error regarding the patient's gender, as the input refers to the patient as male, and the model response refers to the patient as female.
#
# - Completeness: 4.5
#   - The model's response covers most of the critical aspects discussed in the conversation, including the patient's diagnosis, treatment plan, and follow-up advice. It lacks slight specificity, such as the precise details of the fractures and the mention of the absence of trauma.
#
# - Naturalness: 4.8
#   - The model's response is fluent and sounds natural. It effectively uses appropriate medical terminology while maintaining a clear and understandable narrative. Minor issues in pronoun usage slightly affect its naturalness.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   - The model's response is coherent and logically aligns with the context provided in the input. It accurately summarizes the sequence of events and medical findings described in the dialogue.
#
# - Completeness: 4.0
#   - While the model's response captures the main elements, such as the cerebellar hematoma, fever, CSF findings, and the antibiotic resistance of E. coli, it lacks some specific details from the original conversation, such as the patient's age and medical history. This slightly reduces the completeness of the answer.
#
# - Naturalness: 4.5
#   - The response is fluent and human-like. It uses appropriate medical terminology and constructs sentences naturally. The flow of the summary reads smoothly, similar to how a healthcare professional might document a case.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.5
#   The model's response generally aligns with the context, acknowledging several symptoms and lab results accurately. However, the suggestion of an autoimmune disorder like systemic lupus erythematosus (SLE) feels somewhat speculative without a more direct alignment with the patient's entire medical profile and history provided.
#
# - Completeness: 4.0
#   The model sufficiently addresses the patient's symptoms and lab findings, considering possible conditions and the need for further evaluation, which is appropriate based on the information given. However, it could benefit from referencing more specific details like the patient's age and complete medical history for a more comprehensive analysis.
#
# - Naturalness: 4.5
#   The response is fluent and clear, closely resembling a human-like explanation a professional might provide. It presents the information in a structured and logical manner, making it easy to follow for the reader.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
# - Completeness: 4.5
# - Naturalness: 5.0
#
# **Explanation**:
# - **Coherence**: The model's response logically follows the sequence of events and details provided in the input dialogue, accurately reflecting that the extraoral swelling was investigated and determined not to be of dental origin. It summarizes the testing and the decision to refer the patient for further evaluation, making it fully coherent with the context given.
# ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided in the input. It accurately summarizes the key steps of the surgery and postoperative findings, maintaining a clear connection to the events detailed in the dialogue. The only minor detail missing is that the patient originally went to the hospital due to vertigo.
#
# - Completeness: 4.5
#   The model's response sufficiently answers the implicit question by summarizing the medical procedure and the patient's condition and recovery. It misses some non-critical context such as the initial complaint of vertigo and specific details of the patient's medical history, but all major points are covered.
#
# - Naturalness: 4.8
#   The model's response sounds fluent and human-like. It uses clear and professional medical language suitable for summarizing the context, though it feels slightly more clinical than conversational. Minor variations in sentence structure or use of transitional phrases could enhance naturalness slightly.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context and accurately reflects the suspected diagnosis and treatment plan outlined in the dialogue between the doctor and the patient. However, it does not include all the specifics present in the conversation, such as the initial symptoms and the suspected massive cerebrovascular event.
#
# - Completeness: 4.0
#   The response addresses the main point by stating the suspected condition and treatment plan, but it misses some details, such as the initial symptoms of decreased sensorium and seizure, examination findings, and other differential diagnoses considered, like the cerebrovascular event.
#
# - Naturalness: 4.8
#   The model's response is fluent and human-like. It is clear and concise, using appropriate medical terminology as would be expected in a clinical setting. The sentence structure is natural and comprehensible.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#
# The model's response aligns well with the context provided. It accurately reflects the symptoms, diagnostic possibilities, and treatment measures discussed between the doctor and the patient. Most details match the original dialogue, showcasing a coherent understanding of the input.
#
# - Completeness: 4.0
#
# The model's response is fairly thorough, covering most critical aspects of the patient's condition, history, diagnosis, and treatment plan. However, it introduces some information not explicitly mentioned in the provided context, such as the blood test for COVID-19 being inconclusive and some specific test details that were incomplete in the original input, which slightly affects the completeness.
#
# - Naturalness: 4.7
#
# The response is fluent and reads naturally, resembling a well-organized summary of medical communication. The language used is clear and professional, consistent with what one would expect from a medical context, making the response sound human-like and articulate.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context of the conversation. It accurately mentions key details such as the symptoms, medical history, examination findings, diagnostic results, pathological findings, surgical management, and the plan for adjuvant chemotherapy.
#
# - Completeness: 4.0
#   The model's response sufficiently answers the question by summarizing the key aspects of the case, but omits some specific details such as the patient's age, the exact vitals being within normal limits, and the precise immunohistochemical stain results. However, it captures most of the critical information necessary to understand the case.
#
# - Naturalness: 4.5
#   The model's response is fluent and uses medical terminology appropriately, consistent with what might be expected in a medical summary. It conveys the information clearly and accurately, mimicking a human-like response, though slightly more clinical in tone compared to conversational language.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - **Coherence: 4.5**
#   The model's response logically aligns with the context provided in the input. However, it slightly misrepresents the doctor's message, as the doctor was conveying condolences from their team, not from the family. This is a minor discrepancy.
#
# - **Completeness: 4.0**
#   The model captures the main points relevant to the question from the input context. However, it lacks specific details like the precise amount of insulin administered and the timeline of the patient's glucose levels, as seen in the true answer. Including more of these specifics would have enhanced completeness.
#
# - **Naturalness: 4.8**
#   The model's response is fluent and human-like, maintaining a clear and natural narrative flow. It reads like a summary that a person might provide in such a situation. The language used is appropriate for the context. The minor issue mentioned under coherence barely impacts this score.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response aligns well with the context provided and captures the main points of the conversation, including the technical challenges faced during the procedure. However, it omits certain specifics, such as the patient's complete medical background and the precise measurements involved, which are present in the true answer.
#
# - Completeness: 3.5
#   While the model's response covers the main parts of the procedure, it lacks some detailed information that is present in the true answer. This includes the patient's full medical history and specific procedural details such as the exact instruments used, access points, and the measures taken during the procedure.
#
# - Naturalness: 4.8
#   The model's response is fluent and sounds human-like. It effectively summarizes the conversation in a coherent manner with appropriate use of medical terminology, similar to how a professional might convey the information.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response remains mostly coherent with the context provided. It accurately summarizes the key events in the doctor's dialogue with the patient regarding the patient's condition and treatment plan. However, it lacks details about the severity and specifics of the patient's symptoms and the surgery, which are present in the true answer.
#
# - Completeness: 3.5
#   While the model's response covers the main points of the medical plan and potential interventions, it misses several important specifics that are present in the true answer, such as the size and specifics of the aneurysm, details of the surgery, and postoperative events. This results in a less comprehensive understanding of the scenario.
#
# - Naturalness: 4.0
#   The response is written in clear and fluent language, making it sound natural and human-like. However, it's a bit concise and could benefit from incorporating a few more specifics and narrative style elements to match the richness of the true answer.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#
# The model's response is generally coherent as it identifies the doctor's current focus on managing the patient's symptoms and ensuring comfort. However, it lacks specific details from the conversation that would make it fully coherent with the context.
#
# - Completeness: 2.5
#
# The response is quite general and doesn't answer the implicit questions about the patient's status and treatment interventions explicitly mentioned in the input conversation. Key details concerning the patient's condition, diagnoses, and specific treatments (e.g., NMS, rhabdomyolysis, cooling methods, specific medications) are missing.
#
# - Naturalness: 4.5
#
# The language used in the model's response is fluent and human-like. It reads naturally and flows as one would expect in a professional medical discussion. However, it feels slightly generic and lacks personalized detail.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# Based on the given metrics, here is the evaluation of the model's response:
#
# - **Coherence: 4.0**
#   - The model's response generally captures key details from the conversation accurately. However, there is a minor incoherence in the presented questions and answers about hypertension, diabetes, and tuberculosis, which were unnecessarily included in the response as questions rather than just stating the patient does not have these conditions. Overall, the alignment with the context is mostly logical, but it could be phrased better.
#
# - **Completeness: 3.5**
#   - The model's response covers most of the important aspects discussed between the patient and the doctor, such as the patient's condition upon admission, history of COPD, smoking habits, and treatment. However, some additional context details, such as the patient's occupation, history of symptom worsening, and the details about the previous spirometry test, are missing, which creates a gap in the comprehensiveness of the summary compared to the true answer.
#
# - **Naturalness: 3.0**
#   - The language used by the model is generally clear and understandable. However, parts of the response do not flow naturally, such as the unnecessary question format included in the response or slightly mechanical phrasing about symptom details. Improving the linguistic structure would enhance the naturalness of the output.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 5.0
#   The model's response logically aligns with the context provided in the conversation. It correctly identifies the patient's diagnosis based on the given details.
#
# - Completeness: 4.0
#   The model's response includes the essential information about the diagnosis and the immediate management plan. However, it doesn't mention some of the detailed medical findings (such as liver and kidney dysfunction, imaging details) that were shared during the conversation. While these details are not strictly necessary to answer the patient's question, their inclusion could have provided a fuller picture of the situation.
#
# - Naturalness: 4.5
#   The model's response is fluent and reads like a summary a doctor might give. However, the slightly structured format, typical of summarizing clinical notes, might detract slightly from sounding entirely human-like in a conversational context.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 3.0
#   The model's response is partially coherent as it acknowledges the sad news shared by the patient's family. However, it assumes uncertainty about the cause of death without reference to specific details provided in the conversation, such as the patient's complex medical history or the recent findings.
#
# - Completeness: 3.5
#   The model does address the situation (the patient passing away) and correctly notes a need for further information to understand the cause of death. However, it lacks depth in tying this to the specific medical context or history provided, making it less complete than it could be.
#
# - Naturalness: 4.0
#   The model's response sounds reasonably fluent and human-like, with an appropriate tone in response to the situation. However, the transition to discussing the cause of death without focusing on the shared history could slightly affect the natural flow.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response logically aligns with the context provided in the input. It accurately states that the patient had atheroembolic disease and received dialysis and supportive care, but these measures were insufficient to save his life. The response is consistent with the information exchanged between the doctor and the patient's family in the dialogue.
#
# - Completeness: 3.0
#   The model's response is quite brief and omits significant details regarding the patient's medical history, symptoms, and treatment as outlined in the true answer. While it covers the main cause of death, it lacks the comprehensive background necessary for a more thorough understanding of the case.
#
# - Naturalness: 4.5
#   The response sounds fluent and human-like. It uses natural language to convey the information clearly and concisely. However, the brevity of the response slightly detracts from its expressiveness, which could have been enhanced with more detailed information.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       4.478000
# Completeness    3.856000
# Naturalness     4.630000
# BLEURT          0.542912
# BERTScore_F1    0.518066
# dtype: float64

# %%
# generation

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        client = openai.OpenAI()
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

generation = df[df['task'] == 'generation']
results = []

for _, row in generation.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output_512'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    print(f"Evaluation result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Evaluation result:
# - **Coherence: 4.5**
#   The model's response is coherent as it refers to the patient's diabetes medication (Glynase MF) and mentions their blood sugar levels (FBS, PPBS, Hba1c), aligning well with the context provided in the input.
#
# - **Completeness: 3.0**
#   While the model mentions general advice about diet and exercise, it lacks specificity compared to the true answer, which provides specific recommendations like the additional medication (Volibo 0.2 mg) and follow-up steps. It also misses referring the user to a diabetologist for personalized advice.
#
# - **Naturalness: 4.7**
#   The response flows naturally and is easy to understand. It uses appropriate language and offers generalized advice that sounds typical for a healthcare-related response. However, it could be slightly improved by suggesting a more personalized approach.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.0
#   The model's response aligns with the context provided in the input, noting the importance of additional testing such as a pancreas MRI, while also considering stress as a factor affecting blood glucose levels. However, it could have included more detailed reasoning about why pancreatic cancer is unlikely based on the given data.
#
# - Completeness: 3.5
#   The response addresses the possibility of pancreatic issues but falls short of providing a comprehensive explanation, especially about why pancreatic cancer is unlikely. It doesn't fully address why insulin levels might have dropped, which could have been elaborated on with an explanation similar to the true answer concerning beta cell exhaustion.
#
# - Naturalness: 4.5
#   The response is fluent and human-like, clearly articulated in a way that would be typical of professional medical advice. The language is appropriate for the context, though it might benefit from more specific medical terms related to the scenario for greater authenticity.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 4.5
#   The model's response aligns logically with the context provided in the input, acknowledging the reports and discussing the two recommended treatment options. However, it lacks specific insights from the reports themselves.
#
# - Completeness: 3.5
#   While the response advises the patient to follow up with their ophthalmologist, it does not provide a definitive answer or recommendation based on the OCT and fluorescein angiography reports, which would have made it more complete.
#
# - Naturalness: 4.5
#   The response is fluent, human-like, and uses appropriate language for a medical context. It sounds like advice that could be given in a real conversation with a healthcare professional.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Evaluation result:
# - Coherence: 2.0
# The model's response incorrectly identifies the condition as priapism, which is a prolonged erection, not failure to achieve an erection. This mismatch shows a lack of coherence with the context provided.
#
# - Completeness: 1.5
# The response does not address potential causes such as diabetes or hypertension and does not provide practical advice for alternative treatments or medications. It simply suggests seeking medical attention, which is inadequate compared to the more thorough advice in the true answer.
#
# - Naturalness: 3.5
# The response is generally fluent and uses proper language, but the incorrect use of medical terminology (priapism) affects its perceived naturalness for an audience expecting medical advice.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# daily_diets

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response["choices"][0]["message"]["content"]
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

daily = df[df['task'] == 'daily_diets']
results = []

for i, row in daily.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_outpu_1024'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    if i % 10 == 0:
        print(f"Evaluation {i+1} result:\n{evaluation}")
    
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Warning: Column BLEURT not found in DataFrame. Skipping normalization.
# Warning: Column BERTScore_F1 not found in DataFrame. Skipping normalization.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 147
#     144 evaluation_df = normalize_scores(evaluation_df, "BLEURT")
#     145 evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")
# --> 147 average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
#     148 print("평균 점수:")
#     149 print(average_scores)
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/unsloth_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Coherence', 'Completeness', 'Naturalness', 'BLEURT', 'BERTScore_F1'], dtype='object')] are in the [columns]"

# %%
# alternative_diets

import openai
import pandas as pd
import re
from sklearn.metrics import f1_score
from bert_score import score as bert_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import os
from dotenv import load_dotenv

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# BLEURT 모델 로드
bleurt_model_name = "Elron/bleurt-large-512"
tokenizer = AutoTokenizer.from_pretrained(bleurt_model_name)
bleurt_model = AutoModelForSequenceClassification.from_pretrained(bleurt_model_name)
bleurt_model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bleurt_model = bleurt_model.to(device)

MAX_CONTEXT_LENGTH = 8192

# GPT-4 평가 함수
def evaluate_with_gpt4(input_text, model_output, true_output):
    input_text = str(input_text)[:MAX_CONTEXT_LENGTH]
    model_output = str(model_output)[:MAX_CONTEXT_LENGTH]
    true_output = str(true_output)[:MAX_CONTEXT_LENGTH]

    prompt = f"""
    You are tasked with evaluating the quality of a QA model's responses based on the following metrics:
    1. **Coherence**: Does the model's response logically align with the context provided in the input?
    2. **Completeness**: Does the model's response sufficiently answer the question in the input?
    3. **Naturalness**: Does the model's response sound fluent and human-like?

    **Input**:
    {input_text}

    **Model's Response**:
    {model_output}

    **True Answer**:
    {true_output}

    Please rate each metric on a scale from 1 to 5. 
    Example response format:
    - Coherence: X.X
    - Completeness: X.X
    - Naturalness: X.X
    """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are an expert evaluator for Summarization models."},
                {"role": "user", "content": prompt}
            ]
        )
        return response["choices"][0]["message"]["content"]
    except Exception as e:
        print("Error with GPT-4 API:", e)
        return None

# GPT-4 점수 추출
def extract_scores(evaluation):
    if evaluation is None:
        return {"Coherence": 0.0, "Completeness": 0.0, "Naturalness": 0.0}
    coherence = re.search(r"Coherence: (\d\.\d)", evaluation)
    completeness = re.search(r"Completeness: (\d\.\d)", evaluation)
    naturalness = re.search(r"Naturalness: (\d\.\d)", evaluation)
    
    return {
        "Coherence": float(coherence.group(1)) if coherence else 0.0,
        "Completeness": float(completeness.group(1)) if completeness else 0.0,
        "Naturalness": float(naturalness.group(1)) if naturalness else 0.0
    }

# BLEURT 점수 계산
def calculate_bleurt(y_true, y_pred):
    inputs = tokenizer(y_pred, y_true, return_tensors="pt", padding=True, truncation=True, max_length=512)
    inputs = {key: value.to(device) for key, value in inputs.items()}
    
    with torch.no_grad():
        scores = bleurt_model(**inputs).logits

    if scores.numel() == 1:
        return float(scores.squeeze().item())  
    return [float(score) for score in scores.squeeze().tolist()]  

# BLEURT 및 BERTScore 계산
def calculate_bleurt_and_bertscore(y_true, y_pred):
    bleurt_score_value = calculate_bleurt(y_true, y_pred)
    _, _, bert_f1 = bert_score(y_pred, y_true, lang="en", rescale_with_baseline=True)
    bert_f1_avg = sum(bert_f1) / len(bert_f1) if len(bert_f1) > 0 else 0

    return {
        "BLEURT": bleurt_score_value if isinstance(bleurt_score_value, float) else sum(bleurt_score_value) / len(bleurt_score_value),
        "BERTScore_F1": bert_f1_avg
    }

# 점수 정규화 함수
def normalize_scores(df, column):
    if column not in df.columns:
        print(f"Warning: Column {column} not found in DataFrame. Skipping normalization.")
        return df
    df[column] = df[column].apply(lambda x: float(x) if isinstance(x, torch.Tensor) else x)
    min_val, max_val = df[column].min(), df[column].max()
    df[column] = df[column].apply(lambda x: (x - min_val) / (max_val - min_val) if max_val > min_val else 0.5)
    return df

alternative = df[df['task'] == 'alternative_diet']
results = []

for _, row in alternative.iterrows():
    input_text = str(row['input'])
    model_output = str(row['model_output'])
    true_output = str(row['output'])
    
    evaluation = evaluate_with_gpt4(input_text, model_output, true_output)
    if i % 10 == 0:
        print(f"Evaluation {i+1} result:\n{evaluation}")
            
    scores = extract_scores(evaluation)
    metric_scores = calculate_bleurt_and_bertscore([true_output], [model_output])

    results.append({
        "input": input_text,
        "model_output": model_output,
        "true_output": true_output,
        "evaluation": evaluation,
        "Coherence": scores["Coherence"],
        "Completeness": scores["Completeness"],
        "Naturalness": scores["Naturalness"],
        "BLEURT": metric_scores.get("BLEURT", 0.0),  # 기본값 설정
        "BERTScore_F1": metric_scores.get("BERTScore_F1", 0.0)
    })

evaluation_df = pd.DataFrame(results)

# 'BLEURT' 컬럼이 존재하는지 확인 후 정규화 수행
evaluation_df = normalize_scores(evaluation_df, "BLEURT")
evaluation_df = normalize_scores(evaluation_df, "BERTScore_F1")

average_scores = evaluation_df[["Coherence", "Completeness", "Naturalness", "BLEURT", "BERTScore_F1"]].mean()
print("평균 점수:")
print(average_scores)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 평균 점수:
# Coherence       3.223577
# Completeness    2.880081
# Naturalness     3.008130
# BLEURT          0.488236
# BERTScore_F1    0.627131
# dtype: float64

# %%
import pandas as pd

dfh = pd.read_csv("/data/jaesung/llm_for_diabetes/src/data/data2_daily_diets/diabetes_food_hub_new_nutri_facts.csv")
dfh.head(2)
# Out:
#                                  title  \
# 0   Raspberry Swirl Frozen Yogurt Bark
# 1  Maple-Pumpkin Spice Oatmeal Cookies
#
#                                          description prep_time cook_time  \
# 0  Raspberry Swirl Frozen Yogurt Bark: Dive into ...    10 min      4 hr
# 1                              Description not found    10 min    25 min
#
#       servings                                              steps  \
# 0   6 Servings  ['Cover a freezer-safe tray with parchment pap...
# 1  14 Servings  ['Preheat the oven to 350 degrees F. Line two ...
#
#                                                 tags  \
# 0  ['Kid Friendly', 'Vegetarian', 'Dessert', 'Sna...
# 1  ['Kid Friendly', 'Vegetarian', 'Snacks', 'Glut...
#
#                                      nutrition_facts  \
# 0  {'Servings': '6 Servings', 'Serving Size': '1 ...
# 1  {'Servings': '14 Servings', 'Serving Size': '1...
#
#                                          ingredients
# 0  [{'label': 'Plain Nonfat Greek yogurt', 'us_me...
# 1  [{'label': 'old-fashioned rolled oats', 'us_me...

# %%
# daily diet - nutri score

import ast
import pandas as pd
import json
import re
import openai
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from dotenv import load_dotenv
import os
from tqdm import tqdm

# Load environment variables
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def extract_numeric_value(value):
    try:
        if isinstance(value, str):
            match = re.search(r"(\d+(\.\d+)?)", value)
            if match:
                return float(match.group(1))
        elif isinstance(value, (int, float)):
            return float(value)
    except Exception as e:
        print(f"Error in extract_numeric_value: {e}, value: {value}")
    return 0.0

def is_valid_meal_structure(json_string):
    try:
        data = json.loads(json_string)
        return all(key in data for key in ['Breakfast', 'Lunch', 'Dinner'])
    except (json.JSONDecodeError, TypeError):
        return False

def find_most_similar_row(title, dfh):
    try:
        dfh['title'] = dfh['title'].fillna('')  # Handle NaN values
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(dfh['title'])
        input_vector = vectorizer.transform([title])
        similarities = cosine_similarity(input_vector, tfidf_matrix)
        most_similar_idx = similarities.argmax()
        return dfh.iloc[most_similar_idx]
    except Exception as e:
        print(f"Error in find_most_similar_row: {e}, title: {title}")
        return None

def identify_fruit_veg(ingredients_list):
    try:
        prompt = f"Identify which items in the following ingredient list are fruits or vegetables:\n\n{ingredients_list}\n\nReturn only the names of items that are fruits or vegetables in a Python list format."
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an assistant identifying fruits and vegetables."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=100,
            temperature=0
        )
        fruits_vegetables = response['choices'][0]['message']['content']
        return ast.literal_eval(fruits_vegetables)
    except Exception as e:
        print(f"Error identifying fruits and vegetables: {e}")
        return []

def calculate_fruit_veg_points(ingredients, total_weight):
    try:
        ingredients_list = ast.literal_eval(ingredients)
        fruit_veg_labels = identify_fruit_veg(ingredients_list)

        fruit_veg_weight = 0
        for ingredient in ingredients_list:
            label = ingredient.get('label', '')
            weight = extract_numeric_value(ingredient.get('metric_measure', 0))
            if label in fruit_veg_labels:
                fruit_veg_weight += weight

        # 과일/채소 비율을 100g 기준으로 변환
        fruit_veg_ratio = (fruit_veg_weight / total_weight) * 100 if total_weight > 0 else 0

        if fruit_veg_ratio > 80:
            return 5
        elif fruit_veg_ratio > 60:
            return 2
        elif fruit_veg_ratio > 40:
            return 1
        else:
            return 0
    except Exception as e:
        print(f"Error calculating fruit_veg_points: {e}")
        return 0

def extract_nested_value(data, keys, default=0):
    try:
        for key in keys:
            if isinstance(data, dict):
                data = data.get(key, {})
            else:
                return default
        return extract_numeric_value(data) if isinstance(data, (int, float, str)) else default
    except Exception as e:
        print(f"Error in extract_nested_value: {e}, keys: {keys}, data: {data}")
        return default

def calculate_nutri_score(nutrition_facts, ingredients):
    try:
        if isinstance(nutrition_facts, str):
            nutrition_facts = ast.literal_eval(nutrition_facts)

        # 전체 무게 계산
        total_weight = sum(
            extract_numeric_value(ingredient.get('metric_measure', 0)) 
            for ingredient in ast.literal_eval(ingredients)
        )
        if total_weight == 0:
            print("Warning: Total weight is zero. Skipping calculation.")
            return None

        # 100g 기준으로 성분 정규화
        energy = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Calories']) / total_weight * 100
        saturated_fat = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Fat', 'Amount']) / total_weight * 100
        sugar = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Total Sugars']) / total_weight * 100
        sodium = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Sodium']) / total_weight * 100
        fiber = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Dietary Fiber']) / total_weight * 100
        protein = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Protein']) / total_weight * 100

        # Unfavorable points calculation
        energy_points = min(energy / 80, 800)
        saturated_fat_points = min(saturated_fat / 1, 10)
        sugar_points = min(sugar / 4.5, 45)
        sodium_points = min(sodium / 90, 900)

        unfavorable_points = energy_points + saturated_fat_points + sugar_points + sodium_points

        # Favorable points calculation
        fiber_points = min(fiber / 0.7, 3.5)
        protein_points = min(protein / 1.6, 8.0)
        fruit_veg_points = calculate_fruit_veg_points(ingredients, total_weight)

        favorable_points = fiber_points + protein_points + fruit_veg_points

        # Final Nutri-Score calculation
        total_score = unfavorable_points - favorable_points
        return total_score
    except Exception as e:
        print(f"Error in calculate_nutri_score: {e}, nutrition_facts: {nutrition_facts}")
        return None

def get_nutri_score_grade(score):
    if score <= -1:
        return "A"
    elif score <= 2:
        return "B"
    elif score <= 10:
        return "C"
    elif score <= 18:
        return "D"
    else:
        return "E"

def calculate_meal_nutri_score(meal_data, dfh):
    meal_scores = {}

    for meal, title in meal_data.items():
        matched_row = find_most_similar_row(title, dfh)
        if matched_row is None:
            continue

        nutrition_facts = matched_row['nutrition_facts']
        ingredients = matched_row['ingredients']
        score = calculate_nutri_score(nutrition_facts, ingredients)

        if score is None:
            print(f"Warning: Nutri-Score calculation failed for meal '{meal}' with title '{title}'.")
            grade = "N/A"
        else:
            grade = get_nutri_score_grade(score)

        meal_scores[meal] = {'score': score, 'grade': grade}

    return meal_scores

def calculate_scores_with_comparison(df, dfh):
    results = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        output_scores = {}
        model_scores = {}
        if is_valid_meal_structure(row.get('output', '')):
            output_data = json.loads(row['output'])
            output_scores = calculate_meal_nutri_score(output_data, dfh)
        if is_valid_meal_structure(row.get('model_output_512', '')):
            model_data = json.loads(row['model_output_512'])
            model_scores = calculate_meal_nutri_score(model_data, dfh)
        results.append({'row_index': idx, 'output_scores': output_scores, 'model_scores': model_scores})
    return results

def calculate_average_scores(results):
    """
    Calculate the average Nutri-Scores for outputs and model outputs.
    """
    output_total_score = 0
    model_total_score = 0
    output_count = 0
    model_count = 0

    for result in results:
        # Extract output scores
        for meal, score_data in result['output_scores'].items():
            if score_data['score'] is not None:
                output_total_score += score_data['score']
                output_count += 1

        # Extract model scores
        for meal, score_data in result['model_scores'].items():
            if score_data['score'] is not None:
                model_total_score += score_data['score']
                model_count += 1

    # Calculate averages
    output_avg = output_total_score / output_count if output_count > 0 else None
    model_avg = model_total_score / model_count if model_count > 0 else None

    return output_avg, model_avg


# 'daily_diets' task Nutri-Score calculation
filtered_df = df[df['task'] == 'daily_diets']
results = calculate_scores_with_comparison(filtered_df, dfh)

# Calculate overall averages
output_avg, model_avg = calculate_average_scores(results)

# Print results
print("=== Results for Each Row ===")
for result in results:
    print(f"Row Index: {result['row_index']}")
    print(f"Output Scores: {result['output_scores']}")
    print(f"Model Output Scores: {result['model_scores']}")
    print()

print("=== Overall Averages ===")
print(f"Output Average Nutri-Score: {output_avg}")
print(f"Model Output Average Nutri-Score: {model_avg}")
# Out:
# 100%|██████████| 274/274 [00:00<00:00, 22063.42it/s]
# === Results for Each Row ===
# Row Index: 661
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 662
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 663
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 664
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 665
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 666
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 667
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 668
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 669
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 670
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 671
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 672
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 673
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 674
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 675
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 676
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 677
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 678
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 679
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 680
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 681
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 682
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 683
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 684
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 685
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 686
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 687
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 688
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 689
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 690
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 691
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 692
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 693
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 694
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 695
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 696
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 697
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 698
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 699
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 700
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 701
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 702
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 703
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 704
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 705
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 706
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 707
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 708
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 709
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 710
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 711
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 712
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 713
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 714
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 715
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 716
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 717
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 718
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 719
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 720
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 721
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 722
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 723
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 724
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 725
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 726
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 727
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 728
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 729
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 730
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 731
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 732
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 733
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 734
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 735
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 736
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 737
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 738
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 739
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 740
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 741
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 742
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 743
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 744
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 745
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 746
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 747
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 748
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 749
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 750
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 751
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 752
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 753
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 754
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 755
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 756
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 757
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 758
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 759
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 760
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 761
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 762
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 763
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 764
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 765
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 766
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 767
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 768
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 769
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 770
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 771
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 772
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 773
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 774
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 775
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 776
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 777
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 778
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 779
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 780
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 781
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 782
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 783
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 784
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 785
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 786
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 787
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 788
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 789
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 790
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 791
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 792
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 793
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 794
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 795
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 796
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 797
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 798
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 799
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 800
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 801
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 802
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 803
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 804
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 805
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 806
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 807
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 808
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 809
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 810
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 811
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 812
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 813
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 814
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 815
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 816
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 817
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 818
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 819
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 820
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 821
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 822
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 823
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 824
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 825
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 826
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 827
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 828
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 829
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 830
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 831
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 832
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 833
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 834
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 835
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 836
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 837
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 838
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 839
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 840
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 841
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 842
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 843
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 844
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 845
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 846
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 847
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 848
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 849
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 850
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 851
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 852
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 853
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 854
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 855
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 856
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 857
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 858
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 859
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 860
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 861
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 862
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 863
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 864
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 865
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 866
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 867
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 868
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 869
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 870
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 871
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 872
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 873
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 874
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 875
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 876
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 877
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 878
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 879
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 880
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 881
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 882
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 883
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 884
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 885
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 886
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 887
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 888
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 889
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 890
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 891
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 892
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 893
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 894
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 895
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 896
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 897
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 898
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 899
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 900
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 901
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 902
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 903
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 904
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 905
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 906
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 907
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 908
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 909
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 910
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 911
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 912
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 913
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 914
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 915
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 916
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 917
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 918
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 919
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 920
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 921
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 922
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 923
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 924
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 925
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 926
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 927
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 928
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 929
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 930
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 931
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 932
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 933
# Output Scores: {}
# Model Output Scores: {}
#
# Row Index: 934
# Output Scores: {}
# Model Output Scores: {}
#
# === Overall Averages ===
# Output Average Nutri-Score: None
# Model Output Average Nutri-Score: None

# %%
# alternative diet - nutri score

import ast
import pandas as pd
import json
import re
import openai
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from dotenv import load_dotenv
import os
from tqdm import tqdm

# Load environment variables
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

def extract_numeric_value(value):
    try:
        if isinstance(value, str):
            match = re.search(r"(\d+(\.\d+)?)", value)
            if match:
                return float(match.group(1))
        elif isinstance(value, (int, float)):
            return float(value)
    except Exception as e:
        print(f"Error in extract_numeric_value: {e}, value: {value}")
    return 0.0

def is_valid_meal_structure(json_string):
    try:
        data = json.loads(json_string)
        return isinstance(data, dict)
    except (json.JSONDecodeError, TypeError):
        return False

def find_most_similar_row(title, dfh):
    try:
        dfh['title'] = dfh['title'].fillna('')  # Handle NaN values
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(dfh['title'])
        input_vector = vectorizer.transform([title])
        similarities = cosine_similarity(input_vector, tfidf_matrix)
        most_similar_idx = similarities.argmax()
        return dfh.iloc[most_similar_idx]
    except Exception as e:
        print(f"Error in find_most_similar_row: {e}, title: {title}")
        return None

def identify_fruit_veg(ingredients_list):
    try:
        prompt = f"Identify which items in the following ingredient list are fruits or vegetables:\n\n{ingredients_list}\n\nReturn only the names of items that are fruits or vegetables in a Python list format."
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an assistant identifying fruits and vegetables."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=100,
            temperature=0
        )
        fruits_vegetables = response['choices'][0]['message']['content']
        return ast.literal_eval(fruits_vegetables)
    except Exception as e:
        print(f"Error identifying fruits and vegetables: {e}")
        return []

def calculate_fruit_veg_points(ingredients, total_weight):
    try:
        ingredients_list = ast.literal_eval(ingredients)
        fruit_veg_labels = identify_fruit_veg(ingredients_list)

        fruit_veg_weight = 0
        for ingredient in ingredients_list:
            label = ingredient.get('label', '')
            weight = extract_numeric_value(ingredient.get('metric_measure', 0))
            if label in fruit_veg_labels:
                fruit_veg_weight += weight

        # 과일/채소 비율을 100g 기준으로 변환
        fruit_veg_ratio = (fruit_veg_weight / total_weight) * 100 if total_weight > 0 else 0

        if fruit_veg_ratio > 80:
            return 5
        elif fruit_veg_ratio > 60:
            return 2
        elif fruit_veg_ratio > 40:
            return 1
        else:
            return 0
    except Exception as e:
        print(f"Error calculating fruit_veg_points: {e}")
        return 0

def extract_nested_value(data, keys, default=0):
    try:
        for key in keys:
            if isinstance(data, dict):
                data = data.get(key, {})
            else:
                return default
        return extract_numeric_value(data)
    except Exception as e:
        print(f"Error in extract_nested_value: {e}, keys: {keys}, data: {data}")
        return default

def calculate_nutri_score(nutrition_facts, ingredients):
    try:
        if isinstance(nutrition_facts, str):
            nutrition_facts = ast.literal_eval(nutrition_facts)

        # 전체 무게 계산
        total_weight = sum(
            extract_numeric_value(ingredient.get('metric_measure', 0)) 
            for ingredient in ast.literal_eval(ingredients)
        )
        if total_weight == 0:
            print("Warning: Total weight is zero. Skipping calculation.")
            return None

        # 100g 기준으로 성분 정규화
        energy = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Calories']) / total_weight * 100
        saturated_fat = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Fat', 'Amount']) / total_weight * 100
        sugar = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Total Sugars']) / total_weight * 100
        sodium = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Sodium']) / total_weight * 100
        fiber = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Total Carbohydrates', 'Dietary Fiber']) / total_weight * 100
        protein = extract_nested_value(nutrition_facts, ['Amount per Serving', 'Protein']) / total_weight * 100

        # Unfavorable points calculation
        energy_points = min(energy / 80, 800)
        saturated_fat_points = min(saturated_fat / 1, 10)
        sugar_points = min(sugar / 4.5, 45)
        sodium_points = min(sodium / 90, 900)

        unfavorable_points = energy_points + saturated_fat_points + sugar_points + sodium_points

        # Favorable points calculation
        fiber_points = min(fiber / 0.7, 3.5)
        protein_points = min(protein / 1.6, 8.0)
        fruit_veg_points = calculate_fruit_veg_points(ingredients, total_weight)

        favorable_points = fiber_points + protein_points + fruit_veg_points

        # Final Nutri-Score calculation
        total_score = unfavorable_points - favorable_points
        return total_score
    except Exception as e:
        print(f"Error in calculate_nutri_score: {e}, nutrition_facts: {nutrition_facts}")
        return None

def get_nutri_score_grade(score):
    if score <= -1:
        return "A"
    elif score <= 2:
        return "B"
    elif score <= 10:
        return "C"
    elif score <= 18:
        return "D"
    else:
        return "E"

def calculate_scores_with_comparison_no_meals(df, dfh):
    results = []
    output_scores_list = []
    model_output_scores_list = []

    for idx, row in tqdm(df.iterrows(), total=len(df)):
        try:
            output_text = row.get('output', '')
            if output_text:
                matched_row = find_most_similar_row(output_text, dfh)
                if matched_row is not None:
                    nutrition_facts = matched_row['nutrition_facts']
                    ingredients = matched_row['ingredients']
                    output_score = calculate_nutri_score(nutrition_facts, ingredients)
                    output_scores_list.append(output_score)
                else:
                    output_score = None

            model_output_text = row.get('model_output_512', '')
            if model_output_text:
                matched_row = find_most_similar_row(model_output_text, dfh)
                if matched_row is not None:
                    nutrition_facts = matched_row['nutrition_facts']
                    ingredients = matched_row['ingredients']
                    model_output_score = calculate_nutri_score(nutrition_facts, ingredients)
                    model_output_scores_list.append(model_output_score)
                else:
                    model_output_score = None

            results.append({
                'row_index': idx,
                'output_score': output_score,
                'model_output_score': model_output_score
            })

        except Exception as e:
            print(f"Error processing row {idx}: {e}")
            results.append({
                'row_index': idx,
                'output_score': None,
                'model_output_score': None
            })

    final_output_avg = sum(output_scores_list) / len(output_scores_list) if output_scores_list else None
    final_model_output_avg = sum(model_output_scores_list) / len(model_output_scores_list) if model_output_scores_list else None

    print(f"Output Average Nutri-Score: {final_output_avg}")
    print(f"Model Output Average Nutri-Score: {final_model_output_avg}")

    return results

# Execution
filtered_df = df[df['task'] == 'alternative_diet']
results = calculate_scores_with_comparison_no_meals(filtered_df, dfh)

# Print results
for result in results:
    print(result)
# Out:
#   0%|          | 0/246 [00:00<?, ?it/s]
#  64%|██████▍   | 158/246 [03:34<01:46,  1.21s/it]
# Error identifying fruits and vegetables: unterminated string literal (detected at line 1) (<unknown>, line 1)
#  84%|████████▍ | 207/246 [04:37<00:40,  1.03s/it]
# Warning: Total weight is zero. Skipping calculation.
# 100%|██████████| 246/246 [05:27<00:00,  1.33s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 216
#     214 # Execution
#     215 filtered_df = df[df['task'] == 'alternative_diet']
# --> 216 results = calculate_scores_with_comparison_no_meals(filtered_df, dfh)
#     218 # Print results
#     219 for result in results:
#
# Cell In[32], line 207, in calculate_scores_with_comparison_no_meals(df, dfh)
#     200         results.append({
#     201             'row_index': idx,
#     202             'output_score': None,
#     203             'model_output_score': None
#     204         })
#     206 final_output_avg = sum(output_scores_list) / len(output_scores_list) if output_scores_list else None
# --> 207 final_model_output_avg = sum(model_output_scores_list) / len(model_output_scores_list) if model_output_scores_list else None
#     209 print(f"Output Average Nutri-Score: {final_output_avg}")
#     210 print(f"Model Output Average Nutri-Score: {final_model_output_avg}")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'
