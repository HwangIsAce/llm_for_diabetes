# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] ="1"

# %%
from huggingface_hub import logout, notebook_login
# logout()
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset

seed = load_dataset("passionMan/real_seed_IFD_rIFD14")
seed
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output', 'ifd_loss'],
#         num_rows: 15156
#     })
# })

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = False # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "BioMistral/BioMistral-7B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 04-01 23:52:16 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.2.12: Fast Mistral patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-PCIE-40GB. Max memory: 39.394 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# BioMistral/BioMistral-7B does not have a padding token! Will use pad_token = <unk>.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj"],
    lora_alpha = 32,
    lora_dropout = 0.05, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2025.2.12 patched 28 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]

    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("passionMan/real_seed_IFD_rIFD14", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 8,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 16,
        gradient_accumulation_steps = 4,
        warmup_steps = 150, # 50
        num_train_epochs = 2, # Set this for 1 full training run.
        # max_steps = 60,
        learning_rate = 2e-5,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 100,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs/real_seed_IFD_rIFD14",
        report_to = "none", # Use this for WandB etc
        save_steps = 100,
    ),
)
# Out:
# Applying chat template to train dataset (num_proc=8):   0%|          | 0/15156 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=8):   0%|          | 0/15156 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=8):   0%|          | 0/15156 [00:00<?, ? examples/s]

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 15,156 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 4
# \        /    Total batch size = 64 | Total steps = 474
#  "-____-"     Number of trainable parameters = 9,175,040
#     <div>
#
#       <progress value='474' max='474' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [474/474 44:03, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>2.040000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.563100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.465400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.440700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
import json
import time
import random
from datasets import load_dataset
from collections import defaultdict

### ✅ Hugging Face에서 데이터 로드
dataset_name = "passionMan/test_dataset10"
dataset = load_dataset(dataset_name, split="test")  # 'test' split 로드

### ✅ JSONL 저장 함수 (평가 결과 저장용)
def save_to_jsonl(file_path, data):
    with open(file_path, "a", encoding="utf-8") as f: 
        f.write(json.dumps(data, ensure_ascii=False) + "\n")

### ✅ 모델 응답 생성 함수
def generate_response(instruction_text, input_text, max_new_tokens=128):
    try:
        FastLanguageModel.for_inference(model)  # Enable native 2x faster inference

        # ✅ 모델의 최대 입력 길이 가져오기 (보통 4096 또는 2048)
        max_input_length = getattr(model.config, "max_position_embeddings", 4096)

        # ✅ 입력 토큰 길이 확인
        input_tokens = tokenizer(
            alpaca_prompt.format(instruction_text, input_text, ""), 
            return_tensors="pt"
        ).to("cuda")

        input_length = input_tokens['input_ids'].shape[1]

        # 🔥 입력이 너무 길면 최대 입력 길이에 맞게 자름
        if input_length > max_input_length:
            print(f"[WARNING] Truncating input from {input_length} to {max_input_length} tokens.")
            input_text = tokenizer.decode(input_tokens['input_ids'][0, :max_input_length], skip_special_tokens=True)

        # ✅ 생성 수행 (max_new_tokens을 적용)
        outputs = model.generate(
            **tokenizer(alpaca_prompt.format(instruction_text, input_text, ""), return_tensors="pt").to("cuda"),
            max_new_tokens=max_new_tokens,  # ✅ 생성 길이 적용
            use_cache=True
        )

        decoded_outputs = tokenizer.batch_decode(outputs)
        response_texts = [output.split("### Response:\n")[-1].strip() for output in decoded_outputs]
        return response_texts[0].replace("<|eot_id|>", "")

    except Exception as e:
        print(f"[ERROR] Exception in response generation: {str(e)}")
        return None

# ✅ 데이터 경로 설정 (결과 저장용)
output_json_path = "response/bio_mistral.jsonl"

# ✅ Task별 데이터 그룹화 (각 태스크별 0~29번 샘플 선택)
grouped_data = defaultdict(list)
for item in dataset:
    grouped_data[item["task"]].append(item)

# ✅ 성능 평가할 데이터 생성 (각 태스크별 30개만 추출)
sampled_data = []
for task, samples in grouped_data.items():
    sampled_data.extend(samples[:100])  # 최대 30개 선택

# ✅ 성능 평가 시작
start_time = time.time()
total_samples = len(sampled_data)

for idx, item in enumerate(sampled_data):
    sample_start_time = time.time()

    input_text = item.get("input", "")
    instruction = item.get("instruction", "")
    task = item.get("task", "").lower()

    # ✅ 생성할 토큰 길이 설정 (생성 토큰 수 조절)
    short_context_tasks = {"qa1", "qa2", "qa3", "nli", "re", "re2"}  # 생성 32
    medium_context_tasks = {"ie"} # 생성 128
    long_context_tasks = {"summarization", "generation", "daily_diets", "alternative_diet"}  # 생성 1024

    if task in short_context_tasks:
        max_new_tokens = 32  # ✅ 생성 길이 128
    elif task in medium_context_tasks:
        max_new_tokens = 32
    elif task in long_context_tasks:
        max_new_tokens = 512  # ✅ 생성 길이 1024
    else:
        max_new_tokens = 128  # 기본값

    try:
        model_output = generate_response(instruction, input_text, max_new_tokens)

        if model_output is not None:
            output_data = item.copy()
            output_data.update({f"model_output_{max_new_tokens}": model_output})
            save_to_jsonl(output_json_path, output_data)
        else:
            print(f"[WARNING] Skipping sample {idx+1}/{total_samples} due to length limit or generation failure.")

    except Exception as e:
        print(f"[ERROR] Skipping sample {idx+1}/{total_samples} due to unexpected error: {str(e)}")

    elapsed_time = time.time() - start_time
    avg_time_per_sample = elapsed_time / (idx + 1) 
    remaining_samples = total_samples - (idx + 1)
    estimated_remaining_time = remaining_samples * avg_time_per_sample

    print(f"[{idx+1}/{total_samples}] Sample processed in {time.time() - sample_start_time:.2f}s, ETA: {estimated_remaining_time/60:.2f} min")

print(f"\nAll samples processed. Total time: {(time.time() - start_time)/60:.2f} min")
# Out:
# [1/900] Sample processed in 2.13s, ETA: 31.86 min
# [2/900] Sample processed in 0.21s, ETA: 17.48 min
# [3/900] Sample processed in 11.02s, ETA: 66.56 min
# [4/900] Sample processed in 2.59s, ETA: 59.52 min
# [5/900] Sample processed in 3.36s, ETA: 57.59 min
# [6/900] Sample processed in 10.98s, ETA: 75.20 min
# [7/900] Sample processed in 0.22s, ETA: 64.86 min
# [8/900] Sample processed in 0.24s, ETA: 57.14 min
# [9/900] Sample processed in 4.84s, ETA: 58.72 min
# [10/900] Sample processed in 4.36s, ETA: 59.25 min
# [11/900] Sample processed in 2.99s, ETA: 57.83 min
# [12/900] Sample processed in 0.25s, ETA: 53.25 min
# [13/900] Sample processed in 3.32s, ETA: 52.87 min
# [14/900] Sample processed in 3.31s, ETA: 52.54 min
# [15/900] Sample processed in 0.21s, ETA: 49.19 min
# [16/900] Sample processed in 10.30s, ETA: 55.55 min
# [17/900] Sample processed in 0.28s, ETA: 52.46 min
# [18/900] Sample processed in 5.54s, ETA: 54.01 min
# [19/900] Sample processed in 3.06s, ETA: 53.48 min
# [20/900] Sample processed in 6.38s, ETA: 55.42 min
# [21/900] Sample processed in 0.21s, ETA: 52.87 min
# [22/900] Sample processed in 4.79s, ETA: 53.59 min
# [23/900] Sample processed in 2.35s, ETA: 52.70 min
# [24/900] Sample processed in 0.25s, ETA: 50.60 min
# [25/900] Sample processed in 4.52s, ETA: 51.16 min
# [26/900] Sample processed in 0.24s, ETA: 49.27 min
# [27/900] Sample processed in 16.38s, ETA: 56.21 min
# [28/900] Sample processed in 3.03s, ETA: 55.72 min
# [29/900] Sample processed in 3.02s, ETA: 55.25 min
# [30/900] Sample processed in 0.21s, ETA: 53.44 min
# [31/900] Sample processed in 0.21s, ETA: 51.76 min
# [32/900] Sample processed in 0.28s, ETA: 50.21 min
# [33/900] Sample processed in 3.69s, ETA: 50.25 min
# [34/900] Sample processed in 2.89s, ETA: 49.94 min
# [35/900] Sample processed in 6.85s, ETA: 51.28 min
# [36/900] Sample processed in 2.29s, ETA: 50.71 min
# [37/900] Sample processed in 3.95s, ETA: 50.82 min
# [38/900] Sample processed in 2.33s, ETA: 50.30 min
# [39/900] Sample processed in 0.21s, ETA: 49.03 min
# [40/900] Sample processed in 3.20s, ETA: 48.90 min
# [41/900] Sample processed in 3.36s, ETA: 48.83 min
# [42/900] Sample processed in 3.46s, ETA: 48.79 min
# [43/900] Sample processed in 4.17s, ETA: 48.98 min
# [44/900] Sample processed in 10.59s, ETA: 51.25 min
# [45/900] Sample processed in 0.27s, ETA: 50.14 min
# [46/900] Sample processed in 3.30s, ETA: 50.01 min
# [47/900] Sample processed in 0.28s, ETA: 48.97 min
# [48/900] Sample processed in 5.46s, ETA: 49.51 min
# [49/900] Sample processed in 2.29s, ETA: 49.11 min
# [50/900] Sample processed in 2.26s, ETA: 48.71 min
# [51/900] Sample processed in 7.99s, ETA: 49.91 min
# [52/900] Sample processed in 3.32s, ETA: 49.80 min
# [53/900] Sample processed in 0.21s, ETA: 48.86 min
# [54/900] Sample processed in 2.22s, ETA: 48.48 min
# [55/900] Sample processed in 9.03s, ETA: 49.85 min
# [56/900] Sample processed in 0.25s, ETA: 48.96 min
# [57/900] Sample processed in 4.88s, ETA: 49.25 min
# [58/900] Sample processed in 3.17s, ETA: 49.11 min
# [59/900] Sample processed in 0.28s, ETA: 48.29 min
# [60/900] Sample processed in 0.24s, ETA: 47.48 min
# [61/900] Sample processed in 2.62s, ETA: 47.25 min
# [62/900] Sample processed in 2.00s, ETA: 46.88 min
# [63/900] Sample processed in 1.31s, ETA: 46.37 min
# [64/900] Sample processed in 4.23s, ETA: 46.51 min
# [65/900] Sample processed in 0.24s, ETA: 45.80 min
# [66/900] Sample processed in 0.24s, ETA: 45.10 min
# [67/900] Sample processed in 0.24s, ETA: 44.42 min
# [68/900] Sample processed in 4.27s, ETA: 44.59 min
# [69/900] Sample processed in 2.88s, ETA: 44.47 min
# [70/900] Sample processed in 5.38s, ETA: 44.84 min
# [71/900] Sample processed in 5.67s, ETA: 45.26 min
# [72/900] Sample processed in 2.28s, ETA: 45.02 min
# [73/900] Sample processed in 6.03s, ETA: 45.49 min
# [74/900] Sample processed in 0.21s, ETA: 44.86 min
# [75/900] Sample processed in 5.87s, ETA: 45.28 min
# [76/900] Sample processed in 7.44s, ETA: 45.97 min
# [77/900] Sample processed in 3.39s, ETA: 45.93 min
# [78/900] Sample processed in 0.21s, ETA: 45.32 min
# [79/900] Sample processed in 4.85s, ETA: 45.53 min
# [80/900] Sample processed in 2.61s, ETA: 45.35 min
# [81/900] Sample processed in 7.58s, ETA: 46.02 min
# [82/900] Sample processed in 6.18s, ETA: 46.43 min
# [83/900] Sample processed in 3.19s, ETA: 46.33 min
# [84/900] Sample processed in 2.51s, ETA: 46.13 min
# [85/900] Sample processed in 0.28s, ETA: 45.58 min
# [86/900] Sample processed in 0.28s, ETA: 45.04 min
# [87/900] Sample processed in 7.90s, ETA: 45.70 min
# [88/900] Sample processed in 2.29s, ETA: 45.47 min
# [89/900] Sample processed in 5.63s, ETA: 45.76 min
# [90/900] Sample processed in 0.21s, ETA: 45.23 min
# [91/900] Sample processed in 4.10s, ETA: 45.29 min
# [92/900] Sample processed in 7.80s, ETA: 45.88 min
# [93/900] Sample processed in 0.28s, ETA: 45.37 min
# [94/900] Sample processed in 6.35s, ETA: 45.74 min
# [95/900] Sample processed in 8.08s, ETA: 46.34 min
# [96/900] Sample processed in 1.77s, ETA: 46.05 min
# [97/900] Sample processed in 3.33s, ETA: 45.98 min
# [98/900] Sample processed in 0.25s, ETA: 45.49 min
# [99/900] Sample processed in 1.84s, ETA: 45.22 min
# [100/900] Sample processed in 0.27s, ETA: 44.75 min
# [101/900] Sample processed in 1.06s, ETA: 44.39 min
# [102/900] Sample processed in 1.06s, ETA: 44.04 min
# [103/900] Sample processed in 1.07s, ETA: 43.69 min
# [104/900] Sample processed in 1.06s, ETA: 43.35 min
# [105/900] Sample processed in 1.07s, ETA: 43.02 min
# [106/900] Sample processed in 1.08s, ETA: 42.70 min
# [107/900] Sample processed in 1.07s, ETA: 42.38 min
# [108/900] Sample processed in 1.08s, ETA: 42.06 min
# [109/900] Sample processed in 1.07s, ETA: 41.75 min
# [110/900] Sample processed in 1.08s, ETA: 41.45 min
# [111/900] Sample processed in 1.09s, ETA: 41.15 min
# [112/900] Sample processed in 1.06s, ETA: 40.86 min
# [113/900] Sample processed in 1.06s, ETA: 40.57 min
# [114/900] Sample processed in 1.07s, ETA: 40.29 min
# [115/900] Sample processed in 1.05s, ETA: 40.01 min
# [116/900] Sample processed in 1.06s, ETA: 39.73 min
# [117/900] Sample processed in 1.10s, ETA: 39.46 min
# [118/900] Sample processed in 1.06s, ETA: 39.20 min
# [119/900] Sample processed in 1.07s, ETA: 38.93 min
# [120/900] Sample processed in 1.06s, ETA: 38.68 min
# [121/900] Sample processed in 1.05s, ETA: 38.42 min
# [122/900] Sample processed in 1.06s, ETA: 38.17 min
# [123/900] Sample processed in 1.08s, ETA: 37.92 min
# [124/900] Sample processed in 0.77s, ETA: 37.65 min
# [125/900] Sample processed in 1.04s, ETA: 37.41 min
# [126/900] Sample processed in 1.04s, ETA: 37.17 min
# [127/900] Sample processed in 1.07s, ETA: 36.94 min
# [128/900] Sample processed in 1.06s, ETA: 36.71 min
# [129/900] Sample processed in 1.07s, ETA: 36.48 min
# [130/900] Sample processed in 1.04s, ETA: 36.26 min
# [131/900] Sample processed in 1.07s, ETA: 36.04 min
# [132/900] Sample processed in 1.07s, ETA: 35.82 min
# [133/900] Sample processed in 1.06s, ETA: 35.61 min
# [134/900] Sample processed in 1.06s, ETA: 35.40 min
# [135/900] Sample processed in 1.07s, ETA: 35.19 min
# [136/900] Sample processed in 1.06s, ETA: 34.99 min
# [137/900] Sample processed in 1.09s, ETA: 34.79 min
# [138/900] Sample processed in 1.06s, ETA: 34.59 min
# [139/900] Sample processed in 1.10s, ETA: 34.39 min
# [140/900] Sample processed in 1.05s, ETA: 34.20 min
# [141/900] Sample processed in 1.06s, ETA: 34.00 min
# [142/900] Sample processed in 1.06s, ETA: 33.82 min
# [143/900] Sample processed in 1.08s, ETA: 33.63 min
# [144/900] Sample processed in 1.06s, ETA: 33.44 min
# [145/900] Sample processed in 1.07s, ETA: 33.26 min
# [146/900] Sample processed in 0.81s, ETA: 33.06 min
# [147/900] Sample processed in 1.06s, ETA: 32.88 min
# [148/900] Sample processed in 1.06s, ETA: 32.71 min
# [149/900] Sample processed in 1.07s, ETA: 32.53 min
# [150/900] Sample processed in 1.06s, ETA: 32.36 min
# [151/900] Sample processed in 1.06s, ETA: 32.19 min
# [152/900] Sample processed in 1.07s, ETA: 32.03 min
# [153/900] Sample processed in 1.07s, ETA: 31.86 min
# [154/900] Sample processed in 1.07s, ETA: 31.70 min
# [155/900] Sample processed in 1.05s, ETA: 31.54 min
# [156/900] Sample processed in 1.06s, ETA: 31.38 min
# [157/900] Sample processed in 1.06s, ETA: 31.22 min
# [158/900] Sample processed in 1.07s, ETA: 31.06 min
# [159/900] Sample processed in 1.06s, ETA: 30.91 min
# [160/900] Sample processed in 1.10s, ETA: 30.76 min
# [161/900] Sample processed in 1.07s, ETA: 30.61 min
# [162/900] Sample processed in 1.05s, ETA: 30.46 min
# [163/900] Sample processed in 0.56s, ETA: 30.27 min
# [164/900] Sample processed in 1.07s, ETA: 30.13 min
# [165/900] Sample processed in 1.07s, ETA: 29.98 min
# [166/900] Sample processed in 1.06s, ETA: 29.84 min
# [167/900] Sample processed in 1.08s, ETA: 29.70 min
# [168/900] Sample processed in 1.10s, ETA: 29.56 min
# [169/900] Sample processed in 1.04s, ETA: 29.42 min
# [170/900] Sample processed in 1.08s, ETA: 29.28 min
# [171/900] Sample processed in 1.07s, ETA: 29.15 min
# [172/900] Sample processed in 1.07s, ETA: 29.02 min
# [173/900] Sample processed in 1.09s, ETA: 28.88 min
# [174/900] Sample processed in 1.07s, ETA: 28.75 min
# [175/900] Sample processed in 0.88s, ETA: 28.61 min
# [176/900] Sample processed in 1.07s, ETA: 28.48 min
# [177/900] Sample processed in 1.06s, ETA: 28.35 min
# [178/900] Sample processed in 0.64s, ETA: 28.20 min
# [179/900] Sample processed in 0.95s, ETA: 28.07 min
# [180/900] Sample processed in 1.06s, ETA: 27.94 min
# [181/900] Sample processed in 1.07s, ETA: 27.82 min
# [182/900] Sample processed in 1.05s, ETA: 27.70 min
# [183/900] Sample processed in 1.04s, ETA: 27.58 min
# [184/900] Sample processed in 1.10s, ETA: 27.46 min
# [185/900] Sample processed in 1.06s, ETA: 27.34 min
# [186/900] Sample processed in 1.07s, ETA: 27.23 min
# [187/900] Sample processed in 1.06s, ETA: 27.11 min
# [188/900] Sample processed in 1.06s, ETA: 26.99 min
# [189/900] Sample processed in 1.08s, ETA: 26.88 min
# [190/900] Sample processed in 1.06s, ETA: 26.77 min
# [191/900] Sample processed in 1.08s, ETA: 26.66 min
# [192/900] Sample processed in 1.06s, ETA: 26.55 min
# [193/900] Sample processed in 1.07s, ETA: 26.44 min
# [194/900] Sample processed in 1.04s, ETA: 26.33 min
# [195/900] Sample processed in 0.94s, ETA: 26.21 min
# [196/900] Sample processed in 1.06s, ETA: 26.10 min
# [197/900] Sample processed in 1.07s, ETA: 26.00 min
# [198/900] Sample processed in 1.06s, ETA: 25.89 min
# [199/900] Sample processed in 1.08s, ETA: 25.79 min
# [200/900] Sample processed in 1.05s, ETA: 25.69 min
# [201/900] Sample processed in 0.80s, ETA: 25.57 min
# [202/900] Sample processed in 0.11s, ETA: 25.41 min
# [203/900] Sample processed in 0.50s, ETA: 25.28 min
# [204/900] Sample processed in 0.21s, ETA: 25.13 min
# [205/900] Sample processed in 0.21s, ETA: 24.98 min
# [206/900] Sample processed in 0.50s, ETA: 24.86 min
# [207/900] Sample processed in 0.21s, ETA: 24.71 min
# [208/900] Sample processed in 0.15s, ETA: 24.56 min
# [209/900] Sample processed in 0.21s, ETA: 24.42 min
# [210/900] Sample processed in 1.05s, ETA: 24.33 min
# [211/900] Sample processed in 0.31s, ETA: 24.20 min
# [212/900] Sample processed in 0.21s, ETA: 24.06 min
# [213/900] Sample processed in 0.30s, ETA: 23.93 min
# [214/900] Sample processed in 1.06s, ETA: 23.84 min
# [215/900] Sample processed in 0.21s, ETA: 23.70 min
# [216/900] Sample processed in 0.21s, ETA: 23.57 min
# [217/900] Sample processed in 1.07s, ETA: 23.48 min
# [218/900] Sample processed in 1.06s, ETA: 23.40 min
# [219/900] Sample processed in 0.11s, ETA: 23.26 min
# [220/900] Sample processed in 0.21s, ETA: 23.13 min
# [221/900] Sample processed in 0.14s, ETA: 23.00 min
# [222/900] Sample processed in 0.21s, ETA: 22.87 min
# [223/900] Sample processed in 0.21s, ETA: 22.75 min
# [224/900] Sample processed in 0.21s, ETA: 22.62 min
# [225/900] Sample processed in 0.43s, ETA: 22.51 min
# [226/900] Sample processed in 0.47s, ETA: 22.40 min
# [227/900] Sample processed in 0.22s, ETA: 22.28 min
# [228/900] Sample processed in 0.21s, ETA: 22.16 min
# [229/900] Sample processed in 0.21s, ETA: 22.04 min
# [230/900] Sample processed in 0.11s, ETA: 21.92 min
# [231/900] Sample processed in 0.47s, ETA: 21.81 min
# [232/900] Sample processed in 1.06s, ETA: 21.74 min
# [233/900] Sample processed in 0.14s, ETA: 21.62 min
# [234/900] Sample processed in 0.21s, ETA: 21.51 min
# [235/900] Sample processed in 1.05s, ETA: 21.43 min
# [236/900] Sample processed in 0.21s, ETA: 21.32 min
# [237/900] Sample processed in 0.47s, ETA: 21.22 min
# [238/900] Sample processed in 0.21s, ETA: 21.11 min
# [239/900] Sample processed in 0.44s, ETA: 21.01 min
# [240/900] Sample processed in 1.06s, ETA: 20.94 min
# [241/900] Sample processed in 0.22s, ETA: 20.83 min
# [242/900] Sample processed in 1.06s, ETA: 20.76 min
# [243/900] Sample processed in 0.21s, ETA: 20.65 min
# [244/900] Sample processed in 1.04s, ETA: 20.58 min
# [245/900] Sample processed in 1.06s, ETA: 20.51 min
# [246/900] Sample processed in 0.15s, ETA: 20.41 min
# [247/900] Sample processed in 0.21s, ETA: 20.30 min
# [248/900] Sample processed in 0.21s, ETA: 20.20 min
# [249/900] Sample processed in 1.05s, ETA: 20.13 min
# [250/900] Sample processed in 1.05s, ETA: 20.07 min
# [251/900] Sample processed in 0.21s, ETA: 19.96 min
# [252/900] Sample processed in 1.04s, ETA: 19.90 min
# [253/900] Sample processed in 0.21s, ETA: 19.80 min
# [254/900] Sample processed in 0.46s, ETA: 19.71 min
# [255/900] Sample processed in 0.21s, ETA: 19.61 min
# [256/900] Sample processed in 1.05s, ETA: 19.55 min
# [257/900] Sample processed in 0.18s, ETA: 19.45 min
# [258/900] Sample processed in 0.89s, ETA: 19.38 min
# [259/900] Sample processed in 0.21s, ETA: 19.28 min
# [260/900] Sample processed in 1.04s, ETA: 19.22 min
# [261/900] Sample processed in 1.05s, ETA: 19.16 min
# [262/900] Sample processed in 0.21s, ETA: 19.07 min
# [263/900] Sample processed in 0.21s, ETA: 18.97 min
# [264/900] Sample processed in 0.21s, ETA: 18.88 min
# [265/900] Sample processed in 0.88s, ETA: 18.82 min
# [266/900] Sample processed in 0.11s, ETA: 18.72 min
# [267/900] Sample processed in 0.46s, ETA: 18.64 min
# [268/900] Sample processed in 0.21s, ETA: 18.55 min
# [269/900] Sample processed in 0.43s, ETA: 18.47 min
# [270/900] Sample processed in 0.14s, ETA: 18.37 min
# [271/900] Sample processed in 0.18s, ETA: 18.28 min
# [272/900] Sample processed in 0.14s, ETA: 18.19 min
# [273/900] Sample processed in 0.21s, ETA: 18.11 min
# [274/900] Sample processed in 0.21s, ETA: 18.02 min
# [275/900] Sample processed in 0.50s, ETA: 17.94 min
# [276/900] Sample processed in 1.05s, ETA: 17.89 min
# [277/900] Sample processed in 0.21s, ETA: 17.81 min
# [278/900] Sample processed in 0.86s, ETA: 17.74 min
# [279/900] Sample processed in 1.05s, ETA: 17.69 min
# [280/900] Sample processed in 0.21s, ETA: 17.61 min
# [281/900] Sample processed in 0.21s, ETA: 17.52 min
# [282/900] Sample processed in 1.05s, ETA: 17.47 min
# [283/900] Sample processed in 0.44s, ETA: 17.40 min
# [284/900] Sample processed in 0.21s, ETA: 17.32 min
# [285/900] Sample processed in 1.05s, ETA: 17.27 min
# [286/900] Sample processed in 0.17s, ETA: 17.18 min
# [287/900] Sample processed in 0.21s, ETA: 17.10 min
# [288/900] Sample processed in 0.18s, ETA: 17.02 min
# [289/900] Sample processed in 0.21s, ETA: 16.94 min
# [290/900] Sample processed in 0.21s, ETA: 16.87 min
# [291/900] Sample processed in 0.21s, ETA: 16.79 min
# [292/900] Sample processed in 0.46s, ETA: 16.72 min
# [293/900] Sample processed in 0.47s, ETA: 16.65 min
# [294/900] Sample processed in 0.30s, ETA: 16.58 min
# [295/900] Sample processed in 0.21s, ETA: 16.50 min
# [296/900] Sample processed in 1.02s, ETA: 16.45 min
# [297/900] Sample processed in 1.05s, ETA: 16.40 min
# [298/900] Sample processed in 1.04s, ETA: 16.36 min
# [299/900] Sample processed in 0.21s, ETA: 16.28 min
# [300/900] Sample processed in 0.21s, ETA: 16.21 min
# [301/900] Sample processed in 0.35s, ETA: 16.14 min
# [302/900] Sample processed in 0.49s, ETA: 16.08 min
# [303/900] Sample processed in 0.37s, ETA: 16.01 min
# [304/900] Sample processed in 0.38s, ETA: 15.94 min
# [305/900] Sample processed in 0.54s, ETA: 15.88 min
# [306/900] Sample processed in 0.31s, ETA: 15.81 min
# [307/900] Sample processed in 0.54s, ETA: 15.75 min
# [308/900] Sample processed in 0.24s, ETA: 15.68 min
# [309/900] Sample processed in 0.34s, ETA: 15.61 min
# [310/900] Sample processed in 0.34s, ETA: 15.55 min
# [311/900] Sample processed in 0.25s, ETA: 15.48 min
# [312/900] Sample processed in 0.44s, ETA: 15.42 min
# [313/900] Sample processed in 0.32s, ETA: 15.35 min
# [314/900] Sample processed in 0.34s, ETA: 15.29 min
# [315/900] Sample processed in 1.07s, ETA: 15.25 min
# [316/900] Sample processed in 0.54s, ETA: 15.19 min
# [317/900] Sample processed in 0.35s, ETA: 15.13 min
# [318/900] Sample processed in 0.51s, ETA: 15.07 min
# [319/900] Sample processed in 0.38s, ETA: 15.01 min
# [320/900] Sample processed in 1.05s, ETA: 14.97 min
# [321/900] Sample processed in 0.25s, ETA: 14.90 min
# [322/900] Sample processed in 0.38s, ETA: 14.84 min
# [323/900] Sample processed in 0.35s, ETA: 14.78 min
# [324/900] Sample processed in 0.35s, ETA: 14.72 min
# [325/900] Sample processed in 0.31s, ETA: 14.66 min
# [326/900] Sample processed in 0.28s, ETA: 14.59 min
# [327/900] Sample processed in 0.64s, ETA: 14.54 min
# [328/900] Sample processed in 0.37s, ETA: 14.48 min
# [329/900] Sample processed in 0.42s, ETA: 14.43 min
# [330/900] Sample processed in 0.73s, ETA: 14.38 min
# [331/900] Sample processed in 0.84s, ETA: 14.34 min
# [332/900] Sample processed in 0.58s, ETA: 14.28 min
# [333/900] Sample processed in 0.41s, ETA: 14.23 min
# [334/900] Sample processed in 0.61s, ETA: 14.18 min
# [335/900] Sample processed in 0.37s, ETA: 14.12 min
# [336/900] Sample processed in 0.45s, ETA: 14.07 min
# [337/900] Sample processed in 0.34s, ETA: 14.01 min
# [338/900] Sample processed in 0.47s, ETA: 13.95 min
# [339/900] Sample processed in 0.35s, ETA: 13.90 min
# [340/900] Sample processed in 0.52s, ETA: 13.85 min
# [341/900] Sample processed in 0.31s, ETA: 13.79 min
# [342/900] Sample processed in 0.73s, ETA: 13.75 min
# [343/900] Sample processed in 0.39s, ETA: 13.69 min
# [344/900] Sample processed in 0.44s, ETA: 13.64 min
# [345/900] Sample processed in 0.36s, ETA: 13.58 min
# [346/900] Sample processed in 0.34s, ETA: 13.53 min
# [347/900] Sample processed in 0.24s, ETA: 13.47 min
# [348/900] Sample processed in 0.70s, ETA: 13.43 min
# [349/900] Sample processed in 1.06s, ETA: 13.39 min
# [350/900] Sample processed in 0.28s, ETA: 13.34 min
# [351/900] Sample processed in 0.23s, ETA: 13.28 min
# [352/900] Sample processed in 0.34s, ETA: 13.23 min
# [353/900] Sample processed in 0.38s, ETA: 13.18 min
# [354/900] Sample processed in 0.24s, ETA: 13.12 min
# [355/900] Sample processed in 0.28s, ETA: 13.07 min
# [356/900] Sample processed in 0.61s, ETA: 13.02 min
# [357/900] Sample processed in 0.35s, ETA: 12.97 min
# [358/900] Sample processed in 0.25s, ETA: 12.92 min
# [359/900] Sample processed in 0.38s, ETA: 12.87 min
# [360/900] Sample processed in 0.21s, ETA: 12.81 min
# [361/900] Sample processed in 0.45s, ETA: 12.77 min
# [362/900] Sample processed in 0.28s, ETA: 12.71 min
# [363/900] Sample processed in 0.24s, ETA: 12.66 min
# [364/900] Sample processed in 0.28s, ETA: 12.61 min
# [365/900] Sample processed in 0.47s, ETA: 12.56 min
# [366/900] Sample processed in 1.05s, ETA: 12.53 min
# [367/900] Sample processed in 0.35s, ETA: 12.48 min
# [368/900] Sample processed in 0.25s, ETA: 12.43 min
# [369/900] Sample processed in 0.25s, ETA: 12.38 min
# [370/900] Sample processed in 0.42s, ETA: 12.33 min
# [371/900] Sample processed in 0.67s, ETA: 12.29 min
# [372/900] Sample processed in 0.24s, ETA: 12.24 min
# [373/900] Sample processed in 0.46s, ETA: 12.20 min
# [374/900] Sample processed in 0.35s, ETA: 12.15 min
# [375/900] Sample processed in 1.03s, ETA: 12.12 min
# [376/900] Sample processed in 0.57s, ETA: 12.08 min
# [377/900] Sample processed in 0.53s, ETA: 12.03 min
# [378/900] Sample processed in 0.41s, ETA: 11.99 min
# [379/900] Sample processed in 0.25s, ETA: 11.94 min
# [380/900] Sample processed in 0.32s, ETA: 11.89 min
# [381/900] Sample processed in 0.64s, ETA: 11.85 min
# [382/900] Sample processed in 0.79s, ETA: 11.82 min
# [383/900] Sample processed in 0.35s, ETA: 11.77 min
# [384/900] Sample processed in 0.73s, ETA: 11.73 min
# [385/900] Sample processed in 0.25s, ETA: 11.69 min
# [386/900] Sample processed in 0.43s, ETA: 11.64 min
# [387/900] Sample processed in 0.41s, ETA: 11.60 min
# [388/900] Sample processed in 0.34s, ETA: 11.55 min
# [389/900] Sample processed in 0.31s, ETA: 11.51 min
# [390/900] Sample processed in 0.31s, ETA: 11.46 min
# [391/900] Sample processed in 1.04s, ETA: 11.43 min
# [392/900] Sample processed in 0.25s, ETA: 11.39 min
# [393/900] Sample processed in 0.27s, ETA: 11.34 min
# [394/900] Sample processed in 0.45s, ETA: 11.30 min
# [395/900] Sample processed in 0.51s, ETA: 11.26 min
# [396/900] Sample processed in 0.31s, ETA: 11.22 min
# [397/900] Sample processed in 0.29s, ETA: 11.17 min
# [398/900] Sample processed in 0.31s, ETA: 11.13 min
# [399/900] Sample processed in 1.06s, ETA: 11.10 min
# [400/900] Sample processed in 1.06s, ETA: 11.07 min
# [401/900] Sample processed in 0.08s, ETA: 11.03 min
# [402/900] Sample processed in 1.05s, ETA: 11.00 min
# [403/900] Sample processed in 0.44s, ETA: 10.96 min
# [404/900] Sample processed in 0.28s, ETA: 10.91 min
# [405/900] Sample processed in 0.08s, ETA: 10.87 min
# [406/900] Sample processed in 0.31s, ETA: 10.82 min
# [407/900] Sample processed in 0.41s, ETA: 10.78 min
# [408/900] Sample processed in 1.05s, ETA: 10.76 min
# [409/900] Sample processed in 0.80s, ETA: 10.73 min
# [410/900] Sample processed in 1.06s, ETA: 10.70 min
# [411/900] Sample processed in 0.24s, ETA: 10.66 min
# [412/900] Sample processed in 1.04s, ETA: 10.63 min
# [413/900] Sample processed in 0.54s, ETA: 10.59 min
# [414/900] Sample processed in 0.86s, ETA: 10.56 min
# [415/900] Sample processed in 1.05s, ETA: 10.53 min
# [416/900] Sample processed in 0.35s, ETA: 10.49 min
# [417/900] Sample processed in 1.05s, ETA: 10.47 min
# [418/900] Sample processed in 1.05s, ETA: 10.44 min
# [419/900] Sample processed in 0.47s, ETA: 10.40 min
# [420/900] Sample processed in 0.08s, ETA: 10.36 min
# [421/900] Sample processed in 0.40s, ETA: 10.32 min
# [422/900] Sample processed in 0.24s, ETA: 10.28 min
# [423/900] Sample processed in 0.56s, ETA: 10.24 min
# [424/900] Sample processed in 1.04s, ETA: 10.22 min
# [425/900] Sample processed in 0.08s, ETA: 10.17 min
# [426/900] Sample processed in 1.05s, ETA: 10.15 min
# [427/900] Sample processed in 0.41s, ETA: 10.11 min
# [428/900] Sample processed in 0.24s, ETA: 10.07 min
# [429/900] Sample processed in 0.27s, ETA: 10.03 min
# [430/900] Sample processed in 1.05s, ETA: 10.00 min
# [431/900] Sample processed in 0.28s, ETA: 9.97 min
# [432/900] Sample processed in 0.31s, ETA: 9.93 min
# [433/900] Sample processed in 0.21s, ETA: 9.89 min
# [434/900] Sample processed in 0.24s, ETA: 9.85 min
# [435/900] Sample processed in 0.27s, ETA: 9.81 min
# [436/900] Sample processed in 1.05s, ETA: 9.78 min
# [437/900] Sample processed in 1.06s, ETA: 9.76 min
# [438/900] Sample processed in 0.31s, ETA: 9.72 min
# [439/900] Sample processed in 0.34s, ETA: 9.68 min
# [440/900] Sample processed in 0.27s, ETA: 9.64 min
# [441/900] Sample processed in 0.27s, ETA: 9.61 min
# [442/900] Sample processed in 0.27s, ETA: 9.57 min
# [443/900] Sample processed in 1.04s, ETA: 9.54 min
# [444/900] Sample processed in 1.05s, ETA: 9.52 min
# [445/900] Sample processed in 0.28s, ETA: 9.48 min
# [446/900] Sample processed in 1.04s, ETA: 9.46 min
# [447/900] Sample processed in 0.21s, ETA: 9.42 min
# [448/900] Sample processed in 0.21s, ETA: 9.38 min
# [449/900] Sample processed in 0.34s, ETA: 9.35 min
# [450/900] Sample processed in 0.08s, ETA: 9.31 min
# [451/900] Sample processed in 1.05s, ETA: 9.28 min
# [452/900] Sample processed in 0.89s, ETA: 9.26 min
# [453/900] Sample processed in 0.27s, ETA: 9.22 min
# [454/900] Sample processed in 1.05s, ETA: 9.19 min
# [455/900] Sample processed in 0.21s, ETA: 9.16 min
# [456/900] Sample processed in 0.25s, ETA: 9.12 min
# [457/900] Sample processed in 0.34s, ETA: 9.09 min
# [458/900] Sample processed in 0.24s, ETA: 9.05 min
# [459/900] Sample processed in 0.66s, ETA: 9.02 min
# [460/900] Sample processed in 0.92s, ETA: 8.99 min
# [461/900] Sample processed in 0.08s, ETA: 8.96 min
# [462/900] Sample processed in 0.54s, ETA: 8.92 min
# [463/900] Sample processed in 0.30s, ETA: 8.89 min
# [464/900] Sample processed in 0.34s, ETA: 8.86 min
# [465/900] Sample processed in 0.60s, ETA: 8.83 min
# [466/900] Sample processed in 0.34s, ETA: 8.79 min
# [467/900] Sample processed in 0.50s, ETA: 8.76 min
# [468/900] Sample processed in 0.92s, ETA: 8.74 min
# [469/900] Sample processed in 1.05s, ETA: 8.71 min
# [470/900] Sample processed in 0.44s, ETA: 8.68 min
# [471/900] Sample processed in 1.06s, ETA: 8.66 min
# [472/900] Sample processed in 1.05s, ETA: 8.64 min
# [473/900] Sample processed in 0.31s, ETA: 8.60 min
# [474/900] Sample processed in 0.24s, ETA: 8.57 min
# [475/900] Sample processed in 0.27s, ETA: 8.53 min
# [476/900] Sample processed in 1.05s, ETA: 8.51 min
# [477/900] Sample processed in 0.91s, ETA: 8.49 min
# [478/900] Sample processed in 0.34s, ETA: 8.45 min
# [479/900] Sample processed in 0.08s, ETA: 8.42 min
# [480/900] Sample processed in 1.05s, ETA: 8.40 min
# [481/900] Sample processed in 0.48s, ETA: 8.37 min
# [482/900] Sample processed in 0.21s, ETA: 8.33 min
# [483/900] Sample processed in 0.28s, ETA: 8.30 min
# [484/900] Sample processed in 0.21s, ETA: 8.26 min
# [485/900] Sample processed in 1.04s, ETA: 8.24 min
# [486/900] Sample processed in 0.31s, ETA: 8.21 min
# [487/900] Sample processed in 0.24s, ETA: 8.18 min
# [488/900] Sample processed in 0.24s, ETA: 8.14 min
# [489/900] Sample processed in 0.30s, ETA: 8.11 min
# [490/900] Sample processed in 0.24s, ETA: 8.08 min
# [491/900] Sample processed in 0.54s, ETA: 8.05 min
# [492/900] Sample processed in 0.34s, ETA: 8.02 min
# [493/900] Sample processed in 0.47s, ETA: 7.99 min
# [494/900] Sample processed in 0.08s, ETA: 7.95 min
# [495/900] Sample processed in 0.28s, ETA: 7.92 min
# [496/900] Sample processed in 0.24s, ETA: 7.89 min
# [497/900] Sample processed in 0.53s, ETA: 7.86 min
# [498/900] Sample processed in 0.15s, ETA: 7.83 min
# [499/900] Sample processed in 0.24s, ETA: 7.80 min
# [500/900] Sample processed in 1.05s, ETA: 7.78 min
# [501/900] Sample processed in 0.13s, ETA: 7.74 min
# [502/900] Sample processed in 0.14s, ETA: 7.71 min
# [503/900] Sample processed in 0.13s, ETA: 7.68 min
# [504/900] Sample processed in 0.14s, ETA: 7.64 min
# [505/900] Sample processed in 0.13s, ETA: 7.61 min
# [506/900] Sample processed in 0.14s, ETA: 7.58 min
# [507/900] Sample processed in 0.11s, ETA: 7.55 min
# [508/900] Sample processed in 0.13s, ETA: 7.51 min
# [509/900] Sample processed in 0.15s, ETA: 7.48 min
# [510/900] Sample processed in 0.13s, ETA: 7.45 min
# [511/900] Sample processed in 1.04s, ETA: 7.43 min
# [512/900] Sample processed in 0.12s, ETA: 7.40 min
# [513/900] Sample processed in 0.12s, ETA: 7.37 min
# [514/900] Sample processed in 0.13s, ETA: 7.33 min
# [515/900] Sample processed in 0.12s, ETA: 7.30 min
# [516/900] Sample processed in 0.11s, ETA: 7.27 min
# [517/900] Sample processed in 1.07s, ETA: 7.25 min
# [518/900] Sample processed in 0.14s, ETA: 7.22 min
# [519/900] Sample processed in 0.11s, ETA: 7.19 min
# [520/900] Sample processed in 0.09s, ETA: 7.16 min
# [521/900] Sample processed in 0.09s, ETA: 7.12 min
# [522/900] Sample processed in 0.11s, ETA: 7.09 min
# [523/900] Sample processed in 0.12s, ETA: 7.06 min
# [524/900] Sample processed in 0.10s, ETA: 7.03 min
# [525/900] Sample processed in 0.13s, ETA: 7.00 min
# [526/900] Sample processed in 0.12s, ETA: 6.97 min
# [527/900] Sample processed in 0.85s, ETA: 6.95 min
# [528/900] Sample processed in 0.13s, ETA: 6.92 min
# [529/900] Sample processed in 0.74s, ETA: 6.90 min
# [530/900] Sample processed in 0.10s, ETA: 6.87 min
# [531/900] Sample processed in 0.12s, ETA: 6.84 min
# [532/900] Sample processed in 1.07s, ETA: 6.82 min
# [533/900] Sample processed in 0.91s, ETA: 6.80 min
# [534/900] Sample processed in 0.12s, ETA: 6.77 min
# [535/900] Sample processed in 0.94s, ETA: 6.75 min
# [536/900] Sample processed in 0.13s, ETA: 6.72 min
# [537/900] Sample processed in 0.13s, ETA: 6.69 min
# [538/900] Sample processed in 0.13s, ETA: 6.66 min
# [539/900] Sample processed in 0.90s, ETA: 6.64 min
# [540/900] Sample processed in 0.10s, ETA: 6.61 min
# [541/900] Sample processed in 1.06s, ETA: 6.59 min
# [542/900] Sample processed in 0.13s, ETA: 6.56 min
# [543/900] Sample processed in 0.62s, ETA: 6.54 min
# [544/900] Sample processed in 0.12s, ETA: 6.51 min
# [545/900] Sample processed in 0.11s, ETA: 6.48 min
# [546/900] Sample processed in 0.13s, ETA: 6.45 min
# [547/900] Sample processed in 0.12s, ETA: 6.42 min
# [548/900] Sample processed in 1.07s, ETA: 6.40 min
# [549/900] Sample processed in 0.13s, ETA: 6.37 min
# [550/900] Sample processed in 0.13s, ETA: 6.35 min
# [551/900] Sample processed in 0.14s, ETA: 6.32 min
# [552/900] Sample processed in 0.12s, ETA: 6.29 min
# [553/900] Sample processed in 0.16s, ETA: 6.26 min
# [554/900] Sample processed in 1.08s, ETA: 6.24 min
# [555/900] Sample processed in 0.13s, ETA: 6.22 min
# [556/900] Sample processed in 0.12s, ETA: 6.19 min
# [557/900] Sample processed in 0.13s, ETA: 6.16 min
# [558/900] Sample processed in 0.13s, ETA: 6.13 min
# [559/900] Sample processed in 0.12s, ETA: 6.10 min
# [560/900] Sample processed in 0.14s, ETA: 6.08 min
# [561/900] Sample processed in 0.13s, ETA: 6.05 min
# [562/900] Sample processed in 0.13s, ETA: 6.02 min
# [563/900] Sample processed in 0.13s, ETA: 5.99 min
# [564/900] Sample processed in 0.13s, ETA: 5.97 min
# [565/900] Sample processed in 1.07s, ETA: 5.95 min
# [566/900] Sample processed in 1.07s, ETA: 5.93 min
# [567/900] Sample processed in 1.08s, ETA: 5.91 min
# [568/900] Sample processed in 0.10s, ETA: 5.89 min
# [569/900] Sample processed in 0.12s, ETA: 5.86 min
# [570/900] Sample processed in 0.13s, ETA: 5.83 min
# [571/900] Sample processed in 0.13s, ETA: 5.81 min
# [572/900] Sample processed in 0.13s, ETA: 5.78 min
# [573/900] Sample processed in 0.14s, ETA: 5.75 min
# [574/900] Sample processed in 1.06s, ETA: 5.74 min
# [575/900] Sample processed in 0.12s, ETA: 5.71 min
# [576/900] Sample processed in 0.13s, ETA: 5.68 min
# [577/900] Sample processed in 1.07s, ETA: 5.67 min
# [578/900] Sample processed in 0.12s, ETA: 5.64 min
# [579/900] Sample processed in 0.13s, ETA: 5.61 min
# [580/900] Sample processed in 0.13s, ETA: 5.59 min
# [581/900] Sample processed in 0.10s, ETA: 5.56 min
# [582/900] Sample processed in 0.17s, ETA: 5.54 min
# [583/900] Sample processed in 0.14s, ETA: 5.51 min
# [584/900] Sample processed in 0.14s, ETA: 5.49 min
# [585/900] Sample processed in 0.13s, ETA: 5.46 min
# [586/900] Sample processed in 1.10s, ETA: 5.44 min
# [587/900] Sample processed in 0.13s, ETA: 5.42 min
# [588/900] Sample processed in 0.13s, ETA: 5.39 min
# [589/900] Sample processed in 0.13s, ETA: 5.37 min
# [590/900] Sample processed in 0.12s, ETA: 5.34 min
# [591/900] Sample processed in 0.14s, ETA: 5.32 min
# [592/900] Sample processed in 0.12s, ETA: 5.29 min
# [593/900] Sample processed in 0.13s, ETA: 5.27 min
# [594/900] Sample processed in 1.08s, ETA: 5.25 min
# [595/900] Sample processed in 0.13s, ETA: 5.23 min
# [596/900] Sample processed in 0.13s, ETA: 5.20 min
# [597/900] Sample processed in 0.13s, ETA: 5.18 min
# [598/900] Sample processed in 0.09s, ETA: 5.15 min
# [599/900] Sample processed in 0.12s, ETA: 5.13 min
# [600/900] Sample processed in 0.12s, ETA: 5.10 min
# [601/900] Sample processed in 0.18s, ETA: 5.08 min
# [602/900] Sample processed in 0.18s, ETA: 5.05 min
# [603/900] Sample processed in 0.18s, ETA: 5.03 min
# [604/900] Sample processed in 0.18s, ETA: 5.01 min
# [605/900] Sample processed in 0.18s, ETA: 4.98 min
# [606/900] Sample processed in 0.18s, ETA: 4.96 min
# [607/900] Sample processed in 0.21s, ETA: 4.94 min
# [608/900] Sample processed in 0.18s, ETA: 4.91 min
# [609/900] Sample processed in 0.18s, ETA: 4.89 min
# [610/900] Sample processed in 0.21s, ETA: 4.87 min
# [611/900] Sample processed in 0.18s, ETA: 4.84 min
# [612/900] Sample processed in 0.18s, ETA: 4.82 min
# [613/900] Sample processed in 0.18s, ETA: 4.80 min
# [614/900] Sample processed in 0.18s, ETA: 4.77 min
# [615/900] Sample processed in 0.18s, ETA: 4.75 min
# [616/900] Sample processed in 0.18s, ETA: 4.73 min
# [617/900] Sample processed in 0.18s, ETA: 4.70 min
# [618/900] Sample processed in 0.18s, ETA: 4.68 min
# [619/900] Sample processed in 0.21s, ETA: 4.66 min
# [620/900] Sample processed in 0.18s, ETA: 4.64 min
# [621/900] Sample processed in 0.18s, ETA: 4.61 min
# [622/900] Sample processed in 0.18s, ETA: 4.59 min
# [623/900] Sample processed in 0.18s, ETA: 4.57 min
# [624/900] Sample processed in 0.18s, ETA: 4.55 min
# [625/900] Sample processed in 0.18s, ETA: 4.52 min
# [626/900] Sample processed in 0.18s, ETA: 4.50 min
# [627/900] Sample processed in 0.18s, ETA: 4.48 min
# [628/900] Sample processed in 0.18s, ETA: 4.46 min
# [629/900] Sample processed in 0.18s, ETA: 4.43 min
# [630/900] Sample processed in 0.18s, ETA: 4.41 min
# [631/900] Sample processed in 0.18s, ETA: 4.39 min
# [632/900] Sample processed in 0.18s, ETA: 4.37 min
# [633/900] Sample processed in 0.18s, ETA: 4.35 min
# [634/900] Sample processed in 0.18s, ETA: 4.32 min
# [635/900] Sample processed in 0.21s, ETA: 4.30 min
# [636/900] Sample processed in 0.18s, ETA: 4.28 min
# [637/900] Sample processed in 0.18s, ETA: 4.26 min
# [638/900] Sample processed in 0.18s, ETA: 4.24 min
# [639/900] Sample processed in 0.18s, ETA: 4.22 min
# [640/900] Sample processed in 0.18s, ETA: 4.19 min
# [641/900] Sample processed in 0.18s, ETA: 4.17 min
# [642/900] Sample processed in 0.18s, ETA: 4.15 min
# [643/900] Sample processed in 0.18s, ETA: 4.13 min
# [644/900] Sample processed in 0.18s, ETA: 4.11 min
# [645/900] Sample processed in 0.18s, ETA: 4.09 min
# [646/900] Sample processed in 0.18s, ETA: 4.07 min
# [647/900] Sample processed in 0.18s, ETA: 4.05 min
# [648/900] Sample processed in 0.18s, ETA: 4.02 min
# [649/900] Sample processed in 0.18s, ETA: 4.00 min
# [650/900] Sample processed in 0.18s, ETA: 3.98 min
# [651/900] Sample processed in 0.18s, ETA: 3.96 min
# [652/900] Sample processed in 0.18s, ETA: 3.94 min
# [653/900] Sample processed in 0.18s, ETA: 3.92 min
# [654/900] Sample processed in 0.18s, ETA: 3.90 min
# [655/900] Sample processed in 0.18s, ETA: 3.88 min
# [656/900] Sample processed in 0.18s, ETA: 3.86 min
# [657/900] Sample processed in 0.18s, ETA: 3.84 min
# [658/900] Sample processed in 0.18s, ETA: 3.82 min
# [659/900] Sample processed in 0.18s, ETA: 3.80 min
# [660/900] Sample processed in 0.18s, ETA: 3.78 min
# [661/900] Sample processed in 0.18s, ETA: 3.76 min
# [662/900] Sample processed in 0.18s, ETA: 3.74 min
# [663/900] Sample processed in 0.21s, ETA: 3.72 min
# [664/900] Sample processed in 0.18s, ETA: 3.70 min
# [665/900] Sample processed in 0.18s, ETA: 3.68 min
# [666/900] Sample processed in 0.18s, ETA: 3.66 min
# [667/900] Sample processed in 0.18s, ETA: 3.64 min
# [668/900] Sample processed in 0.18s, ETA: 3.62 min
# [669/900] Sample processed in 0.18s, ETA: 3.60 min
# [670/900] Sample processed in 0.18s, ETA: 3.58 min
# [671/900] Sample processed in 0.18s, ETA: 3.56 min
# [672/900] Sample processed in 0.18s, ETA: 3.54 min
# [673/900] Sample processed in 0.18s, ETA: 3.52 min
# [674/900] Sample processed in 0.18s, ETA: 3.50 min
# [675/900] Sample processed in 0.18s, ETA: 3.48 min
# [676/900] Sample processed in 0.18s, ETA: 3.46 min
# [677/900] Sample processed in 0.18s, ETA: 3.44 min
# [678/900] Sample processed in 0.18s, ETA: 3.42 min
# [679/900] Sample processed in 0.18s, ETA: 3.40 min
# [680/900] Sample processed in 0.18s, ETA: 3.38 min
# [681/900] Sample processed in 0.18s, ETA: 3.36 min
# [682/900] Sample processed in 0.18s, ETA: 3.34 min
# [683/900] Sample processed in 0.18s, ETA: 3.32 min
# [684/900] Sample processed in 0.18s, ETA: 3.30 min
# [685/900] Sample processed in 0.18s, ETA: 3.28 min
# [686/900] Sample processed in 0.18s, ETA: 3.26 min
# [687/900] Sample processed in 0.18s, ETA: 3.24 min
# [688/900] Sample processed in 0.18s, ETA: 3.23 min
# [689/900] Sample processed in 0.18s, ETA: 3.21 min
# [690/900] Sample processed in 0.18s, ETA: 3.19 min
# [691/900] Sample processed in 0.18s, ETA: 3.17 min
# [692/900] Sample processed in 0.18s, ETA: 3.15 min
# [693/900] Sample processed in 0.18s, ETA: 3.13 min
# [694/900] Sample processed in 0.18s, ETA: 3.11 min
# [695/900] Sample processed in 0.18s, ETA: 3.09 min
# [696/900] Sample processed in 0.18s, ETA: 3.08 min
# [697/900] Sample processed in 0.18s, ETA: 3.06 min
# [698/900] Sample processed in 0.18s, ETA: 3.04 min
# [699/900] Sample processed in 0.18s, ETA: 3.02 min
# [700/900] Sample processed in 0.18s, ETA: 3.00 min
# [701/900] Sample processed in 0.56s, ETA: 2.98 min
# [702/900] Sample processed in 0.54s, ETA: 2.97 min
# [703/900] Sample processed in 0.54s, ETA: 2.95 min
# [704/900] Sample processed in 0.56s, ETA: 2.93 min
# [705/900] Sample processed in 0.57s, ETA: 2.92 min
# [706/900] Sample processed in 0.67s, ETA: 2.90 min
# [707/900] Sample processed in 0.57s, ETA: 2.89 min
# [708/900] Sample processed in 0.57s, ETA: 2.87 min
# [709/900] Sample processed in 0.53s, ETA: 2.85 min
# [710/900] Sample processed in 0.70s, ETA: 2.84 min
# [711/900] Sample processed in 0.47s, ETA: 2.82 min
# [712/900] Sample processed in 0.93s, ETA: 2.81 min
# [713/900] Sample processed in 0.63s, ETA: 2.79 min
# [714/900] Sample processed in 0.48s, ETA: 2.77 min
# [715/900] Sample processed in 0.43s, ETA: 2.76 min
# [716/900] Sample processed in 0.60s, ETA: 2.74 min
# [717/900] Sample processed in 0.44s, ETA: 2.72 min
# [718/900] Sample processed in 0.86s, ETA: 2.71 min
# [719/900] Sample processed in 0.41s, ETA: 2.69 min
# [720/900] Sample processed in 0.46s, ETA: 2.67 min
# [721/900] Sample processed in 0.64s, ETA: 2.66 min
# [722/900] Sample processed in 0.60s, ETA: 2.64 min
# [723/900] Sample processed in 0.50s, ETA: 2.63 min
# [724/900] Sample processed in 0.56s, ETA: 2.61 min
# [725/900] Sample processed in 0.57s, ETA: 2.59 min
# [726/900] Sample processed in 0.57s, ETA: 2.58 min
# [727/900] Sample processed in 0.50s, ETA: 2.56 min
# [728/900] Sample processed in 0.44s, ETA: 2.54 min
# [729/900] Sample processed in 0.46s, ETA: 2.53 min
# [730/900] Sample processed in 0.37s, ETA: 2.51 min
# [731/900] Sample processed in 0.56s, ETA: 2.50 min
# [732/900] Sample processed in 0.43s, ETA: 2.48 min
# [733/900] Sample processed in 0.40s, ETA: 2.46 min
# [734/900] Sample processed in 0.43s, ETA: 2.45 min
# [735/900] Sample processed in 0.59s, ETA: 2.43 min
# [736/900] Sample processed in 0.53s, ETA: 2.41 min
# [737/900] Sample processed in 0.50s, ETA: 2.40 min
# [738/900] Sample processed in 0.96s, ETA: 2.38 min
# [739/900] Sample processed in 0.66s, ETA: 2.37 min
# [740/900] Sample processed in 0.59s, ETA: 2.35 min
# [741/900] Sample processed in 0.62s, ETA: 2.34 min
# [742/900] Sample processed in 0.56s, ETA: 2.32 min
# [743/900] Sample processed in 0.62s, ETA: 2.30 min
# [744/900] Sample processed in 0.53s, ETA: 2.29 min
# [745/900] Sample processed in 0.43s, ETA: 2.27 min
# [746/900] Sample processed in 0.47s, ETA: 2.26 min
# [747/900] Sample processed in 0.63s, ETA: 2.24 min
# [748/900] Sample processed in 0.53s, ETA: 2.23 min
# [749/900] Sample processed in 0.53s, ETA: 2.21 min
# [750/900] Sample processed in 0.46s, ETA: 2.19 min
# [751/900] Sample processed in 0.43s, ETA: 2.18 min
# [752/900] Sample processed in 0.57s, ETA: 2.16 min
# [753/900] Sample processed in 0.56s, ETA: 2.15 min
# [754/900] Sample processed in 0.40s, ETA: 2.13 min
# [755/900] Sample processed in 0.47s, ETA: 2.11 min
# [756/900] Sample processed in 0.60s, ETA: 2.10 min
# [757/900] Sample processed in 0.43s, ETA: 2.08 min
# [758/900] Sample processed in 0.63s, ETA: 2.07 min
# [759/900] Sample processed in 0.73s, ETA: 2.05 min
# [760/900] Sample processed in 0.85s, ETA: 2.04 min
# [761/900] Sample processed in 0.40s, ETA: 2.02 min
# [762/900] Sample processed in 0.53s, ETA: 2.01 min
# [763/900] Sample processed in 0.72s, ETA: 1.99 min
# [764/900] Sample processed in 0.40s, ETA: 1.98 min
# [765/900] Sample processed in 0.57s, ETA: 1.96 min
# [766/900] Sample processed in 0.59s, ETA: 1.94 min
# [767/900] Sample processed in 0.63s, ETA: 1.93 min
# [768/900] Sample processed in 0.40s, ETA: 1.91 min
# [769/900] Sample processed in 0.53s, ETA: 1.90 min
# [770/900] Sample processed in 0.59s, ETA: 1.88 min
# [771/900] Sample processed in 0.56s, ETA: 1.87 min
# [772/900] Sample processed in 0.46s, ETA: 1.85 min
# [773/900] Sample processed in 0.56s, ETA: 1.84 min
# [774/900] Sample processed in 0.57s, ETA: 1.82 min
# [775/900] Sample processed in 0.93s, ETA: 1.81 min
# [776/900] Sample processed in 0.69s, ETA: 1.79 min
# [777/900] Sample processed in 0.50s, ETA: 1.78 min
# [778/900] Sample processed in 0.59s, ETA: 1.76 min
# [779/900] Sample processed in 0.62s, ETA: 1.75 min
# [780/900] Sample processed in 0.56s, ETA: 1.73 min
# [781/900] Sample processed in 0.62s, ETA: 1.72 min
# [782/900] Sample processed in 0.47s, ETA: 1.70 min
# [783/900] Sample processed in 0.50s, ETA: 1.69 min
# [784/900] Sample processed in 0.47s, ETA: 1.67 min
# [785/900] Sample processed in 0.56s, ETA: 1.65 min
# [786/900] Sample processed in 0.59s, ETA: 1.64 min
# [787/900] Sample processed in 0.40s, ETA: 1.62 min
# [788/900] Sample processed in 0.91s, ETA: 1.61 min
# [789/900] Sample processed in 0.56s, ETA: 1.59 min
# [790/900] Sample processed in 0.72s, ETA: 1.58 min
# [791/900] Sample processed in 0.59s, ETA: 1.57 min
# [792/900] Sample processed in 0.40s, ETA: 1.55 min
# [793/900] Sample processed in 0.66s, ETA: 1.53 min
# [794/900] Sample processed in 0.59s, ETA: 1.52 min
# [795/900] Sample processed in 0.53s, ETA: 1.50 min
# [796/900] Sample processed in 0.60s, ETA: 1.49 min
# [797/900] Sample processed in 0.57s, ETA: 1.47 min
# [798/900] Sample processed in 0.40s, ETA: 1.46 min
# [799/900] Sample processed in 0.62s, ETA: 1.44 min
# [800/900] Sample processed in 0.44s, ETA: 1.43 min
# [801/900] Sample processed in 16.70s, ETA: 1.45 min
# [802/900] Sample processed in 4.43s, ETA: 1.44 min
# [803/900] Sample processed in 2.25s, ETA: 1.43 min
# [804/900] Sample processed in 4.33s, ETA: 1.42 min
# [805/900] Sample processed in 5.09s, ETA: 1.41 min
# [806/900] Sample processed in 9.20s, ETA: 1.42 min
# [807/900] Sample processed in 4.31s, ETA: 1.41 min
# [808/900] Sample processed in 5.68s, ETA: 1.40 min
# [809/900] Sample processed in 2.78s, ETA: 1.39 min
# [810/900] Sample processed in 3.57s, ETA: 1.38 min
# [811/900] Sample processed in 3.48s, ETA: 1.37 min
# [812/900] Sample processed in 9.45s, ETA: 1.37 min
# [813/900] Sample processed in 3.55s, ETA: 1.36 min
# [814/900] Sample processed in 3.21s, ETA: 1.35 min
# [815/900] Sample processed in 9.67s, ETA: 1.35 min
# [816/900] Sample processed in 2.54s, ETA: 1.33 min
# [817/900] Sample processed in 7.22s, ETA: 1.33 min
# [818/900] Sample processed in 7.46s, ETA: 1.32 min
# [819/900] Sample processed in 2.53s, ETA: 1.31 min
# [820/900] Sample processed in 5.03s, ETA: 1.30 min
# [821/900] Sample processed in 2.00s, ETA: 1.28 min
# [822/900] Sample processed in 12.30s, ETA: 1.29 min
# [823/900] Sample processed in 12.29s, ETA: 1.29 min
# [824/900] Sample processed in 8.69s, ETA: 1.28 min
# [825/900] Sample processed in 6.10s, ETA: 1.27 min
# [826/900] Sample processed in 3.32s, ETA: 1.26 min
# [827/900] Sample processed in 3.13s, ETA: 1.25 min
# [828/900] Sample processed in 4.75s, ETA: 1.23 min
# [829/900] Sample processed in 12.31s, ETA: 1.23 min
# [830/900] Sample processed in 2.30s, ETA: 1.22 min
# [831/900] Sample processed in 8.11s, ETA: 1.21 min
# [832/900] Sample processed in 5.55s, ETA: 1.20 min
# [833/900] Sample processed in 9.05s, ETA: 1.19 min
# [834/900] Sample processed in 3.90s, ETA: 1.18 min
# [835/900] Sample processed in 2.71s, ETA: 1.16 min
# [836/900] Sample processed in 7.01s, ETA: 1.15 min
# [837/900] Sample processed in 6.54s, ETA: 1.14 min
# [838/900] Sample processed in 3.08s, ETA: 1.12 min
# [839/900] Sample processed in 3.90s, ETA: 1.11 min
# [840/900] Sample processed in 6.90s, ETA: 1.10 min
# [841/900] Sample processed in 5.26s, ETA: 1.08 min
# [842/900] Sample processed in 8.09s, ETA: 1.07 min
# [843/900] Sample processed in 4.95s, ETA: 1.06 min
# [844/900] Sample processed in 6.78s, ETA: 1.05 min
# [845/900] Sample processed in 3.52s, ETA: 1.03 min
# [846/900] Sample processed in 4.19s, ETA: 1.02 min
# [847/900] Sample processed in 12.22s, ETA: 1.01 min
# [848/900] Sample processed in 7.64s, ETA: 1.00 min
# [849/900] Sample processed in 7.10s, ETA: 0.98 min
# [850/900] Sample processed in 5.72s, ETA: 0.97 min
# [851/900] Sample processed in 5.71s, ETA: 0.95 min
# [852/900] Sample processed in 2.94s, ETA: 0.94 min
# [853/900] Sample processed in 4.14s, ETA: 0.92 min
# [854/900] Sample processed in 1.83s, ETA: 0.90 min
# [855/900] Sample processed in 4.20s, ETA: 0.88 min
# [856/900] Sample processed in 7.30s, ETA: 0.87 min
# [857/900] Sample processed in 8.53s, ETA: 0.86 min
# [858/900] Sample processed in 7.06s, ETA: 0.84 min
# [859/900] Sample processed in 7.61s, ETA: 0.83 min
# [860/900] Sample processed in 8.27s, ETA: 0.81 min
# [861/900] Sample processed in 6.53s, ETA: 0.79 min
# [862/900] Sample processed in 3.08s, ETA: 0.78 min
# [863/900] Sample processed in 4.10s, ETA: 0.76 min
# [864/900] Sample processed in 12.24s, ETA: 0.74 min
# [865/900] Sample processed in 11.36s, ETA: 0.73 min
# [866/900] Sample processed in 9.48s, ETA: 0.71 min
# [867/900] Sample processed in 4.94s, ETA: 0.70 min
# [868/900] Sample processed in 8.22s, ETA: 0.68 min
# [869/900] Sample processed in 9.10s, ETA: 0.66 min
# [870/900] Sample processed in 8.44s, ETA: 0.65 min
# [871/900] Sample processed in 7.33s, ETA: 0.63 min
# [872/900] Sample processed in 2.45s, ETA: 0.61 min
# [873/900] Sample processed in 4.72s, ETA: 0.59 min
# [874/900] Sample processed in 3.19s, ETA: 0.57 min
# [875/900] Sample processed in 5.78s, ETA: 0.55 min
# [876/900] Sample processed in 5.79s, ETA: 0.53 min
# [877/900] Sample processed in 12.41s, ETA: 0.51 min
# [878/900] Sample processed in 4.41s, ETA: 0.49 min
# [879/900] Sample processed in 11.30s, ETA: 0.47 min
# [880/900] Sample processed in 5.09s, ETA: 0.45 min
# [881/900] Sample processed in 9.09s, ETA: 0.43 min
# [882/900] Sample processed in 12.27s, ETA: 0.41 min
# [883/900] Sample processed in 4.17s, ETA: 0.39 min
# [884/900] Sample processed in 4.15s, ETA: 0.37 min
# [885/900] Sample processed in 5.66s, ETA: 0.34 min
# [886/900] Sample processed in 7.31s, ETA: 0.32 min
# [887/900] Sample processed in 10.56s, ETA: 0.30 min
# [888/900] Sample processed in 3.79s, ETA: 0.28 min
# [889/900] Sample processed in 7.36s, ETA: 0.26 min
# [890/900] Sample processed in 8.02s, ETA: 0.24 min
# [891/900] Sample processed in 8.19s, ETA: 0.21 min
# [892/900] Sample processed in 10.91s, ETA: 0.19 min
# [893/900] Sample processed in 5.30s, ETA: 0.17 min
# [894/900] Sample processed in 9.56s, ETA: 0.14 min
# [895/900] Sample processed in 5.93s, ETA: 0.12 min
# [896/900] Sample processed in 3.28s, ETA: 0.10 min
# [897/900] Sample processed in 6.78s, ETA: 0.07 min
# [898/900] Sample processed in 8.73s, ETA: 0.05 min
# [899/900] Sample processed in 12.27s, ETA: 0.02 min
# [900/900] Sample processed in 4.66s, ETA: 0.00 min
#
# All samples processed. Total time: 22.23 min
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from unsloth import FastLanguageModel

import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    # model_name = "unsloth/Meta-Llama-3.1-8B-bnb-4bit",
    model_name = "/data/jaesung/llm_for_diabetes/src/trial7/main_table/llama_8b/outputs/last_seed/checkpoint-458",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)


alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-26 17:53:33 __init__.py:190] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.2.12: Fast Llama patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-PCIE-40GB. Max memory: 39.394 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.2.12 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %%
import torch
torch.manual_seed(1000) 

FastLanguageModel.for_inference(model) 

inputs = tokenizer(
[
    alpaca_prompt.format(
        # "Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.", 
        # "Can you recommend a daily diet recipe? Please provide detailed information on breakfast, lunch, and dinner.", 
        # "Prepare a healthy daily meal plan for a female aged 35 with 1400 kcal, including portion sizes in grams.",
        "Prepare a healthy daily meal plan for diebeic patien, including portion sizes in grams.",
        "",
        "", 
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 1024, do_sample=True)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Prepare a healthy daily meal plan for diebeic patien, including portion sizes in grams.
#
# ### Input:
#
#
# ### Response:
# Breakfast: 1 cup of steel-cut oats with 1/2 cup of nonfat milk and 1 tablespoon of ground flaxseed. Lunch: 3 ounces of grilled chicken breast with 1 cup of steamed broccoli and 1/2 cup of brown rice. Snack: 1 small apple with 1 tablespoon of almond butter. Dinner: 4 ounces of grilled salmon with 1 cup of steamed asparagus and 1/2 cup of quinoa.<|end_of_text|>

# %%
import torch
torch.manual_seed(400) 

FastLanguageModel.for_inference(model) 

inputs = tokenizer(
[
    alpaca_prompt.format(
        "Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.", 
        "",
        "", 
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 1024, do_sample=True)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Can you recommend a daily diet recipe for a diabetic patient? Please provide detailed information on breakfast, lunch, and dinner.
#
# ### Input:
#
#
# ### Response:
# Diabetes is a metabolic disorder that affects how the body uses food for energy. It occurs when the body cannot produce enough insulin or when the body cannot properly use the insulin it produces. Insulin is a hormone that helps the body use glucose, a type of sugar, for energy. People with diabetes must carefully manage their blood sugar levels to avoid complications such as heart disease, stroke, and nerve damage.
#
# A healthy diet for a diabetic patient should include plenty of vegetables, fruits, whole grains, lean proteins, and healthy fats. It should also limit processed foods, sugary drinks, and refined carbohydrates. A typical daily diet for a diabetic patient might look like this:
#
# Breakfast: oatmeal with fresh berries, a glass of milk, and a cup of green tea
# Lunch: grilled chicken breast with steamed vegetables, brown rice, and a glass of water
# Dinner: baked fish with roasted vegetables, quinoa, and a small glass of red wine
# Snacks: a handful of nuts, a piece of fruit, or a small serving of yogurt
# It's important to consult with a registered dietitian or healthcare provider to develop a personalized diet plan for a diabetic patient. They can provide guidance on portion sizes, macronutrient ratios, and specific foods to include or avoid based on individual needs and health goals.<|end_of_text|>
